# %%
### Simulation notebook

# %%
import lqr_simulation
import feedback_controllers, plot_flow_field_utils
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
# %matplotlib notebook
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 15:59:02.169251. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
lqr_simulation.sims_with_diff_dynamics_strengths()
# Out:
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# Starting dyn: 0.000000
# Starting rep: 0
# Aborting CO trial -- timeout time
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting dyn: 0.250000
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting dyn: 0.500000
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting dyn: 0.750000
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting dyn: 0.900000
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting rep: 0
# Starting dyn: 0.990000
# Starting rep: 0
# ...

# %%
### Simulate dynamics matrix ~ identity ###
### Get controller (offset off by default, but turn it on); 
ctl =  Combined_Curs_Brain_LQR_Simulation(states, inputs, 
    dyn_strength = dyn, task = task, dyn_freq = freq, 
    state_noise = state_noise)

# %%
### Example; 
A = np.mat([[np.cos(np.pi/4.), -np.sin(np.pi/4.)], [np.sin(np.pi/4.), np.cos(np.pi/4.)]])
B = np.mat([[0.], [1.,]])
Q = np.mat(np.eye(2))
R = .500000

ctl = feedback_controllers.LQRController(A, B, Q, R)
K = ctl.dlqr(A, B, Q, R)

Acl = np.squeeze(np.array(A - np.dot(B, K)))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 18:58:49.048970. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
_, ev = np.linalg.eig(A)
_, evx = np.linalg.eig(Acl)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 18:58:50.017761. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
evx
# Out:
# array([[0.83399555+0.j        , 0.83399555-0.j        ],
#        [0.4468524 -0.32368868j, 0.4468524 +0.32368868j]])
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 18:58:50.409836. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Plot A matrix flow field; 
f, ax = plt.subplots(ncols = 2, figsize = (10, 5))
for axi in ax:
    axi.axis('equal')
plot_flow_field_utils.plot_flow(np.squeeze(np.array(A)), ax[0], cmax = 5., width = .05, scale=1.)
ax[0].set_title('A matrix')
plot_flow_field_utils.plot_flow(np.squeeze(np.array(Acl)), ax[1], cmax = 5., width = .05, scale=1.)
ax[1].set_title('A - BK matrix, R = %.1f, Q = %.1f' %(R, Q[0, 0]))
# Out:
# <img src="data:image/png;base64,..." width="999.4444709206812">
# Text(0.5,1,'A - BK matrix, R = 0.5, Q = 1.0')
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 18:58:53.433563. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
X = []
for x1 in np.arange(-5,5,.1):
    for x2 in np.arange(-5, 5, .1):
        x = np.array([[x1], [x2]])
        u = -1*np.dot(K, x)
        X.append(np.hstack(( [[x1], [x2], np.squeeze(np.array(u))])) )
X = np.vstack((X))
f, ax = plt.subplots(figsize = (10, 5), ncols = 2)
cax =ax[0].scatter(X[:, 0], X[:, 1], s=3, c=X[:, 2], cmap='viridis')
cax =ax[1].scatter(X[:, 0], X[:, 1], s=3, c=X[:, 3], cmap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 17:35:54.685529. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
X.shape
# Out:
# (10000, 4)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-26 17:35:15.899277. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
