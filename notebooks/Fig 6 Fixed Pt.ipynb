# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_generated_models, generate_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# error importing BMI configuration variables
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-20 12:30:20.145110. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-09 20:23:56.580764. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
######## Run the no intercept models ########
# generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 6, 
#                                 within_bin_shuffle = False, fit_intercept = False)
for i_a, animal in enumerate(['grom','jeev']):
    for fit_intc in [False]:#, True]:
        for shuffle in [False]:#True, False]: 
            generate_models.model_individual_cell_tuning_curves(model_set_number = 6, animal=animal, 
                                                    fit_task_spec_and_general = True, match_task_spec_n = True,
                                                    add_model_to_datafile = True, fit_intercept = fit_intc,
                                                               within_bin_shuffle = shuffle, alpha_always_zero = True)
# for i_a, animal in enumerate(['grom']):#, 'jeev']):
#     generate_models.model_individual_cell_tuning_curves(model_set_number = 11, animal=animal, 
#                                                     fit_task_spec_and_general = True, match_task_spec_n = True,
#                                                     add_model_to_datafile = True, fit_intercept = False)
# Out:
# online_analysis/generate_models_utils.py:87: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(pref+hdf[hdfix:])
# ##############################
# ########## DAY 0 ##########
# ##############################
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Staring shuff 0
# R2 again, 0.31
# online_analysis/generate_models_utils.py:1221: DeprecationWarning: createTable() is pending deprecation, use create_table() instead. You may use the pt2to3 tool to update your source code.
#   tab = h5file.createTable("/", model_nm+'_fold_'+str(int(fold)), Model_Table)
#
# online_analysis/generate_models_utils.py:1222: DeprecationWarning: createGroup() is pending deprecation, use create_group() instead. You may use the pt2to3 tool to update your source code.
#   col = h5file.createGroup(h5file.root, model_nm+'_fold_'+str(int(fold))+'_nms')
#
# online_analysis/generate_models_utils.py:1226: DeprecationWarning: createArray() is pending deprecation, use create_array() instead. You may use the pt2to3 tool to update your source code.
#   h5file.createArray(col, 'vars', vrs)
# R2 train ix: 0.32
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.33
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.32
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.32
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.33
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.30
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.30
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.30
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.30
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.32
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 1 ##########
# ##############################
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# Staring shuff 0
# R2 again, 0.37
# R2 train ix: 0.39
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.39
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.39
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.39
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.39
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.36
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.37
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.37
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.38
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 2 ##########
# ##############################
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# Staring shuff 0
# R2 again, 0.11
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# online_analysis/generate_models_utils.py:1404: RuntimeWarning: invalid value encountered in sqrt
#   se = np.array([ np.sqrt(np.diagonal(sse[i] * X2)) for i in range(sse.shape[0]) ])
#
# online_analysis/generate_models_utils.py:1405: RuntimeWarning: invalid value encountered in divide
#   model.t_ = np.mat(model.coef_) / se
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1738: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0
#
# online_analysis/generate_models_utils.py:1409: RuntimeWarning: invalid value encountered in divide
#   model.rsquared = 1 - (SSR/SST)
#
# online_analysis/generate_models_utils.py:1413: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(SSR) * nobs2
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.13
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.13
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.13
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.13
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.13
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 3 ##########
# ##############################
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# Staring shuff 0
# R2 again, 0.11
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# online_analysis/generate_models_utils.py:1405: RuntimeWarning: divide by zero encountered in divide
#   model.t_ = np.mat(model.coef_) / se
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.11
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 4 ##########
# ##############################
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# Staring shuff 0
# R2 again, 0.08
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.10
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 5 ##########
# ##############################
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# Staring shuff 0
# R2 again, 0.12
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.12
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 6 ##########
# ##############################
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# Staring shuff 0
# R2 again, 0.15
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.16
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.15
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.15
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.14
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 7 ##########
# ##############################
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# Staring shuff 0
# R2 again, 0.09
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.08
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.10
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.10
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.10
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.10
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.10
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 8 ##########
# ##############################
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# Staring shuff 0
# R2 again, 0.09
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.09
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/grom_models_to_pred_mn_diffs_model_set6_alphazero_no_intc.h5
# ##############################
# ########## DAY 0 ##########
# ##############################
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL
# new trial offset 369, total trls in this blk 170
# Staring shuff 0
# R2 again, 0.27
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.32
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.32
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.31
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.24
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.27
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 1 ##########
# ##############################
# 16 (38, 7)
# new trial offset 16, total trls in this blk 16
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# new trial offset 168, total trls in this blk 152
# Staring shuff 0
# R2 again, 0.24
# R2 train ix: 0.20
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.20
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.20
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.19
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.20
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.27
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.22
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.21
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.22
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.22
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.22
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 2 ##########
# ##############################
# 90 (16, 7)
# new trial offset 90, total trls in this blk 90
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# new trial offset 223, total trls in this blk 133
# Staring shuff 0
# R2 again, 0.26
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.28
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.29
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.26
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.26
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.25
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.27
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.26
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.27
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.27
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.27
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# ##############################
# ########## DAY 3 ##########
# ##############################
# 80 (17, 7)
# new trial offset 80, total trls in this blk 80
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# new trial offset 181, total trls in this blk 101
# Staring shuff 0
# R2 again, 0.18
# R2 train ix: 0.20
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.20
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.19
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.19
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.19
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.17
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.19
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# R2 train ix: 0.18
# Conditioning on push
# No push
# No push
# Identity dynamcis
# alpha zero
# Adding model and test_indices
# alpha zero
# Adding model and test_indices
# Identity dynamcis
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_models_to_pred_mn_diffs_model_set6_alphazero_no_intc.h5
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-20 12:34:25.292284. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Latent no intc ####
latent_dat = dict()
for animal in ['grom', 'jeev']:
    dati = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N_no_intc_ndim15.pkl' %(11), 'rb'))
    latent_dat[animal] = dati
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-20 12:41:45.736028. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
###### Ridge no intc ####
ridge_dat = dict()
for animal in ['grom', 'jeev']:
    dati = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N_no_intc.pkl' %(6), 'rb'))
    ridge_dat[animal] = dati
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-20 12:40:48.269057. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
###### LS no intc ####
ls_dat = dict()
for animal in ['grom', 'jeev']:
    dati = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N_no_intc_alphazero.pkl' %(6), 'rb'))
    ls_dat[animal] = dati
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-20 12:41:26.950367. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for i_dat, dat in enumerate([ls_dat]):
    latent_dat = False
    print('Starting Model dat %d'%(i_dat))
    plot_generated_models.eigvalue_plot(dat=dat, with_intercept=False, LDS=latent_dat)
# Out:
# Starting Model dat 0
# <img src="data:image/png;base64,..." width="1199.9999821186068">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="1194.9999821931126">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-20 12:50:30.791960. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_plot2('grom', 3, dt = 0.1, plt_evs_gte = .99, dat = dat['grom'],
                                    with_intercept = True)
# Out:
# <img src="data:image/png;base64,..." width="431.24999357387435">
# len shuff 250
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-12 17:16:08.570511. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_2D_hist('grom', dt = 0.1, plt_evs_gte = .99, dat = dat['grom'], with_intercept = True)
plot_generated_models.eigvalue_2D_hist('jeev', dt = 0.1, plt_evs_gte = .99, dat = dat['jeev'], with_intercept = True)
# Out:
# <img src="data:image/png;base64,..." width="431.24999357387435">
# online_analysis/plot_generated_models.py:4843: RuntimeWarning: divide by zero encountered in log
#   decay = -1./np.log(np.abs(ev))*dt # Time decay constant in
# <img src="data:image/png;base64,..." width="287.4999957159162">
# Day 0, PV cnt 643
# Day 1, PV cnt 2
# Day 2, PV cnt 0
# Day 3, PV cnt 4
# Day 4, PV cnt 0
# Day 5, PV cnt 38
# Day 6, PV cnt 9
# Day 7, PV cnt 218
# Day 8, PV cnt 0
# <img src="data:image/png;base64,..." width="431.24999357387435">
# <img src="data:image/png;base64,..." width="287.4999957159162">
# Day 0, PV cnt 0
# Day 1, PV cnt 0
# Day 2, PV cnt 0
# Day 3, PV cnt 0
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-12 21:25:53.441905. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_perc_gte_binsize(dat=dat, with_intercept=True)
# Out:
# <img src="data:image/png;base64,..." width="973.7499854899945">
# online_analysis/plot_generated_models.py:5193: RuntimeWarning: divide by zero encountered in log
#   decay = -1./np.log(np.abs(ev))*dt # Time decay constant in
#
# online_analysis/plot_generated_models.py:4977: RuntimeWarning: divide by zero encountered in double_scalars
#   ax[1].plot([3*i_a, 3*i_a + 1], [0, (np.mean(day) - np.mean(shuff_day)) / np.mean(shuff_day)],
# Animal grom, Day 0, pv = 0.00000
# Animal grom, Day 1, pv = 0.00000
# Animal grom, Day 2, pv = 0.00000
# Animal grom, Day 3, pv = 0.00000
# Animal grom, Day 4, pv = 0.00000
# Animal grom, Day 5, pv = 0.00000
# Animal grom, Day 6, pv = 0.00000
# Animal grom, Day 7, pv = 0.00000
# Animal grom, Day 8, pv = 0.00000
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom
# PV = 4.328e-07
# SLP 0.03570, N = 18, t(16) = 5.054
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal jeev, Day 0, pv = 0.00000
# Animal jeev, Day 1, pv = 0.00000
# Animal jeev, Day 2, pv = 0.00000
# Animal jeev, Day 3, pv = 0.00000
# Animal jeev
# PV = 9.199e-07
# SLP 0.11115, N = 8, t(6) = 4.908
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-14 09:00:47.193401. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Want to see if fixed point is the same? 
##### Vector norm diff b/w data fixed point and mFR  // shuffled fixed point and mFR 
#### // and shuffled fixed point and data fixed point;

# %%
plot_generated_models.analze_fixed_pt(dat)
# Out:
# <img src="data:image/png;base64,..." width="287.4999957159162">
# <img src="data:image/png;base64,..." width="287.4999957159162">
# Animal grom, day 0, pv 0.02900
# Animal grom, day 1, pv 0.11300
# Animal grom, day 2, pv 0.00000
# Animal grom, day 3, pv 0.00000
# Animal grom, day 4, pv 0.00000
# Animal grom, day 5, pv 0.14300
# Animal grom, day 6, pv 0.08300
# Animal grom, day 7, pv 0.09400
# Animal grom, day 8, pv 0.10500
# Animal grom
# PV = 5.947e-04
# SLP 1.04557, N = 18, t(16) = 3.434
# Animal jeev, day 0, pv 0.02000
# Animal jeev, day 1, pv 0.00000
# Animal jeev, day 2, pv 0.00000
# Animal jeev, day 3, pv 0.10000
# Animal jeev
# PV = 1.176e-01
# SLP 1.12977, N = 8, t(6) = 1.565
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-13 23:54:24.535897. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.plot_eigs_from_LDS()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-12 22:49:14.428396. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
