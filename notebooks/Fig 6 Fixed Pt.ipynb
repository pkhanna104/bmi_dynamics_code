# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_generated_models, generate_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-09 20:23:56.580764. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
######## Run the no intercept models ########
# generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 6, 
#                                 within_bin_shuffle = False, fit_intercept = False)
for i_a, animal in enumerate(['grom','jeev']):
    for fit_intc in [True, False]:
        for shuffle in [True, False]: 
            generate_models.model_individual_cell_tuning_curves(model_set_number = 6, animal=animal, 
                                                    fit_task_spec_and_general = True, match_task_spec_n = True,
                                                    add_model_to_datafile = True, fit_intercept = fit_intc,
                                                               within_bin_shuffle = shuffle)
# for i_a, animal in enumerate(['grom']):#, 'jeev']):
#     generate_models.model_individual_cell_tuning_curves(model_set_number = 11, animal=animal, 
#                                                     fit_task_spec_and_general = True, match_task_spec_n = True,
#                                                     add_model_to_datafile = True, fit_intercept = False)
# Out:
# online_analysis/generate_models.py:427: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# ##############################
# ########## DAY 0 ##########
# ##############################
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ...

# %%
dat = dict()
for animal in ['grom','jeev']:
    dati = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N.pkl' %(6), 'rb'))
    dat[animal] = dati
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-12 17:11:18.383735. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
dat['grom'].keys()
# Out:
# [(3, 'np'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_2spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_2spksm_1_spksp_0', 9, 1, 'model'),
#  (3, 'pos_tm1'),
#  (2, 'hist_1pos_0psh_2spksm_1_spksp_0', 13, 2, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (5, 'hist_1pos_0psh_2spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (3, 'hist_1pos_0psh_2spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_2spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (4, 'hist_1pos_0psh_2spksm_1_spksp_0', 0, 0, 'model'),
# ...

# %%
plot_generated_models.eigvalue_plot(dat=dat, with_intercept=False, LDS=True)
# Out:
# <img src="data:image/png;base64,..." width="863.7499871291222">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# online_analysis/plot_generated_models.py:4432: RuntimeWarning: divide by zero encountered in divide
#   decay = -1./np.log(np.abs(ev_sort_truc))*dt # Time decay constant in ms
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# <img src="data:image/png;base64,..." width="647.4999903514982">
# ...

# %%
plot_generated_models.eigvalue_plot2('grom', 3, dt = 0.1, plt_evs_gte = .99, dat = dat['grom'],
                                    with_intercept = True)
# Out:
# <img src="data:image/png;base64,..." width="431.24999357387435">
# len shuff 250
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-12 17:16:08.570511. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_2D_hist('grom', dt = 0.1, plt_evs_gte = .99, dat = dat['grom'], with_intercept = True)
plot_generated_models.eigvalue_2D_hist('jeev', dt = 0.1, plt_evs_gte = .99, dat = dat['jeev'], with_intercept = True)
# Out:
# <img src="data:image/png;base64,..." width="431.24999357387435">
# online_analysis/plot_generated_models.py:4843: RuntimeWarning: divide by zero encountered in log
#   decay = -1./np.log(np.abs(ev))*dt # Time decay constant in
# <img src="data:image/png;base64,..." width="287.4999957159162">
# Day 0, PV cnt 643
# Day 1, PV cnt 2
# Day 2, PV cnt 0
# Day 3, PV cnt 4
# Day 4, PV cnt 0
# Day 5, PV cnt 38
# Day 6, PV cnt 9
# Day 7, PV cnt 218
# Day 8, PV cnt 0
# <img src="data:image/png;base64,..." width="431.24999357387435">
# <img src="data:image/png;base64,..." width="287.4999957159162">
# Day 0, PV cnt 0
# Day 1, PV cnt 0
# Day 2, PV cnt 0
# Day 3, PV cnt 0
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-12 21:25:53.441905. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_perc_gte_binsize(dat=dat, with_intercept=True)
# Out:
# <div id='2463f1ef-fab3-4ef6-81c7-b6a4b6add4e9'></div>

# %%
##### Want to see if fixed point is the same? 
##### Vector norm diff b/w data fixed point and mFR  // shuffled fixed point and mFR 
#### // and shuffled fixed point and data fixed point;

# %%
plot_generated_models.analze_fixed_pt(dat)

# %%
plot_generated_models.plot_eigs_from_LDS()
# Out:
# <div id='62f3ab96-e873-4350-a01a-556676d71d5b'></div>
# <div id='dec842e7-bb11-41d5-bb75-de111b709cc0'></div>
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-26-5ef242096c39> in <module>()
# ----> 1 plot_generated_models.plot_eigs_from_LDS()
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_generated_models.pyc in plot_eigs_from_LDS()
#    4653     for ia, animal in enumerate(['grom', 'jeev']):
#    4654         fn = pref + animal + 'LDSmodels_nstates_'+str(n_states)+'_combined_models_w_dyn_inno_norms.pkl'
# -> 4655         dat = pickle.load(open(fn, 'rb'))
#    4656
#    4657         hist_ = np.zeros_like(hist_bins)
#
# IOError: [Errno 2] No such file or directory: '/Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/gromLDSmodels_nstates_15_combined_models_w_dyn_inno_norms.pkl'
# ...
