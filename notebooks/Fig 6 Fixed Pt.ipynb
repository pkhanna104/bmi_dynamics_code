# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_generated_models, generate_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-07 16:49:14.959048. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-08 18:21:50.904940. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
######## Run the no intercept models ########
# generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 6, 
#                                 within_bin_shuffle = False, fit_intercept = False)

for i_a, animal in enumerate(['grom']):#, 'jeev']):
    generate_models.model_individual_cell_tuning_curves(model_set_number = 11, animal=animal, 
                                                    fit_task_spec_and_general = True, match_task_spec_n = True,
                                                    add_model_to_datafile = True, fit_intercept = False)
# Out:
# online_analysis/generate_models.py:342: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
#
# online_analysis/generate_models_utils.py:87: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(pref+hdf[hdfix:])
# ##############################
# ########## DAY 0 ##########
# ##############################
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Staring shuff 0
# R2 again, 0.31
# No push
# online_analysis/generate_models.py:1193: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   A = np.mat(np.linalg.lstsq(x_hat[:-1, :], x_hat[1:, :])[0])
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 1 ##########
# ##############################
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# Staring shuff 0
# R2 again, 0.37
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 2 ##########
# ##############################
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# Staring shuff 0
# R2 again, 0.11
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 3 ##########
# ##############################
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# Staring shuff 0
# R2 again, 0.11
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 4 ##########
# ##############################
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# Staring shuff 0
# R2 again, 0.08
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 5 ##########
# ##############################
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# Staring shuff 0
# R2 again, 0.12
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 6 ##########
# ##############################
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# Staring shuff 0
# R2 again, 0.15
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 7 ##########
# ##############################
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# Staring shuff 0
# R2 again, 0.09
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# ##############################
# ########## DAY 8 ##########
# ##############################
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# Staring shuff 0
# R2 again, 0.09
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/grom_models_to_pred_mn_diffs_model_set11_no_intc.h5
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-09 11:31:08.095325. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
dat = dict()
for animal in ['grom']:#, 'jeev']:
    dati = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N_no_intc.pkl' %(7), 'rb'))
    dat[animal] = dati
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-09 07:48:50.401098. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
dat['grom'].keys()
# Out:
# [(3, 'np'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (3, 'pos_tm1'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (6, 'pos_tm1'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (6, 'trl'),
#  (3, 'trl'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (7, 'np'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (4, 'task'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (5, 'day_bin_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (1, 'np'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (3, 'pos'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (6, 'vel'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (4, 'spks'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (1, 'pos'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (1, 'trg'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (4, 'day_bin_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (7, 'trg'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (1, 'vel'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (8, 'vel'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (7, 'task'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (0, 'bin_num'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (5, 'np'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (6, 'day_bin_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (0, 'vel_tm1'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  ('hist_1pos_4psh_0spksm_1_spksp_0', 'variables'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (5, 'trl'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'vel_tm1'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (7, 'day_bin_ix_shuff'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (1, 'bin_num'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (5, 'trg'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (6, 'day_bin_ix_shuff'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (0, 'task'),
#  (1, 'day_bin_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'vel'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (1, 'trl'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (2, 'bin_num'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (6, 'np'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (2, 'vel_tm1'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (0, 'np'),
#  (8, 'vel_tm1'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (2, 'day_bin_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (0, 'pos'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (4, 'np'),
#  (2, 'spks'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (3, 'trg'),
#  (8, 'np'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (7, 'spks'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (4, 'day_bin_ix_shuff'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (5, 'vel'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (8, 'spks'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (2, 'pos_tm1'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (2, 'np'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (5, 'pos_tm1'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (3, 'spks'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (6, 'vel_tm1'),
#  (8, 'pos'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (5, 'pos'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (2, 'pos'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (0, 'vel'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (5, 'day_bin_ix_shuff'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (6, 'spks'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (7, 'pos_tm1'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (2, 'trg'),
#  (8, 'trl'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (8, 'task'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (4, 'pos_tm1'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (1, 'vel_tm1'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (6, 'bin_num'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (1, 'spks'),
#  (3, 'day_bin_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (3, 'bin_num'),
#  (2, 'day_bin_ix_shuff'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (4, 'trl'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (5, 'task'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (5, 'vel_tm1'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (3, 'day_bin_ix_shuff'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (8, 'day_bin_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (0, 'trg'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (5, 'spks'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (4, 'bin_num'),
#  (5, 'bin_num'),
#  (2, 'task'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (6, 'trg'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (4, 'vel_tm1'),
#  (8, 'bin_num'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (7, 'bin_num'),
#  (0, 'trl'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (8, 'trg'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (4, 'pos'),
#  ('hist_1pos_0psh_0spksm_1_spksp_0', 'variables'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (8, 'day_bin_ix_shuff'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'test_ix'),
#  (7, 'pos'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (0, 'day_bin_ix_shuff'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (3, 'task'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (4, 'vel'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (8, 'pos_tm1'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (4, 'trg'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (1, 'pos_tm1'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (0, 'day_bin_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (1, 'task'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (2, 'trl'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (7, 'day_bin_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 0, 0, 'test_ix'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 9, 1, 'model'),
#  (6, 'task'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0'),
#  (3, 'vel_tm1'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 11, 2, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 9, 1, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 13, 2, 'test_ix'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (6, 'pos'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 11, 2, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 14, 2, 'model'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 13, 2, 'model'),
#  (1, 'day_bin_ix_shuff'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 10, 2, 'test_ix'),
#  (0, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (3, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 2, 0, 'test_ix'),
#  (1, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (3, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'model'),
#  (7, 'hist_1pos_4psh_0spksm_1_spksp_0', 12, 2, 'test_ix'),
#  (7, 'trl'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (8, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 1, 0, 'model'),
#  (3, 'vel'),
#  (2, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (0, 'hist_1pos_4psh_0spksm_1_spksp_0', 7, 1, 'test_ix'),
#  (6, 'hist_1pos_0psh_0spksm_1_spksp_0', 12, 2, 'model'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (5, 'hist_1pos_4psh_0spksm_1_spksp_0', 3, 0, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'model'),
#  (0, 'spks'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 6, 1, 'model'),
#  (5, 'hist_1pos_0psh_0spksm_1_spksp_0', 5, 1, 'test_ix'),
#  (4, 'hist_1pos_0psh_0spksm_1_spksp_0', 1, 0, 'test_ix'),
#  (7, 'hist_1pos_0psh_0spksm_1_spksp_0', 10, 2, 'model'),
#  (6, 'hist_1pos_4psh_0spksm_1_spksp_0', 4, 0, 'model'),
#  (0, 'pos_tm1'),
#  (4, 'hist_1pos_4psh_0spksm_1_spksp_0', 0, 0, 'model'),
#  (8, 'hist_1pos_4psh_0spksm_1_spksp_0', 14, 2, 'test_ix'),
#  (1, 'hist_1pos_4psh_0spksm_1_spksp_0', 8, 1, 'test_ix'),
#  (2, 'hist_1pos_0psh_0spksm_1_spksp_0', 3, 0, 'model'),
#  (2, 'vel')]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-09 08:42:55.029239. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_plot(dat=dat, with_intercept = False, LDS=False)
# Out:
# <img src="data:image/png;base64,..." width="1199.9999821186068">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# <img src="data:image/png;base64,..." width="899.9999865889552">
# No shuffs available
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# No intercept
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-09 07:52:10.683012. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_plot2('grom', 0, dt = 0.1, plt_evs_gte = .99, dat = dat['grom'],
                                    with_intercept = False)
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-08 17:59:24.777229. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models. ('grom', dt = 0.1, plt_evs_gte = .99, dat = dat['grom'], with_intercept = False)
plot_generated_models.eigvalue_2D_hist('jeev', dt = 0.1, plt_evs_gte = .99, dat = dat['jeev'], with_intercept = False)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
# online_analysis/plot_generated_models.py:4736: RuntimeWarning: divide by zero encountered in log
#   def check_models(model_dicts, day, model_nm, command_bins):
# <img src="data:image/png;base64,..." width="287.77778540128566">
# Day 0, PV cnt 156
# Day 1, PV cnt 9
# Day 2, PV cnt 137
# Day 3, PV cnt 0
# Day 4, PV cnt 20
# Day 5, PV cnt 0
# Day 6, PV cnt 0
# Day 7, PV cnt 0
# Day 8, PV cnt 0
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="287.77778540128566">
# Day 0, PV cnt 0
# Day 1, PV cnt 0
# Day 2, PV cnt 0
# Day 3, PV cnt 0
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-06 22:26:48.478542. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Want to see if fixed point is the same? 
##### Vector norm diff b/w data fixed point and mFR  // shuffled fixed point and mFR 
#### // and shuffled fixed point and data fixed point;

# %%
plot_generated_models.analze_fixed_pt(dat)
# Out:
# <img src="data:image/png;base64,..." width="287.77778540128566">
# <img src="data:image/png;base64,..." width="287.77778540128566">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-06 19:26:37.925779. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.eigvalue_plot(dt = 0.1, plt_evs_gte = .99)#, dat = dat)
# Out:
# <img src="data:image/png;base64,..." width="1199.9999821186068">
# <img src="data:image/png;base64,..." width="1379.9999794363978">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="1318.749980349094">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-08 10:43:29.696739. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.plot_eigs_from_LDS()
# Out:
# <div id='62f3ab96-e873-4350-a01a-556676d71d5b'></div>
# <div id='dec842e7-bb11-41d5-bb75-de111b709cc0'></div>
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-26-5ef242096c39> in <module>()
# ----> 1 plot_generated_models.plot_eigs_from_LDS()
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_generated_models.pyc in plot_eigs_from_LDS()
#    4653     for ia, animal in enumerate(['grom', 'jeev']):
#    4654         fn = pref + animal + 'LDSmodels_nstates_'+str(n_states)+'_combined_models_w_dyn_inno_norms.pkl'
# -> 4655         dat = pickle.load(open(fn, 'rb'))
#    4656
#    4657         hist_ = np.zeros_like(hist_bins)
#
# IOError: [Errno 2] No such file or directory: '/Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/gromLDSmodels_nstates_15_combined_models_w_dyn_inno_norms.pkl'
# > /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_generated_models.py(4655)plot_eigs_from_LDS()
#    4654         fn = pref + animal + 'LDSmodels_nstates_'+str(n_states)+'_combined_models_w_dyn_inno_norms.pkl'
# -> 4655         dat = pickle.load(open(fn, 'rb'))
#    4656
#
# ipdb> exit
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-08 18:35:03.627841. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
