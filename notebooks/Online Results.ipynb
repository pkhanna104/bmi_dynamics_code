# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import co_obs_te_list
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 09:25:13.210439. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
datfrm.keys()
# Out:
# Index([u'ape', u'ape_corr', u'avg_dt2', u'avg_dt2_corr', u'cond_gen',
#        u'cond_spec', u'date', u'dec', u'pe', u'pe_corr', u'pl', u'pl_corr',
#        u'sa', u'spd', u'spd_corr', u't2t', u't2t_corr', u'te', u'trl_num'],
#       dtype='object')
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 09:47:16.268156. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Shared vs. regular time to target; 
xlist = co_obs_te_list.make_input_type()
datfrm, datfrm_rpm = co_obs_te_list.make_dataframe(xlist, total_or_share='share')
co_obs_te_list.plot_t2t(datfrm, combine_tasks=True)
co_obs_te_list.plot_any(datfrm, combine_tasks=False, norm='sub', save=False, met='pe_corr')
# Out:
# rejecting:  4384  due to inclusion in poor data list!
# rejecting:  4505  due to inclusion in poor data list!
# rejecting:  4515  due to inclusion in poor data list!
# 675 0 win_task
# 755 1 xtask
# combo:  KruskalResult(statistic=13.548417802005039, pvalue=0.0002324873262357087)
#
#
# ttest:
# combo: Ttest_indResult(statistic=2.328056855066756, pvalue=0.020048157427618684)
# 443 0 co_co_shar
# 548 1 co_obs_shar
# 207 2 obs_co_shar
# 232 3 obs_obs_shar
# obs KruskalResult(statistic=4.596579551133573, pvalue=0.03203581033023117)
# co KruskalResult(statistic=0.8882224526032587, pvalue=0.34595946133327604)
# obs Ttest_indResult(statistic=-1.2226569420892268, pvalue=0.22211828225202748)
# co Ttest_indResult(statistic=0.8218762157914864, pvalue=0.4113454378970255)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 09:49:56.864159. Please add timezone info to timestamps.
# ...

# %%
###### Decoder fit based on Task #########
xlist = co_obs_te_list.make_input_type()
datfrm, datfrm_rpm = co_obs_te_list.make_dataframe(xlist, total_or_share='total')
co_obs_te_list.plot_co_vs_obs_dec(datfrm_rpm, cnt_lte=2)
co_obs_te_list.plot_decoder_mismatch(xlist)
# Out:
# online_analysis/co_obs_te_list.py:117: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile('/Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/grom2017_performance_w_shar_co_obs_on_tasks_co_obs_include_control_add_eff.hdf')
# rejecting:  4384  due to inclusion in poor data list!
# rejecting:  4505  due to inclusion in poor data list!
# rejecting:  4515  due to inclusion in poor data list!
# 27.5
# 27.5
# 28.75
# 28.75
# 28.75
# 28.75
# 37.0
# 34.0
# 34.0
# 27.5
# 27.5
# 27.5
# 27.5
# 20.333333333333332
# 20.333333333333332
# 20.333333333333332
# 27.25
# 27.25
# 27.25
# 27.25
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 20.444444444444443
# 30.666666666666668
# 30.666666666666668
# 30.666666666666668
# 30.666666666666668
# 30.666666666666668
# ...
