# %%
# %load_ext autoreload
# %autoreload 2

# %%
import seaborn

# %%
seaborn.set(font='Arial',context='talk',font_scale=.8, style='white')

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from online_analysis import plot_pred_fr_diffs

# %%
# only_sig_cc --> only sig command-conditions used to assess neuron signficance 
plot_pred_fr_diffs.frac_sig_science_compressions(nshuffs=100, only_sig_cc=True)
# Out:
# Shuffle 0, 0.91026
# Done with big fcn, 27.98697
# Monk R2 of cond-spec activity (null) 0.377, [0.021, 0.028] mn | 95th perc
# NNeurons Monk grom, Day 0, pv 0.00000
# CCs Monk grom, Day 0, pv 0.00000
# Shuffle 0, 0.59390
# Done with big fcn, 13.91624
# Monk R2 of cond-spec activity (null) 0.338, [-0.001, 0.001] mn | 95th perc
# NNeurons Monk grom, Day 1, pv 0.00000
# CCs Monk grom, Day 1, pv 0.00000
# Shuffle 0, 2.00064
# Done with big fcn, 71.39238
# Monk R2 of cond-spec activity (null) 0.229, [-0.007, -0.005] mn | 95th perc
# NNeurons Monk grom, Day 2, pv 0.00000
# CCs Monk grom, Day 2, pv 0.00000
# Shuffle 0, 1.23080
# Done with big fcn, 33.85951
# Monk R2 of cond-spec activity (null) 0.194, [-0.009, -0.008] mn | 95th perc
# NNeurons Monk grom, Day 3, pv 0.00000
# CCs Monk grom, Day 3, pv 0.00000
# Shuffle 0, 1.09053
# Done with big fcn, 48.63007
# Monk R2 of cond-spec activity (null) 0.288, [-0.007, -0.006] mn | 95th perc
# NNeurons Monk grom, Day 4, pv 0.00000
# ...

# %%
plot_pred_fr_diffs.plot_example_neuron_comm_predictions(nshuffs=10)
# Out:
# Shuffle 0, 0.94212
# Done with big fcn, 3.04198
# SU -- Mov 10.1, Pos 0, [22.76, 23.09], pred = 20.00,  true = 10.88
# POP -- Mov 10.1, Pos 0, [25.11, 25.62], pred = 19.45 distances
# SU -- Mov 1.0, Pos 1, [23.00, 23.32], pred = 19.68,  true = 14.40
# POP -- Mov 1.0, Pos 1, [25.80, 26.29], pred = 17.88 distances
# SU -- Mov 11.1, Pos 2, [23.03, 23.27], pred = 20.49,  true = 16.38
# POP -- Mov 11.1, Pos 2, [20.29, 20.68], pred = 14.49 distances
# SU -- Mov 2.0, Pos 3, [23.14, 23.41], pred = 21.49,  true = 21.11
# POP -- Mov 2.0, Pos 3, [17.75, 18.15], pred = 14.49 distances
# SU -- Mov 12.1, Pos 4, [23.15, 23.30], pred = 21.73,  true = 20.69
# POP -- Mov 12.1, Pos 4, [15.13, 15.55], pred = 10.11 distances
# SU -- Mov 3.0, Pos 5, [23.69, 23.86], pred = 25.65,  true = 30.00
# POP -- Mov 3.0, Pos 5, [19.56, 19.78], pred = 15.62 distances
# SU -- Mov 13.1, Pos 6, [23.74, 23.89], pred = 23.91,  true = 23.00
# POP -- Mov 13.1, Pos 6, [14.66, 14.97], pred = 9.21 distances
# ...

# %%
8/9.
# Out:
# 0.8888888888888888
