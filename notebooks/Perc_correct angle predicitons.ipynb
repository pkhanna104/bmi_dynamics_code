# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from online_analysis import pred_fwd
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
pred_fwd.perc_corr_pred_next_command_mov_com2com(only_pairwise_com = False, min_obs_next_command = 5)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 00:15:45.098983. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.perc_corr_pred_next_command_mov_com2com(only_pairwise_com = True, min_obs_next_command=5)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 00:13:46.343014. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.perc_corr_pred_next_command_mov_com2com(only_pairwise_com = True, min_obs_next_command=5, 
                                                 exclude_same_dir=True)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 00:22:41.119050. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.perc_corr_ang_pw()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 01:01:38.827267. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
## Can compare across magnitudes; #####
pred_fwd.perc_corr_ang_pw(min_obs_next_command=7)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 01:28:38.824150. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
