# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from online_analysis import plot_pred_fr_diffs

# %%
plot_pred_fr_diffs.get_data_EVs()
# Out:
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="400">
# Animal grom: Day 0, Num dim 4
# Animal grom: Day 1, Num dim 3
# Animal grom: Day 2, Num dim 3
# Animal grom: Day 3, Num dim 3
# Animal grom: Day 4, Num dim 4
# Animal grom: Day 5, Num dim 3
# Animal grom: Day 6, Num dim 3
# Animal grom: Day 7, Num dim 2
# Animal grom: Day 8, Num dim 2
# Animal jeev: Day 0, Num dim 3
# Animal jeev: Day 1, Num dim 3
# Animal jeev: Day 2, Num dim 3
# Animal jeev: Day 3, Num dim 2

# %%
######### null models 
path = '/Users/preeyakhanna/Dropbox/Carmena_Lab/Documentation/BMI_co_obs_paper/data/null_dynamics_models'
dat = pickle.load(open(os.path.join(path, 'null_dynamics_models.pkl'), 'rb'))

# %%
####### Plot null files 
plot_pred_fr_diffs.get_data_EVs(plot_null_dynamics = True, ridge_dict = dat)
# Out:
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="300">
# <img src="data:image/png;base64,..." width="400">
