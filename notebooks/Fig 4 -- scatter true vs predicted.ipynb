# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import plot_pred_fr_diffs, plot_generated_models
import analysis_config
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
plot_pred_fr_diffs.plot_example_neuron_comm_predictions(nshuffs=2)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.05432
# End Cnt: 386
# pv_all
# [0.29392474 0.83062357]
# End Cnt: 386
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 18:20:31.500334. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.perc_sig_neuron_comm_predictions(nshuffs=10)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.04014
# Conditioning on push
# No push
# Shuffle 0, 0.02622
# Conditioning on push
# No push
# Shuffle 0, 0.05203
# Conditioning on push
# No push
# Shuffle 0, 0.04603
# Conditioning on push
# No push
# Shuffle 0, 0.03464
# Conditioning on push
# No push
# Shuffle 0, 0.03387
# Conditioning on push
# No push
# Shuffle 0, 0.01464
# Conditioning on push
# No push
# Shuffle 0, 0.07032
# Conditioning on push
# No push
# Shuffle 0, 0.01943
# Conditioning on push
# No push
# Shuffle 0, 0.03242
# Conditioning on push
# No push
# Shuffle 0, 0.01822
# Conditioning on push
# No push
# Shuffle 0, 0.02435
# Conditioning on push
# No push
# Shuffle 0, 0.02273
# Neural su, Dat true, Vaf 0.36175, Corr Coeff 0.60410
# Neural su, Dat shuff, Vaf -0.06503, Corr Coeff 0.24159
# Neural pop, Dat true, Vaf 0.50399, Corr Coeff 0.62088
# Neural pop, Dat shuff, Vaf 0.35951, Corr Coeff 0.27298
# ...

# %%
plot_pred_fr_diffs.pw_comparison(nshuffs=100)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.03476
# Shuffle 10, 2.07100
# Shuffle 20, 3.87859
# Shuffle 30, 5.79737
# Shuffle 40, 7.77131
# Shuffle 50, 9.62070
# Shuffle 60, 11.62062
# Shuffle 70, 13.62084
# Shuffle 80, 15.63249
# Shuffle 90, 17.71716
# Skipping Movement PW 11.1, 2.0, Niter = 4
# Skipping Movement PW 11.1, 3.0, Niter = 2
# Skipping Movement PW 11.1, 4.0, Niter = 3
# Skipping Movement PW 3.0, 4.0, Niter = 3
# Skipping Movement PW 10.1, 12.1, Niter = 2
# Skipping Movement PW 10.1, 14.0, Niter = 2
# Skipping Movement PW 10.1, 12.1, Niter = 5
# Skipping Movement PW 10.1, 17.1, Niter = 2
# Skipping Movement PW 12.1, 15.0, Niter = 9
# Skipping Movement PW 12.1, 17.1, Niter = 5
# Skipping Movement PW 15.0, 17.1, Niter = 6
# Skipping Movement PW 1.0, 2.0, Niter = 2
# Skipping Movement PW 1.0, 13.1, Niter = 16
# Skipping Movement PW 1.0, 15.0, Niter = 2
# Skipping Movement PW 1.0, 14.1, Niter = 12
# Skipping Movement PW 1.0, 17.1, Niter = 2
# ...

# %%
plot_pred_fr_diffs.get_data_EVs()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-23 17:37:01.320600. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs._test_distGlobal_dirTrue()
# Out:
# frac 0.67
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-26 12:39:48.149223. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from online_analysis import util_fcns
import pandas as pd
import statsmodels.formula.api as smf
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 17:40:04.141374. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
X = []; Mov = []; 
for i in range(10): 
    x = np.random.randn(50) + 0.2*i
    X.append(x)
    Mov.append(np.zeros((50, )) + i)
X = np.hstack((X))
Mov = np.hstack((Mov))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 17:40:15.433855. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
f, ax = plt.subplots()
for i in range(10):
    ix = np.nonzero(Mov == i)[0]
    util_fcns.draw_plot(i, X[ix], 'k', 'w', ax)
ax.hlines(np.mean(X), 0, 10)
ax.set_xlim([-1, 10])
# Out:
# (-1, 10)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 17:47:00.248051. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pv  = 0. 
keep_ix = np.arange(len(Mov))
while pv < 0.05:
    M = []
    for i in range(10):
        ix_ = np.nonzero(Mov[keep_ix]==i)[0]
        M.append(X[keep_ix[ix_]])
    _, pv = scipy.stats.f_oneway(*M)
    
    if pv < 0.05: 
        mn = np.mean(X[keep_ix])
        print('mn %.2f'%(mn))
        cost = np.abs(X[keep_ix] - mn)
        argsort = np.argsort(cost)[::-1]
        keep_ix = np.delete(keep_ix, argsort[:5])
# Out:
# mn 0.89
# mn 0.90
# mn 0.89
# mn 0.86
# mn 0.88
# mn 0.86
# mn 0.84
# mn 0.84
# mn 0.84
# mn 0.83
# mn 0.81
# mn 0.82
# mn 0.83
# mn 0.84
# mn 0.86
# mn 0.87
# mn 0.87
# mn 0.88
# mn 0.90
# mn 0.92
# mn 0.92
# mn 0.90
# mn 0.88
# mn 0.87
# mn 0.87
# mn 0.85
# mn 0.84
# mn 0.85
# mn 0.84
# mn 0.85
# mn 0.86
# mn 0.87
# mn 0.88
# mn 0.90
# mn 0.91
# mn 0.92
# mn 0.92
# mn 0.93
# mn 0.94
# mn 0.95
# mn 0.97
# mn 0.98
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 17:47:05.452274. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
f, ax = plt.subplots()
for i in range(10):
    ix = np.nonzero(Mov[keep_ix] == i)[0]
    util_fcns.draw_plot(i, X[keep_ix[ix]], 'k', 'w', ax)
ax.hlines(np.mean(X[keep_ix]), 0, 10)
ax.set_xlim([-1, 10])
# Out:
# (-1, 10)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 17:47:13.114884. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
M
# Out:
# [array([ 1.08648066,  1.5359931 , -0.4145052 ,  0.72316787, -0.69938826,
#         -0.63702784,  0.4880849 ,  0.39051466,  0.43693268,  0.61779388]),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64)]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-27 17:45:24.143781. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
