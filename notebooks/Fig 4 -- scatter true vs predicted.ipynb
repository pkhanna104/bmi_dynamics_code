# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-06 10:35:37.340280. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from online_analysis import plot_pred_fr_diffs, plot_generated_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-06 10:35:38.576286. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#############Load models ##############
mod_dic = {}
for animal in ['grom', 'jeev']:
    model_set_number = 6
    model_dict = pickle.load(open(analysis_config.config[animal+'_pref']+'tuning_models_'+animal+'_model_set%d_.pkl'%model_set_number, 'rb'))
    mod_dic[animal] = model_dict
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-06 13:26:23.246068. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.plot_fig4c_R2(mod_dic, nshuffs=1000)
# Out:
# Shuffle 0, 0.04624
# Shuffle 10, 0.04238
# Shuffle 20, 0.04877
# Shuffle 30, 0.05025
# Shuffle 40, 0.05543
# Shuffle 50, 0.05522
# Shuffle 60, 0.03730
# Shuffle 70, 0.04275
# Shuffle 80, 0.03779
# Shuffle 90, 0.03677
# Shuffle 100, 0.03674
# Shuffle 110, 0.04782
# Shuffle 120, 0.03683
# Shuffle 130, 0.06774
# Shuffle 140, 0.04459
# Shuffle 150, 0.06970
# Shuffle 160, 0.05891
# Shuffle 170, 0.04839
# Shuffle 180, 0.05186
# Shuffle 190, 0.06276
# Shuffle 200, 0.03986
# Shuffle 210, 0.04812
# Shuffle 220, 0.05169
# Shuffle 230, 0.03991
# Shuffle 240, 0.03545
# Shuffle 250, 0.03903
# Shuffle 260, 0.03807
# Shuffle 270, 0.03786
# Shuffle 280, 0.05638
# Shuffle 290, 0.04191
# Shuffle 300, 0.03664
# Shuffle 310, 0.03606
# Shuffle 320, 0.04491
# Shuffle 330, 0.03334
# Shuffle 340, 0.05081
# Shuffle 350, 0.04434
# Shuffle 360, 0.03795
# Shuffle 370, 0.04377
# Shuffle 380, 0.05100
# Shuffle 390, 0.03711
# Shuffle 400, 0.03595
# Shuffle 410, 0.04190
# Shuffle 420, 0.03956
# Shuffle 430, 0.05037
# Shuffle 440, 0.03546
# Shuffle 450, 0.03691
# Shuffle 460, 0.04227
# Shuffle 470, 0.03745
# Shuffle 480, 0.04073
# Shuffle 490, 0.03513
# Shuffle 500, 0.03801
# Shuffle 510, 0.04133
# Shuffle 520, 0.03824
# Shuffle 530, 0.04908
# Shuffle 540, 0.04886
# Shuffle 550, 0.05880
# Shuffle 560, 0.05317
# Shuffle 570, 0.05292
# Shuffle 580, 0.03985
# Shuffle 590, 0.03744
# Shuffle 600, 0.03723
# Shuffle 610, 0.04741
# Shuffle 620, 0.04826
# Shuffle 630, 0.05178
# Shuffle 640, 0.04769
# Shuffle 650, 0.03678
# Shuffle 660, 0.04864
# Shuffle 670, 0.04896
# Shuffle 680, 0.03799
# Shuffle 690, 0.04231
# Shuffle 700, 0.04177
# Shuffle 710, 0.04220
# Shuffle 720, 0.08202
# Shuffle 730, 0.03697
# Shuffle 740, 0.04311
# Shuffle 750, 0.03641
# Shuffle 760, 0.04186
# Shuffle 770, 0.03811
# Shuffle 780, 0.03718
# Shuffle 790, 0.03559
# Shuffle 800, 0.04510
# Shuffle 810, 0.04795
# Shuffle 820, 0.07535
# Shuffle 830, 0.05588
# Shuffle 840, 0.04936
# Shuffle 850, 0.05345
# Shuffle 860, 0.05277
# Shuffle 870, 0.05070
# Shuffle 880, 0.03796
# Shuffle 890, 0.04565
# Shuffle 900, 0.04041
# Shuffle 910, 0.04236
# Shuffle 920, 0.03845
# Shuffle 930, 0.04469
# Shuffle 940, 0.05391
# Shuffle 950, 0.03804
# Shuffle 960, 0.04556
# Shuffle 970, 0.03884
# Shuffle 980, 0.03908
# Shuffle 990, 0.05059
# Animal grom, Day 0, pv 0.00000, r2_pred 0.368, mn r2_shuff0.319, 95th r2_shuff0.321
# Shuffle 0, 0.02229
# Shuffle 10, 0.02135
# Shuffle 20, 0.02099
# Shuffle 30, 0.02444
# Shuffle 40, 0.02735
# Shuffle 50, 0.02509
# Shuffle 60, 0.02663
# Shuffle 70, 0.02207
# Shuffle 80, 0.02220
# Shuffle 90, 0.02100
# Shuffle 100, 0.02508
# Shuffle 110, 0.02406
# Shuffle 120, 0.02749
# Shuffle 130, 0.02794
# Shuffle 140, 0.02456
# Shuffle 150, 0.02700
# Shuffle 160, 0.02432
# Shuffle 170, 0.03246
# Shuffle 180, 0.02745
# Shuffle 190, 0.02330
# Shuffle 200, 0.02391
# Shuffle 210, 0.02216
# Shuffle 220, 0.02247
# Shuffle 230, 0.02218
# Shuffle 240, 0.02139
# Shuffle 250, 0.02546
# Shuffle 260, 0.02808
# Shuffle 270, 0.02163
# Shuffle 280, 0.02402
# Shuffle 290, 0.02754
# Shuffle 300, 0.02209
# Shuffle 310, 0.02898
# Shuffle 320, 0.02168
# Shuffle 330, 0.02242
# Shuffle 340, 0.02150
# Shuffle 350, 0.02645
# Shuffle 360, 0.02296
# Shuffle 370, 0.02246
# Shuffle 380, 0.02895
# Shuffle 390, 0.02866
# Shuffle 400, 0.02772
# Shuffle 410, 0.02145
# Shuffle 420, 0.02115
# Shuffle 430, 0.02167
# Shuffle 440, 0.02339
# Shuffle 450, 0.02167
# Shuffle 460, 0.02158
# Shuffle 470, 0.02139
# Shuffle 480, 0.02239
# Shuffle 490, 0.03958
# Shuffle 500, 0.02540
# Shuffle 510, 0.02256
# Shuffle 520, 0.03214
# Shuffle 530, 0.02197
# Shuffle 540, 0.02873
# Shuffle 550, 0.02224
# Shuffle 560, 0.02287
# Shuffle 570, 0.02201
# Shuffle 580, 0.02072
# Shuffle 590, 0.03410
# Shuffle 600, 0.03281
# Shuffle 610, 0.02182
# Shuffle 620, 0.03683
# Shuffle 630, 0.02839
# Shuffle 640, 0.02232
# Shuffle 650, 0.05319
# Shuffle 660, 0.02858
# Shuffle 670, 0.02212
# Shuffle 680, 0.03210
# Shuffle 690, 0.02193
# Shuffle 700, 0.03305
# Shuffle 710, 0.02192
# Shuffle 720, 0.02161
# Shuffle 730, 0.02140
# Shuffle 740, 0.03282
# Shuffle 750, 0.03689
# Shuffle 760, 0.02116
# Shuffle 770, 0.02172
# Shuffle 780, 0.03255
# Shuffle 790, 0.02196
# Shuffle 800, 0.03794
# Shuffle 810, 0.02150
# Shuffle 820, 0.03663
# Shuffle 830, 0.03236
# Shuffle 840, 0.02154
# Shuffle 850, 0.02285
# Shuffle 860, 0.02165
# Shuffle 870, 0.02145
# Shuffle 880, 0.02280
# Shuffle 890, 0.02001
# Shuffle 900, 0.04763
# Shuffle 910, 0.02427
# Shuffle 920, 0.02331
# Shuffle 930, 0.02757
# Shuffle 940, 0.04651
# Shuffle 950, 0.02931
# Shuffle 960, 0.02829
# Shuffle 970, 0.02150
# Shuffle 980, 0.03375
# Shuffle 990, 0.03485
# Animal grom, Day 1, pv 0.00000, r2_pred 0.429, mn r2_shuff0.374, 95th r2_shuff0.375
# Shuffle 0, 0.05549
# Shuffle 10, 0.06285
# Shuffle 20, 0.09782
# Shuffle 30, 0.06369
# Shuffle 40, 0.08457
# Shuffle 50, 0.09264
# Shuffle 60, 0.08645
# Shuffle 70, 0.10658
# Shuffle 80, 0.08045
# Shuffle 90, 0.30260
# Shuffle 100, 0.08018
# Shuffle 110, 0.06063
# Shuffle 120, 0.07992
# Shuffle 130, 0.06127
# Shuffle 140, 0.10283
# Shuffle 150, 0.09325
# Shuffle 160, 0.10090
# Shuffle 170, 0.06902
# Shuffle 180, 0.07508
# Shuffle 190, 0.07966
# Shuffle 200, 0.10528
# Shuffle 210, 0.06086
# Shuffle 220, 0.05870
# Shuffle 230, 0.06114
# Shuffle 240, 0.06063
# Shuffle 250, 0.06054
# Shuffle 260, 0.05740
# Shuffle 270, 0.05565
# Shuffle 280, 0.05531
# Shuffle 290, 0.06244
# Shuffle 300, 0.09634
# Shuffle 310, 0.47522
# Shuffle 320, 0.05225
# Shuffle 330, 0.07800
# Shuffle 340, 0.07606
# Shuffle 350, 0.05242
# Shuffle 360, 0.06864
# Shuffle 370, 0.07770
# Shuffle 380, 0.05524
# Shuffle 390, 0.06771
# Shuffle 400, 0.07110
# Shuffle 410, 0.05487
# Shuffle 420, 0.05696
# Shuffle 430, 0.06614
# Shuffle 440, 0.07136
# Shuffle 450, 0.06534
# Shuffle 460, 0.05946
# Shuffle 470, 0.06007
# Shuffle 480, 0.06610
# Shuffle 490, 0.04787
# Shuffle 500, 0.04923
# Shuffle 510, 0.04805
# Shuffle 520, 0.04820
# Shuffle 530, 0.04791
# Shuffle 540, 0.04841
# Shuffle 550, 0.04870
# Shuffle 560, 0.06615
# Shuffle 570, 0.04890
# Shuffle 580, 0.04732
# Shuffle 590, 0.04769
# Shuffle 600, 0.04906
# Shuffle 610, 0.04810
# Shuffle 620, 0.04809
# Shuffle 630, 0.04835
# Shuffle 640, 0.04914
# Shuffle 650, 0.04968
# Shuffle 660, 0.04798
# Shuffle 670, 0.04859
# Shuffle 680, 0.04875
# Shuffle 690, 0.04801
# Shuffle 700, 0.04837
# Shuffle 710, 0.04828
# Shuffle 720, 0.04853
# Shuffle 730, 0.04810
# Shuffle 740, 0.04829
# Shuffle 750, 0.04875
# Shuffle 760, 0.04874
# Shuffle 770, 0.04886
# Shuffle 780, 0.04812
# Shuffle 790, 0.04877
# Shuffle 800, 0.04877
# Shuffle 810, 0.04798
# Shuffle 820, 0.04927
# Shuffle 830, 0.04851
# Shuffle 840, 0.04969
# Shuffle 850, 0.04841
# Shuffle 860, 0.04844
# Shuffle 870, 0.04914
# Shuffle 880, 0.04802
# Shuffle 890, 0.04841
# Shuffle 900, 0.04914
# Shuffle 910, 0.04974
# Shuffle 920, 0.04835
# Shuffle 930, 0.04808
# Shuffle 940, 0.04878
# Shuffle 950, 0.04862
# Shuffle 960, 0.07157
# Shuffle 970, 0.17069
# Shuffle 980, 0.05758
# Shuffle 990, 0.05903
# Animal grom, Day 2, pv 0.00000, r2_pred 0.148, mn r2_shuff0.109, 95th r2_shuff0.109
# Shuffle 0, 0.05477
# Shuffle 10, 0.05464
# Shuffle 20, 0.05165
# Shuffle 30, 0.05656
# Shuffle 40, 0.05568
# Shuffle 50, 0.05297
# Shuffle 60, 0.09960
# Shuffle 70, 0.05721
# Shuffle 80, 0.05682
# Shuffle 90, 0.05694
# Shuffle 100, 0.05904
# Shuffle 110, 0.06572
# Shuffle 120, 0.05634
# Shuffle 130, 0.06367
# Shuffle 140, 0.05293
# Shuffle 150, 0.08824
# Shuffle 160, 0.06360
# Shuffle 170, 0.05613
# Shuffle 180, 0.07017
# Shuffle 190, 0.07903
# Shuffle 200, 0.06577
# Shuffle 210, 0.05567
# Shuffle 220, 0.05770
# Shuffle 230, 0.08072
# Shuffle 240, 0.07841
# Shuffle 250, 0.04986
# Shuffle 260, 0.05439
# Shuffle 270, 0.04994
# Shuffle 280, 0.06228
# Shuffle 290, 0.06364
# Shuffle 300, 0.05029
# Shuffle 310, 0.05142
# Shuffle 320, 0.05348
# Shuffle 330, 0.04887
# Shuffle 340, 0.05425
# Shuffle 350, 0.05571
# Shuffle 360, 0.05512
# Shuffle 370, 0.04846
# Shuffle 380, 0.04922
# Shuffle 390, 0.04878
# Shuffle 400, 0.05071
# Shuffle 410, 0.07297
# Shuffle 420, 0.04740
# Shuffle 430, 0.05001
# Shuffle 440, 0.09409
# Shuffle 450, 0.04466
# Shuffle 460, 0.05018
# Shuffle 470, 0.06620
# Shuffle 480, 0.04957
# Shuffle 490, 0.05404
# Shuffle 500, 0.05375
# Shuffle 510, 0.04894
# Shuffle 520, 0.05642
# Shuffle 530, 0.06589
# Shuffle 540, 0.04946
# Shuffle 550, 0.05123
# Shuffle 560, 0.06016
# Shuffle 570, 0.05027
# Shuffle 580, 0.04741
# Shuffle 590, 0.04890
# Shuffle 600, 0.05748
# Shuffle 610, 0.04905
# Shuffle 620, 0.04921
# Shuffle 630, 0.05325
# Shuffle 640, 0.04687
# Shuffle 650, 0.05238
# Shuffle 660, 0.05214
# Shuffle 670, 0.05200
# Shuffle 680, 0.04926
# Shuffle 690, 0.05069
# Shuffle 700, 0.04801
# Shuffle 710, 0.05057
# Shuffle 720, 0.05627
# Shuffle 730, 0.04891
# Shuffle 740, 0.05316
# Shuffle 750, 0.04974
# Shuffle 760, 0.04909
# Shuffle 770, 0.05021
# Shuffle 780, 0.05342
# Shuffle 790, 0.05039
# Shuffle 800, 0.05005
# Shuffle 810, 0.05091
# Shuffle 820, 0.05309
# Shuffle 830, 0.05008
# Shuffle 840, 0.06281
# Shuffle 850, 0.05264
# Shuffle 860, 0.06353
# Shuffle 870, 0.04804
# Shuffle 880, 0.06095
# Shuffle 890, 0.05256
# Shuffle 900, 0.05095
# Shuffle 910, 0.05124
# Shuffle 920, 0.05094
# Shuffle 930, 0.05188
# Shuffle 940, 0.05500
# Shuffle 950, 0.05695
# Shuffle 960, 0.05688
# Shuffle 970, 0.05704
# Shuffle 980, 0.05605
# Shuffle 990, 0.04737
# Animal grom, Day 3, pv 0.00000, r2_pred 0.142, mn r2_shuff0.107, 95th r2_shuff0.107
# Shuffle 0, 0.03604
# Shuffle 10, 0.03619
# Shuffle 20, 0.03408
# Shuffle 30, 0.03556
# Shuffle 40, 0.03734
# Shuffle 50, 0.03922
# Shuffle 60, 0.04207
# Shuffle 70, 0.03808
# Shuffle 80, 0.05073
# Shuffle 90, 0.04145
# Shuffle 100, 0.03776
# Shuffle 110, 0.03788
# Shuffle 120, 0.04418
# Shuffle 130, 0.04214
# Shuffle 140, 0.05007
# Shuffle 150, 0.05152
# Shuffle 160, 0.03758
# Shuffle 170, 0.04461
# Shuffle 180, 0.03931
# Shuffle 190, 0.03960
# Shuffle 200, 0.03896
# Shuffle 210, 0.03955
# Shuffle 220, 0.04029
# Shuffle 230, 0.03604
# Shuffle 240, 0.04230
# Shuffle 250, 0.03907
# Shuffle 260, 0.03522
# Shuffle 270, 0.03500
# Shuffle 280, 0.03918
# Shuffle 290, 0.03712
# Shuffle 300, 0.05487
# Shuffle 310, 0.03537
# Shuffle 320, 0.03950
# Shuffle 330, 0.03616
# Shuffle 340, 0.03663
# Shuffle 350, 0.12173
# Shuffle 360, 0.04105
# Shuffle 370, 0.03626
# Shuffle 380, 0.03776
# Shuffle 390, 0.03935
# Shuffle 400, 0.03797
# Shuffle 410, 0.03622
# Shuffle 420, 0.03469
# Shuffle 430, 0.04033
# Shuffle 440, 0.04167
# Shuffle 450, 0.03701
# Shuffle 460, 0.03795
# Shuffle 470, 0.03595
# Shuffle 480, 0.03647
# Shuffle 490, 0.03741
# Shuffle 500, 0.04375
# Shuffle 510, 0.03941
# Shuffle 520, 0.03781
# Shuffle 530, 0.03882
# Shuffle 540, 0.03695
# Shuffle 550, 0.04009
# Shuffle 560, 0.04296
# Shuffle 570, 0.04033
# Shuffle 580, 0.03666
# Shuffle 590, 0.03919
# Shuffle 600, 0.03632
# Shuffle 610, 0.03480
# Shuffle 620, 0.03754
# Shuffle 630, 0.04727
# Shuffle 640, 0.03628
# Shuffle 650, 0.03805
# Shuffle 660, 0.04180
# Shuffle 670, 0.04147
# Shuffle 680, 0.03651
# Shuffle 690, 0.05318
# Shuffle 700, 0.03664
# Shuffle 710, 0.03609
# Shuffle 720, 0.03670
# Shuffle 730, 0.03782
# Shuffle 740, 0.04455
# Shuffle 750, 0.03924
# Shuffle 760, 0.09451
# Shuffle 770, 0.03372
# Shuffle 780, 0.04110
# Shuffle 790, 0.06028
# Shuffle 800, 0.03492
# Shuffle 810, 0.03537
# Shuffle 820, 0.03704
# Shuffle 830, 0.03431
# Shuffle 840, 0.04115
# Shuffle 850, 0.03692
# Shuffle 860, 0.04315
# Shuffle 870, 0.03698
# Shuffle 880, 0.05251
# Shuffle 890, 0.03725
# Shuffle 900, 0.03823
# Shuffle 910, 0.04110
# Shuffle 920, 0.03435
# Shuffle 930, 0.03966
# Shuffle 940, 0.03766
# Shuffle 950, 0.04213
# Shuffle 960, 0.03502
# Shuffle 970, 0.03500
# Shuffle 980, 0.03623
# Shuffle 990, 0.03716
# Animal grom, Day 4, pv 0.00000, r2_pred 0.119, mn r2_shuff0.076, 95th r2_shuff0.076
# Shuffle 0, 0.03755
# Shuffle 10, 0.04206
# Shuffle 20, 0.03903
# Shuffle 30, 0.04306
# Shuffle 40, 0.04439
# Shuffle 50, 0.03768
# Shuffle 60, 0.03830
# Shuffle 70, 0.03828
# Shuffle 80, 0.05796
# Shuffle 90, 0.03794
# Shuffle 100, 0.03873
# Shuffle 110, 0.03787
# Shuffle 120, 0.03847
# Shuffle 130, 0.03677
# Shuffle 140, 0.04131
# Shuffle 150, 0.03754
# Shuffle 160, 0.03774
# Shuffle 170, 0.03712
# Shuffle 180, 0.03716
# Shuffle 190, 0.05498
# Shuffle 200, 0.03902
# Shuffle 210, 0.04603
# Shuffle 220, 0.03842
# Shuffle 230, 0.08249
# Shuffle 240, 0.03799
# Shuffle 250, 0.03770
# Shuffle 260, 0.03715
# Shuffle 270, 0.03838
# Shuffle 280, 0.03829
# Shuffle 290, 0.03726
# Shuffle 300, 0.05972
# Shuffle 310, 0.03757
# Shuffle 320, 0.03639
# Shuffle 330, 0.04116
# Shuffle 340, 0.03822
# Shuffle 350, 0.03757
# Shuffle 360, 0.03876
# Shuffle 370, 0.03902
# Shuffle 380, 0.03697
# Shuffle 390, 0.04906
# Shuffle 400, 0.03856
# Shuffle 410, 0.03656
# Shuffle 420, 0.03717
# Shuffle 430, 0.03679
# Shuffle 440, 0.04400
# Shuffle 450, 0.03721
# Shuffle 460, 0.03668
# Shuffle 470, 0.03838
# Shuffle 480, 0.03861
# Shuffle 490, 0.03708
# Shuffle 500, 0.03712
# Shuffle 510, 0.03718
# Shuffle 520, 0.03420
# Shuffle 530, 0.03727
# Shuffle 540, 0.03677
# Shuffle 550, 0.03820
# Shuffle 560, 0.03709
# Shuffle 570, 0.03749
# Shuffle 580, 0.06247
# Shuffle 590, 0.03787
# Shuffle 600, 0.04437
# Shuffle 610, 0.03805
# Shuffle 620, 0.03810
# Shuffle 630, 0.03718
# Shuffle 640, 0.04693
# Shuffle 650, 0.03731
# Shuffle 660, 0.04150
# Shuffle 670, 0.03762
# Shuffle 680, 0.03680
# Shuffle 690, 0.03716
# Shuffle 700, 0.03728
# Shuffle 710, 0.05143
# Shuffle 720, 0.03866
# Shuffle 730, 0.04971
# Shuffle 740, 0.03746
# Shuffle 750, 0.03802
# Shuffle 760, 0.03864
# Shuffle 770, 0.04122
# Shuffle 780, 0.03970
# Shuffle 790, 0.03637
# Shuffle 800, 0.03833
# Shuffle 810, 0.04272
# Shuffle 820, 0.04738
# Shuffle 830, 0.04311
# Shuffle 840, 0.04557
# Shuffle 850, 0.04146
# Shuffle 860, 0.04278
# Shuffle 870, 0.04147
# Shuffle 880, 0.03407
# Shuffle 890, 0.03833
# Shuffle 900, 0.03896
# Shuffle 910, 0.03961
# Shuffle 920, 0.04009
# Shuffle 930, 0.04678
# Shuffle 940, 0.03822
# Shuffle 950, 0.04055
# Shuffle 960, 0.06604
# Shuffle 970, 0.04067
# Shuffle 980, 0.04172
# Shuffle 990, 0.04202
# Animal grom, Day 5, pv 0.00000, r2_pred 0.137, mn r2_shuff0.117, 95th r2_shuff0.117
# Shuffle 0, 0.01395
# Shuffle 10, 0.01639
# Shuffle 20, 0.01397
# Shuffle 30, 0.01426
# Shuffle 40, 0.01419
# Shuffle 50, 0.01527
# Shuffle 60, 0.01395
# Shuffle 70, 0.01396
# Shuffle 80, 0.01389
# Shuffle 90, 0.01507
# Shuffle 100, 0.01479
# Shuffle 110, 0.01407
# Shuffle 120, 0.01714
# Shuffle 130, 0.05462
# Shuffle 140, 0.01373
# Shuffle 150, 0.01532
# Shuffle 160, 0.01430
# Shuffle 170, 0.01360
# Shuffle 180, 0.01507
# Shuffle 190, 0.01367
# Shuffle 200, 0.01396
# Shuffle 210, 0.01452
# Shuffle 220, 0.25044
# Shuffle 230, 0.02313
# Shuffle 240, 0.01438
# Shuffle 250, 0.01503
# Shuffle 260, 0.01399
# Shuffle 270, 0.01669
# Shuffle 280, 0.01635
# Shuffle 290, 0.01664
# Shuffle 300, 0.01402
# Shuffle 310, 0.01415
# Shuffle 320, 0.01941
# Shuffle 330, 0.01464
# Shuffle 340, 0.01400
# Shuffle 350, 0.01508
# Shuffle 360, 0.01732
# Shuffle 370, 0.01240
# Shuffle 380, 0.01530
# Shuffle 390, 0.01604
# Shuffle 400, 0.01549
# Shuffle 410, 0.01523
# Shuffle 420, 0.01521
# Shuffle 430, 0.01679
# Shuffle 440, 0.01493
# Shuffle 450, 0.02980
# Shuffle 460, 0.01453
# Shuffle 470, 0.01453
# Shuffle 480, 0.01363
# Shuffle 490, 0.01270
# Shuffle 500, 0.01575
# Shuffle 510, 0.01383
# Shuffle 520, 0.01533
# Shuffle 530, 0.01386
# Shuffle 540, 0.02233
# Shuffle 550, 0.01521
# Shuffle 560, 0.02172
# Shuffle 570, 0.01716
# Shuffle 580, 0.01458
# Shuffle 590, 0.01846
# Shuffle 600, 0.02120
# Shuffle 610, 0.01559
# Shuffle 620, 0.01411
# Shuffle 630, 0.01615
# Shuffle 640, 0.01401
# Shuffle 650, 0.01534
# Shuffle 660, 0.01421
# Shuffle 670, 0.01411
# Shuffle 680, 0.01429
# Shuffle 690, 0.01461
# Shuffle 700, 0.01402
# Shuffle 710, 0.01377
# Shuffle 720, 0.01383
# Shuffle 730, 0.01365
# Shuffle 740, 0.01371
# Shuffle 750, 0.01459
# Shuffle 760, 0.01418
# Shuffle 770, 0.01240
# Shuffle 780, 0.01371
# Shuffle 790, 0.01427
# Shuffle 800, 0.01521
# Shuffle 810, 0.01408
# Shuffle 820, 0.01370
# Shuffle 830, 0.01366
# Shuffle 840, 0.01371
# Shuffle 850, 0.01359
# Shuffle 860, 0.01379
# Shuffle 870, 0.01660
# Shuffle 880, 0.01339
# Shuffle 890, 0.01362
# Shuffle 900, 0.01391
# Shuffle 910, 0.01418
# Shuffle 920, 0.01384
# Shuffle 930, 0.01386
# Shuffle 940, 0.01377
# Shuffle 950, 0.01396
# Shuffle 960, 0.01517
# Shuffle 970, 0.01403
# Shuffle 980, 0.01359
# Shuffle 990, 0.01372
# Animal grom, Day 6, pv 0.00000, r2_pred 0.191, mn r2_shuff0.149, 95th r2_shuff0.149
# Shuffle 0, 0.01503
# Shuffle 10, 0.01725
# Shuffle 20, 0.01736
# Shuffle 30, 0.01814
# Shuffle 40, 0.01702
# Shuffle 50, 0.01734
# Shuffle 60, 0.01714
# Shuffle 70, 0.01679
# Shuffle 80, 0.01886
# Shuffle 90, 0.02076
# Shuffle 100, 0.01758
# Shuffle 110, 0.01814
# Shuffle 120, 0.01899
# Shuffle 130, 0.02516
# Shuffle 140, 0.01773
# Shuffle 150, 0.01688
# Shuffle 160, 0.01727
# Shuffle 170, 0.02197
# Shuffle 180, 0.01744
# Shuffle 190, 0.01755
# Shuffle 200, 0.01728
# Shuffle 210, 0.01717
# Shuffle 220, 0.01659
# Shuffle 230, 0.01697
# Shuffle 240, 0.01679
# Shuffle 250, 0.01754
# Shuffle 260, 0.01763
# Shuffle 270, 0.01728
# Shuffle 280, 0.01732
# Shuffle 290, 0.01728
# Shuffle 300, 0.02489
# Shuffle 310, 0.01713
# Shuffle 320, 0.01865
# Shuffle 330, 0.01734
# Shuffle 340, 0.01731
# Shuffle 350, 0.01704
# Shuffle 360, 0.01740
# Shuffle 370, 0.01719
# Shuffle 380, 0.01676
# Shuffle 390, 0.01710
# Shuffle 400, 0.01694
# Shuffle 410, 0.01762
# Shuffle 420, 0.02100
# Shuffle 430, 0.01781
# Shuffle 440, 0.01701
# Shuffle 450, 0.01682
# Shuffle 460, 0.01735
# Shuffle 470, 0.01685
# Shuffle 480, 0.01706
# Shuffle 490, 0.01688
# Shuffle 500, 0.01683
# Shuffle 510, 0.01676
# Shuffle 520, 0.01699
# Shuffle 530, 0.01690
# Shuffle 540, 0.01929
# Shuffle 550, 0.01715
# Shuffle 560, 0.01834
# Shuffle 570, 0.01716
# Shuffle 580, 0.01854
# Shuffle 590, 0.01802
# Shuffle 600, 0.01770
# Shuffle 610, 0.01683
# Shuffle 620, 0.01790
# Shuffle 630, 0.01744
# Shuffle 640, 0.01856
# Shuffle 650, 0.01665
# Shuffle 660, 0.01815
# Shuffle 670, 0.01657
# Shuffle 680, 0.01740
# Shuffle 690, 0.01753
# Shuffle 700, 0.01717
# Shuffle 710, 0.01702
# Shuffle 720, 0.01866
# Shuffle 730, 0.02072
# Shuffle 740, 0.01809
# Shuffle 750, 0.01719
# Shuffle 760, 0.02320
# Shuffle 770, 0.01737
# Shuffle 780, 0.01685
# Shuffle 790, 0.01705
# Shuffle 800, 0.01688
# Shuffle 810, 0.01840
# Shuffle 820, 0.01730
# Shuffle 830, 0.01747
# Shuffle 840, 0.01748
# Shuffle 850, 0.01754
# Shuffle 860, 0.01644
# Shuffle 870, 0.01688
# Shuffle 880, 0.01692
# Shuffle 890, 0.01738
# Shuffle 900, 0.01728
# Shuffle 910, 0.01857
# Shuffle 920, 0.01651
# Shuffle 930, 0.01702
# Shuffle 940, 0.01774
# Shuffle 950, 0.01889
# Shuffle 960, 0.01777
# Shuffle 970, 0.02106
# Shuffle 980, 0.01809
# Shuffle 990, 0.01743
# Animal grom, Day 7, pv 0.00000, r2_pred 0.116, mn r2_shuff0.089, 95th r2_shuff0.089
# Shuffle 0, 0.01733
# Shuffle 10, 0.01593
# Shuffle 20, 0.01679
# Shuffle 30, 0.01805
# Shuffle 40, 0.01631
# Shuffle 50, 0.01643
# Shuffle 60, 0.01696
# Shuffle 70, 0.01659
# Shuffle 80, 0.01683
# Shuffle 90, 0.01641
# Shuffle 100, 0.01705
# Shuffle 110, 0.01870
# Shuffle 120, 0.01668
# Shuffle 130, 0.01596
# Shuffle 140, 0.01686
# Shuffle 150, 0.01622
# Shuffle 160, 0.01658
# Shuffle 170, 0.01936
# Shuffle 180, 0.01674
# Shuffle 190, 0.02043
# Shuffle 200, 0.01934
# Shuffle 210, 0.01740
# Shuffle 220, 0.01690
# Shuffle 230, 0.01759
# Shuffle 240, 0.01668
# Shuffle 250, 0.02390
# Shuffle 260, 0.02738
# Shuffle 270, 0.01782
# Shuffle 280, 0.02249
# Shuffle 290, 0.02291
# Shuffle 300, 0.01961
# Shuffle 310, 0.01640
# Shuffle 320, 0.07972
# Shuffle 330, 0.01764
# Shuffle 340, 0.01945
# Shuffle 350, 0.04500
# Shuffle 360, 0.01446
# Shuffle 370, 0.02165
# Shuffle 380, 0.02254
# Shuffle 390, 0.01610
# Shuffle 400, 0.01573
# Shuffle 410, 0.01631
# Shuffle 420, 0.01795
# Shuffle 430, 0.01633
# Shuffle 440, 0.01758
# Shuffle 450, 0.01828
# Shuffle 460, 0.01744
# Shuffle 470, 0.01904
# Shuffle 480, 0.01770
# Shuffle 490, 0.01662
# Shuffle 500, 0.02259
# Shuffle 510, 0.02236
# Shuffle 520, 0.01737
# Shuffle 530, 0.01988
# Shuffle 540, 0.01897
# Shuffle 550, 0.01907
# Shuffle 560, 0.01877
# Shuffle 570, 0.01782
# Shuffle 580, 0.01731
# Shuffle 590, 0.01892
# Shuffle 600, 0.01937
# Shuffle 610, 0.02310
# Shuffle 620, 0.01769
# Shuffle 630, 0.02160
# Shuffle 640, 0.01910
# Shuffle 650, 0.01672
# Shuffle 660, 0.03674
# Shuffle 670, 0.01736
# Shuffle 680, 0.02230
# Shuffle 690, 0.01890
# Shuffle 700, 0.03000
# Shuffle 710, 0.01911
# Shuffle 720, 0.01730
# Shuffle 730, 0.01774
# Shuffle 740, 0.02146
# Shuffle 750, 0.01789
# Shuffle 760, 0.01753
# Shuffle 770, 0.01749
# Shuffle 780, 0.01622
# Shuffle 790, 0.01891
# Shuffle 800, 0.01837
# Shuffle 810, 0.01903
# Shuffle 820, 0.02042
# Shuffle 830, 0.01993
# Shuffle 840, 0.02033
# Shuffle 850, 0.01781
# Shuffle 860, 0.01903
# Shuffle 870, 0.01897
# Shuffle 880, 0.01845
# Shuffle 890, 0.01768
# Shuffle 900, 0.01844
# Shuffle 910, 0.01689
# Shuffle 920, 0.01805
# Shuffle 930, 0.01782
# Shuffle 940, 0.01472
# Shuffle 950, 0.02140
# Shuffle 960, 0.02043
# Shuffle 970, 0.01754
# Shuffle 980, 0.01821
# Shuffle 990, 0.02327
# Animal grom, Day 8, pv 0.00000, r2_pred 0.111, mn r2_shuff0.086, 95th r2_shuff0.086
# POOLED: Animal grom, Day 8, pv 0.000000, r2_pred 0.196, mn r2_shuff0.158, 95th r2_shuff0.159
# Shuffle 0, 0.06100
# Shuffle 10, 0.02389
# Shuffle 20, 0.03415
# Shuffle 30, 0.03152
# Shuffle 40, 0.03370
# Shuffle 50, 0.03700
# Shuffle 60, 0.03889
# Shuffle 70, 0.04852
# Shuffle 80, 0.04489
# Shuffle 90, 0.03634
# Shuffle 100, 0.03784
# Shuffle 110, 0.04267
# Shuffle 120, 0.03362
# Shuffle 130, 0.03309
# Shuffle 140, 0.04451
# Shuffle 150, 0.03770
# Shuffle 160, 0.03264
# Shuffle 170, 0.04093
# Shuffle 180, 0.03601
# Shuffle 190, 0.03523
# Shuffle 200, 0.03581
# Shuffle 210, 0.03383
# Shuffle 220, 0.03520
# Shuffle 230, 0.03360
# Shuffle 240, 0.03357
# Shuffle 250, 0.03463
# Shuffle 260, 0.03225
# Shuffle 270, 0.03003
# Shuffle 280, 0.02433
# Shuffle 290, 0.02449
# Shuffle 300, 0.04082
# Shuffle 310, 0.03501
# Shuffle 320, 0.03267
# Shuffle 330, 0.03555
# Shuffle 340, 0.03472
# Shuffle 350, 0.05847
# Shuffle 360, 0.03431
# Shuffle 370, 0.03579
# Shuffle 380, 0.03589
# Shuffle 390, 0.03317
# Shuffle 400, 0.04104
# Shuffle 410, 0.03356
# Shuffle 420, 0.03327
# Shuffle 430, 0.02818
# Shuffle 440, 0.03438
# Shuffle 450, 0.03532
# Shuffle 460, 0.03425
# Shuffle 470, 0.03294
# Shuffle 480, 0.03285
# Shuffle 490, 0.03248
# Shuffle 500, 0.03249
# Shuffle 510, 0.03227
# Shuffle 520, 0.03209
# Shuffle 530, 0.03271
# Shuffle 540, 0.03200
# Shuffle 550, 0.03213
# Shuffle 560, 0.03283
# Shuffle 570, 0.03595
# Shuffle 580, 0.03365
# Shuffle 590, 0.03251
# Shuffle 600, 0.03280
# Shuffle 610, 0.03462
# Shuffle 620, 0.04475
# Shuffle 630, 0.03461
# Shuffle 640, 0.04653
# Shuffle 650, 0.04062
# Shuffle 660, 0.03280
# Shuffle 670, 0.07032
# Shuffle 680, 0.03235
# Shuffle 690, 0.02637
# Shuffle 700, 0.03533
# Shuffle 710, 0.03959
# Shuffle 720, 0.03219
# Shuffle 730, 0.03824
# Shuffle 740, 0.03496
# Shuffle 750, 0.03674
# Shuffle 760, 0.03525
# Shuffle 770, 0.04042
# Shuffle 780, 0.03971
# Shuffle 790, 0.03266
# Shuffle 800, 0.03291
# Shuffle 810, 0.03489
# Shuffle 820, 0.05134
# Shuffle 830, 0.03536
# Shuffle 840, 0.03568
# Shuffle 850, 0.03505
# Shuffle 860, 0.03272
# Shuffle 870, 0.03284
# Shuffle 880, 0.03818
# Shuffle 890, 0.03578
# Shuffle 900, 0.03861
# Shuffle 910, 0.03865
# Shuffle 920, 0.03355
# Shuffle 930, 0.03366
# Shuffle 940, 0.03752
# Shuffle 950, 0.02428
# Shuffle 960, 0.03375
# Shuffle 970, 0.04334
# Shuffle 980, 0.03872
# Shuffle 990, 0.04571
# Animal jeev, Day 0, pv 0.00000, r2_pred 0.333, mn r2_shuff0.267, 95th r2_shuff0.267
# Shuffle 0, 0.01872
# Shuffle 10, 0.01904
# Shuffle 20, 0.02070
# Shuffle 30, 0.01906
# Shuffle 40, 0.02085
# Shuffle 50, 0.02104
# Shuffle 60, 0.02891
# Shuffle 70, 0.02151
# Shuffle 80, 0.01435
# Shuffle 90, 0.02041
# Shuffle 100, 0.02250
# Shuffle 110, 0.01912
# Shuffle 120, 0.01931
# Shuffle 130, 0.01891
# Shuffle 140, 0.01861
# Shuffle 150, 0.01960
# Shuffle 160, 0.02061
# Shuffle 170, 0.02079
# Shuffle 180, 0.01909
# Shuffle 190, 0.01909
# Shuffle 200, 0.02164
# Shuffle 210, 0.02119
# Shuffle 220, 0.01654
# Shuffle 230, 0.01598
# Shuffle 240, 0.02832
# Shuffle 250, 0.02326
# Shuffle 260, 0.01991
# Shuffle 270, 0.01901
# Shuffle 280, 0.02039
# Shuffle 290, 0.01894
# Shuffle 300, 0.02007
# Shuffle 310, 0.02181
# Shuffle 320, 0.01965
# Shuffle 330, 0.02512
# Shuffle 340, 0.02107
# Shuffle 350, 0.01992
# Shuffle 360, 0.02832
# Shuffle 370, 0.01922
# Shuffle 380, 0.02056
# Shuffle 390, 0.02501
# Shuffle 400, 0.02315
# Shuffle 410, 0.02514
# Shuffle 420, 0.02677
# Shuffle 430, 0.01803
# Shuffle 440, 0.01945
# Shuffle 450, 0.02062
# Shuffle 460, 0.02205
# Shuffle 470, 0.01909
# Shuffle 480, 0.01958
# Shuffle 490, 0.02231
# Shuffle 500, 0.02527
# Shuffle 510, 0.02094
# Shuffle 520, 0.01926
# Shuffle 530, 0.02392
# Shuffle 540, 0.01682
# Shuffle 550, 0.02769
# Shuffle 560, 0.01953
# Shuffle 570, 0.02051
# Shuffle 580, 0.01403
# Shuffle 590, 0.02032
# Shuffle 600, 0.02027
# Shuffle 610, 0.02017
# Shuffle 620, 0.03159
# Shuffle 630, 0.02439
# Shuffle 640, 0.01882
# Shuffle 650, 0.01918
# Shuffle 660, 0.01868
# Shuffle 670, 0.02783
# Shuffle 680, 0.02100
# Shuffle 690, 0.01914
# Shuffle 700, 0.02088
# Shuffle 710, 0.02064
# Shuffle 720, 0.01551
# Shuffle 730, 0.02350
# Shuffle 740, 0.02159
# Shuffle 750, 0.02088
# Shuffle 760, 0.02017
# Shuffle 770, 0.02070
# Shuffle 780, 0.02100
# Shuffle 790, 0.02068
# Shuffle 800, 0.01909
# Shuffle 810, 0.01944
# Shuffle 820, 0.03926
# Shuffle 830, 0.02240
# Shuffle 840, 0.02319
# Shuffle 850, 0.01869
# Shuffle 860, 0.02166
# Shuffle 870, 0.02296
# Shuffle 880, 0.01865
# Shuffle 890, 0.02093
# Shuffle 900, 0.02049
# Shuffle 910, 0.02043
# Shuffle 920, 0.02278
# Shuffle 930, 0.02023
# Shuffle 940, 0.01703
# Shuffle 950, 0.02100
# Shuffle 960, 0.02192
# Shuffle 970, 0.02150
# Shuffle 980, 0.01938
# Shuffle 990, 0.02014
# Animal jeev, Day 1, pv 0.00000, r2_pred 0.312, mn r2_shuff0.240, 95th r2_shuff0.240
# Shuffle 0, 0.02020
# Shuffle 10, 0.02048
# Shuffle 20, 0.02584
# Shuffle 30, 0.02052
# Shuffle 40, 0.01578
# Shuffle 50, 0.02035
# Shuffle 60, 0.02067
# Shuffle 70, 0.02090
# Shuffle 80, 0.02583
# Shuffle 90, 0.02280
# Shuffle 100, 0.02075
# Shuffle 110, 0.02102
# Shuffle 120, 0.02821
# Shuffle 130, 0.02647
# Shuffle 140, 0.02128
# Shuffle 150, 0.02286
# Shuffle 160, 0.02738
# Shuffle 170, 0.03047
# Shuffle 180, 0.02076
# Shuffle 190, 0.02082
# Shuffle 200, 0.02254
# Shuffle 210, 0.02150
# Shuffle 220, 0.02266
# Shuffle 230, 0.02512
# Shuffle 240, 0.02082
# Shuffle 250, 0.02066
# Shuffle 260, 0.01935
# Shuffle 270, 0.02029
# Shuffle 280, 0.02045
# Shuffle 290, 0.02113
# Shuffle 300, 0.02479
# Shuffle 310, 0.02042
# Shuffle 320, 0.02108
# Shuffle 330, 0.02052
# Shuffle 340, 0.02101
# Shuffle 350, 0.02083
# Shuffle 360, 0.02127
# Shuffle 370, 0.02075
# Shuffle 380, 0.02192
# Shuffle 390, 0.02264
# Shuffle 400, 0.02184
# Shuffle 410, 0.02039
# Shuffle 420, 0.02081
# Shuffle 430, 0.03776
# Shuffle 440, 0.02087
# Shuffle 450, 0.02041
# Shuffle 460, 0.02086
# Shuffle 470, 0.02295
# Shuffle 480, 0.02146
# Shuffle 490, 0.02117
# Shuffle 500, 0.02104
# Shuffle 510, 0.02070
# Shuffle 520, 0.02131
# Shuffle 530, 0.02093
# Shuffle 540, 0.02135
# Shuffle 550, 0.02091
# Shuffle 560, 0.02164
# Shuffle 570, 0.02193
# Shuffle 580, 0.02053
# Shuffle 590, 0.02067
# Shuffle 600, 0.02270
# Shuffle 610, 0.02524
# Shuffle 620, 0.02180
# Shuffle 630, 0.02894
# Shuffle 640, 0.02672
# Shuffle 650, 0.02055
# Shuffle 660, 0.02349
# Shuffle 670, 0.02490
# Shuffle 680, 0.02091
# Shuffle 690, 0.02225
# Shuffle 700, 0.02170
# Shuffle 710, 0.02100
# Shuffle 720, 0.02061
# Shuffle 730, 0.02121
# Shuffle 740, 0.02350
# Shuffle 750, 0.02097
# Shuffle 760, 0.02703
# Shuffle 770, 0.02120
# Shuffle 780, 0.02318
# Shuffle 790, 0.02324
# Shuffle 800, 0.02136
# Shuffle 810, 0.02168
# Shuffle 820, 0.02336
# Shuffle 830, 0.02066
# Shuffle 840, 0.02720
# Shuffle 850, 0.02047
# Shuffle 860, 0.02715
# Shuffle 870, 0.02062
# Shuffle 880, 0.02871
# Shuffle 890, 0.02538
# Shuffle 900, 0.02090
# Shuffle 910, 0.02297
# Shuffle 920, 0.02959
# Shuffle 930, 0.02186
# Shuffle 940, 0.02038
# Shuffle 950, 0.02398
# Shuffle 960, 0.02267
# Shuffle 970, 0.01814
# Shuffle 980, 0.02045
# Shuffle 990, 0.01939
# Animal jeev, Day 2, pv 0.00000, r2_pred 0.319, mn r2_shuff0.258, 95th r2_shuff0.259
# Shuffle 0, 0.01604
# Shuffle 10, 0.02349
# Shuffle 20, 0.03506
# Shuffle 30, 0.03099
# Shuffle 40, 0.02643
# Shuffle 50, 0.02270
# Shuffle 60, 0.02222
# Shuffle 70, 0.02691
# Shuffle 80, 0.02628
# Shuffle 90, 0.02579
# Shuffle 100, 0.02252
# Shuffle 110, 0.02374
# Shuffle 120, 0.03535
# Shuffle 130, 0.02239
# Shuffle 140, 0.02210
# Shuffle 150, 0.02271
# Shuffle 160, 0.02129
# Shuffle 170, 0.02304
# Shuffle 180, 0.02299
# Shuffle 190, 0.02403
# Shuffle 200, 0.02320
# Shuffle 210, 0.02249
# Shuffle 220, 0.02262
# Shuffle 230, 0.02241
# Shuffle 240, 0.02220
# Shuffle 250, 0.02336
# Shuffle 260, 0.02381
# Shuffle 270, 0.02823
# Shuffle 280, 0.02325
# Shuffle 290, 0.02960
# Shuffle 300, 0.02349
# Shuffle 310, 0.02292
# Shuffle 320, 0.02254
# Shuffle 330, 0.02211
# Shuffle 340, 0.02433
# Shuffle 350, 0.02227
# Shuffle 360, 0.02219
# Shuffle 370, 0.02433
# Shuffle 380, 0.02377
# Shuffle 390, 0.02434
# Shuffle 400, 0.02212
# Shuffle 410, 0.02205
# Shuffle 420, 0.05944
# Shuffle 430, 0.02318
# Shuffle 440, 0.02138
# Shuffle 450, 0.02277
# Shuffle 460, 0.02312
# Shuffle 470, 0.02250
# Shuffle 480, 0.02319
# Shuffle 490, 0.02400
# Shuffle 500, 0.02180
# Shuffle 510, 0.02367
# Shuffle 520, 0.02327
# Shuffle 530, 0.02263
# Shuffle 540, 0.02220
# Shuffle 550, 0.02233
# Shuffle 560, 0.02393
# Shuffle 570, 0.02448
# Shuffle 580, 0.02730
# Shuffle 590, 0.02245
# Shuffle 600, 0.02236
# Shuffle 610, 0.02193
# Shuffle 620, 0.02233
# Shuffle 630, 0.02243
# Shuffle 640, 0.02758
# Shuffle 650, 0.02433
# Shuffle 660, 0.02452
# Shuffle 670, 0.02361
# Shuffle 680, 0.02281
# Shuffle 690, 0.02296
# Shuffle 700, 0.02387
# Shuffle 710, 0.02441
# Shuffle 720, 0.02237
# Shuffle 730, 0.02370
# Shuffle 740, 0.02251
# Shuffle 750, 0.02243
# Shuffle 760, 0.02509
# Shuffle 770, 0.02248
# Shuffle 780, 0.02251
# Shuffle 790, 0.02305
# Shuffle 800, 0.02245
# Shuffle 810, 0.02201
# Shuffle 820, 0.02261
# Shuffle 830, 0.02300
# Shuffle 840, 0.02194
# Shuffle 850, 0.02330
# Shuffle 860, 0.01649
# Shuffle 870, 0.02250
# Shuffle 880, 0.02281
# Shuffle 890, 0.02380
# Shuffle 900, 0.02457
# Shuffle 910, 0.02943
# Shuffle 920, 0.02245
# Shuffle 930, 0.02311
# Shuffle 940, 0.02234
# Shuffle 950, 0.02268
# Shuffle 960, 0.02264
# Shuffle 970, 0.01659
# Shuffle 980, 0.02255
# Shuffle 990, 0.02833
# Animal jeev, Day 3, pv 0.00000, r2_pred 0.206, mn r2_shuff0.180, 95th r2_shuff0.180
# POOLED: Animal jeev, Day 3, pv 0.000000, r2_pred 0.292, mn r2_shuff0.236, 95th r2_shuff0.236
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-06 16:55:46.095575. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.plot_example_neuron_comm_predictions(nshuffs=100)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.04556
# Shuffle 10, 2.00862
# Shuffle 20, 3.85745
# Shuffle 30, 5.63726
# Shuffle 40, 7.48348
# Shuffle 50, 9.21647
# Shuffle 60, 10.99095
# Shuffle 70, 12.82622
# Shuffle 80, 14.55225
# Shuffle 90, 16.33975
# End Cnt: 386
# pv_all
# [0.29392474 0.83062357]
# End Cnt: 386
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-17 23:11:00.460124. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.perc_sig_neuron_comm_predictions(nshuffs=2)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.04619
# Conditioning on push
# No push
# Shuffle 0, 0.02767
# Conditioning on push
# No push
# Shuffle 0, 0.06801
# Conditioning on push
# No push
# Shuffle 0, 0.08192
# Conditioning on push
# No push
# Shuffle 0, 0.06534
# Conditioning on push
# No push
# Shuffle 0, 0.05224
# Conditioning on push
# No push
# Shuffle 0, 0.02324
# Conditioning on push
# No push
# Shuffle 0, 0.03578
# Conditioning on push
# No push
# Shuffle 0, 0.03105
# Conditioning on push
# No push
# Shuffle 0, 0.03539
# Conditioning on push
# No push
# Shuffle 0, 0.01924
# Conditioning on push
# No push
# Shuffle 0, 0.04045
# Conditioning on push
# No push
# Shuffle 0, 0.02402
# Neural su, Dat true, Vaf 0.36175, Corr Coeff 0.60410
# Neural su, Dat shuff, Vaf -0.06503, Corr Coeff 0.24159
# Neural pop, Dat true, Vaf 0.50399, Corr Coeff 0.62088
# Neural pop, Dat shuff, Vaf 0.35951, Corr Coeff 0.27298
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-06 12:43:14.976613. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.pw_comparison(nshuffs=10)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.03397
# Skipping Movement PW 11.1, 2.0, Niter = 4
# Skipping Movement PW 11.1, 3.0, Niter = 2
# Skipping Movement PW 11.1, 4.0, Niter = 3
# Skipping Movement PW 3.0, 4.0, Niter = 3
# Skipping Movement PW 10.1, 12.1, Niter = 2
# Skipping Movement PW 10.1, 14.0, Niter = 2
# Skipping Movement PW 10.1, 12.1, Niter = 5
# Skipping Movement PW 10.1, 17.1, Niter = 2
# Skipping Movement PW 12.1, 15.0, Niter = 9
# Skipping Movement PW 12.1, 17.1, Niter = 5
# Skipping Movement PW 15.0, 17.1, Niter = 6
# Skipping Movement PW 1.0, 2.0, Niter = 2
# Skipping Movement PW 1.0, 13.1, Niter = 16
# Skipping Movement PW 1.0, 15.0, Niter = 2
# Skipping Movement PW 1.0, 14.1, Niter = 12
# Skipping Movement PW 1.0, 17.1, Niter = 2
# Skipping Movement PW 13.1, 17.1, Niter = 7
# Skipping Movement PW 11.1, 15.0, Niter = 4
# Skipping Movement PW 12.1, 15.0, Niter = 3
# Skipping Movement PW 12.1, 7.0, Niter = 3
# Skipping Movement PW 13.1, 15.0, Niter = 2
# Skipping Movement PW 13.1, 7.0, Niter = 2
# Skipping Movement PW 14.1, 15.0, Niter = 7
# Skipping Movement PW 14.1, 7.0, Niter = 7
# Skipping Movement PW 15.0, 7.0, Niter = 2
# Skipping Movement PW 0.0, 2.0, Niter = 2
# Skipping Movement PW 0.0, 17.1, Niter = 2
# Skipping Movement PW 2.0, 17.1, Niter = 2
# Skipping Movement PW 10.1, 1.0, Niter = 8
# Skipping Movement PW 1.0, 14.1, Niter = 22
# Skipping Movement PW 4.0, 14.0, Niter = 5
# Skipping Movement PW 4.0, 15.0, Niter = 5
# Skipping Movement PW 13.1, 16.1, Niter = 22
# Skipping Movement PW 4.0, 16.1, Niter = 6
# Skipping Movement PW 14.0, 16.1, Niter = 22
# Skipping Movement PW 5.0, 16.1, Niter = 2
# Skipping Movement PW 10.1, 14.1, Niter = 3
# Skipping Movement PW 14.1, 17.1, Niter = 20
# Skipping Movement PW 14.1, 17.1, Niter = 2
# Skipping Movement PW 10.1, 3.0, Niter = 10
# Skipping Movement PW 10.1, 14.1, Niter = 13
# Skipping Movement PW 1.0, 2.0, Niter = 21
# Skipping Movement PW 1.0, 3.0, Niter = 2
# Skipping Movement PW 1.0, 14.1, Niter = 5
# Skipping Movement PW 12.1, 3.0, Niter = 4
# Skipping Movement PW 12.1, 4.0, Niter = 13
# Skipping Movement PW 12.1, 14.0, Niter = 18
# Skipping Movement PW 12.1, 15.0, Niter = 23
# Skipping Movement PW 13.1, 15.0, Niter = 65
# Skipping Movement PW 13.1, 17.1, Niter = 21
# Skipping Movement PW 4.0, 17.1, Niter = 7
# Skipping Movement PW 14.0, 17.1, Niter = 20
# Skipping Movement PW 14.1, 17.1, Niter = 38
# Skipping Movement PW 5.0, 17.1, Niter = 17
# Skipping Movement PW 5.0, 7.0, Niter = 2
# Skipping Movement PW 0.0, 14.1, Niter = 12
# Skipping Movement PW 0.0, 15.0, Niter = 13
# Skipping Movement PW 14.1, 6.0, Niter = 6
# Skipping Movement PW 1.0, 12.1, Niter = 3
# Skipping Movement PW 12.1, 16.1, Niter = 10
# Skipping Movement PW 12.1, 7.0, Niter = 3
# Skipping Movement PW 16.1, 7.0, Niter = 11
# Day 0, Animal grom, len(data) true, su = 29216
# Day 0, Animal grom, len(data) true, pop = 664
# Day 0, Animal grom, len(data) shuff, su = 29216
# Day 0, Animal grom, len(data) shuff, pop = 664
# Conditioning on push
# No push
# Shuffle 0, 0.02250
# Conditioning on push
# No push
# Shuffle 0, 0.04963
# Conditioning on push
# No push
# Shuffle 0, 0.04470
# Conditioning on push
# No push
# Shuffle 0, 0.10985
# Conditioning on push
# No push
# Shuffle 0, 0.04350
# Conditioning on push
# No push
# Shuffle 0, 0.01346
# Conditioning on push
# No push
# Shuffle 0, 0.01841
# Conditioning on push
# No push
# Shuffle 0, 0.01406
# Conditioning on push
# No push
# Shuffle 0, 0.02773
# Conditioning on push
# No push
# Shuffle 0, 0.01849
# Conditioning on push
# No push
# Shuffle 0, 0.02001
# Conditioning on push
# No push
# Shuffle 0, 0.02118
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-18 00:18:18.005390. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
29216/44
# Out:
# 664
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-02 22:57:30.965695. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.get_data_EVs()
# Out:
# grom, 0 alpha 2500.0
# grom, 1 alpha 750.0
# grom, 2 alpha 5000.0
# grom, 3 alpha 2500.0
# grom, 4 alpha 5000.0
# grom, 5 alpha 2500.0
# grom, 6 alpha 750.0
# grom, 7 alpha 2500.0
# grom, 8 alpha 1000.0
# jeev, 0 alpha 250.0
# jeev, 1 alpha 250.0
# jeev, 2 alpha 250.0
# jeev, 3 alpha 250.0
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-28 14:59:52.898867. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs._test_distGlobal_dirTrue()
# Out:
# frac 0.67
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-26 12:39:48.149223. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.neuraldiff_vs_behaviordiff_corr_pairwise_predictions(nshuffs=1)
# Out:
# Shuffle 0, 0.03438
# True slp 0.102, intc 0.279, rv 0.729, N = 36
# Pred slp 0.032, intc 0.099, rv 0.503, N = 36
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-ed969b59a6a6> in <module>()
# ----> 1 plot_pred_fr_diffs.neuraldiff_vs_behaviordiff_corr_pairwise_predictions(nshuffs=1)
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_pred_fr_diffs.py in neuraldiff_vs_behaviordiff_corr_pairwise_predictions(min_bin_indices, nshuffs, ncommands_psth, min_commands, min_move_per_command)
#    1587                                 ### Figure out which of the "ix_com" indices can be used for shuffling for this movement
#    1588                                 ix_ok1, ix_ok2, niter = plot_fr_diffs.distribution_match_mov_pairwise(push_sub[np.ix_(ix_mc_all, [3, 5])],
# -> 1589                                                              push_sub[np.ix_(ix_mc_all2, [3, 5])])
#    1590
#    1591                                 if np.logical_and(len(ix_ok1) >= min_commands, len(ix_ok2) >= min_commands):
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_fr_diffs.pyc in distribution_match_mov_pairwise(push_com1, push_com2, psig, perc_drop)
#     180
#     181         for var in range(nVar):
# --> 182             t, pv = scipy.stats.ttest_ind(dct['push_com1'][dct['indices1'], var], dct['push_com2'][dct['indices2'], var])
#     183             pv_recent[var] = pv
#     184
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/stats.pyc in ttest_ind(a, b, axis, equal_var, nan_policy)
#    4210         df, denom = _unequal_var_ttest_denom(v1, n1, v2, n2)
#    4211
# -> 4212     res = _ttest_ind_from_stats(np.mean(a, axis), np.mean(b, axis), denom, df)
#    4213
#    4214     return Ttest_indResult(*res)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3118                           out=out, **kwargs)
#    3119
#    3120
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      69         if issubclass(arr.dtype.type, (nt.integer, nt.bool_)):
#      70             dtype = mu.dtype('f8')
# ---> 71         elif issubclass(arr.dtype.type, nt.float16):
#      72             dtype = mu.dtype('f4')
#      73             is_float16_result = True
#
# KeyboardInterrupt:
# > /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/_methods.py(71)_mean()
#      70             dtype = mu.dtype('f8')
# ---> 71         elif issubclass(arr.dtype.type, nt.float16):
#      72             dtype = mu.dtype('f4')
#
# ipdb> c
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-07 18:30:29.987928. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
