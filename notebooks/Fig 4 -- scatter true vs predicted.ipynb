# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import plot_pred_fr_diffs
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-22 22:16:44.109651. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.plot_example_neuron_comm_predictions(nshuffs=100)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.03641
# Shuffle 10, 2.35903
# Shuffle 20, 4.05873
# Shuffle 30, 5.81549
# Shuffle 40, 7.51467
# Shuffle 50, 8.97571
# Shuffle 60, 10.46169
# Shuffle 70, 11.98328
# Shuffle 80, 13.52439
# Shuffle 90, 15.09908
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-23 10:40:24.384891. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.perc_sig_neuron_comm_predictions(nshuffs=100)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.03373
# Shuffle 10, 1.63050
# Shuffle 20, 3.15061
# Shuffle 30, 4.64633
# Shuffle 40, 6.09653
# Shuffle 50, 7.62169
# Shuffle 60, 9.16536
# Shuffle 70, 10.66217
# Shuffle 80, 12.14335
# Shuffle 90, 13.68747
# Conditioning on push
# No push
# Shuffle 0, 0.02101
# Shuffle 10, 0.81354
# Shuffle 20, 1.36216
# Shuffle 30, 1.81140
# Shuffle 40, 2.25310
# Shuffle 50, 2.69714
# Shuffle 60, 3.18234
# Shuffle 70, 4.40017
# Shuffle 80, 5.65651
# Shuffle 90, 6.12297
# Conditioning on push
# No push
# Shuffle 0, 0.06027
# Shuffle 10, 18.29397
# Shuffle 20, 34.90848
# Shuffle 30, 53.65587
# Shuffle 40, 72.53810
# Shuffle 50, 91.48779
# Shuffle 60, 132.25405
# Shuffle 70, 172.44512
# Shuffle 80, 194.46847
# Shuffle 90, 214.22606
# Conditioning on push
# No push
# Shuffle 0, 0.06205
# Shuffle 10, 3.76389
# Shuffle 20, 7.29585
# Shuffle 30, 11.43199
# Shuffle 40, 14.91987
# Shuffle 50, 18.77625
# Shuffle 60, 22.53014
# Shuffle 70, 27.96460
# Shuffle 80, 32.79212
# Shuffle 90, 37.36970
# Conditioning on push
# No push
# Shuffle 0, 0.06470
# Shuffle 10, 25.45371
# Shuffle 20, 55.40311
# Shuffle 30, 75.42868
# Shuffle 40, 91.94209
# Shuffle 50, 108.11888
# Shuffle 60, 123.86917
# Shuffle 70, 143.85910
# Shuffle 80, 161.10505
# Shuffle 90, 182.91648
# Conditioning on push
# No push
# Shuffle 0, 0.04107
# Shuffle 10, 1.77981
# Shuffle 20, 3.36240
# Shuffle 30, 5.12168
# Shuffle 40, 6.69627
# Shuffle 50, 8.39558
# Shuffle 60, 10.01831
# Shuffle 70, 11.92853
# Shuffle 80, 13.42981
# Shuffle 90, 14.86747
# Conditioning on push
# No push
# Shuffle 0, 0.01338
# Shuffle 10, 1.04354
# Shuffle 20, 2.42053
# Shuffle 30, 4.23632
# Shuffle 40, 5.73904
# Shuffle 50, 6.90679
# Shuffle 60, 8.28859
# Shuffle 70, 10.98035
# Shuffle 80, 11.91767
# Shuffle 90, 12.81629
# Conditioning on push
# No push
# Shuffle 0, 0.01719
# Shuffle 10, 1.13788
# Shuffle 20, 2.15145
# Shuffle 30, 3.33016
# Shuffle 40, 4.24287
# Shuffle 50, 5.61356
# Shuffle 60, 6.62507
# Shuffle 70, 7.69468
# Shuffle 80, 9.02181
# Shuffle 90, 10.44564
# Conditioning on push
# No push
# Shuffle 0, 0.02261
# Shuffle 10, 1.27899
# Shuffle 20, 2.66993
# Shuffle 30, 3.89898
# Shuffle 40, 5.09502
# Shuffle 50, 5.96803
# Shuffle 60, 7.13210
# Shuffle 70, 8.42285
# Shuffle 80, 9.57082
# Shuffle 90, 11.43648
# Conditioning on push
# No push
# Shuffle 0, 0.03473
# Shuffle 10, 0.45163
# Shuffle 20, 0.86941
# Shuffle 30, 1.13982
# Shuffle 40, 1.40827
# Shuffle 50, 1.81729
# Shuffle 60, 2.17555
# Shuffle 70, 2.46086
# Shuffle 80, 2.66650
# Shuffle 90, 2.89340
# Conditioning on push
# No push
# Shuffle 0, 0.01850
# Shuffle 10, 0.29399
# Shuffle 20, 0.51878
# Shuffle 30, 0.73370
# Shuffle 40, 1.07293
# Shuffle 50, 1.39823
# Shuffle 60, 1.69917
# Shuffle 70, 1.88272
# Shuffle 80, 2.21712
# Shuffle 90, 2.43634
# Conditioning on push
# No push
# Shuffle 0, 0.02473
# Shuffle 10, 0.31486
# Shuffle 20, 0.48169
# Shuffle 30, 0.61733
# Shuffle 40, 0.79326
# Shuffle 50, 0.96315
# Shuffle 60, 1.31912
# Shuffle 70, 1.69783
# Shuffle 80, 1.91432
# Shuffle 90, 2.16780
# Conditioning on push
# No push
# Shuffle 0, 0.02213
# Shuffle 10, 0.29863
# Shuffle 20, 0.53740
# Shuffle 30, 0.75653
# Shuffle 40, 0.95276
# Shuffle 50, 1.20995
# Shuffle 60, 1.53758
# Shuffle 70, 1.75501
# Shuffle 80, 1.94834
# Shuffle 90, 2.13632
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-23 08:15:52.980114. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
