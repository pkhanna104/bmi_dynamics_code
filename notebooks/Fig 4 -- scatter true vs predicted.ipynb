# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import plot_pred_fr_diffs, plot_generated_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-23 15:15:21.074085. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.plot_example_neuron_comm_predictions(nshuffs=100)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.04279
# Shuffle 10, 2.44046
# Shuffle 20, 4.53935
# Shuffle 30, 6.69435
# Shuffle 40, 8.79399
# Shuffle 50, 10.85798
# Shuffle 60, 12.90983
# Shuffle 70, 15.04079
# Shuffle 80, 17.10124
# Shuffle 90, 19.20487
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-23 12:17:17.292303. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.perc_sig_neuron_comm_predictions(nshuffs=100)
# Out:
# Conditioning on push
# No push
# Shuffle 0, 0.03373
# Shuffle 10, 1.63050
# Shuffle 20, 3.15061
# Shuffle 30, 4.64633
# Shuffle 40, 6.09653
# Shuffle 50, 7.62169
# Shuffle 60, 9.16536
# Shuffle 70, 10.66217
# Shuffle 80, 12.14335
# Shuffle 90, 13.68747
# Conditioning on push
# No push
# Shuffle 0, 0.02101
# Shuffle 10, 0.81354
# Shuffle 20, 1.36216
# Shuffle 30, 1.81140
# Shuffle 40, 2.25310
# Shuffle 50, 2.69714
# Shuffle 60, 3.18234
# Shuffle 70, 4.40017
# Shuffle 80, 5.65651
# Shuffle 90, 6.12297
# Conditioning on push
# No push
# Shuffle 0, 0.06027
# Shuffle 10, 18.29397
# Shuffle 20, 34.90848
# Shuffle 30, 53.65587
# Shuffle 40, 72.53810
# Shuffle 50, 91.48779
# Shuffle 60, 132.25405
# Shuffle 70, 172.44512
# Shuffle 80, 194.46847
# Shuffle 90, 214.22606
# Conditioning on push
# No push
# Shuffle 0, 0.06205
# Shuffle 10, 3.76389
# Shuffle 20, 7.29585
# Shuffle 30, 11.43199
# Shuffle 40, 14.91987
# Shuffle 50, 18.77625
# Shuffle 60, 22.53014
# Shuffle 70, 27.96460
# ...

# %%
plot_pred_fr_diffs.get_data_EVs()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-23 17:37:01.320600. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
