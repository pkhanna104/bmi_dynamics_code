# %%
import os
bmidir = os.environ['BMI_DYN']
os.chdir(bmidir)

# %%
#### Auto reload ###
# %load_ext autoreload
# %autoreload 2

# %%
### Use this to suppress annoying timezone warning: 
import warnings
warnings.filterwarnings(action='ignore')

# %%
import analysis_config
from online_analysis import basic_perf_analysis
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-04-21 13:49:29.355917. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Basic performance plot -- rewards per minute adn percent correct for the gromit dataset #####
basic_perf_analysis.plot_metric(analysis_config.data_params['grom_input_type'])
# Out:
# online_analysis/basic_perf_analysis.py:28: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(analysis_config.config['grom_pref']+hdf[hdfix:])
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-04-21 13:49:31.088993. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
basic_perf_analysis.example_tarj(analysis_config.data_params['grom_input_type'])
# Out:
# online_analysis/basic_perf_analysis.py:96: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(analysis_config.config['grom_pref']+hdf[hdfix:])
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-04-21 13:49:51.720846. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
