# %%
import os
bmidir = os.environ['BMI_DYN']
os.chdir(bmidir)

# %%
#### Auto reload ###
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
### Use this to suppress annoying timezone warning: 
import warnings
warnings.filterwarnings(action='ignore')

# %%
import analysis_config
from online_analysis import basic_perf_analysis

# %%
##### Basic performance plot -- rewards per minute adn percent correct for the gromit dataset #####
basic_perf_analysis.plot_metric(analysis_config.data_params['grom_input_type'])
# Out:
# online_analysis/basic_perf_analysis.py:28: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(analysis_config.config['grom_pref']+hdf[hdfix:])
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-17 12:53:18.986876. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
analysis_config.data_params['grom_input_type']
# Out:
# [[[4377], [4378, 4382]],
#  [[4395], [4394]],
#  [[4411], [4412, 4415]],
#  [[4499], [4497, 4498, 4504]],
#  [[4510], [4509, 4514]],
#  [[4523, 4525], [4520, 4522]],
#  [[4536], [4532, 4533]],
#  [[4553], [4549]],
#  [[4558], [4560]]]

# %%
basic_perf_analysis.example_tarj([analysis_config.data_params['grom_input_type'][0]])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# day 0, tsk 4377
# 1.2999999999999998 1.7 0.4
# ((64,), (64,), (18, 44), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# day 0, tsk 4378
# 1.5 2 0.5
# ((101,), (101,), (40, 44), 6, (40,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# day 0, tsk 4382
# 1.5 2 0.5
# ((122,), (122,), (97, 44), 6, (97,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
