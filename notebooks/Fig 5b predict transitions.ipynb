# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import analysis_config
from online_analysis import util_fcns, plot_actions, generate_models
from matplotlib import cm
import copy
import matplotlib as mpl
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
animal = 'grom'; 
model_set_number = 6;
day = 0; 
ang = 2; 
mag = 3;
dat = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N.pkl' %(model_set_number), 'rb'))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 18:59:11.366520. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# for ang in range(8):
#     for mag in [2, 3]:
ang = 2
mag = 3; 
plot_actions.plot_example_dAng_dMag(animal, day, ang, mag, dat=dat)
# Out:
# R2 of action 0.44
# R2 of neural 0.23
# <img src="data:image/png;base64,..." width="863.3333562038569">
# online_analysis/plot_actions.py:434: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   angles1 = angles1[:-1]
#
# online_analysis/plot_actions.py:435: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   angles2 = angles2[:-1]
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 22:28:31.869666. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Plot scatter for true data vs. predicted data angle;
# Out:
# R2 of action 0.27
# R2 of neural 0.17
# <div id='31350d9a-516c-4a45-af42-2e372231d1ce'></div>
# R2 of action 0.25
# R2 of neural 0.13
# <div id='27685d9e-0975-4e45-97fe-21840a979aa4'></div>
# R2 of action 0.30
# R2 of neural 0.16
# <div id='30b98def-7325-4d77-bf4f-0270294fbc20'></div>
# R2 of action 0.17
# R2 of neural 0.06
# <div id='13efcb33-7f0e-4a5f-afce-23b6f5cab573'></div>
# R2 of action 0.45
# R2 of neural 0.23
# <div id='07a842f5-3472-4668-892e-712a7f54da03'></div>
# R2 of action 0.41
# R2 of neural 0.28
# <div id='568872ae-dc74-4588-9f59-2fd09f07f39a'></div>
# R2 of action 0.24
# R2 of neural 0.07
# <div id='7912d3dc-5aa8-4a4b-a435-7e6d74b091a5'></div>
# R2 of action 0.33
# R2 of neural 0.07
# <div id='96b97ad1-87c0-4cc1-80d9-f73e30b5c12e'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-48cda9d11c77> in <module>()
# ...
