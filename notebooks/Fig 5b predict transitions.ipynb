# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import analysis_config
from online_analysis import util_fcns, generate_models, plot_actions
from matplotlib import cm
import copy
import matplotlib as mpl
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
animal = 'grom'; 
model_set_number = 6;
day = 0; 
ang = 2; 
mag = 3;
dat = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N.pkl' %(model_set_number), 'rb'))
plot_actions.plot_example_dAng_dMag(animal, day, ang, mag, dat=dat)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-13 17:50:45.050073. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Plot scatter for true data vs. predicted data angle; UPDATES 4/7/21
stats_dict = plot_actions.extract_trans_stats(include_shuffle=True)
# Out:
# R2 of action 0.28
# R2 of neural 0.17
# R2 of action 0.27
# R2 of neural 0.17
# R2 of action 0.30
# R2 of neural 0.17
# R2 of action 0.17
# R2 of neural 0.07
# R2 of action 0.46
# R2 of neural 0.24
# R2 of action 0.42
# R2 of neural 0.29
# R2 of action 0.32
# R2 of neural 0.09
# R2 of action 0.35
# R2 of neural 0.08
# R2 of action 0.31
# R2 of neural 0.09
# R2 of action 0.34
# R2 of neural 0.06
# R2 of action 0.33
# R2 of neural 0.11
# R2 of action 0.32
# R2 of neural 0.06
# R2 of action 0.31
# R2 of neural 0.06
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 09:18:07.082515. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_actions.plot_barplots_new_shuff(stats_dict)
# Out:
# <img src="data:image/png;base64,..." width="525">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom, Day 0, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 1, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 2, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 3, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 4, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 5, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 6, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 7, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 8, perc corr None, key ang, pv = 0.00000
# PV = 7.954e-10
# SLP 0.26178, N = 18, t(16) = 6.146
# Animal jeev, Day 0, perc corr None, key ang, pv = 0.00000
# ...

# %%
#### Plot scatter for true data vs. predicted data angle; 
#stats_dict = plot_actions.extract_trans_stats(include_shuffle=False)
# Out:
# R2 of action 0.28
# R2 of neural 0.17
# R2 of action 0.27
# R2 of neural 0.17
# R2 of action 0.30
# R2 of neural 0.17
# R2 of action 0.17
# R2 of neural 0.07
# R2 of action 0.46
# R2 of neural 0.24
# R2 of action 0.42
# R2 of neural 0.29
# R2 of action 0.32
# R2 of neural 0.09
# R2 of action 0.35
# R2 of neural 0.08
# R2 of action 0.31
# R2 of neural 0.09
# R2 of action 0.34
# R2 of neural 0.06
# R2 of action 0.33
# R2 of neural 0.11
# R2 of action 0.32
# R2 of neural 0.06
# R2 of action 0.31
# R2 of neural 0.06
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 09:06:34.238492. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for animal in ['grom', 'jeev']:
    if animal == 'grom':
        days = 9;
    elif animal == 'jeev':
        days = 4
    for day_ix in range(days): 
        tmp = stats_dict['grom']['pc','ang_pw', 'trans'][day_ix]
        pc = np.sum(tmp[0])/float(len(tmp[0]))
        print('%s %d %.4f' %(animal, day_ix, pc))
# Out:
# grom 0 0.8447
# grom 1 0.7606
# grom 2 0.8528
# grom 3 0.8765
# grom 4 0.8166
# grom 5 0.7975
# grom 6 1.0000
# grom 7 0.8462
# grom 8 0.9032
# jeev 0 0.8447
# jeev 1 0.7606
# jeev 2 0.8528
# jeev 3 0.8765
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-07 09:10:56.543350. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_actions.plot_barplots_new_shuff(stats_dict)
# Out:
# <img src="data:image/png;base64,..." width="399.99999403953564">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom, Day 0, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 1, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 2, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 3, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 4, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 5, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 6, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 7, perc corr None, key ang, pv = 0.00000
# Animal grom, Day 8, perc corr None, key ang, pv = 0.00000
# PV = 8.850e-06
# SLP 0.51078, N = 18, t(16) = 4.444
# Animal jeev, Day 0, perc corr None, key ang, pv = 0.00000
# ...

# %%
plot_actions.plot_disc_colorless()
# Out:
# <img src="data:image/png;base64,..." width="287.77778540128566">
# online_analysis/plot_actions.py:582: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   angles1 = np.linspace(0., 2*np.pi, 9.) - np.pi/8
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-03 11:18:32.460433. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Plot scatter for true data vs. predicted data angle; 
stats_dict = plot_actions.extract_trans_stats_gen_vs_task_spec()
# Out:
# R2 of action 0.27
# R2 of neural 0.17
# R2 of action 0.28
# R2 of neural 0.17
# R2 of action 0.25
# R2 of neural 0.13
# R2 of action 0.27
# R2 of neural 0.15
# R2 of action 0.30
# R2 of neural 0.16
# R2 of action 0.30
# R2 of neural 0.17
# R2 of action 0.17
# R2 of neural 0.06
# R2 of action 0.17
# R2 of neural 0.07
# R2 of action 0.45
# R2 of neural 0.23
# R2 of action 0.45
# R2 of neural 0.24
# R2 of action 0.41
# R2 of neural 0.28
# R2 of action 0.41
# R2 of neural 0.28
# R2 of action 0.24
# R2 of neural 0.07
# R2 of action 0.23
# R2 of neural 0.07
# R2 of action 0.33
# R2 of neural 0.07
# R2 of action 0.33
# R2 of neural 0.07
# R2 of action 0.27
# R2 of neural 0.07
# R2 of action 0.27
# R2 of neural 0.07
# R2 of action 0.33
# R2 of neural 0.05
# R2 of action 0.33
# R2 of neural 0.06
# R2 of action 0.31
# R2 of neural 0.10
# R2 of action 0.32
# R2 of neural 0.10
# R2 of action 0.30
# R2 of neural 0.06
# R2 of action 0.31
# R2 of neural 0.06
# R2 of action 0.29
# R2 of neural 0.05
# ...

# %%
plot_actions.plot_barplots_gen_vs_task_spec(stats_dict)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="399.99999403953564">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom, key ang, perc corr None
# PV = 2.319e-02
# SLP 0.04938, N = 18, t(16) = 2.270
# Animal jeev, key ang, perc corr None
# PV = 7.824e-02
# SLP 0.01641, N = 8, t(6) = 1.761
# <img src="data:image/png;base64,..." width="399.99999403953564">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom, key mag, perc corr None
# PV = 5.081e-01
# SLP 0.00977, N = 18, t(16) = 0.662
# ...

# %%
x = cbar.get_ticks()

# %%
cbar.set_ticklabels?
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-13 17:47:10.281398. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
xt = x*100
cbar.set_ticklabels(xt)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/colorbar.py:427: UserWarning: set_ticks() must have been called.
#   warnings.warn("set_ticks() must have been called.")

# %%
cbar
