# %%
#%matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
from online_analysis import generalization_plots
from online_analysis import generate_models_utils
import analysis_config
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
generalization_plots.plot_err_by_cat(yval = 'r2', run_f_test=False)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="802.6666666666666">
# > /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generalization_plots.py(213)plot_err_by_cat()
# -> if run_f_test:
# (Pdb) N_dat[:, 0]
# array([2.2290e+03, 9.1680e+03, 2.5800e+02, 3.3700e+02, 3.1900e+02,
#        3.2100e+02, 3.0800e+02, 2.7100e+02, 1.8900e+02, 2.2600e+02,
#        1.0280e+03, 1.0670e+03, 1.2410e+03, 1.4710e+03, 5.5000e+02,
#        1.2860e+03, 9.9200e+02, 6.9900e+02, 8.3400e+02, 3.6500e+02,
#        3.5900e+02, 2.9100e+02, 2.4600e+02, 2.4900e+02, 3.3100e+02,
#        3.3300e+02, 4.1800e+02, 3.7200e+02, 3.9100e+02, 3.0000e+02,
#        2.1300e+02, 2.5300e+02, 3.2700e+02, 4.4300e+02, 3.7100e+02,
#        3.2200e+02, 3.8600e+02, 3.1700e+02, 2.3000e+02, 3.2900e+02,
#        3.8900e+02, 3.8700e+02, 3.8900e+02, 1.2500e+02, 2.8400e+02,
# ...

# %%
#generalization_plots.fit_predict_loo_model(cat='tsk')
#generalization_plots.fit_predict_loo_model(cat='mov')
generalization_plots.fit_predict_loo_model(cat='com')
generalization_plots.fit_predict_loo_model(cat='com_ang')
generalization_plots.fit_predict_loo_model(cat='com_mag')
# Out:
# Starting grom, Day 0
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Starting fold 0 for LO 0, training pts = 8565, alpha 2500.0
# Starting fold 1 for LO 0, training pts = 8564, alpha 2500.0
# Starting fold 2 for LO 0, training pts = 8540, alpha 2500.0
# Starting fold 3 for LO 0, training pts = 8571, alpha 2500.0
# ...

# %%
### Open example file; 
#generalization_plots.plot_loo_r2_overall(cat='mov', yval='err')
generalization_plots.plot_loo_r2_overall(cat='com_mag', yval='r2', nshuffs=50)
generalization_plots.plot_loo_r2_overall(cat='com', yval='r2', nshuffs=50)
generalization_plots.plot_loo_r2_overall(cat='com_ang', yval='r2', nshuffs=50)

#generalization_plots.plot_loo_r2_overall(cat='tsk', yval='r2', nshuffs=10, mean_sub_no_offs=False)
# Out:
# <div id='74c2b993-ffcb-4840-9b51-af04ea9bcfa2'></div>
# <div id='d6b8b3bf-07ff-41ce-9331-9c6cf4304dd0'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.04782
# Shuffle 10, 1.91236
# Shuffle 20, 3.46652
# Shuffle 30, 4.95461
# Shuffle 40, 6.53888
# Conditioning on push
# No push
# Shuffle 0, 0.02563
# Shuffle 10, 0.45056
# Shuffle 20, 0.83477
# Shuffle 30, 1.21788
# Shuffle 40, 1.56526
# Conditioning on push
# No push
# Shuffle 0, 0.05090
# Shuffle 10, 16.31741
# Shuffle 20, 33.24143
# Shuffle 30, 49.48670
# Shuffle 40, 65.34184
# Conditioning on push
# No push
# Shuffle 0, 0.05472
# Shuffle 10, 2.89992
# Shuffle 20, 5.67722
# Shuffle 30, 8.48376
# Shuffle 40, 11.01285
# Conditioning on push
# No push
# Shuffle 0, 0.04001

# %%
#generalization_plots.plot_loo_r2_overall(cat='tsk', yval='err')
#generalization_plots.plot_loo_r2_overall(cat='tsk', yval='r2')

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-05 17:25:27.055551. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#generalization_plots.plot_loo_r2_overall(cat='com', yval='r2')
#generalization_plots.plot_loo_r2_overall(cat='com', yval='err')

# %%
generalization_plots.plot_pop_dist_corr_COMMAND(nshuffs=50)

# %%
generalization_plots.plot_pop_dist_corr_MOV_TSK(nshuffs=10, cat='mov')
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# Conditioning on push
# No push
# Shuffle 0, 0.04116
# num diffs 700
# <img src="data:image/png;base64,..." width="300">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-04 19:15:12.015971. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#generalization_plots.plot_pop_dist_corr_MOV_TSK(nshuffs=10, cat='tsk')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-04 18:45:02.372776. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.move_spec_dyn(zero_alpha=False)
# Out:
# Starting grom, Day 0
# <img src="data:image/png;base64,..." width="800">
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Starting grom, Day 1
# <img src="data:image/png;base64,..." width="800">
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-04 08:30:23.118482. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-03 18:18:24.792341. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# Out:
# Ridge(alpha=2500.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-03 18:20:34.623247. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from sklearn.linear_model import Ridge

#### Randomly generate X data
Npts = 200
X = np.random.randn(Npts, 2)

#### Construct an A matrix (decay only) and compute X_{t+1}
A = np.array([[.9, 0.], [0, .9]])
Xt = np.dot(A, X.T).T

### Plot "flow"
f, ax = plt.subplots()
keep = []
for i in range(Npts):
    if X[i, 1] > 0:
        ax.plot([X[i, 0], Xt[i, 0]], [X[i, 1], Xt[i, 1]], 'k-')
        keep.append(i)
    else:
        ax.plot([X[i, 0], Xt[i, 0]], [X[i, 1], Xt[i, 1]], 'b-')
        
### Post hoc fit these points 
keep = np.array(keep)

### Try fitting data; 
X_train = X[keep, :]
Y_train = Xt[keep, :]

model = Ridge(alpha=1000, fit_intercept=True)
model.fit(X_train, Y_train)

#### Plot the estimated intercept; 
ax.plot(model.intercept_[0], model.intercept_[1], 'r*')
print('A, dyn matrix ', model.coef_)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ('A, dyn matrix ', array([[0.08277392, 0.00069407],
#        [0.00069407, 0.02692499]]))
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-03 18:31:02.687955. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
day_ix = 0; 
animal = 'grom'
model_nm = 'hist_1pos_0psh_2spksm_1_spksp_0'
ridge_dict = pickle.load(open(os.path.join(analysis_config.config['grom_pref'] , 'max_alphas_ridge_model_set%d.pkl'%6), 'rb')); 
alpha_spec = ridge_dict[animal][0][day_ix, model_nm]
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-03 18:19:44.780534. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.fit_predict_lomov_model()
# Out:
# <img src="data:image/png;base64,..." width="300">
# Starting grom, Day 0 Mov Cat diag_neg
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Conditioning on push
# No push
# Shuffle 0, 0.04026
# Starting grom, Day 1 Mov Cat diag_neg
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ...
