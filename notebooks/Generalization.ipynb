# %%
#%matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
from online_analysis import generalization_plots
from online_analysis import generate_models_utils
import analysis_config
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
generalization_plots.plot_err_by_cat(yval = 'r2', run_f_test=False)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="802.6666666666666">
# > /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generalization_plots.py(213)plot_err_by_cat()
# -> if run_f_test:
# (Pdb) N_dat[:, 0]
# array([2.2290e+03, 9.1680e+03, 2.5800e+02, 3.3700e+02, 3.1900e+02,
#        3.2100e+02, 3.0800e+02, 2.7100e+02, 1.8900e+02, 2.2600e+02,
#        1.0280e+03, 1.0670e+03, 1.2410e+03, 1.4710e+03, 5.5000e+02,
#        1.2860e+03, 9.9200e+02, 6.9900e+02, 8.3400e+02, 3.6500e+02,
#        3.5900e+02, 2.9100e+02, 2.4600e+02, 2.4900e+02, 3.3100e+02,
#        3.3300e+02, 4.1800e+02, 3.7200e+02, 3.9100e+02, 3.0000e+02,
#        2.1300e+02, 2.5300e+02, 3.2700e+02, 4.4300e+02, 3.7100e+02,
#        3.2200e+02, 3.8600e+02, 3.1700e+02, 2.3000e+02, 3.2900e+02,
#        3.8900e+02, 3.8700e+02, 3.8900e+02, 1.2500e+02, 2.8400e+02,
# ...

# %%
#generalization_plots.fit_predict_loo_model()
generalization_plots.fit_predict_loo_model(cat='mov')
#generalization_plots.fit_predict_loo_model(cat='com')
# Out:
# Starting grom, Day 0
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Starting fold 0 for LO 0
# Starting fold 1 for LO 0
# Starting fold 2 for LO 0
# Starting fold 3 for LO 0
# Starting fold 4 for LO 0
# Starting fold 0 for LO 1
# Starting fold 1 for LO 1
# Starting fold 2 for LO 1
# Starting fold 3 for LO 1
# Starting fold 4 for LO 1
# ...

# %%
### Open example file; 
#generalization_plots.plot_loo_r2_overall(cat='mov', yval='err')
#generalization_plots.plot_loo_r2_overall(cat='mov', yval='r2', nshuffs=10)
#generalization_plots.plot_loo_r2_overall(cat='com', yval='r2', nshuffs=10)
generalization_plots.plot_loo_r2_overall(cat='tsk', yval='r2', nshuffs=10, mean_sub_no_offs=False)
# Out:
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Conditioning on push
# No push
# Shuffle 0, 0.03452
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Conditioning on push
# No push
# Shuffle 0, 0.02352
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Conditioning on push
# No push
# Shuffle 0, 0.03380
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Conditioning on push
# No push
# Shuffle 0, 0.03222
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-03 10:55:04.763646. Please add timezone info to timestamps.
# ...

# %%
#generalization_plots.plot_loo_r2_overall(cat='tsk', yval='err')
#generalization_plots.plot_loo_r2_overall(cat='tsk', yval='r2')

# %%
#generalization_plots.plot_loo_r2_overall(cat='com', yval='r2')
#generalization_plots.plot_loo_r2_overall(cat='com', yval='err')

# %%
generalization_plots.plot_pop_dist_corr_COMMAND(nshuffs=10)
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# Conditioning on push
# No push
# Shuffle 0, 0.04235
# n comparisons 700
# <div id='af2e8376-6383-484b-a4c2-f83e5bfaf5cf'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.02552
# n comparisons 385
# <div id='2cd54bc3-4f1f-424d-995b-2c135d961f44'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.05335
# n comparisons 667
# <div id='c22d1234-0184-40d2-915e-eee785879545'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.09574
# n comparisons 1083
# <div id='20500dd1-9ff1-402e-a388-b4f07b849d88'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.03757
# n comparisons 711
# <div id='2cb242a1-fe69-4e29-a306-12b5f8f29cba'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.03440
# n comparisons 935
# <div id='f88dc79a-fdac-4273-aa37-57c46813b37d'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.01510
# n comparisons 140
# ...

# %%
generalization_plots.plot_pop_dist_corr_MOV_TSK(nshuffs=10, cat='mov')
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# Conditioning on push
# No push
# Shuffle 0, 0.05881
# num diffs 700
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.02665
# num diffs 385
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.05455
# num diffs 667
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.05091
# num diffs 1083
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.03984
# num diffs 711
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.04109
# num diffs 935
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.01464
# num diffs 140
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# ...

# %%
generalization_plots.plot_pop_dist_corr_MOV_TSK(nshuffs=10, cat='tsk')
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# Conditioning on push
# No push
# Shuffle 0, 0.04591
# num diffs 700
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.02859
# num diffs 385
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.07222
# num diffs 667
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.06408
# num diffs 1083
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# Shuffle 0, 0.03547
# num diffs 711
# <div id='e05ea822-d604-44eb-824f-dd3c6394bdb0'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.05829
# num diffs 935
# <div id='88e0e849-43eb-4791-8a04-ec7c63665eee'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.01698
# num diffs 140
# <img src="data:image/png;base64,..." width="300">
# Conditioning on push
# No push
# ...
