# %%
from online_analysis import generalization_plots
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 21:35:51.781813. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
for cat in ['com_mag']:
    print('########################################')
    print('########################################')
    print('########################################')
    print('')
    print('Starting %s'%cat)
    generalization_plots.plot_loo_r2_overall(cat=cat, yval='r2', nshuffs=1000, plot_eig=False)
# Out:
# ########################################
# ########################################
# ########################################
#
# Starting com_mag
# Shuffle 0, 0.07198
# Shuffle 100, 0.03988
# Shuffle 200, 0.04592
# Shuffle 300, 0.03795
# Shuffle 400, 0.03499
# Shuffle 500, 0.04454
# Shuffle 600, 0.03718
# Shuffle 700, 0.04052
# Shuffle 800, 0.03985
# Shuffle 900, 0.04509
# Animal grom, Day ix 0, pv = 0.00000, r2_ = 0.315, shuff = [0.272, 0.274]
# Shuffle 0, 0.02468
# Shuffle 100, 0.02316
# Shuffle 200, 0.02284
# Shuffle 300, 0.02471
# Shuffle 400, 0.02525
# Shuffle 500, 0.02436
# Shuffle 600, 0.02465
# Shuffle 700, 0.02453
# Shuffle 800, 0.02489
# Shuffle 900, 0.03452
# Animal grom, Day ix 1, pv = 0.00000, r2_ = 0.375, shuff = [0.330, 0.330]
# Shuffle 0, 0.04737
# Shuffle 100, 0.04813
# Shuffle 200, 0.05522
# Shuffle 300, 0.04990
# Shuffle 400, 0.04987
# Shuffle 500, 0.04861
# Shuffle 600, 0.04779
# Shuffle 700, 0.04764
# Shuffle 800, 0.04956
# Shuffle 900, 0.04888
# Animal grom, Day ix 2, pv = 0.00000, r2_ = 0.131, shuff = [0.096, 0.096]
# Shuffle 0, 0.04807
# Shuffle 100, 0.05439
# Shuffle 200, 0.05000
# Shuffle 300, 0.05116
# Shuffle 400, 0.04933
# Shuffle 500, 0.04744
# Shuffle 600, 0.05200
# Shuffle 700, 0.05067
# Shuffle 800, 0.05301
# Shuffle 900, 0.04931
# Animal grom, Day ix 3, pv = 0.00000, r2_ = 0.128, shuff = [0.098, 0.098]
# Shuffle 0, 0.03571
# Shuffle 100, 0.03735
# Shuffle 200, 0.03590
# Shuffle 300, 0.03639
# Shuffle 400, 0.03566
# Shuffle 500, 0.04011
# Shuffle 600, 0.03942
# Shuffle 700, 0.03658
# Shuffle 800, 0.03465
# Shuffle 900, 0.03319
# Animal grom, Day ix 4, pv = 0.00000, r2_ = 0.108, shuff = [0.070, 0.070]
# Shuffle 0, 0.03873
# Shuffle 100, 0.04166
# Shuffle 200, 0.03736
# Shuffle 300, 0.03969
# Shuffle 400, 0.03936
# Shuffle 500, 0.03798
# Shuffle 600, 0.04179
# Shuffle 700, 0.03646
# Shuffle 800, 0.04223
# Shuffle 900, 0.03897
# Animal grom, Day ix 5, pv = 0.00000, r2_ = 0.119, shuff = [0.105, 0.105]
# Shuffle 0, 0.02436
# Shuffle 100, 0.01405
# Shuffle 200, 0.01350
# Shuffle 300, 0.01535
# Shuffle 400, 0.01357
# Shuffle 500, 0.01541
# Shuffle 600, 0.01708
# Shuffle 700, 0.01372
# Shuffle 800, 0.01390
# Shuffle 900, 0.01623
# Animal grom, Day ix 6, pv = 0.00000, r2_ = 0.169, shuff = [0.136, 0.137]
# Shuffle 0, 0.01669
# Shuffle 100, 0.01732
# Shuffle 200, 0.03115
# Shuffle 300, 0.01982
# Shuffle 400, 0.01843
# Shuffle 500, 0.01912
# Shuffle 600, 0.01925
# Shuffle 700, 0.01754
# Shuffle 800, 0.01564
# Shuffle 900, 0.01651
# Animal grom, Day ix 7, pv = 0.00000, r2_ = 0.104, shuff = [0.083, 0.083]
# Shuffle 0, 0.01617
# Shuffle 100, 0.01826
# Shuffle 200, 0.01945
# Shuffle 300, 0.01682
# Shuffle 400, 0.02014
# Shuffle 500, 0.01706
# Shuffle 600, 0.01766
# Shuffle 700, 0.01850
# Shuffle 800, 0.02141
# Shuffle 900, 0.04155
# Animal grom, Day ix 8, pv = 0.00000, r2_ = 0.099, shuff = [0.080, 0.080]
# Animal POOLED grom, pv = 0.00000, r2_ = 0.174, shuff = [0.141, 0.141]
# Shuffle 0, 0.04231
# Shuffle 100, 0.03139
# Shuffle 200, 0.03268
# Shuffle 300, 0.03124
# Shuffle 400, 0.03404
# Shuffle 500, 0.03251
# Shuffle 600, 0.03414
# Shuffle 700, 0.03269
# Shuffle 800, 0.03296
# Shuffle 900, 0.03161
# Animal jeev, Day ix 0, pv = 0.00000, r2_ = 0.302, shuff = [0.246, 0.246]
# Shuffle 0, 0.01528
# Shuffle 100, 0.01819
# Shuffle 200, 0.01859
# Shuffle 300, 0.01775
# Shuffle 400, 0.01911
# Shuffle 500, 0.01842
# Shuffle 600, 0.02198
# Shuffle 700, 0.01792
# Shuffle 800, 0.01869
# Shuffle 900, 0.01796
# Animal jeev, Day ix 1, pv = 0.00000, r2_ = 0.275, shuff = [0.218, 0.219]
# Shuffle 0, 0.02123
# Shuffle 100, 0.01983
# Shuffle 200, 0.02015
# Shuffle 300, 0.01945
# Shuffle 400, 0.02040
# Shuffle 500, 0.02006
# Shuffle 600, 0.01953
# Shuffle 700, 0.02093
# Shuffle 800, 0.02026
# Shuffle 900, 0.01997
# Animal jeev, Day ix 2, pv = 0.00000, r2_ = 0.283, shuff = [0.234, 0.234]
# Shuffle 0, 0.02213
# Shuffle 100, 0.02096
# Shuffle 200, 0.02675
# Shuffle 300, 0.06323
# Shuffle 400, 0.02134
# Shuffle 500, 0.02168
# Shuffle 600, 0.02236
# Shuffle 700, 0.02117
# Shuffle 800, 0.02210
# Shuffle 900, 0.02121
# Animal jeev, Day ix 3, pv = 0.00000, r2_ = 0.175, shuff = [0.159, 0.160]
# Animal POOLED jeev, pv = 0.00000, r2_ = 0.264, shuff = [0.214, 0.215]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-10 09:39:31.942774. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.fit_predict_lomov_model()
# Out:
# Starting grom, Day 0 Mov Cat vert
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Starting jeev, Day 0 Mov Cat vert
# Bin Curson kin Size 20
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# Bin Curson kin Size 20
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# Starting grom, Day 0 Mov Cat horz
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Starting jeev, Day 0 Mov Cat horz
# Bin Curson kin Size 20
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# Bin Curson kin Size 20
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# Starting grom, Day 0 Mov Cat diag_pos
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Starting jeev, Day 0 Mov Cat diag_pos
# Bin Curson kin Size 20
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# Bin Curson kin Size 20
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# Starting grom, Day 0 Mov Cat diag_neg
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 22:17:11.077059. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_n36_eg_lo_command()
# Out:
# mov 10.1, len 34
# mov 1.0, len 25
# mov 11.1, len 58
# mov 2.0, len 27
# mov 12.1, len 58
# mov 3.0, len 15
# mov 13.1, len 90
# mov 14.1, len 60
# mov 15.0, len 19
# pop_mns -- (9, 44)
# [10.30942491  3.67602532  0.2654321   0.32330061 10.47461155 19.85500481
#  12.78170422  2.22675846  0.14017229  0.10621541  0.         20.34322912
#   0.36560388  0.39630882  7.77171297 15.85135646  4.68859818  5.93858006
#  12.21918301  5.14582825  5.22402726 12.92551005 13.84461838 14.69076141
#   2.93040233  5.02626206 10.02315879 11.19610681  9.64324986  7.06763456
#  11.64259305 22.99416764  9.51933005  5.85369222  2.67505563  5.34657064
#  21.36424656 16.47637394 27.10518351  6.75586291 21.13401575 13.05170353
#   6.62080608 11.5687962 ]
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 23:45:42.828843. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_n36_eg_lo_command(cat = 'mov')
# Out:
# mov 1.0, len 25
# mov 2.0, len 27
# mov 3.0, len 15
# mov 10.1, len 34
# mov 11.1, len 58
# mov 12.1, len 58
# mov 13.1, len 90
# mov 14.1, len 60
# mov 15.0, len 19
# pop_mns -- (9, 44)
# [10.30942491  3.67602532  0.2654321   0.32330061 10.47461155 19.85500481
#  12.78170422  2.22675846  0.14017229  0.10621541  0.         20.34322912
#   0.36560388  0.39630882  7.77171297 15.85135646  4.68859818  5.93858006
#  12.21918301  5.14582825  5.22402726 12.92551005 13.84461838 14.69076141
#   2.93040233  5.02626206 10.02315879 11.19610681  9.64324986  7.06763456
#  11.64259305 22.99416764  9.51933005  5.85369222  2.67505563  5.34657064
#  21.36424656 16.47637394 27.10518351  6.75586291 21.13401575 13.05170353
#   6.62080608 11.5687962 ]
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 23:47:50.836603. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
left_out = np.unique([11.1, 15., 13.1, 10.1, 14.1, 3., 12.1, 14.1, 1., 3., 2.])
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 23:47:44.888339. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
left_out
# Out:
# array([ 1. ,  2. ,  3. , 10.1, 11.1, 12.1, 13.1, 14.1, 15. ])
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 23:47:47.433431. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
