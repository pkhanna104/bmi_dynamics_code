# %%
from online_analysis import generalization_plots

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
save_dict = {}
for cat in ['com', 'mov']:
    print('########################################')
    print('########################################')
    print('########################################')
    print('')
    print('Starting %s'%cat)
    save_dict = generalization_plots.plot_loo_r2_overall(cat=cat, yval='r2', nshuffs=10, save_bars = True, 
                                                         save_dict=save_dict)
    #save_dict = generalization_plots.plot_loo_r2_overall(cat='mov', yval='r2', nshuffs=2, save_bars = True)

generalization_plots.bar_plot_loo_r2_overall(save_dict, 'combo_com_mov', fig4=True, 
                                                        fig5=False)
#generalization_plots.plot_loo_frac_commands_sig(cat = cat, nshuffs = 2, save=True)
# Out:
# ########################################
# ########################################
# ########################################
#
# Starting com
# ##################
# Starting Animal grom Day 0
# ##################
# done with left out
# r2 of full: 0.3016, r2 of purple LO 0.2973
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.29733, cyan r2_0.30155, shuff = [0.250, 0.252], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 1
# ##################
# done with left out
# r2 of full: 0.3597, r2 of purple LO 0.3523
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.35233, cyan r2_0.35975, shuff = [0.302, 0.302], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 2
# ##################
# done with left out
# r2 of full: 0.1254, r2 of purple LO 0.1234
# Animal grom, Day ix 2, pv = 0.00000, purple r2_ = 0.12339, cyan r2_0.12538, shuff = [0.086, 0.087], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 3
# ##################
# done with left out
# r2 of full: 0.1245, r2 of purple LO 0.1217
# Animal grom, Day ix 3, pv = 0.00000, purple r2_ = 0.12167, cyan r2_0.12448, shuff = [0.091, 0.091], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 4
# ##################
# done with left out
# r2 of full: 0.1063, r2 of purple LO 0.1041
# Animal grom, Day ix 4, pv = 0.00000, purple r2_ = 0.10407, cyan r2_0.10629, shuff = [0.066, 0.066], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 5
# ##################
# done with left out
# r2 of full: 0.1149, r2 of purple LO 0.1122
# Animal grom, Day ix 5, pv = 0.00000, purple r2_ = 0.11219, cyan r2_0.11493, shuff = [0.095, 0.095], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 6
# ##################
# done with left out
# r2 of full: 0.1645, r2 of purple LO 0.1600
# Animal grom, Day ix 6, pv = 0.00000, purple r2_ = 0.16000, cyan r2_0.16453, shuff = [0.126, 0.126], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 7
# ##################
# done with left out
# r2 of full: 0.1040, r2 of purple LO 0.1009
# Animal grom, Day ix 7, pv = 0.00000, purple r2_ = 0.10095, cyan r2_0.10402, shuff = [0.077, 0.077], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 8
# ##################
# done with left out
# r2 of full: 0.0981, r2 of purple LO 0.0946
# Animal grom, Day ix 8, pv = 0.00000, purple r2_ = 0.09464, cyan r2_0.09809, shuff = [0.075, 0.075], null_r2 -1.00000
# pv null 0.10000
# Animal POOLED grom, pv = 0.00000, r2_ purple = 0.163, r2_ cyan = 0.167, shuff = [0.130, 0.130], r2_null -1.000
# pv null 1.00000
# ##################
# Starting Animal jeev Day 0
# ##################
# done with left out
# r2 of full: 0.2963, r2 of purple LO 0.2887
# Animal jeev, Day ix 0, pv = 0.00000, purple r2_ = 0.28866, cyan r2_0.29634, shuff = [0.229, 0.229], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal jeev Day 1
# ##################
# done with left out
# r2 of full: 0.2714, r2 of purple LO 0.2623
# Animal jeev, Day ix 1, pv = 0.00000, purple r2_ = 0.26226, cyan r2_0.27140, shuff = [0.200, 0.200], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal jeev Day 2
# ##################
# done with left out
# r2 of full: 0.2716, r2 of purple LO 0.2635
# Animal jeev, Day ix 2, pv = 0.00000, purple r2_ = 0.26350, cyan r2_0.27157, shuff = [0.213, 0.213], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal jeev Day 3
# ##################
# done with left out
# r2 of full: 0.1672, r2 of purple LO 0.1573
# Animal jeev, Day ix 3, pv = 0.00000, purple r2_ = 0.15732, cyan r2_0.16719, shuff = [0.143, 0.143], null_r2 -1.00000
# pv null 0.10000
# Animal POOLED jeev, pv = 0.00000, r2_ purple = 0.243, r2_ cyan = 0.252, shuff = [0.196, 0.196], r2_null -1.000
# pv null 1.00000
# ########################################
# ########################################
# ########################################
#
# Starting mov
# ##################
# Starting Animal grom Day 0
# ##################
# done with left out
# r2 of full: 0.3016, r2 of purple LO 0.2984
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.29840, cyan r2_0.30155, shuff = [0.250, 0.252], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 1
# ##################
# done with left out
# r2 of full: 0.3595, r2 of purple LO 0.3544
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.35440, cyan r2_0.35954, shuff = [0.302, 0.302], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 2
# ##################
# done with left out
# r2 of full: 0.1254, r2 of purple LO 0.1228
# Animal grom, Day ix 2, pv = 0.00000, purple r2_ = 0.12283, cyan r2_0.12538, shuff = [0.086, 0.087], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 3
# ##################
# done with left out
# r2 of full: 0.1245, r2 of purple LO 0.1221
# Animal grom, Day ix 3, pv = 0.00000, purple r2_ = 0.12214, cyan r2_0.12448, shuff = [0.091, 0.091], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 4
# ##################
# done with left out
# r2 of full: 0.1063, r2 of purple LO 0.1038
# Animal grom, Day ix 4, pv = 0.00000, purple r2_ = 0.10378, cyan r2_0.10629, shuff = [0.066, 0.066], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 5
# ##################
# done with left out
# r2 of full: 0.1149, r2 of purple LO 0.1127
# Animal grom, Day ix 5, pv = 0.00000, purple r2_ = 0.11268, cyan r2_0.11493, shuff = [0.095, 0.095], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 6
# ##################
# done with left out
# r2 of full: 0.1645, r2 of purple LO 0.1611
# Animal grom, Day ix 6, pv = 0.00000, purple r2_ = 0.16106, cyan r2_0.16453, shuff = [0.126, 0.126], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 7
# ##################
# done with left out
# r2 of full: 0.1040, r2 of purple LO 0.1013
# Animal grom, Day ix 7, pv = 0.00000, purple r2_ = 0.10129, cyan r2_0.10402, shuff = [0.077, 0.077], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal grom Day 8
# ##################
# done with left out
# r2 of full: 0.0981, r2 of purple LO 0.0949
# Animal grom, Day ix 8, pv = 0.00000, purple r2_ = 0.09488, cyan r2_0.09809, shuff = [0.075, 0.075], null_r2 -1.00000
# pv null 0.10000
# Animal POOLED grom, pv = 0.00000, r2_ purple = 0.163, r2_ cyan = 0.167, shuff = [0.130, 0.130], r2_null -1.000
# pv null 1.00000
# ##################
# Starting Animal jeev Day 0
# ##################
# done with left out
# r2 of full: 0.2966, r2 of purple LO 0.2864
# Animal jeev, Day ix 0, pv = 0.00000, purple r2_ = 0.28639, cyan r2_0.29659, shuff = [0.229, 0.229], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal jeev Day 1
# ##################
# done with left out
# r2 of full: 0.2716, r2 of purple LO 0.2530
# Animal jeev, Day ix 1, pv = 0.00000, purple r2_ = 0.25302, cyan r2_0.27158, shuff = [0.200, 0.200], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal jeev Day 2
# ##################
# done with left out
# r2 of full: 0.2721, r2 of purple LO 0.2608
# Animal jeev, Day ix 2, pv = 0.00000, purple r2_ = 0.26077, cyan r2_0.27205, shuff = [0.213, 0.213], null_r2 -1.00000
# pv null 0.10000
# ##################
# Starting Animal jeev Day 3
# ##################
# done with left out
# r2 of full: 0.1674, r2 of purple LO 0.1604
# Animal jeev, Day ix 3, pv = 0.00000, purple r2_ = 0.16042, cyan r2_0.16743, shuff = [0.143, 0.143], null_r2 -1.00000
# pv null 0.10000
# Animal POOLED jeev, pv = 0.00000, r2_ purple = 0.240, r2_ cyan = 0.252, shuff = [0.196, 0.196], r2_null -1.000
# pv null 1.00000
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-12 00:01:07.589227. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for cat in ['mov']:
    print('########################################')
    print('########################################')
    print('########################################')
    print('')
    print('Starting %s'%cat)
    generalization_plots.plot_loo_r2_overall(cat=cat, yval='r2', nshuffs=50)
# Out:
# ########################################
# ########################################
# ########################################
#
# Starting mov
# ##################
# Starting Animal grom Day 0
# ##################
# done with left out
# r2 of full: 0.3016, r2 of purple LO 0.2984
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.29840, cyan r2_0.30155, shuff = [0.250, 0.252], null_r2 -1.00000
# ##################
# Starting Animal grom Day 1
# ##################
# done with left out
# r2 of full: 0.3595, r2 of purple LO 0.3544
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.35440, cyan r2_0.35954, shuff = [0.302, 0.302], null_r2 -1.00000
# ##################
# Starting Animal grom Day 2
# ##################
# done with left out
# r2 of full: 0.1254, r2 of purple LO 0.1228
# Animal grom, Day ix 2, pv = 0.00000, purple r2_ = 0.12283, cyan r2_0.12538, shuff = [0.086, 0.087], null_r2 -1.00000
# ##################
# Starting Animal grom Day 3
# ##################
# done with left out
# r2 of full: 0.1245, r2 of purple LO 0.1221
# Animal grom, Day ix 3, pv = 0.00000, purple r2_ = 0.12214, cyan r2_0.12448, shuff = [0.091, 0.091], null_r2 -1.00000
# ##################
# Starting Animal grom Day 4
# ##################
# done with left out
# r2 of full: 0.1063, r2 of purple LO 0.1038
# Animal grom, Day ix 4, pv = 0.00000, purple r2_ = 0.10378, cyan r2_0.10629, shuff = [0.066, 0.066], null_r2 -1.00000
# ##################
# Starting Animal grom Day 5
# ##################
# done with left out
# r2 of full: 0.1149, r2 of purple LO 0.1127
# Animal grom, Day ix 5, pv = 0.00000, purple r2_ = 0.11268, cyan r2_0.11493, shuff = [0.095, 0.095], null_r2 -1.00000
# ##################
# Starting Animal grom Day 6
# ##################
# done with left out
# r2 of full: 0.1645, r2 of purple LO 0.1611
# Animal grom, Day ix 6, pv = 0.00000, purple r2_ = 0.16106, cyan r2_0.16453, shuff = [0.126, 0.126], null_r2 -1.00000
# ##################
# Starting Animal grom Day 7
# ##################
# done with left out
# r2 of full: 0.1040, r2 of purple LO 0.1013
# Animal grom, Day ix 7, pv = 0.00000, purple r2_ = 0.10129, cyan r2_0.10402, shuff = [0.077, 0.077], null_r2 -1.00000
# ##################
# Starting Animal grom Day 8
# ##################
# done with left out
# r2 of full: 0.0981, r2 of purple LO 0.0949
# Animal grom, Day ix 8, pv = 0.00000, purple r2_ = 0.09488, cyan r2_0.09809, shuff = [0.075, 0.075], null_r2 -1.00000
# Animal POOLED grom, pv = 0.00000, r2_ purple = 0.163, r2_ cyan = 0.167, shuff = [0.130, 0.130], r2_null -1.000
# ##################
# Starting Animal jeev Day 0
# ##################
# done with left out
# r2 of full: 0.2966, r2 of purple LO 0.2864
# Animal jeev, Day ix 0, pv = 0.00000, purple r2_ = 0.28639, cyan r2_0.29659, shuff = [0.229, 0.229], null_r2 -1.00000
# ##################
# Starting Animal jeev Day 1
# ##################
# done with left out
# r2 of full: 0.2716, r2 of purple LO 0.2530
# Animal jeev, Day ix 1, pv = 0.00000, purple r2_ = 0.25302, cyan r2_0.27158, shuff = [0.200, 0.200], null_r2 -1.00000
# ##################
# Starting Animal jeev Day 2
# ##################
# done with left out
# r2 of full: 0.2721, r2 of purple LO 0.2608
# Animal jeev, Day ix 2, pv = 0.00000, purple r2_ = 0.26077, cyan r2_0.27205, shuff = [0.213, 0.213], null_r2 -1.00000
# ##################
# Starting Animal jeev Day 3
# ##################
# done with left out
# r2 of full: 0.1674, r2 of purple LO 0.1604
# Animal jeev, Day ix 3, pv = 0.00000, purple r2_ = 0.16042, cyan r2_0.16743, shuff = [0.143, 0.143], null_r2 -1.00000
# Animal POOLED jeev, pv = 0.00000, r2_ purple = 0.240, r2_ cyan = 0.252, shuff = [0.196, 0.196], r2_null -1.000
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-08 19:55:55.157946. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for cat in ['com_ang', 'com_mag']:
    print('########################################')
    print('########################################')
    print('########################################')
    print('')
    print('Starting %s'%cat)
    save_dict = generalization_plots.plot_loo_r2_overall(cat=cat, yval='r2', nshuffs=20, save_bars = True)
    generalization_plots.bar_plot_loo_r2_overall(save_dict, cat)
# Out:
# ########################################
# ########################################
# ########################################
#
# Starting com_ang
# ##################
# Starting Animal grom Day 0
# ##################
# done with left out
# r2 of full: 0.3016, r2 of purple LO 0.2932
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.29321, cyan r2_0.30155, shuff = [0.250, 0.252], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 1
# ##################
# done with left out
# r2 of full: 0.3595, r2 of purple LO 0.3374
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.33738, cyan r2_0.35954, shuff = [0.302, 0.302], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 2
# ##################
# done with left out
# r2 of full: 0.1254, r2 of purple LO 0.1185
# Animal grom, Day ix 2, pv = 0.00000, purple r2_ = 0.11853, cyan r2_0.12538, shuff = [0.086, 0.087], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 3
# ##################
# done with left out
# r2 of full: 0.1245, r2 of purple LO 0.1143
# Animal grom, Day ix 3, pv = 0.00000, purple r2_ = 0.11431, cyan r2_0.12448, shuff = [0.091, 0.091], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 4
# ##################
# done with left out
# r2 of full: 0.1063, r2 of purple LO 0.0970
# Animal grom, Day ix 4, pv = 0.00000, purple r2_ = 0.09695, cyan r2_0.10629, shuff = [0.066, 0.066], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 5
# ##################
# done with left out
# r2 of full: 0.1149, r2 of purple LO 0.1070
# Animal grom, Day ix 5, pv = 0.00000, purple r2_ = 0.10703, cyan r2_0.11493, shuff = [0.095, 0.095], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 6
# ##################
# done with left out
# r2 of full: 0.1645, r2 of purple LO 0.1475
# Animal grom, Day ix 6, pv = 0.00000, purple r2_ = 0.14752, cyan r2_0.16453, shuff = [0.126, 0.126], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 7
# ##################
# done with left out
# r2 of full: 0.1040, r2 of purple LO 0.0928
# Animal grom, Day ix 7, pv = 0.00000, purple r2_ = 0.09285, cyan r2_0.10402, shuff = [0.077, 0.077], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 8
# ##################
# done with left out
# r2 of full: 0.0981, r2 of purple LO 0.0865
# Animal grom, Day ix 8, pv = 0.00000, purple r2_ = 0.08655, cyan r2_0.09809, shuff = [0.075, 0.075], null_r2 -1.00000
# pv null 0.05000
# Animal POOLED grom, pv = 0.00000, r2_ purple = 0.155, r2_ cyan = 0.167, shuff = [0.130, 0.130], r2_null -1.000
# pv null 1.00000
# ##################
# Starting Animal jeev Day 0
# ##################
# done with left out
# r2 of full: 0.2966, r2 of purple LO 0.2623
# Animal jeev, Day ix 0, pv = 0.00000, purple r2_ = 0.26229, cyan r2_0.29659, shuff = [0.229, 0.229], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal jeev Day 1
# ##################
# done with left out
# r2 of full: 0.2715, r2 of purple LO 0.2315
# Animal jeev, Day ix 1, pv = 0.00000, purple r2_ = 0.23155, cyan r2_0.27152, shuff = [0.200, 0.200], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal jeev Day 2
# ##################
# done with left out
# r2 of full: 0.2716, r2 of purple LO 0.2405
# Animal jeev, Day ix 2, pv = 0.00000, purple r2_ = 0.24047, cyan r2_0.27163, shuff = [0.213, 0.213], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal jeev Day 3
# ##################
# done with left out
# r2 of full: 0.1674, r2 of purple LO 0.1286
# Animal jeev, Day ix 3, pv = 1.00000, purple r2_ = 0.12864, cyan r2_0.16743, shuff = [0.143, 0.143], null_r2 -1.00000
# pv null 0.05000
# Animal POOLED jeev, pv = 0.00000, r2_ purple = 0.216, r2_ cyan = 0.252, shuff = [0.196, 0.196], r2_null -1.000
# pv null 1.00000
# ########################################
# ########################################
# ########################################
#
# Starting com_mag
# ##################
# Starting Animal grom Day 0
# ##################
# done with left out
# r2 of full: 0.3016, r2 of purple LO 0.2920
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.29199, cyan r2_0.30155, shuff = [0.250, 0.252], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 1
# ##################
# done with left out
# r2 of full: 0.3595, r2 of purple LO 0.3452
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.34520, cyan r2_0.35954, shuff = [0.302, 0.302], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 2
# ##################
# done with left out
# r2 of full: 0.1254, r2 of purple LO 0.1202
# Animal grom, Day ix 2, pv = 0.00000, purple r2_ = 0.12016, cyan r2_0.12538, shuff = [0.086, 0.087], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 3
# ##################
# done with left out
# r2 of full: 0.1245, r2 of purple LO 0.1191
# Animal grom, Day ix 3, pv = 0.00000, purple r2_ = 0.11912, cyan r2_0.12448, shuff = [0.091, 0.091], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 4
# ##################
# done with left out
# r2 of full: 0.1063, r2 of purple LO 0.1019
# Animal grom, Day ix 4, pv = 0.00000, purple r2_ = 0.10187, cyan r2_0.10629, shuff = [0.066, 0.066], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 5
# ##################
# done with left out
# r2 of full: 0.1149, r2 of purple LO 0.1089
# Animal grom, Day ix 5, pv = 0.00000, purple r2_ = 0.10893, cyan r2_0.11493, shuff = [0.095, 0.095], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 6
# ##################
# done with left out
# r2 of full: 0.1645, r2 of purple LO 0.1557
# Animal grom, Day ix 6, pv = 0.00000, purple r2_ = 0.15568, cyan r2_0.16453, shuff = [0.126, 0.126], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 7
# ##################
# done with left out
# r2 of full: 0.1040, r2 of purple LO 0.0972
# Animal grom, Day ix 7, pv = 0.00000, purple r2_ = 0.09716, cyan r2_0.10402, shuff = [0.077, 0.077], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal grom Day 8
# ##################
# done with left out
# r2 of full: 0.0981, r2 of purple LO 0.0920
# Animal grom, Day ix 8, pv = 0.00000, purple r2_ = 0.09199, cyan r2_0.09809, shuff = [0.075, 0.075], null_r2 -1.00000
# pv null 0.05000
# Animal POOLED grom, pv = 0.00000, r2_ purple = 0.159, r2_ cyan = 0.167, shuff = [0.130, 0.130], r2_null -1.000
# pv null 1.00000
# ##################
# Starting Animal jeev Day 0
# ##################
# done with left out
# r2 of full: 0.2966, r2 of purple LO 0.2827
# Animal jeev, Day ix 0, pv = 0.00000, purple r2_ = 0.28271, cyan r2_0.29659, shuff = [0.229, 0.229], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal jeev Day 1
# ##################
# done with left out
# r2 of full: 0.2716, r2 of purple LO 0.2548
# Animal jeev, Day ix 1, pv = 0.00000, purple r2_ = 0.25477, cyan r2_0.27158, shuff = [0.200, 0.200], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal jeev Day 2
# ##################
# done with left out
# r2 of full: 0.2721, r2 of purple LO 0.2589
# Animal jeev, Day ix 2, pv = 0.00000, purple r2_ = 0.25891, cyan r2_0.27205, shuff = [0.213, 0.213], null_r2 -1.00000
# pv null 0.05000
# ##################
# Starting Animal jeev Day 3
# ##################
# done with left out
# r2 of full: 0.1674, r2 of purple LO 0.1548
# Animal jeev, Day ix 3, pv = 0.00000, purple r2_ = 0.15479, cyan r2_0.16743, shuff = [0.143, 0.143], null_r2 -1.00000
# pv null 0.05000
# Animal POOLED jeev, pv = 0.00000, r2_ purple = 0.238, r2_ cyan = 0.252, shuff = [0.196, 0.196], r2_null -1.000
# pv null 1.00000
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-10 18:11:26.938843. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
save_bars = generalization_plots.fit_predict_lomov_model(nshuffs=10)
# Out:
# ############ starting vert ##############
# online_analysis/generate_models_utils.py:144: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(pref+hdf[hdfix:])
# Starting grom, Day 0 Mov Cat vert
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/computation/check.py:19: UserWarning: The installed version of numexpr 2.4 is not supported in pandas and will be not be used
# The minimum supported version is 2.6.1
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   return getattr(obj, method)(*args, **kwds)
# grom, 0: r2 0.315, shuff = [0.256, 0.257], pv = 0.00000
# Starting grom, Day 1 Mov Cat vert
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# grom, 1: r2 0.381, shuff = [0.320, 0.321], pv = 0.00000
# Starting grom, Day 2 Mov Cat vert
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# grom, 2: r2 0.131, shuff = [0.090, 0.091], pv = 0.00000
# Starting grom, Day 3 Mov Cat vert
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# grom, 3: r2 0.119, shuff = [0.086, 0.086], pv = 0.00000
# Starting grom, Day 4 Mov Cat vert
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# grom, 4: r2 0.110, shuff = [0.068, 0.068], pv = 0.00000
# Starting grom, Day 5 Mov Cat vert
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# grom, 5: r2 0.117, shuff = [0.094, 0.095], pv = 0.00000
# Starting grom, Day 6 Mov Cat vert
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# grom, 6: r2 0.164, shuff = [0.123, 0.123], pv = 0.00000
# Starting grom, Day 7 Mov Cat vert
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# grom, 7: r2 0.093, shuff = [0.073, 0.073], pv = 0.00000
# Starting grom, Day 8 Mov Cat vert
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# grom, 8: r2 0.090, shuff = [0.069, 0.069], pv = 0.00000
# POOLED grom, r2 0.169, shuff = [0.131, 0.131], pv = 0.00000
# Starting jeev, Day 0 Mov Cat vert
# Bin Curson kin Size 20
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# Bin Curson kin Size 20
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# jeev, 0: r2 0.286, shuff = [0.228, 0.228], pv = 0.00000
# Starting jeev, Day 1 Mov Cat vert
# Bin Curson kin Size 20
# 16 (38, 7)
# new trial offset 16, total trls in this blk 16
# Bin Curson kin Size 20
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 158, total trls in this blk 142
# jeev, 1: r2 0.272, shuff = [0.222, 0.223], pv = 0.00000
# Starting jeev, Day 2 Mov Cat vert
# Bin Curson kin Size 20
# 90 (16, 7)
# new trial offset 90, total trls in this blk 90
# Bin Curson kin Size 20
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 218, total trls in this blk 128
# jeev, 2: r2 0.270, shuff = [0.222, 0.222], pv = 0.00000
# Starting jeev, Day 3 Mov Cat vert
# Bin Curson kin Size 20
# 80 (17, 7)
# new trial offset 80, total trls in this blk 80
# Bin Curson kin Size 20
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Keeping JEEV target 2 2.7
# Correcting JEEV target 2 -0.4
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 0.1
# Correcting JEEV target 2 -0.1
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.9
# Correcting JEEV target 2 -0.0
# Correcting JEEV target 2 -0.6
# Correcting JEEV target 2 -0.3
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.2
# new trial offset 176, total trls in this blk 96
# jeev, 3: r2 0.177, shuff = [0.152, 0.153], pv = 0.00000
# POOLED jeev, r2 0.251, shuff = [0.206, 0.206], pv = 0.00000
# ############ starting horz ##############
# Starting grom, Day 0 Mov Cat horz
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# grom, 0: r2 0.300, shuff = [0.263, 0.264], pv = 0.00000
# Starting grom, Day 1 Mov Cat horz
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# grom, 1: r2 0.332, shuff = [0.280, 0.281], pv = 0.00000
# Starting grom, Day 2 Mov Cat horz
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# grom, 2: r2 0.110, shuff = [0.073, 0.074], pv = 0.00000
# Starting grom, Day 3 Mov Cat horz
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# grom, 3: r2 0.126, shuff = [0.093, 0.093], pv = 0.00000
# Starting grom, Day 4 Mov Cat horz
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# grom, 4: r2 0.100, shuff = [0.063, 0.064], pv = 0.00000
# Starting grom, Day 5 Mov Cat horz
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# grom, 5: r2 0.110, shuff = [0.099, 0.099], pv = 0.00000
# Starting grom, Day 6 Mov Cat horz
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# grom, 6: r2 0.165, shuff = [0.126, 0.126], pv = 0.00000
# Starting grom, Day 7 Mov Cat horz
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# grom, 7: r2 0.105, shuff = [0.075, 0.076], pv = 0.00000
# Starting grom, Day 8 Mov Cat horz
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# grom, 8: r2 0.105, shuff = [0.081, 0.082], pv = 0.00000
# POOLED grom, r2 0.161, shuff = [0.128, 0.128], pv = 0.00000
# Starting jeev, Day 0 Mov Cat horz
# Bin Curson kin Size 20
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# Bin Curson kin Size 20
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# jeev, 0: r2 0.309, shuff = [0.256, 0.256], pv = 0.00000
# Starting jeev, Day 1 Mov Cat horz
# Bin Curson kin Size 20
# 16 (38, 7)
# new trial offset 16, total trls in this blk 16
# Bin Curson kin Size 20
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 158, total trls in this blk 142
# jeev, 1: r2 0.250, shuff = [0.191, 0.191], pv = 0.00000
# Starting jeev, Day 2 Mov Cat horz
# Bin Curson kin Size 20
# 90 (16, 7)
# new trial offset 90, total trls in this blk 90
# Bin Curson kin Size 20
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 218, total trls in this blk 128
# jeev, 2: r2 0.278, shuff = [0.223, 0.224], pv = 0.00000
# Starting jeev, Day 3 Mov Cat horz
# Bin Curson kin Size 20
# 80 (17, 7)
# new trial offset 80, total trls in this blk 80
# Bin Curson kin Size 20
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Keeping JEEV target 2 2.7
# Correcting JEEV target 2 -0.4
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 0.1
# Correcting JEEV target 2 -0.1
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.9
# Correcting JEEV target 2 -0.0
# Correcting JEEV target 2 -0.6
# Correcting JEEV target 2 -0.3
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.2
# new trial offset 176, total trls in this blk 96
# jeev, 3: r2 0.166, shuff = [0.148, 0.148], pv = 0.00000
# POOLED jeev, r2 0.251, shuff = [0.204, 0.205], pv = 0.00000
# ############ starting diag_pos ##############
# Starting grom, Day 0 Mov Cat diag_pos
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# grom, 0: r2 0.316, shuff = [0.265, 0.266], pv = 0.00000
# Starting grom, Day 1 Mov Cat diag_pos
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# grom, 1: r2 0.362, shuff = [0.320, 0.321], pv = 0.00000
# Starting grom, Day 2 Mov Cat diag_pos
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# grom, 2: r2 0.126, shuff = [0.090, 0.090], pv = 0.00000
# Starting grom, Day 3 Mov Cat diag_pos
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# grom, 3: r2 0.132, shuff = [0.094, 0.095], pv = 0.00000
# Starting grom, Day 4 Mov Cat diag_pos
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# grom, 4: r2 0.111, shuff = [0.066, 0.066], pv = 0.00000
# Starting grom, Day 5 Mov Cat diag_pos
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# grom, 5: r2 0.120, shuff = [0.095, 0.095], pv = 0.00000
# Starting grom, Day 6 Mov Cat diag_pos
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# grom, 6: r2 0.171, shuff = [0.129, 0.129], pv = 0.00000
# Starting grom, Day 7 Mov Cat diag_pos
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# grom, 7: r2 0.111, shuff = [0.080, 0.080], pv = 0.00000
# Starting grom, Day 8 Mov Cat diag_pos
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# grom, 8: r2 0.100, shuff = [0.076, 0.076], pv = 0.00000
# POOLED grom, r2 0.172, shuff = [0.135, 0.135], pv = 0.00000
# Starting jeev, Day 0 Mov Cat diag_pos
# Bin Curson kin Size 20
# 199 (15, 7)
# new trial offset 199, total trls in this blk 199
# Bin Curson kin Size 20
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# jeev, 0: r2 0.291, shuff = [0.210, 0.210], pv = 0.00000
# Starting jeev, Day 1 Mov Cat diag_pos
# Bin Curson kin Size 20
# 16 (38, 7)
# new trial offset 16, total trls in this blk 16
# Bin Curson kin Size 20
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 158, total trls in this blk 142
# jeev, 1: r2 0.175, shuff = [0.117, 0.117], pv = 0.00000
# Starting jeev, Day 2 Mov Cat diag_pos
# Bin Curson kin Size 20
# 90 (16, 7)
# new trial offset 90, total trls in this blk 90
# Bin Curson kin Size 20
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 218, total trls in this blk 128
# jeev, 2: r2 0.243, shuff = [0.182, 0.182], pv = 0.00000
# Starting jeev, Day 3 Mov Cat diag_pos
# Bin Curson kin Size 20
# 80 (17, 7)
# new trial offset 80, total trls in this blk 80
# Bin Curson kin Size 20
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Keeping JEEV target 2 2.7
# Correcting JEEV target 2 -0.4
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 0.1
# Correcting JEEV target 2 -0.1
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.9
# Correcting JEEV target 2 -0.0
# Correcting JEEV target 2 -0.6
# Correcting JEEV target 2 -0.3
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.2
# new trial offset 176, total trls in this blk 96
# jeev, 3: r2 0.139, shuff = [0.123, 0.124], pv = 0.00000
# POOLED jeev, r2 0.212, shuff = [0.158, 0.158], pv = 0.00000
# ############ starting diag_neg ##############
# Starting grom, Day 0 Mov Cat diag_neg
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# grom, 0: r2 0.287, shuff = [0.236, 0.238], pv = 0.00000
# Starting grom, Day 1 Mov Cat diag_neg
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# grom, 1: r2 0.383, shuff = [0.316, 0.317], pv = 0.00000
# Starting grom, Day 2 Mov Cat diag_neg
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# grom, 2: r2 0.141, shuff = [0.101, 0.101], pv = 0.00000
# Starting grom, Day 3 Mov Cat diag_neg
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# grom, 3: r2 0.127, shuff = [0.096, 0.096], pv = 0.00000
# Starting grom, Day 4 Mov Cat diag_neg
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# grom, 4: r2 0.107, shuff = [0.071, 0.072], pv = 0.00000
# Starting grom, Day 5 Mov Cat diag_neg
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# grom, 5: r2 0.112, shuff = [0.099, 0.099], pv = 0.00000
# Starting grom, Day 6 Mov Cat diag_neg
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# grom, 6: r2 0.164, shuff = [0.133, 0.133], pv = 0.00000
# Starting grom, Day 7 Mov Cat diag_neg
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# grom, 7: r2 0.097, shuff = [0.079, 0.079], pv = 0.00000
# Starting grom, Day 8 Mov Cat diag_neg
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# grom, 8: r2 0.093, shuff = [0.071, 0.071], pv = 0.00000
# POOLED grom, r2 0.168, shuff = [0.134, 0.134], pv = 0.00000
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-11 22:22:34.009493. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_bars(save_bars)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-11 22:40:01.868175. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_n36_eg_lo_command()
# Out:
# mov 10.1, len 34
# mov 1.0, len 25
# mov 11.1, len 58
# mov 2.0, len 27
# mov 12.1, len 58
# mov 3.0, len 15
# mov 13.1, len 90
# mov 14.1, len 60
# mov 15.0, len 19
# pop_mns -- (9, 44)
# [10.30942491  3.67602532  0.2654321   0.32330061 10.47461155 19.85500481
#  12.78170422  2.22675846  0.14017229  0.10621541  0.         20.34322912
#   0.36560388  0.39630882  7.77171297 15.85135646  4.68859818  5.93858006
#  12.21918301  5.14582825  5.22402726 12.92551005 13.84461838 14.69076141
#   2.93040233  5.02626206 10.02315879 11.19610681  9.64324986  7.06763456
#  11.64259305 22.99416764  9.51933005  5.85369222  2.67505563  5.34657064
#  21.36424656 16.47637394 27.10518351  6.75586291 21.13401575 13.05170353
#   6.62080608 11.5687962 ]
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-10 18:42:14.668592. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_n36_eg_lo_command(cat = 'mov')
# Out:
# mov 1.0, len 25
# mov 2.0, len 27
# mov 3.0, len 15
# mov 10.1, len 34
# mov 11.1, len 58
# mov 12.1, len 58
# mov 13.1, len 90
# mov 14.1, len 60
# mov 15.0, len 19
# pop_mns -- (9, 44)
# [10.30942491  3.67602532  0.2654321   0.32330061 10.47461155 19.85500481
#  12.78170422  2.22675846  0.14017229  0.10621541  0.         20.34322912
#   0.36560388  0.39630882  7.77171297 15.85135646  4.68859818  5.93858006
#  12.21918301  5.14582825  5.22402726 12.92551005 13.84461838 14.69076141
#   2.93040233  5.02626206 10.02315879 11.19610681  9.64324986  7.06763456
#  11.64259305 22.99416764  9.51933005  5.85369222  2.67505563  5.34657064
#  21.36424656 16.47637394 27.10518351  6.75586291 21.13401575 13.05170353
#   6.62080608 11.5687962 ]
# Number of dim 44, number of obs 9
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-10 18:42:28.530290. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
left_out = np.unique([11.1, 15., 13.1, 10.1, 14.1, 3., 12.1, 14.1, 1., 3., 2.])
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 23:47:44.888339. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
left_out
# Out:
# array([ 1. ,  2. ,  3. , 10.1, 11.1, 12.1, 13.1, 14.1, 15. ])
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-11 23:47:47.433431. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
tmp = generalization_plots.plot_loo_frac_commands_sig(cat = 'com', nshuffs=20, save=True)
# Out:
# Spks shape: 11397, 44
# Shuff 0, tm = 0.000
# Su Pv grom: 0 = 0.00000
# Pop Pv grom: 0 = 0.00000
# Spks shape: 6866, 35
# Shuff 0, tm = 0.000
# Su Pv grom: 1 = 0.00000
# Pop Pv grom: 1 = 0.00000
# Spks shape: 15451, 148
# Shuff 0, tm = 0.000
# Su Pv grom: 2 = 0.00000
# Pop Pv grom: 2 = 0.00000
# Spks shape: 14922, 53
# Shuff 0, tm = 0.000
# Su Pv grom: 3 = 0.00000
# Pop Pv grom: 3 = 0.00000
# Spks shape: 11695, 151
# Shuff 0, tm = 0.000
# Su Pv grom: 4 = 0.00000
# Pop Pv grom: 4 = 0.00000
# Spks shape: 10900, 42
# Shuff 0, tm = 0.000
# Su Pv grom: 5 = 0.00000
# Pop Pv grom: 5 = 0.00000
# Spks shape: 4224, 50
# Shuff 0, tm = 0.000
# Su Pv grom: 6 = 0.00000
# Pop Pv grom: 6 = 0.00000
# Spks shape: 5364, 48
# Shuff 0, tm = 0.000
# Su Pv grom: 7 = 0.00000
# Pop Pv grom: 7 = 0.00000
# Spks shape: 5134, 48
# Shuff 0, tm = 0.000
# Su Pv grom: 8 = 0.00000
# Pop Pv grom: 8 = 0.00000
# SU pooled grom, pv = 0.00000, mn = 1.28024, sh_mn = 1.35549, sh_5th = 1.35495
# Pop pooled grom, pv = 0.00000, mn = 14.26845, sh_mn = 15.53765, sh_5th = 15.53030
# Spks shape: 8040, 20
# Shuff 0, tm = 0.000
# Su Pv jeev: 0 = 0.00000
# Pop Pv jeev: 0 = 0.00000
# Spks shape: 4794, 20
# Shuff 0, tm = 0.000
# Su Pv jeev: 1 = 0.00000
# Pop Pv jeev: 1 = 0.00000
# Spks shape: 5089, 20
# Shuff 0, tm = 0.000
# Su Pv jeev: 2 = 0.00000
# Pop Pv jeev: 2 = 0.00000
# Spks shape: 5663, 21
# Shuff 0, tm = 0.000
# Su Pv jeev: 3 = 0.00000
# Pop Pv jeev: 3 = 0.00000
# SU pooled jeev, pv = 0.00000, mn = 1.26528, sh_mn = 1.44153, sh_5th = 1.44042
# Pop pooled jeev, pv = 0.00000, mn = 7.83534, sh_mn = 9.06764, sh_5th = 9.05890

# %%
tmp = generalization_plots.plot_loo_frac_commands_sig(cat = 'mov', nshuffs=20, save=True)
# Out:
# Spks shape: 11397, 44
# Shuff 0, tm = 0.000
# Su Pv grom: 0 = 0.00000
# Pop Pv grom: 0 = 0.00000
# Spks shape: 6866, 35
# Shuff 0, tm = 0.000
# Su Pv grom: 1 = 0.00000
# Pop Pv grom: 1 = 0.00000
# Spks shape: 15451, 148
# Shuff 0, tm = 0.000
# Su Pv grom: 2 = 0.00000
# Pop Pv grom: 2 = 0.00000
# Spks shape: 14922, 53
# Shuff 0, tm = 0.000
# Su Pv grom: 3 = 0.00000
# Pop Pv grom: 3 = 0.00000
# Spks shape: 11695, 151
# Shuff 0, tm = 0.000
# Su Pv grom: 4 = 0.00000
# Pop Pv grom: 4 = 0.00000
# Spks shape: 10900, 42
# Shuff 0, tm = 0.000
# Su Pv grom: 5 = 0.00000
# Pop Pv grom: 5 = 0.00000
# Spks shape: 4224, 50
# Shuff 0, tm = 0.000
# Su Pv grom: 6 = 0.00000
# Pop Pv grom: 6 = 0.00000
# Spks shape: 5364, 48
# Shuff 0, tm = 0.000
# Su Pv grom: 7 = 0.00000
# Pop Pv grom: 7 = 0.00000
# Spks shape: 5134, 48
# Shuff 0, tm = 0.000
# Su Pv grom: 8 = 0.00000
# Pop Pv grom: 8 = 0.00000
# SU pooled grom, pv = 0.00000, mn = 1.27566, sh_mn = 1.35549, sh_5th = 1.35495
# Pop pooled grom, pv = 0.00000, mn = 14.19970, sh_mn = 15.53765, sh_5th = 15.53030
# Spks shape: 8040, 20
# Shuff 0, tm = 0.000
# Su Pv jeev: 0 = 0.00000
# Pop Pv jeev: 0 = 0.00000
# Spks shape: 4794, 20
# Shuff 0, tm = 0.000
# Su Pv jeev: 1 = 0.00000
# Pop Pv jeev: 1 = 0.00000
# Spks shape: 5089, 20
# Shuff 0, tm = 0.000
# Su Pv jeev: 2 = 0.00000
# Pop Pv jeev: 2 = 0.00000
# Spks shape: 5663, 21
# Shuff 0, tm = 0.000
# Su Pv jeev: 3 = 0.00000
# Pop Pv jeev: 3 = 0.00000
# SU pooled jeev, pv = 0.00000, mn = 1.28946, sh_mn = 1.44153, sh_5th = 1.44042
# Pop pooled jeev, pv = 0.00000, mn = 8.02209, sh_mn = 9.06764, sh_5th = 9.05890
