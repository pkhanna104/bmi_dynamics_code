# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
generate_models.sweep_alpha_all(model_set_number=2, within_bin_shuffle = True)

#for ia, animal in enumerate(['jeev','grom']):
#     generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal = animal,
#                                                    fit_task_spec_and_general = True, 
#                                                    match_task_spec_n = True)
#     generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal = animal,
#                                                    fit_task_spec_and_general = True, 
#                                                    match_task_spec_n = True, 
#                                                    full_shuffle = True)
#     generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal= animal,
#                                                    fit_task_spec_and_general = True, 
#                                                    match_task_spec_n = True, 
#                                                    within_bin_shuffle = True)
# Out:
# online_analysis/generate_models.py:111: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# Only using 4 days
# 199 (15, 7)
# Before shuffle R2 0.2976
# Before shuffle sum
# R2 KG 0.97
# R2 KG 0.97
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.93
# R2 KG 0.93
# R2 KG 0.94
# R2 KG 0.78
# R2 KG -inf
# R2 KG 0.94
# R2 KG 0.94
# R2 KG 0.93
# R2 KG 0.91
# R2 KG -inf
# R2 KG 0.90
# R2 KG 0.94
# R2 KG 0.94
# R2 KG 0.95
# R2 KG 0.87
# After shuffle R2 0.2976
# After shuffle sum
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2428
# Before shuffle sum
# R2 KG 0.97
# R2 KG 0.97
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.95
# R2 KG 0.93
# R2 KG 0.89
# R2 KG -inf
# R2 KG 0.96
# R2 KG 0.95
# R2 KG 0.94
# R2 KG 0.90
# R2 KG 0.95
# ...

# %%
###### Figure 4 #########
plot_generated_models.plot_r2_bar_model_1(perc_increase = False, 
                                          model_set_number = 2,
                                          task_spec_ix = 2, 
                                          include_shuffs = 1)
# Out:
# Option 1
# Shuff option 1
# <img src="data:image/png;base64,..." width="287.77778540128566">
# Option 1
# Shuff option 1
# <img src="data:image/png;base64,..." width="287.77778540128566">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-15 13:45:32.854671. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
###### Scatters for condition specific differences | command #######
for mfropt in ['ultra_pooled', 'command_axis_spec']:
    plot_generated_models.plot_real_vs_pred(model_set_number = 2, min_obs = 15, cov = False, 
        use_mFR_option = mfropt, include_shuffs = 1)
# Out:
# Shuff option 1
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="884.4444678742215">
# Shuff option 1
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="972.2222479773163">
# Shuff option 1
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="901.111134982404">
# <img src="data:image/png;base64,..." width="943.3333583231332">
# Shuff option 1
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="863.3333562038569">
# <img src="data:image/png;base64,..." width="698.8889074031223">
# <img src="data:image/png;base64,..." width="695.5555739814857">
# ...
