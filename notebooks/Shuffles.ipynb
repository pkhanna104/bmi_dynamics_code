# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-15 08:53:30.800582. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#generate_models.sweep_alpha_all(model_set_number=2)
for ia, animal in enumerate(['jeev']):#,'jeev']):
    generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal = animal,
                                                   fit_task_spec_and_general = True, 
                                                   match_task_spec_n = True)
    generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal = animal,
                                                   fit_task_spec_and_general = True, 
                                                   match_task_spec_n = True, 
                                                   full_shuffle = True)
    generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal= animal,
                                                   fit_task_spec_and_general = True, 
                                                   match_task_spec_n = True, 
                                                   within_bin_shuffle = True)
# Out:
# ##############################
# ########## DAY 0 ##########
# ##############################
# 199 (15, 7)
# Before shuffle R2 0.2976
# Before shuffle sum
# After shuffle R2 0.2976
# After shuffle sum
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2428
# Before shuffle sum
# After shuffle R2 0.2428
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.27
# R2 train ix: 0.31
# R2 from model: 0.2406
# R2 train ix: 0.32
# R2 from model: 0.2317
# R2 train ix: 0.31
# R2 from model: 0.2275
# R2 train ix: 0.32
# R2 from model: 0.2289
# R2 train ix: 0.31
# R2 from model: 0.2287
# R2 train ix: 0.25
# R2 from model: 0.2550
# R2 train ix: 0.25
# R2 from model: 0.2507
# R2 train ix: 0.25
# R2 from model: 0.2492
# R2 train ix: 0.25
# R2 from model: 0.2497
# R2 train ix: 0.25
# R2 from model: 0.2511
# R2 train ix: 0.27
# R2 from model: 0.2628
# R2 train ix: 0.29
# R2 from model: 0.2554
# R2 train ix: 0.28
# R2 from model: 0.2562
# R2 train ix: 0.28
# R2 from model: 0.2562
# R2 train ix: 0.28
# R2 from model: 0.2562
# ##############################
# ########## DAY 1 ##########
# ##############################
# 16 (38, 7)
# Before shuffle R2 0.1933
# Before shuffle sum
# After shuffle R2 0.1933
# After shuffle sum
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2491
# Before shuffle sum
# After shuffle R2 0.2491
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.24
# R2 train ix: 0.20
# R2 from model: 0.1195
# R2 train ix: 0.20
# R2 from model: 0.1377
# R2 train ix: 0.19
# R2 from model: 0.1474
# R2 train ix: 0.20
# R2 from model: 0.1342
# R2 train ix: 0.20
# R2 from model: 0.1447
# R2 train ix: 0.27
# R2 from model: 0.2410
# R2 train ix: 0.25
# R2 from model: 0.2416
# R2 train ix: 0.25
# R2 from model: 0.2418
# R2 train ix: 0.25
# R2 from model: 0.2422
# R2 train ix: 0.25
# R2 from model: 0.2415
# R2 train ix: 0.23
# R2 from model: 0.2234
# R2 train ix: 0.21
# R2 from model: 0.2209
# R2 train ix: 0.21
# R2 from model: 0.2202
# R2 train ix: 0.21
# R2 from model: 0.2202
# R2 train ix: 0.21
# R2 from model: 0.2202
# ##############################
# ########## DAY 2 ##########
# ##############################
# 90 (16, 7)
# Before shuffle R2 0.2704
# Before shuffle sum
# After shuffle R2 0.2704
# After shuffle sum
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2503
# Before shuffle sum
# After shuffle R2 0.2503
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.26
# R2 train ix: 0.28
# R2 from model: 0.2287
# R2 train ix: 0.28
# R2 from model: 0.2190
# R2 train ix: 0.28
# R2 from model: 0.2212
# R2 train ix: 0.29
# R2 from model: 0.2168
# R2 train ix: 0.29
# R2 from model: 0.2133
# R2 train ix: 0.26
# R2 from model: 0.2546
# R2 train ix: 0.27
# R2 from model: 0.2520
# R2 train ix: 0.27
# R2 from model: 0.2517
# R2 train ix: 0.27
# R2 from model: 0.2488
# R2 train ix: 0.27
# R2 from model: 0.2492
# R2 train ix: 0.26
# R2 from model: 0.2555
# R2 train ix: 0.27
# R2 from model: 0.2526
# R2 train ix: 0.28
# R2 from model: 0.2498
# R2 train ix: 0.28
# R2 from model: 0.2498
# R2 train ix: 0.28
# R2 from model: 0.2498
# ##############################
# ########## DAY 3 ##########
# ##############################
# 80 (17, 7)
# Before shuffle R2 0.1908
# Before shuffle sum
# After shuffle R2 0.1908
# After shuffle sum
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.1790
# Before shuffle sum
# After shuffle R2 0.1790
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.18
# R2 train ix: 0.20
# R2 from model: 0.1577
# R2 train ix: 0.19
# R2 from model: 0.1603
# R2 train ix: 0.20
# R2 from model: 0.1522
# R2 train ix: 0.19
# R2 from model: 0.1558
# R2 train ix: 0.19
# R2 from model: 0.1581
# R2 train ix: 0.18
# R2 from model: 0.1766
# R2 train ix: 0.18
# R2 from model: 0.1768
# R2 train ix: 0.18
# R2 from model: 0.1754
# R2 train ix: 0.18
# R2 from model: 0.1778
# R2 train ix: 0.18
# R2 from model: 0.1781
# R2 train ix: 0.19
# R2 from model: 0.1744
# R2 train ix: 0.19
# R2 from model: 0.1761
# R2 train ix: 0.18
# R2 from model: 0.1741
# R2 train ix: 0.18
# R2 from model: 0.1741
# R2 train ix: 0.18
# R2 from model: 0.1741
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_models_to_pred_mn_diffs_model_set2.h5
# ##############################
# ########## DAY 0 ##########
# ##############################
# 199 (15, 7)
# Before shuffle R2 0.2976
# Before shuffle sum
# After shuffle R2 0.2976
# After shuffle sum
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2428
# Before shuffle sum
# After shuffle R2 0.2428
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.26
# R2 train ix: 0.29
# R2 from model: 0.2338
# R2 train ix: 0.30
# R2 from model: 0.2273
# R2 train ix: 0.30
# R2 from model: 0.2320
# R2 train ix: 0.30
# R2 from model: 0.2327
# R2 train ix: 0.30
# R2 from model: 0.2299
# R2 train ix: 0.24
# R2 from model: 0.2506
# R2 train ix: 0.24
# R2 from model: 0.2492
# R2 train ix: 0.24
# R2 from model: 0.2505
# R2 train ix: 0.24
# R2 from model: 0.2509
# R2 train ix: 0.24
# R2 from model: 0.2500
# R2 train ix: 0.26
# R2 from model: 0.2552
# R2 train ix: 0.27
# R2 from model: 0.2527
# R2 train ix: 0.27
# R2 from model: 0.2519
# R2 train ix: 0.27
# R2 from model: 0.2519
# R2 train ix: 0.27
# R2 from model: 0.2519
# ##############################
# ########## DAY 1 ##########
# ##############################
# 16 (38, 7)
# Before shuffle R2 0.1933
# Before shuffle sum
# After shuffle R2 0.1933
# After shuffle sum
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2491
# Before shuffle sum
# After shuffle R2 0.2491
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.24
# R2 train ix: 0.19
# R2 from model: 0.1477
# R2 train ix: 0.19
# R2 from model: 0.1234
# R2 train ix: 0.19
# R2 from model: 0.1403
# R2 train ix: 0.19
# R2 from model: 0.1476
# R2 train ix: 0.19
# R2 from model: 0.1510
# R2 train ix: 0.24
# R2 from model: 0.2386
# R2 train ix: 0.24
# R2 from model: 0.2416
# R2 train ix: 0.24
# R2 from model: 0.2412
# R2 train ix: 0.24
# R2 from model: 0.2406
# R2 train ix: 0.24
# R2 from model: 0.2402
# R2 train ix: 0.20
# R2 from model: 0.2129
# R2 train ix: 0.20
# R2 from model: 0.2012
# R2 train ix: 0.21
# R2 from model: 0.2123
# R2 train ix: 0.21
# R2 from model: 0.2123
# R2 train ix: 0.21
# R2 from model: 0.2123
# ##############################
# ########## DAY 2 ##########
# ##############################
# 90 (16, 7)
# Before shuffle R2 0.2704
# Before shuffle sum
# After shuffle R2 0.2704
# After shuffle sum
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2503
# Before shuffle sum
# After shuffle R2 0.2503
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.25
# R2 train ix: 0.27
# R2 from model: 0.2173
# R2 train ix: 0.28
# R2 from model: 0.2175
# R2 train ix: 0.27
# R2 from model: 0.2175
# R2 train ix: 0.28
# R2 from model: 0.2203
# R2 train ix: 0.27
# R2 from model: 0.2193
# R2 train ix: 0.25
# R2 from model: 0.2496
# R2 train ix: 0.25
# R2 from model: 0.2481
# R2 train ix: 0.26
# R2 from model: 0.2463
# R2 train ix: 0.26
# R2 from model: 0.2456
# R2 train ix: 0.26
# R2 from model: 0.2473
# R2 train ix: 0.26
# R2 from model: 0.2474
# R2 train ix: 0.27
# R2 from model: 0.2446
# R2 train ix: 0.26
# R2 from model: 0.2463
# R2 train ix: 0.26
# R2 from model: 0.2463
# R2 train ix: 0.26
# R2 from model: 0.2463
# ##############################
# ########## DAY 3 ##########
# ##############################
# 80 (17, 7)
# Before shuffle R2 0.1908
# Before shuffle sum
# After shuffle R2 0.1908
# After shuffle sum
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.1790
# Before shuffle sum
# After shuffle R2 0.1790
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.18
# R2 train ix: 0.19
# R2 from model: 0.1627
# R2 train ix: 0.19
# R2 from model: 0.1577
# R2 train ix: 0.19
# R2 from model: 0.1526
# R2 train ix: 0.19
# R2 from model: 0.1574
# R2 train ix: 0.19
# R2 from model: 0.1555
# R2 train ix: 0.18
# R2 from model: 0.1788
# R2 train ix: 0.19
# R2 from model: 0.1753
# R2 train ix: 0.19
# R2 from model: 0.1740
# R2 train ix: 0.19
# R2 from model: 0.1731
# R2 train ix: 0.19
# R2 from model: 0.1722
# R2 train ix: 0.18
# R2 from model: 0.1749
# R2 train ix: 0.19
# R2 from model: 0.1747
# R2 train ix: 0.19
# R2 from model: 0.1737
# R2 train ix: 0.19
# R2 from model: 0.1737
# R2 train ix: 0.19
# R2 from model: 0.1737
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_models_to_pred_mn_diffs_model_set2_full_shuff0.h5
# ##############################
# ########## DAY 0 ##########
# ##############################
# 199 (15, 7)
# Before shuffle R2 0.2976
# Before shuffle sum
# online_analysis/util_fcns.py:248: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - np.sum(SSR_i)/np.sum(SST_i)
# R2 KG 0.97
# R2 KG 0.97
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.93
# R2 KG 0.93
# R2 KG 0.94
# R2 KG 0.78
# R2 KG -inf
# R2 KG 0.94
# R2 KG 0.94
# R2 KG 0.93
# R2 KG 0.91
# R2 KG -inf
# R2 KG 0.90
# R2 KG 0.94
# R2 KG 0.94
# R2 KG 0.95
# R2 KG 0.87
# After shuffle R2 0.2976
# After shuffle sum
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2428
# Before shuffle sum
# R2 KG 0.97
# R2 KG 0.97
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.95
# R2 KG 0.93
# R2 KG 0.89
# R2 KG -inf
# R2 KG 0.96
# R2 KG 0.95
# R2 KG 0.94
# R2 KG 0.90
# R2 KG 0.95
# R2 KG 0.96
# R2 KG 0.94
# R2 KG 0.87
# R2 KG 0.92
# After shuffle R2 0.2428
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.26
# R2 train ix: 0.30
# R2 from model: 0.2267
# R2 train ix: 0.30
# R2 from model: 0.2292
# R2 train ix: 0.30
# R2 from model: 0.2310
# R2 train ix: 0.30
# R2 from model: 0.2302
# R2 train ix: 0.30
# R2 from model: 0.2328
# R2 train ix: 0.24
# R2 from model: 0.2477
# R2 train ix: 0.25
# R2 from model: 0.2462
# R2 train ix: 0.24
# R2 from model: 0.2458
# R2 train ix: 0.24
# R2 from model: 0.2456
# R2 train ix: 0.24
# R2 from model: 0.2472
# R2 train ix: 0.27
# R2 from model: 0.2524
# R2 train ix: 0.27
# R2 from model: 0.2523
# R2 train ix: 0.27
# R2 from model: 0.2528
# R2 train ix: 0.27
# R2 from model: 0.2528
# R2 train ix: 0.27
# R2 from model: 0.2528
# ##############################
# ########## DAY 1 ##########
# ##############################
# 16 (38, 7)
# Before shuffle R2 0.1933
# Before shuffle sum
# R2 KG 0.99
# R2 KG 0.95
# R2 KG 0.97
# R2 KG 0.99
# R2 KG -inf
# R2 KG 0.51
# R2 KG 0.99
# R2 KG 0.97
# R2 KG 0.95
# R2 KG 0.88
# R2 KG -5.25
# R2 KG 0.87
# R2 KG 0.95
# R2 KG 0.93
# R2 KG 0.90
# R2 KG -inf
# R2 KG 0.96
# R2 KG 0.95
# R2 KG 0.19
# R2 KG 0.57
# After shuffle R2 0.1933
# After shuffle sum
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2491
# Before shuffle sum
# R2 KG 0.98
# R2 KG 0.96
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.96
# R2 KG 0.94
# R2 KG 0.92
# R2 KG -inf
# R2 KG 0.94
# R2 KG 0.96
# R2 KG 0.92
# R2 KG 0.88
# R2 KG -inf
# R2 KG 0.93
# R2 KG 0.95
# R2 KG 0.94
# R2 KG 0.89
# R2 KG 0.94
# After shuffle R2 0.2491
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.24
# R2 train ix: 0.19
# R2 from model: 0.1322
# R2 train ix: 0.19
# R2 from model: 0.1439
# R2 train ix: 0.20
# R2 from model: 0.1446
# R2 train ix: 0.20
# R2 from model: 0.1448
# R2 train ix: 0.19
# R2 from model: 0.1453
# R2 train ix: 0.26
# R2 from model: 0.2412
# R2 train ix: 0.24
# R2 from model: 0.2386
# R2 train ix: 0.24
# R2 from model: 0.2378
# R2 train ix: 0.24
# R2 from model: 0.2380
# R2 train ix: 0.24
# R2 from model: 0.2391
# R2 train ix: 0.22
# R2 from model: 0.2088
# R2 train ix: 0.22
# R2 from model: 0.2195
# R2 train ix: 0.22
# R2 from model: 0.2201
# R2 train ix: 0.22
# R2 from model: 0.2201
# R2 train ix: 0.22
# R2 from model: 0.2201
# ##############################
# ########## DAY 2 ##########
# ##############################
# 90 (16, 7)
# Before shuffle R2 0.2704
# Before shuffle sum
# R2 KG 0.96
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.84
# R2 KG 0.96
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.97
# R2 KG 0.93
# R2 KG 0.95
# R2 KG -inf
# R2 KG 0.91
# R2 KG 0.88
# R2 KG 0.92
# R2 KG 0.94
# R2 KG 0.83
# R2 KG 0.93
# R2 KG 0.94
# R2 KG 0.91
# After shuffle R2 0.2704
# After shuffle sum
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.2503
# Before shuffle sum
# R2 KG 0.97
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.95
# R2 KG -inf
# R2 KG 1.00
# R2 KG 0.99
# R2 KG 0.97
# R2 KG 0.94
# R2 KG 0.95
# R2 KG 0.60
# R2 KG 0.95
# R2 KG 0.91
# R2 KG 0.94
# R2 KG 0.93
# R2 KG 0.88
# R2 KG 0.94
# R2 KG 0.95
# R2 KG 0.91
# After shuffle R2 0.2503
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.25
# R2 train ix: 0.25
# R2 from model: 0.2252
# R2 train ix: 0.26
# R2 from model: 0.2288
# R2 train ix: 0.27
# R2 from model: 0.2193
# R2 train ix: 0.26
# R2 from model: 0.2243
# R2 train ix: 0.28
# R2 from model: 0.2163
# R2 train ix: 0.24
# R2 from model: 0.2529
# R2 train ix: 0.23
# R2 from model: 0.2506
# R2 train ix: 0.24
# R2 from model: 0.2456
# R2 train ix: 0.24
# R2 from model: 0.2470
# R2 train ix: 0.24
# R2 from model: 0.2422
# R2 train ix: 0.24
# R2 from model: 0.2493
# R2 train ix: 0.25
# R2 from model: 0.2467
# R2 train ix: 0.26
# R2 from model: 0.2433
# R2 train ix: 0.26
# R2 from model: 0.2433
# R2 train ix: 0.26
# R2 from model: 0.2433
# ##############################
# ########## DAY 3 ##########
# ##############################
# 80 (17, 7)
# Before shuffle R2 0.1908
# Before shuffle sum
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 1.00
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.97
# R2 KG 0.97
# R2 KG 0.99
# R2 KG 0.95
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.97
# R2 KG 0.97
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.98
# R2 KG -inf
# R2 KG 0.99
# After shuffle R2 0.1908
# After shuffle sum
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# Before shuffle R2 0.1790
# Before shuffle sum
# R2 KG 1.00
# R2 KG 0.98
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 1.00
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.97
# R2 KG 0.96
# R2 KG 0.97
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.96
# R2 KG 0.93
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.90
# R2 KG 0.98
# R2 KG 0.99
# R2 KG 0.98
# R2 KG 0.96
# R2 KG -inf
# R2 KG 0.98
# After shuffle R2 0.1790
# After shuffle sum
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# R2 again, 0.18
# R2 train ix: 0.19
# R2 from model: 0.1633
# R2 train ix: 0.19
# R2 from model: 0.1569
# R2 train ix: 0.19
# R2 from model: 0.1563
# R2 train ix: 0.19
# R2 from model: 0.1583
# R2 train ix: 0.19
# R2 from model: 0.1590
# R2 train ix: 0.17
# R2 from model: 0.1789
# R2 train ix: 0.17
# R2 from model: 0.1743
# R2 train ix: 0.17
# R2 from model: 0.1740
# R2 train ix: 0.17
# R2 from model: 0.1763
# R2 train ix: 0.17
# R2 from model: 0.1765
# R2 train ix: 0.18
# R2 from model: 0.1769
# R2 train ix: 0.19
# R2 from model: 0.1733
# R2 train ix: 0.18
# R2 from model: 0.1752
# R2 train ix: 0.18
# R2 from model: 0.1752
# R2 train ix: 0.18
# R2 from model: 0.1752
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_models_to_pred_mn_diffs_model_set2_within_bin_shuff0.h5
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-15 10:21:16.377667. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
###### Figure 4 #########
plot_generated_models.plot_r2_bar_model_1(perc_increase = True, 
                                          model_set_number = 2,
                                          task_spec_ix = 2, 
                                          include_shuffs = 1)
# Out:
# Option 1
# Shuff option 1
# <img src="data:image/png;base64,..." width="621.111127564937">
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.3116
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.3709
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1025
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1021
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.0717
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1159
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1479
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.0874
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.0844
# Option 1
# Shuff option 1
# <img src="data:image/png;base64,..." width="597.7777936134813">
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.2637
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.2192
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.2558
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1757
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-15 10:30:46.610440. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
###### Scatters for condition specific differences | command #######
for mfropt in ['ultra_pooled', 'command_axis_spec']
    plot_generated_models.plot_real_vs_pred(model_set_number = 2, min_obs = 15, cov = False, 
        use_mFR_option = mfropt)
