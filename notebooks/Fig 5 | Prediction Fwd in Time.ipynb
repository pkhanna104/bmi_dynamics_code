# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
#%matplotlib notebook

# %%
from online_analysis import plot_generated_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# in task
# in task
# in task
# ...

# %%
##### Differences b/w within vs. across condition in action at the next timestep ######
plot_generated_models.plot_real_mean_diffs_behavior_next()
# Out:
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 13376, ndays = 9, pv = 0.0000, slp = 0.1881
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 4288, ndays = 4, pv = 0.0000, slp = 0.4740
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 15:32:42.002389. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Can we predict the across task differences ? What do we compare this to? ######
plot_generated_models.fig_5_neural_dyn(model_set_number=3, ndays=1)
#plot_generated_models.fig_5_neural_dyn_mean_pred(model_set_number=3)
# Out:
# > /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_generated_models.py(1342)fig_5_neural_dyn()
# -> R2S[i_mod, i_d, 0] = R2;
# (Pdb) plt.plot(np_pred[:100, 0])
# ...
# (Pdb) plt.plot(np_data[:100, 0])
# ...
# (Pdb) plt.show()
# (Pdb) plt.plot(np_pred[:100, 0])
# ...
# (Pdb) plt.plot(np_data[:100, 0])
# ...
# (Pdb) plt.show()
# (Pdb) plt.plot(np_data[:10, 0])
# ...
# (Pdb) plt.plot(np_pre[:10, 0])
# *** NameError: name 'np_pre' is not defined
# (Pdb) plt.plot(np_pred[:10, 0])
# ...
# (Pdb) plt.show()
# (Pdb) mod
# 'hist_1pos_0psh_0spksm_1_spksp_0'
# (Pdb) c
# > /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_generated_models.py(1325)fig_5_neural_dyn()
# -> import pdb; pdb.set_trace()
# (Pdb) mod
# 'identity'
# (Pdb) plt.plot(np_pred[:10, 0])
# ...
# (Pdb) plt.plot(np.data[:10, 0])
# *** AttributeError: 'module' object has no attribute 'data'
# (Pdb) plt.plot(np_data[:10, 0])
# ...
# (Pdb) plt.show()
# (Pdb) R2_np
# 0.3071478144707057
# (Pdb) c
# ...

# %%
model_set_number = 3;
import analysis_config
animal = 'grom'
ridge_dict = pickle.load(open(analysis_config.config[animal+'_pref'] + 'max_alphas_ridge_model_set%d.pkl' %model_set_number, 'rb'));
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 18:52:34.428684. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
ridge_dict['grom']
# Out:
# [{(0, 'hist_1pos_0psh_0spksm_1_spksp_0'): 250.0,
#   (0, 'hist_1pos_0psh_1spksm_0_spksp_0'): 7.5,
#   (0, 'prespos_0psh_0spksm_1_spksp_0'): 250.0,
#   (1, 'hist_1pos_0psh_0spksm_1_spksp_0'): 250.0,
#   (1, 'hist_1pos_0psh_1spksm_0_spksp_0'): 5.0,
#   (1, 'prespos_0psh_0spksm_1_spksp_0'): 250.0,
#   (2, 'hist_1pos_0psh_0spksm_1_spksp_0'): 5000.0,
#   (2, 'hist_1pos_0psh_1spksm_0_spksp_0'): 75.0,
#   (2, 'prespos_0psh_0spksm_1_spksp_0'): 5000.0,
#   (3, 'hist_1pos_0psh_0spksm_1_spksp_0'): 250.0,
#   (3, 'hist_1pos_0psh_1spksm_0_spksp_0'): 10.0,
#   (3, 'prespos_0psh_0spksm_1_spksp_0'): 250.0,
#   (4, 'hist_1pos_0psh_0spksm_1_spksp_0'): 1000.0,
#   (4, 'hist_1pos_0psh_1spksm_0_spksp_0'): 25.0,
#   (4, 'prespos_0psh_0spksm_1_spksp_0'): 1000.0,
#   (5, 'hist_1pos_0psh_0spksm_1_spksp_0'): 500.0,
#   (5, 'hist_1pos_0psh_1spksm_0_spksp_0'): 25.0,
#   (5, 'prespos_0psh_0spksm_1_spksp_0'): 500.0,
#   (6, 'hist_1pos_0psh_0spksm_1_spksp_0'): 250.0,
# ...
