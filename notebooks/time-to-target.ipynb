# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
import analysis_config

# %%
from online_analysis import generate_models_utils

# %%
generate_models_utils.plot_t2t()
# Out:
# ((64,), (64,), (18, 44), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (18, 44), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (18, 44), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((101,), (101,), (40, 44), 6, (40,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((101,), (101,), (40, 44), 6, (40,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((101,), (101,), (40, 44), 6, (40,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# ((122,), (122,), (97, 44), 6, (97,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((122,), (122,), (97, 44), 6, (97,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((122,), (122,), (97, 44), 6, (97,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Animal grom, tsk 0, N = 2357
# Tsk 0, Trg 0.00, N = 274
# Tsk 0, Trg 1.00, N = 353
# Tsk 0, Trg 2.00, N = 335
# Tsk 0, Trg 3.00, N = 337
# Tsk 0, Trg 4.00, N = 324
# Tsk 0, Trg 5.00, N = 287
# Tsk 0, Trg 6.00, N = 205
# Tsk 0, Trg 7.00, N = 242
# Animal grom, tsk 1, N = 9614
# Tsk 1, Trg 0.10, N = 1084
# Tsk 1, Trg 1.10, N = 1123
# Tsk 1, Trg 2.10, N = 1301
# Tsk 1, Trg 3.10, N = 1527
# Tsk 1, Trg 4.00, N = 572
# Tsk 1, Trg 4.10, N = 1320
# Tsk 1, Trg 5.00, N = 1046
# Tsk 1, Trg 6.10, N = 753
# Tsk 1, Trg 7.10, N = 888
# ((64,), (64,), (51, 35), 6, (51,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (51, 35), 6, (51,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (51, 35), 6, (51,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((129,), (129,), (21, 35), 6, (21,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((129,), (129,), (21, 35), 6, (21,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((129,), (129,), (21, 35), 6, (21,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 193, total trls in this blk 129
# Animal grom, tsk 0, N = 2233
# Tsk 0, Trg 0.00, N = 332
# Tsk 0, Trg 1.00, N = 417
# Tsk 0, Trg 2.00, N = 283
# Tsk 0, Trg 3.00, N = 232
# Tsk 0, Trg 4.00, N = 326
# Tsk 0, Trg 5.00, N = 296
# Tsk 0, Trg 6.00, N = 161
# Tsk 0, Trg 7.00, N = 186
# Animal grom, tsk 1, N = 5019
# Tsk 1, Trg 0.10, N = 762
# Tsk 1, Trg 1.10, N = 916
# Tsk 1, Trg 2.10, N = 811
# Tsk 1, Trg 3.00, N = 65
# Tsk 1, Trg 3.10, N = 551
# Tsk 1, Trg 4.00, N = 327
# Tsk 1, Trg 4.10, N = 218
# Tsk 1, Trg 5.00, N = 475
# Tsk 1, Trg 6.10, N = 285
# Tsk 1, Trg 7.10, N = 609
# ((64,), (64,), (24, 148), 6, (24,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (24, 148), 6, (24,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (24, 148), 6, (24,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((255,), (255,), (20, 148), 6, (20,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((255,), (255,), (20, 148), 6, (20,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((255,), (255,), (20, 148), 6, (20,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 319, total trls in this blk 255
# ((208,), (208,), (23, 148), 6, (23,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((208,), (208,), (23, 148), 6, (23,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((208,), (208,), (23, 148), 6, (23,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 527, total trls in this blk 208
# Animal grom, tsk 0, N = 1474
# Tsk 0, Trg 0.00, N = 195
# Tsk 0, Trg 1.00, N = 218
# Tsk 0, Trg 2.00, N = 200
# Tsk 0, Trg 3.00, N = 191
# Tsk 0, Trg 4.00, N = 233
# Tsk 0, Trg 5.00, N = 154
# Tsk 0, Trg 6.00, N = 146
# Tsk 0, Trg 7.00, N = 137
# Animal grom, tsk 1, N = 15031
# Tsk 1, Trg 0.10, N = 1704
# Tsk 1, Trg 1.10, N = 1832
# Tsk 1, Trg 2.10, N = 1819
# Tsk 1, Trg 3.10, N = 2856
# Tsk 1, Trg 4.00, N = 1956
# Tsk 1, Trg 4.10, N = 110
# Tsk 1, Trg 5.00, N = 1914
# Tsk 1, Trg 5.10, N = 95
# Tsk 1, Trg 6.00, N = 97
# Tsk 1, Trg 6.10, N = 1276
# Tsk 1, Trg 7.10, N = 1372
# ((64,), (64,), (29, 53), 6, (29,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (29, 53), 6, (29,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (29, 53), 6, (29,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((73,), (73,), (30, 53), 6, (30,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((73,), (73,), (30, 53), 6, (30,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((73,), (73,), (30, 53), 6, (30,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 137, total trls in this blk 73
# ((237,), (237,), (26, 53), 6, (26,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((237,), (237,), (26, 53), 6, (26,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((237,), (237,), (26, 53), 6, (26,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 374, total trls in this blk 237
# ((100,), (100,), (32, 53), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((100,), (100,), (32, 53), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((100,), (100,), (32, 53), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 474, total trls in this blk 100
# Animal grom, tsk 0, N = 1613
# Tsk 0, Trg 0.00, N = 284
# Tsk 0, Trg 1.00, N = 265
# Tsk 0, Trg 2.00, N = 155
# Tsk 0, Trg 3.00, N = 179
# Tsk 0, Trg 4.00, N = 146
# Tsk 0, Trg 5.00, N = 162
# Tsk 0, Trg 6.00, N = 196
# Tsk 0, Trg 7.00, N = 226
# Animal grom, tsk 1, N = 14257
# Tsk 1, Trg 0.10, N = 2077
# Tsk 1, Trg 1.10, N = 2201
# Tsk 1, Trg 2.10, N = 1712
# Tsk 1, Trg 3.00, N = 417
# Tsk 1, Trg 3.10, N = 1199
# Tsk 1, Trg 4.00, N = 550
# Tsk 1, Trg 4.10, N = 1059
# Tsk 1, Trg 5.00, N = 710
# Tsk 1, Trg 5.10, N = 716
# Tsk 1, Trg 6.10, N = 1604
# Tsk 1, Trg 7.10, N = 2012
# ((64,), (64,), (14, 151), 6, (14,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (14, 151), 6, (14,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (14, 151), 6, (14,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((159,), (159,), (34, 151), 6, (34,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((159,), (159,), (34, 151), 6, (34,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((159,), (159,), (34, 151), 6, (34,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# ((121,), (121,), (47, 151), 6, (47,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((121,), (121,), (47, 151), 6, (47,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((121,), (121,), (47, 151), 6, (47,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# Animal grom, tsk 0, N = 1681
# Tsk 0, Trg 0.00, N = 236
# Tsk 0, Trg 1.00, N = 285
# Tsk 0, Trg 2.00, N = 244
# Tsk 0, Trg 3.00, N = 168
# Tsk 0, Trg 4.00, N = 182
# Tsk 0, Trg 5.00, N = 183
# Tsk 0, Trg 6.00, N = 197
# Tsk 0, Trg 7.00, N = 186
# Animal grom, tsk 1, N = 10702
# Tsk 1, Trg 0.10, N = 1682
# Tsk 1, Trg 1.10, N = 1643
# Tsk 1, Trg 2.10, N = 1600
# Tsk 1, Trg 3.00, N = 202
# Tsk 1, Trg 3.10, N = 927
# Tsk 1, Trg 4.00, N = 203
# Tsk 1, Trg 4.10, N = 1040
# Tsk 1, Trg 5.00, N = 860
# Tsk 1, Trg 5.10, N = 304
# Tsk 1, Trg 6.00, N = 216
# Tsk 1, Trg 6.10, N = 713
# Tsk 1, Trg 7.10, N = 1312
# ((63,), (63,), (20, 42), 6, (20,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((63,), (63,), (20, 42), 6, (20,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((63,), (63,), (20, 42), 6, (20,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# ((64,), (64,), (12, 42), 6, (12,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (12, 42), 6, (12,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (12, 42), 6, (12,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 127, total trls in this blk 64
# ((97,), (97,), (32, 42), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((97,), (97,), (32, 42), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((97,), (97,), (32, 42), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 224, total trls in this blk 97
# ((174,), (174,), (38, 42), 6, (38,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((174,), (174,), (38, 42), 6, (38,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((174,), (174,), (38, 42), 6, (38,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 398, total trls in this blk 174
# Animal grom, tsk 0, N = 3232
# Tsk 0, Trg 0.00, N = 507
# Tsk 0, Trg 1.00, N = 522
# Tsk 0, Trg 2.00, N = 432
# Tsk 0, Trg 3.00, N = 348
# Tsk 0, Trg 4.00, N = 311
# Tsk 0, Trg 5.00, N = 304
# Tsk 0, Trg 6.00, N = 373
# Tsk 0, Trg 7.00, N = 435
# Animal grom, tsk 1, N = 8464
# Tsk 1, Trg 0.10, N = 1290
# Tsk 1, Trg 1.10, N = 1278
# Tsk 1, Trg 2.10, N = 1199
# Tsk 1, Trg 3.00, N = 22
# Tsk 1, Trg 3.10, N = 1073
# Tsk 1, Trg 4.10, N = 840
# Tsk 1, Trg 5.00, N = 148
# Tsk 1, Trg 5.10, N = 598
# Tsk 1, Trg 6.10, N = 834
# Tsk 1, Trg 7.10, N = 1182
# ((63,), (63,), (18, 50), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((63,), (63,), (18, 50), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((63,), (63,), (18, 50), 6, (18,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 63, total trls in this blk 63
# ((29,), (29,), (31, 50), 6, (31,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((29,), (29,), (31, 50), 6, (31,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((29,), (29,), (31, 50), 6, (31,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 92, total trls in this blk 29
# ((64,), (64,), (47, 50), 6, (47,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (47, 50), 6, (47,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (47, 50), 6, (47,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 156, total trls in this blk 64
# Animal grom, tsk 0, N = 1837
# Tsk 0, Trg 0.00, N = 326
# Tsk 0, Trg 1.00, N = 290
# Tsk 0, Trg 2.00, N = 207
# Tsk 0, Trg 3.00, N = 202
# Tsk 0, Trg 4.00, N = 199
# Tsk 0, Trg 5.00, N = 156
# Tsk 0, Trg 6.00, N = 245
# Tsk 0, Trg 7.00, N = 212
# Animal grom, tsk 1, N = 2699
# Tsk 1, Trg 0.10, N = 392
# Tsk 1, Trg 1.10, N = 382
# Tsk 1, Trg 2.10, N = 402
# Tsk 1, Trg 3.10, N = 353
# Tsk 1, Trg 4.00, N = 20
# Tsk 1, Trg 4.10, N = 244
# Tsk 1, Trg 5.00, N = 31
# Tsk 1, Trg 5.10, N = 244
# Tsk 1, Trg 6.10, N = 257
# Tsk 1, Trg 7.10, N = 374
# ((64,), (64,), (35, 48), 6, (35,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (35, 48), 6, (35,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (35, 48), 6, (35,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((100,), (100,), (48, 48), 6, (48,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((100,), (100,), (48, 48), 6, (48,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((100,), (100,), (48, 48), 6, (48,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 164, total trls in this blk 100
# Animal grom, tsk 0, N = 2222
# Tsk 0, Trg 0.00, N = 323
# Tsk 0, Trg 1.00, N = 312
# Tsk 0, Trg 2.00, N = 248
# Tsk 0, Trg 3.00, N = 318
# Tsk 0, Trg 4.00, N = 323
# Tsk 0, Trg 5.00, N = 246
# Tsk 0, Trg 6.00, N = 232
# Tsk 0, Trg 7.00, N = 220
# Animal grom, tsk 1, N = 3470
# Tsk 1, Trg 0.10, N = 572
# Tsk 1, Trg 1.10, N = 509
# Tsk 1, Trg 2.10, N = 477
# Tsk 1, Trg 3.10, N = 319
# Tsk 1, Trg 4.10, N = 376
# Tsk 1, Trg 5.10, N = 379
# Tsk 1, Trg 6.10, N = 362
# Tsk 1, Trg 7.10, N = 476
# ((64,), (64,), (36, 48), 6, (36,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (36, 48), 6, (36,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((64,), (64,), (36, 48), 6, (36,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ((75,), (75,), (32, 48), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((75,), (75,), (32, 48), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ((75,), (75,), (32, 48), 6, (32,))
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 139, total trls in this blk 75
# Animal grom, tsk 0, N = 2265
# Tsk 0, Trg 0.00, N = 304
# Tsk 0, Trg 1.00, N = 357
# Tsk 0, Trg 2.00, N = 339
# Tsk 0, Trg 3.00, N = 240
# Tsk 0, Trg 4.00, N = 380
# Tsk 0, Trg 5.00, N = 247
# Tsk 0, Trg 6.00, N = 221
# Tsk 0, Trg 7.00, N = 177
# Animal grom, tsk 1, N = 3147
# Tsk 1, Trg 0.10, N = 431
# Tsk 1, Trg 1.10, N = 475
# Tsk 1, Trg 2.10, N = 511
# Tsk 1, Trg 3.10, N = 406
# Tsk 1, Trg 4.10, N = 373
# Tsk 1, Trg 5.10, N = 362
# Tsk 1, Trg 6.00, N = 124
# Tsk 1, Trg 6.10, N = 166
# Tsk 1, Trg 7.10, N = 299
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (199, (15, 7))
# new trial offset 199, total trls in this blk 199
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (171, (46, 7))
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx -1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 358, total trls in this blk 159
# Animal jeev, tsk 0, N = 3257
# Tsk 0, Trg 0.00, N = 357
# Tsk 0, Trg 1.00, N = 387
# Tsk 0, Trg 2.00, N = 495
# Tsk 0, Trg 3.00, N = 479
# Tsk 0, Trg 4.00, N = 387
# Tsk 0, Trg 5.00, N = 344
# Tsk 0, Trg 6.00, N = 392
# Tsk 0, Trg 7.00, N = 416
# Animal jeev, tsk 1, N = 5499
# Tsk 1, Trg 2.10, N = 670
# Tsk 1, Trg 3.00, N = 621
# Tsk 1, Trg 4.00, N = 1145
# Tsk 1, Trg 5.10, N = 655
# Tsk 1, Trg 6.00, N = 172
# Tsk 1, Trg 6.10, N = 866
# Tsk 1, Trg 8.00, N = 633
# Tsk 1, Trg 9.10, N = 737
# Xlims: -0.05, 0.13
# Ylims: 0.05, 0.23
# Bin Curson kin Size 20
# (16, (38, 7))
# new trial offset 16, total trls in this blk 16
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (152, (39, 7))
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 158, total trls in this blk 142
# Animal jeev, tsk 0, N = 492
# Tsk 0, Trg 0.00, N = 124
# Tsk 0, Trg 1.00, N = 43
# Tsk 0, Trg 2.00, N = 85
# Tsk 0, Trg 3.00, N = 65
# Tsk 0, Trg 4.00, N = 22
# Tsk 0, Trg 5.00, N = 37
# Tsk 0, Trg 6.00, N = 72
# Tsk 0, Trg 7.00, N = 44
# Animal jeev, tsk 1, N = 4618
# Tsk 1, Trg 2.10, N = 590
# Tsk 1, Trg 3.00, N = 530
# Tsk 1, Trg 4.00, N = 817
# Tsk 1, Trg 5.10, N = 532
# Tsk 1, Trg 6.00, N = 40
# Tsk 1, Trg 6.10, N = 831
# Tsk 1, Trg 8.00, N = 658
# Tsk 1, Trg 9.10, N = 620
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (90, (16, 7))
# new trial offset 90, total trls in this blk 90
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (133, (35, 7))
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# new trial offset 218, total trls in this blk 128
# Animal jeev, tsk 0, N = 1562
# Tsk 0, Trg 0.00, N = 173
# Tsk 0, Trg 1.00, N = 174
# Tsk 0, Trg 2.00, N = 194
# Tsk 0, Trg 3.00, N = 265
# Tsk 0, Trg 4.00, N = 184
# Tsk 0, Trg 5.00, N = 225
# Tsk 0, Trg 6.00, N = 193
# Tsk 0, Trg 7.00, N = 154
# Animal jeev, tsk 1, N = 3963
# Tsk 1, Trg 2.10, N = 331
# Tsk 1, Trg 3.00, N = 337
# Tsk 1, Trg 4.00, N = 565
# Tsk 1, Trg 5.10, N = 342
# Tsk 1, Trg 6.00, N = 457
# Tsk 1, Trg 6.10, N = 425
# Tsk 1, Trg 8.00, N = 615
# Tsk 1, Trg 9.10, N = 891
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (80, (17, 7))
# new trial offset 80, total trls in this blk 80
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (101, (46, 7))
# Len Obs Targs [1 2 3 4 5 6 8 9]
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Keeping JEEV target 2 2.7
# Correcting JEEV target 2 -0.4
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 0.1
# Correcting JEEV target 2 -0.1
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.9
# Correcting JEEV target 2 -0.0
# Correcting JEEV target 2 -0.6
# Correcting JEEV target 2 -0.3
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# REMOVING A TRIAL: Animal jeev, TargIx 1.0
# Correcting JEEV target 2 -0.2
# new trial offset 176, total trls in this blk 96
# Animal jeev, tsk 0, N = 1692
# Tsk 0, Trg 0.00, N = 241
# Tsk 0, Trg 1.00, N = 191
# Tsk 0, Trg 2.00, N = 174
# Tsk 0, Trg 3.00, N = 191
# Tsk 0, Trg 4.00, N = 202
# Tsk 0, Trg 5.00, N = 220
# Tsk 0, Trg 6.00, N = 241
# Tsk 0, Trg 7.00, N = 232
# Animal jeev, tsk 1, N = 4323
# Tsk 1, Trg 2.00, N = 54
# Tsk 1, Trg 2.10, N = 368
# Tsk 1, Trg 3.00, N = 225
# Tsk 1, Trg 4.00, N = 515
# Tsk 1, Trg 5.10, N = 221
# Tsk 1, Trg 6.00, N = 1153
# Tsk 1, Trg 6.10, N = 219
# Tsk 1, Trg 8.00, N = 814
# Tsk 1, Trg 9.10, N = 754

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
