# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 20:18:21.425592. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from online_analysis import plot_generated_models, generate_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 20:35:54.823870. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Differences b/w within vs. across condition in action at the next timestep ######
plot_generated_models.plot_real_mean_diffs_behavior_next()
# Out:
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 13376, ndays = 9, pv = 0.0000, slp = 0.1886
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 4288, ndays = 4, pv = 0.0000, slp = 0.4808
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 20:18:27.599638. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Can we predict the across task differences ? What do we compare this to? ######
plot_generated_models.fig_5_neural_dyn(model_set_number=3)

#### Right now as is similar to the top plot but with mean action diffs at {t+1} explained by predictors #### 
#### Models predict next time step -- then get time points that show the same push at t = 0, at the NEXT time 
#### step look at what the prediction is 
plot_generated_models.fig_5_neural_dyn_mean_pred(model_set_number=3)
# Out:
# Animal: grom, Plot 0, PV: 0.00, SLP: 1.49
# Animal: grom, Plot 1, PV: 0.00, SLP: 3.59
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# ...

# %%
##### Generate the model_set_8 ##### 
#generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 8)
generate_models.model_individual_cell_tuning_curves(model_set_number=8, animal='grom')
generate_models.model_individual_cell_tuning_curves(model_set_number=8, animal='jeev')
# Out:
# online_analysis/generate_models.py:254: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# (64,) (64,) (51, 35) 6 (51,)
# ...

# %%
#### Can use model set 8 to use info about state encoding to predict differences in next action ###
plot_generated_models.fig_5_neural_dyn_mean_pred(model_set_number=8, 
                        center_rad_limit = 2, min_obs = 5, jeev_days= [0, 2, 3])
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...
