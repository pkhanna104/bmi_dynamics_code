# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
import seaborn
seaborn.set(font='Arial',context='talk',font_scale=1.2, style='white')

# %%
from online_analysis import plot_generated_models, util_fcns
import analysis_config
from online_analysis import generalization_plots

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
################# REPLOTTING BAR PLOTS ###################
################## REPLOTTING BAR PLOTS ###################
################## REPLOTTING BAR PLOTS ###################
save_dict = {}
for cat in ['com', 'mov']:
    save_dict = generalization_plots.plot_dyn_const_r2(cat=cat, nshuffs = 20,
            model_nm = 'hist_1pos_0psh_2spksm_1_spksp_0', 
                                                         return_trans_from_lo=False, 
                                                         save_dict = save_dict,
                                                         apply_full_axes_to_all = True)
    other_color = analysis_config.blue_rgb
# Out:
# ##################
# Starting Animal grom Day 0
# ##################
# r2 of full: 0.3016, r2 of purple LO 0.2973
# ##################
# Starting Animal grom Day 1
# ##################
# r2 of full: 0.3597, r2 of purple LO 0.3523
# ##################
# Starting Animal grom Day 2
# ##################
# r2 of full: 0.1254, r2 of purple LO 0.1234
# ##################
# Starting Animal grom Day 3
# ##################
# r2 of full: 0.1245, r2 of purple LO 0.1217
# ##################
# Starting Animal grom Day 4
# ##################
# r2 of full: 0.1063, r2 of purple LO 0.1041
# ##################
# Starting Animal grom Day 5
# ##################
# r2 of full: 0.1149, r2 of purple LO 0.1122
# ##################
# Starting Animal grom Day 6
# ##################
# r2 of full: 0.1645, r2 of purple LO 0.1600
# ##################
# Starting Animal grom Day 7
# ##################
# r2 of full: 0.1040, r2 of purple LO 0.1009
# ##################
# Starting Animal grom Day 8
# ##################
# r2 of full: 0.0981, r2 of purple LO 0.0946
# ##################
# Starting Animal jeev Day 0
# ##################
# r2 of full: 0.2963, r2 of purple LO 0.2887
# ##################
# Starting Animal jeev Day 1
# ##################
# r2 of full: 0.2714, r2 of purple LO 0.2623
# ##################
# Starting Animal jeev Day 2
# ##################
# r2 of full: 0.2716, r2 of purple LO 0.2635
# ##################
# Starting Animal jeev Day 3
# ##################
# r2 of full: 0.1672, r2 of purple LO 0.1573
# ##################
# Starting Animal grom Day 0
# ##################
# r2 of full: 0.3016, r2 of purple LO 0.2984
# ##################
# Starting Animal grom Day 1
# ##################
# r2 of full: 0.3595, r2 of purple LO 0.3544
# ##################
# Starting Animal grom Day 2
# ##################
# r2 of full: 0.1254, r2 of purple LO 0.1228
# ##################
# Starting Animal grom Day 3
# ##################
# r2 of full: 0.1245, r2 of purple LO 0.1221
# ##################
# Starting Animal grom Day 4
# ##################
# r2 of full: 0.1063, r2 of purple LO 0.1038
# ##################
# Starting Animal grom Day 5
# ##################
# r2 of full: 0.1149, r2 of purple LO 0.1127
# ##################
# Starting Animal grom Day 6
# ##################
# r2 of full: 0.1645, r2 of purple LO 0.1611
# ##################
# Starting Animal grom Day 7
# ##################
# r2 of full: 0.1040, r2 of purple LO 0.1013
# ##################
# Starting Animal grom Day 8
# ##################
# r2 of full: 0.0981, r2 of purple LO 0.0949
# ##################
# Starting Animal jeev Day 0
# ##################
# r2 of full: 0.2966, r2 of purple LO 0.2864
# ##################
# Starting Animal jeev Day 1
# ##################
# r2 of full: 0.2716, r2 of purple LO 0.2530
# ##################
# Starting Animal jeev Day 2
# ##################
# r2 of full: 0.2721, r2 of purple LO 0.2608
# ##################
# Starting Animal jeev Day 3
# ##################
# r2 of full: 0.1674, r2 of purple LO 0.1604

# %%
#save_dict

# %%
##### Fig 4 -- conditioned on command 

plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'dyn_const_combo_mov_com_'+str(plot_act)+'normTrue', other_color=other_color,
                                            fig4 = True, fig5 = False, shuff_norm = True)

plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'dyn_const_combo_mov_com_'+str(plot_act)+'normFalse', other_color=other_color,
                                            fig4 = True, fig5 = False, shuff_norm = False)
# Out:
# r2_cond mean: 1.00
# r2_shuff mean: 1.00
# r2_pred_lo_mov mean: 1.30
# r2_pred_lo_com mean: 1.30
# r2_pred_full mean: 1.33
# r2_cond mean: 1.00
# r2_shuff mean: 1.00
# r2_pred_lo_mov mean: 1.21
# r2_pred_lo_com mean: 1.23
# r2_pred_full mean: 1.27
# r2_cond mean: 0.13
# r2_shuff mean: 0.13
# r2_pred_lo_mov mean: 0.16
# r2_pred_lo_com mean: 0.16
# r2_pred_full mean: 0.17
# r2_cond mean: 0.20
# r2_shuff mean: 0.20
# r2_pred_lo_mov mean: 0.24
# r2_pred_lo_com mean: 0.24
# r2_pred_full mean: 0.25

# %%
################# REPLOTTING BAR PLOTS ###################
################## REPLOTTING BAR PLOTS ###################
################## REPLOTTING BAR PLOTS ###################
orange = np.array([247, 148, 29])/255.
import analysis_config

save_dict = {}
for cat in ['com', 'mov']:
    save_dict = generalization_plots.plot_dyn_const_r2(cat=cat, nshuffs = 20,
            model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', 
                                                         return_trans_from_lo=True, 
                                                         save_dict = save_dict,
                                                         apply_full_axes_to_all = True)
    other_color = analysis_config.blue_rgb
# save_dict = {}
# for cat in ['com', 'mov']:
#     for plot_act in [False]:#, True]:
#         save_dict = generalization_plots.plot_loo_r2_overall(cat=cat, yval = 'dyn_const_r2', nshuffs = 100,
#                 model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', return_trans_from_lo=True, 
#                                              plot_action=plot_act, null_opt='nulldyn',
#                                                 potent_addon=True, nulldyn_opt='alpha_opt',
#                                                             save_bars = True,
#                                                             save_dict = save_dict)
#         if plot_act: 
#             other_color = orange
#         else:
#             other_color = analysis_config.blue_rgb
            
#     other_color = analysis_config.blue_rgb
# Out:
# ##################
# Starting Animal grom Day 0
# ##################
# r2 of full: 0.3253, r2 of purple LO 0.3221
# ##################
# Starting Animal grom Day 1
# ##################
# r2 of full: 0.2901, r2 of purple LO 0.2863
# ##################
# Starting Animal grom Day 2
# ##################
# r2 of full: 0.2218, r2 of purple LO 0.2190
# ##################
# Starting Animal grom Day 3
# ##################
# r2 of full: 0.2317, r2 of purple LO 0.2296
# ##################
# Starting Animal grom Day 4
# ##################
# r2 of full: 0.2128, r2 of purple LO 0.2106
# ##################
# Starting Animal grom Day 5
# ##################
# r2 of full: 0.1156, r2 of purple LO 0.1127
# ##################
# Starting Animal grom Day 6
# ##################
# r2 of full: 0.1846, r2 of purple LO 0.1801
# ##################
# Starting Animal grom Day 7
# ##################
# r2 of full: 0.2168, r2 of purple LO 0.2118
# ##################
# Starting Animal grom Day 8
# ##################
# r2 of full: 0.1509, r2 of purple LO 0.1468
# ##################
# Starting Animal jeev Day 0
# ##################
# r2 of full: 0.2264, r2 of purple LO 0.2200
# ##################
# Starting Animal jeev Day 1
# ##################
# r2 of full: 0.2060, r2 of purple LO 0.1991
# ##################
# Starting Animal jeev Day 2
# ##################
# r2 of full: 0.2019, r2 of purple LO 0.1958
# ##################
# Starting Animal jeev Day 3
# ##################
# r2 of full: 0.0897, r2 of purple LO 0.0872
# ##################
# Starting Animal grom Day 0
# ##################
# r2 of full: 0.3253, r2 of purple LO 0.3177
# ##################
# Starting Animal grom Day 1
# ##################
# r2 of full: 0.2904, r2 of purple LO 0.2830
# ##################
# Starting Animal grom Day 2
# ##################
# r2 of full: 0.2218, r2 of purple LO 0.2117
# ##################
# Starting Animal grom Day 3
# ##################
# r2 of full: 0.2317, r2 of purple LO 0.2257
# ##################
# Starting Animal grom Day 4
# ##################
# r2 of full: 0.2128, r2 of purple LO 0.2056
# ##################
# Starting Animal grom Day 5
# ##################
# r2 of full: 0.1156, r2 of purple LO 0.1101
# ##################
# Starting Animal grom Day 6
# ##################
# r2 of full: 0.1846, r2 of purple LO 0.1771
# ##################
# Starting Animal grom Day 7
# ##################
# r2 of full: 0.2168, r2 of purple LO 0.2098
# ##################
# Starting Animal grom Day 8
# ##################
# r2 of full: 0.1509, r2 of purple LO 0.1418
# ##################
# Starting Animal jeev Day 0
# ##################
# r2 of full: 0.2265, r2 of purple LO 0.2112
# ##################
# Starting Animal jeev Day 1
# ##################
# r2 of full: 0.2059, r2 of purple LO 0.1740
# ##################
# Starting Animal jeev Day 2
# ##################
# r2 of full: 0.2023, r2 of purple LO 0.1855
# ##################
# Starting Animal jeev Day 3
# ##################
# r2 of full: 0.0896, r2 of purple LO 0.0756

# %%
##### Fig 5 -- NOT conditioned on command 

plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'dyn_const_combo_mov_com_'+str(plot_act)+'normTrue', other_color=other_color,
                                            fig4 = False, fig5 = True, shuff_norm = True)

plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'dyn_const_combo_mov_com_'+str(plot_act)+'normFalse', other_color=other_color,
                                            fig4 = False, fig5 = True, shuff_norm = False)
# Out:
# r2_shuff mean: 1.00
# r2_null mean: 1.84
# r2_pred_lo_mov mean: 2.03
# r2_pred_lo_com mean: 2.07
# r2_pred_full mean: 2.11
# r2_shuff mean: 1.00
# r2_null mean: 1.55
# r2_pred_lo_mov mean: 1.90
# r2_pred_lo_com mean: 2.09
# r2_pred_full mean: 2.15
# r2_shuff mean: 0.11
# r2_null mean: 0.19
# r2_pred_lo_mov mean: 0.21
# r2_pred_lo_com mean: 0.21
# r2_pred_full mean: 0.22
# r2_shuff mean: 0.09
# r2_null mean: 0.13
# r2_pred_lo_mov mean: 0.16
# r2_pred_lo_com mean: 0.18
# r2_pred_full mean: 0.18

# %%
###### Test projection matrices ######
A = np.random.randn(44, 44)
X = np.random.randn(44, 1)

# %%
evect, ev = util_fcns.get_sorted_realized_evs(A) # ev = eigen
ev_inv = np.linalg.pinv(evect)

x_ev = np.dot(ev_inv, X)
x12 = x_ev.copy()
x12[2:] = 0.

x34 = x_ev.copy()
x34[:2] = 0.

x12v = np.dot(evect, x12)
x34v = np.dot(evect, x34)

### make sure these are all close 
assert(np.allclose(np.real(np.dot(evect, np.dot(ev_inv, X))), np.real(x12v+x34v)))
assert(np.allclose(np.real(np.dot(evect, np.dot(ev_inv, X))), X))
assert(np.allclose(np.real(x12v+x34v), X))

# %%
ev, evect = np.linalg.eig(A)

# %%
evect[:, 1]
# Out:
# array([-0.16990558+0.08434522j, -0.47250112+0.33490567j,
#         0.65511934-0.j        , -0.20280785-0.39785235j])

# %%
################## REPLOTTING BAR PLOTS ###################
################## REPLOTTING BAR PLOTS ###################
plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'combo_mov_com_'+str(plot_act)+'normTrue', other_color=other_color,
                                            fig4 = True, fig5 = False, shuff_norm = True)

# %%
################## REPLOTTING BAR PLOTS ###################
################## REPLOTTING BAR PLOTS ###################
plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'combo_mov_com_'+str(plot_act)+'normTrue', other_color=other_color,
                                            fig4 = True, fig5 = False, shuff_norm = True)

plot_act = False
generalization_plots.bar_plot_loo_r2_overall(save_dict, 'combo_mov_com_'+str(plot_act)+'normFalse', other_color=other_color,
                                            fig4 = True, fig5 = False, shuff_norm = False)

# %%
generalization_plots.overlap_dyn_axes_w_beh()
# Out:
# Shuff # 0 eigs: 2
# Shuff # 1 eigs: 2
# Shuff # 2 eigs: 2
# Shuff # 3 eigs: 2
# Shuff # 4 eigs: 2
# Shuff # 5 eigs: 2
# Shuff # 6 eigs: 2
# Shuff # 7 eigs: 2
# Shuff # 8 eigs: 2
# Shuff # 9 eigs: 2
# Shuff # 0 eigs: 0
# Shuff # 1 eigs: 0
# Shuff # 2 eigs: 0
# Shuff # 3 eigs: 0
# Shuff # 4 eigs: 0
# Shuff # 5 eigs: 0
# Shuff # 6 eigs: 0
# Shuff # 7 eigs: 0
# Shuff # 8 eigs: 0
# Shuff # 9 eigs: 0

# %%
generalization_plots.r2_by_dyn_axes(dim=10)
# Out:
# <img src="data:image/png;base64,..." width="399.4444550261088">

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %matplotlib notebook
