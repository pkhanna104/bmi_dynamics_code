# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_generated_models, generate_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
mod_dic = {}
for animal in ['grom', 'jeev']:
    model_set_number = 6
    model_dict = pickle.load(open(analysis_config.config[animal+'_pref']+'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N.pkl'%model_set_number, 'rb'))
    mod_dic[animal] = model_dict
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 15:22:28.811740. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.plot_r2_bar_model_dynamics_only(model_dicts=mod_dic, 
                                                      perc_increase=False)
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 16:01:34.193045. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Plot a single shuffled example: 
generate_models.model_individual_cell_tuning_curves(model_set_number=6, animal='grom', 
                                                    fit_task_spec_and_general=True, match_task_spec_n = True,
                                                   within_bin_shuffle = True)
generate_models.model_individual_cell_tuning_curves(model_set_number=6, animal='jeev', 
                                                    fit_task_spec_and_general=True, match_task_spec_n = True,
                                                   within_bin_shuffle = True)
# Out:
# online_analysis/generate_models.py:334: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
#
# online_analysis/generate_models_utils.py:107: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(pref+hdf[hdfix:])
# ##############################
# ########## DAY 0 ##########
# ##############################
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ...

# %%
for mfr_opt in ['command_axis_spec']: #ultra_pooled']:#'pooled', 'command_spec', 'command_axis_spec']:
    for ds in range(2):
        plot_generated_models.plot_real_vs_pred(model_set_number = 6, 
                                        min_obs = 15, cov = False,
                                           use_mFR_option = mfr_opt, include_shuffs = True,
                                           scatter_ds = ds)
# Out:
# Shuff option 1
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Shuff option 1
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Shuff option 1
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Shuff option 1
# ...

# %%
model_dicts = dict()
for animal in ['jeev', 'grom']:#, 'jeev']:
    model_set_number = 6
    model_dict = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N.pkl' %model_set_number, 'rb'))
    model_dicts[animal] = model_dict
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 15:34:42.494983. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for mfropt in ['ultra_pooled','command_axis_spec']:#, 'ultra_pooled']:
    plot_generated_models.plot_real_vs_pred_bars_w_shuffle(mfropt, model_dicts=model_dicts)
# Out:
# <img src="data:image/png;base64,..." width="179.44444919809897">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# <img src="data:image/png;base64,..." width="359.4444539664707">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# <img src="data:image/png;base64,..." width="359.4444539664707">
# <img src="data:image/png;base64,..." width="359.4444539664707">
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 15:38:23.860802. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
