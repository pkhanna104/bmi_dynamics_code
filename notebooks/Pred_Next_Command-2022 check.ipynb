# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from online_analysis import plot_fr_diffs, pred_fwd, generalization_plots

# %%
orange = np.array([247, 148, 29])/255.
import analysis_config

save_dict = {}
cat = 'mov'
save_dict = generalization_plots.plot_loo_r2_overall(cat=cat, nshuffs = 10,
        model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', return_trans_from_lo=True, 
                                     plot_action=False, null_opt='nulldyn',
                                        potent_addon=True, nulldyn_opt='alpha_opt',
                                                    save_bars = True,
                                                    save_dict = save_dict)

other_color = analysis_config.blue_rgb

generalization_plots.bar_plot_loo_r2_overall(save_dict, 'combo_mov_com_'+str(False), other_color=other_color)
# Out:
# <div id='680717c1-a190-4f70-b6db-bffc942cfbea'></div>
# ##################
# Starting Animal grom Day 0
# ##################
# done with estimating null spks
# done with left out
# r2 of full: 0.1939, r2 of purple LO 0.1891
# r2 of null predicting null: 0.1779
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.18911, cyan r2_0.19387, shuff = [0.133, 0.136], null_r2 0.17794
# pv null 0.00000
# ##################
# Starting Animal grom Day 1
# ##################
# done with estimating null spks
# done with left out
# r2 of full: 0.2315, r2 of purple LO 0.2255
# r2 of null predicting null: 0.1669
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.22553, cyan r2_0.23151, shuff = [0.161, 0.162], null_r2 0.16695
# pv null 0.00000
# ##################
# Starting Animal grom Day 2
# ##################
# done with estimating null spks
# done with left out
# r2 of full: 0.0811, r2 of purple LO 0.0771
# r2 of null predicting null: 0.0806
# ...

# %%
#generalization_plots.predict_shuffles_v2_no_cond(nshuffs=20, keep_bin_spk_zsc=True)
generalization_plots.predict_shuffles_v2_no_cond(nshuffs=20, keep_bin_spk_zsc=False)
# Out:
# Starting home, Day = 0
# Shuff 0, tm = 0.000
# done w/ shuff 0, 2.4
# Starting home, Day = 1
# Shuff 0, tm = 0.000
# done w/ shuff 0, 0.5
# Starting home, Day = 2
# Shuff 0, tm = 0.000
# done w/ shuff 0, 0.4
# Starting home, Day = 3
# Shuff 0, tm = 0.000
# done w/ shuff 0, 0.3
# Starting home, Day = 4
# Shuff 0, tm = 0.000
# done w/ shuff 0, 0.4
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-30 22:01:26.049167. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.plot_R2_model(nshuffs=5, nshuffs_roll=5, plot_action=False, keep_bin_spk_zsc = False)
# Out:
# <img src="data:image/png;base64,..." width="216">
# Shuffle 0, 0.03930
# ix valid: 10798
# ix valid: 10449
# ix valid: 9903
# KS test distributions: mn shuff 0.143, mn roll 0.231, pv ks test: 0.00378
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.200, shuff=[0.143,0.143891]
# grom, 0: shuffled: roll, pv = 0.80000, r2 = 0.200, shuff=[0.231,0.241570]
# Shuffle 0, 0.03084
# ix valid: 6505
# ix valid: 6247
# ix valid: 5923
# KS test distributions: mn shuff 0.177, mn roll 0.238, pv ks test: 0.00378
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.245, shuff=[0.177,0.178582]
# grom, 1: shuffled: roll, pv = 0.80000, r2 = 0.245, shuff=[0.238,0.246893]
# Shuffle 0, 0.06061
# ix valid: 14631
# ix valid: 13996
# ix valid: 13253
# KS test distributions: mn shuff 0.034, mn roll 0.095, pv ks test: 0.00378
# grom, 2: shuffled: std, pv = 0.00000, r2 = 0.083, shuff=[0.034,0.035138]
# grom, 2: shuffled: roll, pv = 1.00000, r2 = 0.083, shuff=[0.095,0.097983]
# Shuffle 0, 0.06146
# ix valid: 14136
# ...

# %%
pred_fwd.plot_R2_model(nshuffs=5, nshuffs_roll=0, plot_action=False, keep_bin_spk_zsc = True)
# Out:
# <img src="data:image/png;base64,..." width="300">
# ix valid: 13283
# ix valid: 16193
# ix valid: 15367
# ix valid: 9926
# ix valid: 15808
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-29 23:36:03.711873. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.eg_command_PSTH_pred(arrow_scale = .01, width=.01)
# Out:
# <img src="data:image/png;base64,..." width="360">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-11-10 18:20:16.481835. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.frac_next_com_mov_sig(nshuffs=50)
# Out:
# <img src="data:image/png;base64,..." width="144">
# <img src="data:image/png;base64,..." width="144">
# Animal grom, Day 0, pv = 0.00000, mn_err = 3.817, mn_shuf = [4.794, 4.739]
# Animal grom, Day 1, pv = 0.00000, mn_err = 4.310, mn_shuf = [5.709, 5.649]
# Animal grom, Day 2, pv = 0.00000, mn_err = 7.481, mn_shuf = [10.569, 10.487]
# Animal grom, Day 3, pv = 0.00000, mn_err = 2.301, mn_shuf = [3.015, 2.989]
# Animal grom, Day 4, pv = 0.00000, mn_err = 2.095, mn_shuf = [3.410, 3.376]
# Animal grom, Day 5, pv = 0.00000, mn_err = 4.175, mn_shuf = [4.891, 4.863]
# Animal grom, Day 6, pv = 0.00000, mn_err = 3.558, mn_shuf = [5.369, 5.304]
# Animal grom, Day 7, pv = 0.00000, mn_err = 2.035, mn_shuf = [2.829, 2.788]
# Animal grom, Day 8, pv = 0.00000, mn_err = 5.829, mn_shuf = [8.017, 7.936]
# Animal grom, POOLED: pv = 0.00000, mn_err = 3.956, mn_shuf = [5.400, 5.384]
# Animal jeev, Day 0, pv = 0.00000, mn_err = 8.316, mn_shuf = [10.271, 10.202]
# ...

# %%
pred_fwd.frac_next_com_mov_sig(nshuffs=5)
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="200">
# Animal grom, Day 0, pv = 0.00000, mn_err = 3.817, mn_shuf = [4.802, 4.767]
# Animal grom, Day 1, pv = 0.00000, mn_err = 4.310, mn_shuf = [5.706, 5.660]
# Animal grom, Day 2, pv = 0.00000, mn_err = 7.481, mn_shuf = [10.566, 10.536]
# Animal grom, Day 3, pv = 0.00000, mn_err = 2.301, mn_shuf = [3.013, 2.995]
# Animal grom, Day 4, pv = 0.00000, mn_err = 2.095, mn_shuf = [3.414, 3.401]
# Animal grom, Day 5, pv = 0.00000, mn_err = 4.175, mn_shuf = [4.877, 4.864]
# Animal grom, Day 6, pv = 0.00000, mn_err = 3.558, mn_shuf = [5.383, 5.321]
# Animal grom, Day 7, pv = 0.00000, mn_err = 2.035, mn_shuf = [2.817, 2.787]
# Animal grom, Day 8, pv = 0.00000, mn_err = 5.829, mn_shuf = [8.001, 7.914]
# Animal grom, POOLED: pv = 0.00000, mn_err = 3.956, mn_shuf = [5.398, 5.381]
# ...

# %%
pred_fwd.frac_next_com_mov_sig(nshuffs=5)
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="640">
# Animal grom, Day 0, pv = 0.00000, mn_err = 3.817, mn_shuf = [4.802, 4.767]
# Animal grom, Day 1, pv = 0.00000, mn_err = 4.310, mn_shuf = [5.706, 5.660]
# Animal grom, Day 2, pv = 0.00000, mn_err = 7.481, mn_shuf = [10.566, 10.536]
# Animal grom, Day 3, pv = 0.00000, mn_err = 2.301, mn_shuf = [3.013, 2.995]
# Animal grom, Day 4, pv = 0.00000, mn_err = 2.095, mn_shuf = [3.414, 3.401]
# Animal grom, Day 5, pv = 0.00000, mn_err = 4.175, mn_shuf = [4.877, 4.864]
# Animal grom, Day 6, pv = 0.00000, mn_err = 3.558, mn_shuf = [5.383, 5.321]
# Animal grom, Day 7, pv = 0.00000, mn_err = 2.035, mn_shuf = [2.817, 2.787]
# Animal grom, Day 8, pv = 0.00000, mn_err = 5.829, mn_shuf = [8.001, 7.914]
# Animal grom, POOLED: pv = 0.00000, mn_err = 3.956, mn_shuf = [5.398, 5.381]
# ...

# %%
#### TODO 
pred_fwd.plot_R2_model(nshuffs=1000)
# Out:
# <img src="data:image/png;base64,..." width="216">
# Shuffle 0, 0.03258
# Shuffle 10, 7.30592
# Shuffle 20, 15.18471
# Shuffle 30, 21.94719
# Shuffle 40, 29.42737
# Shuffle 50, 37.05656
# Shuffle 60, 44.07034
# Shuffle 70, 51.28288
# Shuffle 80, 58.32830
# Shuffle 90, 65.19922
# KS test distributions: mn shuff 0.142, mn roll 0.240, pv ks test: 0.00000
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.200, shuff=[0.142,0.144998]
# grom, 0: shuffled: roll, pv = 1.00000, r2 = 0.200, shuff=[0.240,0.241607]
# Shuffle 0, 0.02060
# Shuffle 10, 3.56492
# Shuffle 20, 6.95978
# Shuffle 30, 10.55420
# Shuffle 40, 13.98352
# Shuffle 50, 17.62733
# Shuffle 60, 20.99911
# Shuffle 70, 24.43232
# Shuffle 80, 28.30790
# Shuffle 90, 31.88126
# KS test distributions: mn shuff 0.177, mn roll 0.246, pv ks test: 0.00000
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.245, shuff=[0.177,0.180608]
# grom, 1: shuffled: roll, pv = 0.83000, r2 = 0.245, shuff=[0.246,0.247824]
# Shuffle 0, 0.07478
# ...

# %%
#### TODO 
pred_fwd.plot_R2_model(nshuffs=1000, plot_action = True)
# Out:
# <div id='675d0938-63ea-44bb-a5e7-416fa31b12aa'></div>
# Shuffle 0, 0.03896
# Shuffle 10, 7.04148
# Shuffle 20, 14.69320
# Shuffle 30, 22.15447
# Shuffle 40, 29.36697
# Shuffle 50, 36.65357
# Shuffle 60, 44.24393
# Shuffle 70, 51.32533
# Shuffle 80, 58.52659
# Shuffle 90, 65.80897
# KS test distributions: mn shuff 0.370, mn roll 0.277, pv ks test: 0.00000
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.403, shuff=[0.370,0.373597]
# grom, 0: shuffled: roll, pv = 0.00000, r2 = 0.403, shuff=[0.277,0.281791]
# Shuffle 0, 0.02293
# Shuffle 10, 3.68044
# Shuffle 20, 7.28678
# Shuffle 30, 10.68813
# Shuffle 40, 14.26265
# Shuffle 50, 18.02259
# Shuffle 60, 21.43424
# Shuffle 70, 25.16095
# Shuffle 80, 28.73795
# Shuffle 90, 32.38013
# KS test distributions: mn shuff 0.357, mn roll 0.257, pv ks test: 0.00000
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.383, shuff=[0.357,0.360650]
# grom, 1: shuffled: roll, pv = 0.00000, r2 = 0.383, shuff=[0.257,0.261863]
# Shuffle 0, 0.19744
# ...

# %%
pred_fwd.plot_R2_model(nshuffs=5, nshuffs_roll=5, plot_action=False)
# Out:
# <img src="data:image/png;base64,..." width="316">
# Shuffle 0, 0.04487
# ix valid: 10798
# ix valid: 10449
# ix valid: 9903
# KS test distributions: mn shuff 0.143, mn roll 0.231, pv ks test: 0.00378
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.200, shuff=[0.143,0.143891]
# grom, 0: shuffled: roll, pv = 0.80000, r2 = 0.200, shuff=[0.231,0.241570]
# Shuffle 0, 0.02352
# ix valid: 6505
# ix valid: 6247
# ix valid: 5923
# KS test distributions: mn shuff 0.177, mn roll 0.238, pv ks test: 0.00378
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.245, shuff=[0.177,0.178582]
# grom, 1: shuffled: roll, pv = 0.80000, r2 = 0.245, shuff=[0.238,0.246893]
# Shuffle 0, 0.06570
# ix valid: 14631
# ix valid: 13996
# ix valid: 13253
# KS test distributions: mn shuff 0.034, mn roll 0.095, pv ks test: 0.00378
# grom, 2: shuffled: std, pv = 0.00000, r2 = 0.083, shuff=[0.034,0.035138]
# grom, 2: shuffled: roll, pv = 1.00000, r2 = 0.083, shuff=[0.095,0.097983]
# Shuffle 0, 0.06419
# ix valid: 14136
# ...

# %%
#pred_fwd.plot_R2_model(nshuffs=5)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 12:41:41.933705. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#pred_fwd.plot_R2_model(nshuffs=10, nshuffs_roll=10)
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">
# Shuffle 0, 0.03487
# KS test distributions: mn shuff 0.178, mn roll 0.241, pv ks test: 0.00002
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.242, shuff=[0.178,0.181031]
# grom, 0: shuffled: roll, pv = 0.00000, r2 = 0.242, shuff=[0.241,0.241759]
# Shuffle 0, 0.02216
# KS test distributions: mn shuff 0.213, mn roll 0.254, pv ks test: 0.00002
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.287, shuff=[0.213,0.214877]
# grom, 1: shuffled: roll, pv = 0.00000, r2 = 0.287, shuff=[0.254,0.255439]
# Shuffle 0, 0.05195
# KS test distributions: mn shuff 0.040, mn roll 0.098, pv ks test: 0.00002
# grom, 2: shuffled: std, pv = 0.00000, r2 = 0.093, shuff=[0.040,0.041544]
# grom, 2: shuffled: roll, pv = 1.00000, r2 = 0.093, shuff=[0.098,0.097902]
# Shuffle 0, 0.05411
# KS test distributions: mn shuff 0.042, mn roll 0.083, pv ks test: 0.00002
# grom, 3: shuffled: std, pv = 0.00000, r2 = 0.085, shuff=[0.042,0.042784]
# ...

# %%
#pred_fwd.plot_R2_model(plot_action=True, nshuffs=10, nshuffs_roll=10)
# Out:
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Shuffle 0, 0.05722
# KS test distributions: mn shuff 0.421, mn roll 0.329, pv ks test: 0.00002
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.463, shuff=[0.421,0.424304]
# grom, 0: shuffled: roll, pv = 0.00000, r2 = 0.463, shuff=[0.329,0.335003]
# Shuffle 0, 0.02271
# KS test distributions: mn shuff 0.382, mn roll 0.286, pv ks test: 0.00002
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.423, shuff=[0.382,0.384856]
# grom, 1: shuffled: roll, pv = 0.00000, r2 = 0.423, shuff=[0.286,0.292539]
# Shuffle 0, 0.04747
# KS test distributions: mn shuff 0.257, mn roll 0.044, pv ks test: 0.00002
# grom, 2: shuffled: std, pv = 0.00000, r2 = 0.323, shuff=[0.257,0.259429]
# grom, 2: shuffled: roll, pv = 0.00000, r2 = 0.323, shuff=[0.044,0.045406]
# Shuffle 0, 0.06717
# KS test distributions: mn shuff 0.296, mn roll 0.218, pv ks test: 0.00002
# grom, 3: shuffled: std, pv = 0.00000, r2 = 0.352, shuff=[0.296,0.297828]
# ...

# %%
#pred_fwd.plot_R2_model(plot_action=True, nshuffs=10, nshuffs_roll=10)
# Out:
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Shuffle 0, 0.03197
# KS test distributions: mn shuff 0.421, mn roll 0.329, pv ks test: 0.00000
# grom, 0: shuffled: std, pv = 0.00000, r2 = 0.463, shuff=[0.421,0.423963]
# grom, 0: shuffled: roll, pv = 0.00000, r2 = 0.463, shuff=[0.329,0.335003]
# Shuffle 0, 0.02234
# KS test distributions: mn shuff 0.382, mn roll 0.286, pv ks test: 0.00000
# grom, 1: shuffled: std, pv = 0.00000, r2 = 0.423, shuff=[0.382,0.385525]
# grom, 1: shuffled: roll, pv = 0.00000, r2 = 0.423, shuff=[0.286,0.292539]
# Shuffle 0, 0.09663
# KS test distributions: mn shuff 0.256, mn roll 0.044, pv ks test: 0.00000
# grom, 2: shuffled: std, pv = 0.00000, r2 = 0.323, shuff=[0.256,0.259238]
# grom, 2: shuffled: roll, pv = 0.00000, r2 = 0.323, shuff=[0.044,0.045406]
# Shuffle 0, 0.05950
# KS test distributions: mn shuff 0.296, mn roll 0.218, pv ks test: 0.00000
# grom, 3: shuffled: std, pv = 0.00000, r2 = 0.352, shuff=[0.296,0.299108]
# ...

# %%
pred_fwd.pred_vs_true_next_command(nshuffs=0)
# Out:
# <img src="data:image/png;base64,..." width="143.33333713037007">
# <img src="data:image/png;base64,..." width="143.33333713037007">
# <img src="data:image/png;base64,..." width="287.77778540128566">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# online_analysis/plot_fr_diffs.py:185: RuntimeWarning: invalid value encountered in greater
#   if np.all(pv_recent > psig):
# grom, 0, pv = 0.00000
# grom, 1, pv = 0.00000
# grom, 2, pv = 0.00000
# grom, 3, pv = 0.00000
# grom, 4, pv = 0.00000
# grom, 5, pv = 0.00000
# grom, 6, pv = 0.00025
# grom, 7, pv = 0.11703
# grom, 8, pv = 0.00000
# POOLED STATS grom, pv = 0.00000, rv = 0.76, slp=0.263
# jeev, 0, pv = 0.00000
# jeev, 1, pv = 0.00000
# jeev, 2, pv = 0.00000
# jeev, 3, pv = 0.00000
# POOLED STATS jeev, pv = 0.00000, rv = 0.63, slp=0.178
# ...

# %%
pred_fwd.pred_vs_true_next_command(nshuffs=0)
# Out:
# <img src="data:image/png;base64,..." width="144">
# <img src="data:image/png;base64,..." width="144">
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="360">
# <img src="data:image/png;base64,..." width="216">
# grom, 0, pv = 0.00000
# POOLED STATS grom, pv = 0.00000, rv = 0.61, slp=0.191
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-14 14:16:28.166571. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-17 16:40:06.939780. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#pred_fwd.pred_vs_true_next_command(nshuffs=20)
# Out:
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="498.88890210493145">
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="298.88889680674066">
# No push
# Shuffle 0, 0.03361
# Shuffle 10, 1.32684
# No push
# Shuffle 0, 0.03485
# Shuffle 10, 6.06405
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="298.88889680674066">
# No push
# Shuffle 0, 0.02628
# Shuffle 10, 0.30532
# No push
# Shuffle 0, 0.02226
# Shuffle 10, 2.26273
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="298.88889680674066">
# No push
# Shuffle 0, 0.05653
# Shuffle 10, 17.23599
# No push
# Shuffle 0, 0.05566
# Shuffle 10, 22.54090
# <img src="data:image/png;base64,..." width="298.88889680674066">
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 17:22:13.830376. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import analysis_config
from online_analysis import generalization_plots, generate_models, util_fcns, generate_models_utils
from online_analysis.generalization_plots import DataExtract
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 11:39:50.354643. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
f, ax = plt.subplots()
f1, ax1 = plt.subplots()

alpha_dict = pickle.load(open(analysis_config.config['grom_pref'] + 'max_alphas_ridge_model_set6.pkl', 'rb'))
mag_boundaries = pickle.load(open(analysis_config.data_params['mag_bound_file']))

for i_a, animal in enumerate(['grom']):#, 'jeev']):
    for day_ix in [2, 4]:#range(analysis_config.data_params['%s_ndays'%animal]):
        
        #### Alpha ####
        alpha = alpha_dict[animal][0][day_ix, 'hist_1pos_0psh_0spksm_1_spksp_0']
        
        #### Get true data ####
        dataObj = DataExtract(animal, day_ix, model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', 
                model_set_number = 6, nshuffs=0)
        dataObj.load()
        
        if animal == 'grom':
            KG, KG_null_proj, KG_potent_orth = generate_models.get_KG_decoder_grom(day_ix)
        elif animal == 'jeev':
            KG, KG_null_proj, KG_potent_orth = generate_models.get_KG_decoder_jeev(day_ix)
            
        #### Decompose activity (tm0 and tm1) into null / potent 
        #### maek sure spks and push are aligned? 
        if animal == 'grom':
            assert(np.allclose(np.dot(KG, 0.1*dataObj.spks.T).T, dataObj.push[:, [3, 5]]))
        
        elif animal == 'jeev': 
            assert(generate_models_utils.quick_reg(np.array(np.dot(KG, 0.1*dataObj.spks.T).T), 
                            dataObj.push[:, [3, 5]]) > .98)
            
            #### Make sure null proj is zero ###
            assert(np.allclose(np.dot(KG, np.dot(KG_null_proj, 0.1*dataObj.spks.T)).T, 
                               0.))
            
            ### Make sure pot proj works: 
            assert(np.allclose(np.array(np.dot(KG, 0.1*dataObj.spks.T).T), 
                            np.dot(KG, np.dot(KG_potent_orth, 0.1*dataObj.spks.T)).T))
        
        ##### Get the null / potent activity ###
        null, pot = generate_models.decompose_null_pot(0.1*dataObj.spks, dataObj.push, KG, KG_null_proj, KG_potent_orth)
        null_tm1, pot_tm1 = generate_models.decompose_null_pot(0.1*dataObj.spks_tm1, dataObj.push_tm1, KG, 
                                                               KG_null_proj, KG_potent_orth)
        
        ### Push at time - 1; 
        command_bins_tm1 = util_fcns.commands2bins([dataObj.push_tm1], mag_boundaries, animal, day_ix, vel_ix = [3, 5])[0]
        
        #### get command bins disk ####
        assert(np.allclose(np.dot(KG, null.T).T, 0.))
        assert(np.allclose(np.dot(KG, null_tm1.T).T, 0.))
        
        ## Dynamics R2 of null / pot / combined ####
        T = dataObj.spks.shape[0]
        spks_pred, _, _ = generalization_plots.train_and_pred(0.1*dataObj.spks_tm1, 0.1*dataObj.spks, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                              skip_cond = True)
        spks_r2 = util_fcns.get_R2(0.1*dataObj.spks, spks_pred)
        print('day %d: spks r2 %.3f' %(day_ix, spks_r2))
        KG = np.array(KG)
        act_r2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred.T).T)
        ax1.plot(day_ix + 10*i_a, act_r2, 'k*')
        print('day %d: act r2 %.3f' %(day_ix, act_r2))
        ax.plot(day_ix + 10*i_a, spks_r2, 'k*')
 
        shuff = dict(); 
        shuff_act = dict();
        for i in range(5):
            shuff[i] = []
            shuff_act[i] = []
            
        #### Now do some rolling; 
        for i in range(10): 
            
            #### Roll this guy ; 
            ix = np.arange(T)
            roll_ix = np.roll(ix, np.random.randint(100, T))
            
            ### Next time step ###
            spks_0 = null[roll_ix] + pot; 
            
            ### Shuffle #### 
            spks_11 = pot_tm1
            spks_2 = null_tm1[roll_ix]
            spks_3 = null_tm1[roll_ix] + pot_tm1; 
            
            for i_s, spks_1 in enumerate([spks_11, spks_2, spks_3]):
                ### Get the 
                spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_0, 
                                                                  dataObj.push[:, [3, 5]], 
                                                                  np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                                  skip_cond = True)
                r2i = util_fcns.get_R2(spks_0, spks_pred_i)
                shuff[i_s].append(r2i)
                KG = np.array(KG)
                #assert(np.allclose(np.dot(KG, spks_0.T).T, dataObj.push[:, [3, 5]]))
                r2i2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred_i.T).T)
                shuff_act[i_s].append(r2i2)
        
        
            #### Another shuffle type
            spks_10 = 0.1*dataObj.spks
            shuff_ix, _ = generate_models_utils.within_bin_shuffling(pot_tm1, dataObj.push_tm1[:, [3, 5]], 
                                                                       animal, day_ix)
            pot_tm1_shuff = pot_tm1[shuff_ix, :]
            
            #### Make srue the same command bins 
            command_bins_tm1_shuff = util_fcns.commands2bins([dataObj.push_tm1[np.ix_(shuff_ix, [3, 5])]], 
                                                             mag_boundaries, animal, day_ix, 
                                                             vel_ix = [0, 1])[0]
            assert(np.allclose(command_bins_tm1_shuff, command_bins_tm1))

            ##### If acceptable, make the tm1 shuff ###
            spks_tm1_shuff1 = null_tm1 + pot_tm1_shuff; 
            spks_tm1_shuff2 = null_tm1[roll_ix] + pot_tm1_shuff; 
            
            for i_s, spks_1 in enumerate([spks_tm1_shuff1, spks_tm1_shuff2]):
                if i_s == 0:
                    spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_10, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                              skip_cond = True)
                    r2i = util_fcns.get_R2(spks_10, spks_pred_i)
                
                elif i_s == 1:
                    spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_0, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                              skip_cond = True)
                    r2i = util_fcns.get_R2(spks_0, spks_pred_i)
                
                shuff[3+i_s].append(r2i)
                KG = np.array(KG)
                #assert(np.allclose(np.dot(KG, spks_0.T).T, dataObj.push[:, [3, 5]]))
                r2i2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred_i.T).T)
                shuff_act[3+i_s].append(r2i2)

            
            
        cols = ['r', 'g', 'k', 'deeppink', 'b']
        for i_s in range(5):
            util_fcns.draw_plot(10*i_a + day_ix, shuff[i_s], cols[i_s], np.array([1.,1.,1.,0.]), ax)
            util_fcns.draw_plot(10*i_a + day_ix, shuff_act[i_s], cols[i_s], np.array([1.,1.,1.,0.]), ax1)
            #print('pink shuffle spks mean %s %d = %.4f' %(animal, day_ix, np.mean(shuff)))
            #print('pink shuffle act mean %s %d = %.4f' %(animal, day_ix, np.mean(shuff_act)))
        
ax.set_xlim([-1, 14])
ax.set_ylabel('R2 of next activity')
f.tight_layout()

ax1.set_xlim([-1, 14])
ax1.set_ylabel('R2 of next command')
f1.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="757.7777978520339">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# day 2: spks r2 0.101
# day 2: act r2 0.331
# day 4: spks r2 0.099
# day 4: act r2 0.322
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 18:02:18.845169. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.test_shuffles()
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 18:52:23.571354. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
