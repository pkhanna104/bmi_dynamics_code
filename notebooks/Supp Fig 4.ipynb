# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from online_analysis import plot_generated_models, generate_models, generate_models_utils, generate_models_list
from online_analysis import plot_pred_fr_diffs

# %%
pdb
# Out:
# Automatic pdb calling has been turned OFF
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 19:01:37.443667. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generate_models.sweep_alpha_all(model_set_number = 12, fit_intercept = True, 
                                normalize_ridge_vars = True, run_alphas=False)
# Out:
# online_analysis/generate_models.py:2222: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(analysis_config.config['jeev_pref'] + 'jeev_sweep_alpha_days_models_set%d.h5' %model_set_number)
#
# online_analysis/generate_models.py:2210: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(analysis_config.config['grom_pref'] + 'grom_sweep_alpha_days_models_set%d.h5' %model_set_number)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
# for animal in ['grom','jeev']:
#     generate_models.model_individual_cell_tuning_curves(hdf_filename='_suppfig4', 
#         animal=animal, 
#         model_set_number = 12, 
#         fit_intercept = True,
#         add_model_to_datafile = True, normalize_ridge_vars = True)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 19:01:46.991830. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 20:11:08.812918. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.plot_suppfig4_R2_bars(ridge_norm=True, fraction=True)
# Out:
# Animal grom, Day 0
# Number of dim 44, number of obs 9
# Extracting
# Number of dim 44, number of obs 9
# Number of dim 44, number of obs 9
# Animal grom, Day 1
# Animal grom, Day 2
# Animal grom, Day 3
# Animal grom, Day 4
# Animal grom, Day 5
# Animal grom, Day 6
# Animal grom, Day 7
# Animal grom, Day 8
# R2 relative: mn = 0.158, std = 0.102
# Animal grom, N = 9, T = -7.182, pv =
# 9.40608899952991e-05
# SU error: Animal grom, N = 116363, T = 41.145, pv =
# 0.0
# POP error: Animal grom, N = 1606, T = 24.600, pv =
# 1.1873640115472671e-113
# Animal grom, Cond err 1.199
# Animal grom, Cond err 0.275
# Animal jeev, Day 0
# Extracting
# Animal jeev, Day 1
# Animal jeev, Day 2
# Animal jeev, Day 3
# R2 relative: mn = 0.237, std = 0.034
# Animal jeev, N = 4, T = -5.141, pv =
# 0.01426217576779537
# SU error: Animal jeev, N = 9019, T = 19.801, pv =
# 1.8618364263336811e-85
# POP error: Animal jeev, N = 445, T = 13.948, pv =
# 6.319751169445586e-37
# Animal jeev, Cond err 1.405
# ...

# %%
#### concerns -- Ridge is squashing coefficients, so it amkes sense that variables 
#### should have approx equal variance otherwise this optimization doesnt' make sense 

### Second concern -- the movement ID should be a categorical dummy variable, not a continuous variable

### Does scaling make sense with the categorical variable?
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 14:01:52.822883. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# Try this out: 
plot_pred_fr_diffs.plot_suppfig4_R2_bars(ridge_norm=True, fraction=False)
# Out:
# Animal grom, Day 0
# Extracting
# Animal grom, Day 1
# Animal grom, Day 2
# Animal grom, Day 3
# Animal grom, Day 4
# Animal grom, Day 5
# Animal grom, Day 6
# Animal grom, Day 7
# Animal grom, Day 8
# Animal grom, N = 9, T = -7.182, pv =
# 9.40608899952991e-05
# Animal jeev, Day 0
# Extracting
# Animal jeev, Day 1
# Animal jeev, Day 2
# Animal jeev, Day 3
# Animal jeev, N = 4, T = -5.141, pv =
# 0.01426217576779537
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 19:40:40.711336. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
ix = np.arange(10)
ix2 = np.arange(5, 15)
ix3 = np.arange(7, 17)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 19:48:06.015570. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
x = np.where((ix==0) & (ix2==5) & (ix3==7))[0]
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 19:48:54.033266. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
x
# Out:
# array([0])
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-15 19:48:54.527559. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_pred_fr_diffs.plot_suppfig4_R2_bars(ridge_norm=True, fraction=True)
# Out:
# Animal grom, Day 0
# Number of dim 44, number of obs 9
# Extracting
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator Ridge from version 0.20.4 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# Number of dim 44, number of obs 9
# Number of dim 44, number of obs 9
# Animal grom, Day 1
# Animal grom, Day 2
# Animal grom, Day 3
# Animal grom, Day 4
# Animal grom, Day 5
# Animal grom, Day 6
# Animal grom, Day 7
# Animal grom, Day 8
# Model: cond, X-pos 0, R2 mean 0.158, R2 norm 0.000
# Model: hist_1pos_1psh_2spksm_0_spksp_0, X-pos 1, R2 mean 0.169, R2 norm 0.070
# ...
