# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import analysis_config
from online_analysis import util_fcns, generate_models, plot_fr_diffs
from matplotlib import colors as mpl_colors
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
plot_fr_diffs.plot_example_neuron_comm(save=True)
# Out:
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="349.99999478459364">
# Mov 14.1, # Iters 0 to match global
# mov 14.1, N = 8, mFR = 29.50
# Mov 1.0, # Iters 0 to match global
# mov 1.0, N = 8, mFR = 14.62
# Mov 2.0, # Iters 0 to match global
# mov 2.0, N = 8, mFR = 21.11
# Mov 3.0, # Iters 0 to match global
# mov 3.0, N = 8, mFR = 30.00
# Mov 12.1, # Iters 0 to match global
# mov 12.1, N = 8, mFR = 20.82
# Mov 10.1, # Iters 0 to match global
# mov 10.1, N = 8, mFR = 12.25
# Mov 11.1, # Iters 0 to match global
# mov 11.1, N = 8, mFR = 16.61
# Mov 15.0, # Iters 0 to match global
# mov 15.0, N = 8, mFR = 26.67
# Mov 13.1, # Iters 0 to match global
# mov 13.1, N = 8, mFR = 23.04
# ...

# %%
ps, psv, nit, pooled_stats = plot_fr_diffs.perc_neuron_command_move_sig()
#plot_fr_diffs.plot_su_pop_stats(ps, psv)
# Out:
# online_analysis/plot_fr_diffs.py:822: RuntimeWarning: invalid value encountered in double_scalars
#   perc_sig[animal, day_ix][mag, ang, mov].append(np.array((pv, dFR, dFR/global_mean_FR[i_neur], global_mean_FR[i_neur]), dtype=dtype_su))
#
# online_analysis/plot_fr_diffs.py:822: RuntimeWarning: divide by zero encountered in double_scalars
#   perc_sig[animal, day_ix][mag, ang, mov].append(np.array((pv, dFR, dFR/global_mean_FR[i_neur], global_mean_FR[i_neur]), dtype=dtype_su))
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 22:11:53.973525. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.print_pooled_stats_fig3(pooled_stats)
# Out:
# pv_ncm = 0.00000, mn_ncm = 1.562, mn_shuff = 1.205 (95th = 1.226)
# pv_cm = 0.00000, mn_cm = 0.349, mn_shuff = 0.254 (95th = 0.259)
# pv_ncm = 0.00000, mn_ncm = 0.943, mn_shuff = 0.746 (95th = 0.763)
# pv_cm = 0.00000, mn_cm = 0.252, mn_shuff = 0.182 (95th = 0.188)
# pv_ncm = 0.00000, mn_ncm = 0.760, mn_shuff = 0.622 (95th = 0.629)
# pv_cm = 0.00000, mn_cm = 0.102, mn_shuff = 0.078 (95th = 0.079)
# pv_ncm = 0.00000, mn_ncm = 1.145, mn_shuff = 0.967 (95th = 0.980)
# pv_cm = 0.00000, mn_cm = 0.225, mn_shuff = 0.185 (95th = 0.187)
# pv_ncm = 0.00000, mn_ncm = 0.855, mn_shuff = 0.731 (95th = 0.738)
# pv_cm = 0.00000, mn_cm = 0.121, mn_shuff = 0.096 (95th = 0.098)
# pv_ncm = 0.00000, mn_ncm = 1.311, mn_shuff = 1.207 (95th = 1.222)
# pv_cm = 0.00000, mn_cm = 0.277, mn_shuff = 0.253 (95th = 0.256)
# pv_ncm = 0.00000, mn_ncm = 0.941, mn_shuff = 0.840 (95th = 0.861)
# pv_cm = 0.00000, mn_cm = 0.192, mn_shuff = 0.165 (95th = 0.170)
# ...

# %%
#sig_mov_command = pickle.load(open(analysis_config.config['grom_pref'] + 'sig_move_comm.pkl', 'rb'))
plot_fr_diffs.plot_su_pop_stats(ps, psv, sig_mov_command)
# Out:
# <img src="data:image/png;base64,..." width="143.88889270064283">
# <img src="data:image/png;base64,..." width="143.88889270064283">
# <img src="data:image/png;base64,..." width="143.88889270064283">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="143.88889270064283">
# <img src="data:image/png;base64,..." width="143.88889270064283">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="143.88889270064283">
# mov 3.00, color w alpha [0.41960784 0.55686275 0.1372549 ], color wo alpha [0.41960784 0.55686275 0.1372549  1.        ]
# ...

# %%
plot_fr_diffs.neuraldiff_vs_behdiff_corr_pw_by_command(min_move_per_command=6)
# Out:
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="199.99999701976782">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-05 23:54:59.326397. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_stats = plot_fr_diffs.neuraldiff_vs_behaviordiff_corr_pairwise(ncommands_psth=5, nshuffs=1, min_commands=15,
                                                                   min_move_per_command = 6)
# Out:
# <img src="data:image/png;base64,..." width="144">
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="288">
# starting grom, day 0
# <img src="data:image/png;base64,..." width="432">
# online_analysis/plot_fr_diffs.py:185: RuntimeWarning: invalid value encountered in greater
#   if np.all(pv_recent > psig):
# Example r = 0.7292, slp = 0.10, intc = 0.28, pv = 0.00000, N = 36
# starting grom, day 1
# <img src="data:image/png;base64,..." width="432">
# starting grom, day 2
# <img src="data:image/png;base64,..." width="432">
# Example r = 0.6067, slp = 0.02, intc = 0.08, pv = 0.00062, N = 28
# starting grom, day 3
# <img src="data:image/png;base64,..." width="432">
# Example r = 0.6423, slp = 0.07, intc = 0.18, pv = 0.00000, N = 55
# starting grom, day 4
# <img src="data:image/png;base64,..." width="432">
# Example r = 0.7489, slp = 0.08, intc = 0.06, pv = 0.00009, N = 21
# ...

# %%
len(plot_stats['grom'])
# Out:
# 4674
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 22:54:54.648724. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Make LME dictionary ###
import pandas as pd
import statsmodels.formula.api as smf

#### Overall stats is done with everything as long as >= 15 commands per ####
dayz = dict(grom=9, jeev=4)

for animal in ['grom', 'jeev']:
    lme_array = np.vstack((plot_stats[animal]))
    lme_dict = {}
    for key in ['dB','dN','day_ix', 'ang', 'mag']:
        lme_dict[key] = np.squeeze(lme_array[:][key])
    lme_dict['grp'] =  lme_dict['day_ix']*100 + lme_dict['mag']*8 + lme_dict['ang']
    df_lme = pd.DataFrame(lme_dict)
    
    for day_ix in range(dayz[animal]):
        ix_day = np.nonzero(lme_dict['day_ix'] == day_ix)[0]
        df_lme_day = dict(dB=lme_dict['dB'][ix_day],
                          dN=lme_dict['dN'][ix_day],
                          grp=lme_dict['grp'][ix_day])
        
        md = smf.mixedlm("dN ~ dB", df_lme_day, groups=df_lme_day["grp"])
        mdf = md.fit()
        print('Animal %s || Day ix %d'%(animal, day_ix))
        print('PV: ',mdf.pvalues['dB'])
        print('Slp:',mdf.params['dB'])
        
    ### Pooled 
    print('POOLED')
    md = smf.mixedlm('dN ~ dB', df_lme, groups=df_lme['grp'])
    mdf = md.fit()
    print('PV: ', mdf.pvalues['dB'])
    print('Slp: ', mdf.params['dB'])
    print(mdf.summary())
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2045: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom || Day ix 0
# ('PV: ', 1.0245427569774943e-52)
# ('Slp:', 0.05467836203979354)
# Animal grom || Day ix 1
# ('PV: ', 1.435334163152804e-26)
# ('Slp:', 0.044214317174539566)
# Animal grom || Day ix 2
# ...

# %%
def linear_mixed_effects(plot_stats):

# %%
####### Test the pairwise subsampling ####
# push_command_mov1 = np.random.randn(200, 2)
# push_command_mov2 = np.random.randn(200, 2) 
# push_command_mov2[:, 1] += -1
# push_command_mov2[:, 1] *= 2

# f, ax = plt.subplots(ncols = 2)
# for i in range(2):
#     ax[i].hist(push_command_mov1[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov1[:, i]), 0, 50, 'b')
#     ax[i].hist(push_command_mov2[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov2[:, i]), 0, 50, 'g')
#     ax[i].set_title('B %d, G %d' %(len(push_command_mov1), len(push_command_mov2)))

# ix1, ix2, niter = plot_fr_diffs.distribution_match_mov_pairwise(push_command_mov1, push_command_mov2)

# print('# iteration %d' %(niter))
# f, ax = plt.subplots(ncols = 2)
# for i in range(2):
#     ax[i].hist(push_command_mov1[ix1, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov1[ix1, i]), 0, 50, 'b')
#     ax[i].hist(push_command_mov2[ix2, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov2[ix2, i]), 0, 50, 'g')
#     ax[i].set_title('B %d, G %d' %(len(ix1), len(ix2)))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-19 11:28:17.165609. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# ###### Test the subsampling #######
# push_command_mov = np.random.randn(100, 2)
# push_command = np.random.randn(1000, 2) + 1
# push_command[:, 1] += -1
# push_command[:, 1] *= 2
# f, ax = plt.subplots(ncols = 2)
# for i in range(2):
#     ax[i].hist(push_command_mov[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov[:, i]), 0, 50, 'b')
#     ax[i].hist(push_command[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command[:, i]), 0, 200, 'g')
#     ax[i].set_title('B %d, G %d' %(len(push_command_mov), len(push_command)))

# ix, niter = distribution_match_global_mov(push_command_mov, push_command,
#                                   plot=False)
# print('# iteration %d' %(niter))
# f, ax = plt.subplots(ncols = 2)
# for i in range(2):
#     ax[i].hist(push_command_mov[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov[:, i]), 0, 50, 'b')
#     ax[i].hist(push_command[ix, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command[ix, i]), 0, 50, 'g')
#     ax[i].set_title('B %d, G %d' %(len(push_command_mov), len(push_command[ix, i])))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 10:22:37.213626. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# Save data with relevant params 
# generate_models.model_ind_cell_tuning_SHUFFLE(nshuffs=2)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-17 12:38:09.930108. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Reproduce neuron 36 plot

# %%
#### Load data from shuffle data

# %%
def get_data(animal, day_ix):
    dat = pickle.load(open('/Volumes/Elements/shuffle_data/w_intc/%s_%d_shuff_ix.pkl'%(animal, day_ix), 'rb'))
    
    #### Extract the data ####
    spks = dat['Data']['spks']
    push = dat['Data']['push']
    tsk = dat['Data']['task']
    trg = dat['Data']['targ']
    move = tsk*10 + trg
    bin_num = dat['Data']['bin_num']
    
    ### Get reversed bin number ####
    rev_bin_num = bin_num_relative_to_end(bin_num)
    bin_num = np.hstack((bin_num))
    
    ### Make sure all the samse length 
    assert(spks.shape[0] == push.shape[0] == len(tsk) == len(trg) == len(bin_num) == len(rev_bin_num))
    return spks, push, tsk, trg, bin_num, rev_bin_num, move, dat
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 10:22:31.198230. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def bin_num_relative_to_end(bin_num): 
    '''
    method to index bin relative to the end of the trial 
    '''
    bin_cnt = []
    for b in bin_num:
        bin_cnt.append(b[::-1])
    bin_cnt = np.hstack((bin_cnt))
    bin_num = np.hstack((bin_num))
    
    ix, _ = scipy.signal.find_peaks(bin_num)
    assert(np.all(bin_cnt[ix] == 0))
    
    ix, _ = scipy.signal.find_peaks(bin_cnt)
    assert(np.all(bin_num[ix] == 0))
    
    return np.hstack((bin_cnt))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 10:22:31.762787. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def return_indices(bin_num, rev_bin_num, push, mag_boundaries, animal='grom', day_ix=0, 
                   min_bin_num=0, min_rev_bin_num=0, mag=0, ang=7):
    
    #### Select correct indices --> indices 0-4 inclusive are rejected 
    ix_valid = np.nonzero(np.logical_and(np.hstack((bin_num)) >= min_bin_num, rev_bin_num >= min_rev_bin_num))[0]
    
    command_bins = util_fcns.commands2bins([push], mag_boundaries, animal, day_ix, 
                                       vel_ix=[3, 5])[0]
    ix_command = np.nonzero(np.logical_and(command_bins[:, 0] == mag, command_bins[:, 1] == ang))[0]
    
    ix_command_valid = np.intersect1d(ix_valid, ix_command)
    return ix_command_valid
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 10:22:34.239044. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def distribution_match_global_mov(push_command_mov, push_command, psig=.05, 
                                  perc_drop = 0.05, plot=False):
    '''
    return indices for push_command that says which of these can be be shuffled around 
    '''
    complete = False
    niter = 0
    nVar = push_command_mov.shape[1]
    assert(push_command.shape[1] == nVar)
    
    #### Keep track of PV 
    PVs = []
    pv_recent = np.zeros((nVar, ))
    
    ### Indices to subsample (will remove these slowly)
    indices = np.arange(push_command.shape[0])
    
    ### mean to match; 
    mean_match = np.mean(push_command_mov, axis=0)
    var_match = np.std(push_command_mov, axis=0)
    
    while not complete:
        for var in range(nVar):
            t,pv = scipy.stats.ttest_ind(push_command_mov[:, var], push_command[indices, var])
            pv_recent[var] = pv 
        
        if np.all(pv_recent > psig):
            complete = True
            return indices, niter
        
        else:
            niter += 1
            #print('Starting iter %d' %(niter))
            #print(pv_recent)
            
            ### Compute cost of each sample of push_command 
            mean_diff = push_command[indices, :] - mean_match[np.newaxis, :]
            
            ### So dimensions with high variance aren't weighted as strongly 
            cost = mean_diff / var_match[np.newaxis, :]
        
            ### Sum across dimensions 
            cost_sum = np.sum(cost**2, axis=1)
            
            ### How many pts to drop
            Npts = len(cost_sum)
            NptsDrop = int(np.floor(perc_drop * Npts))
            
            ### Sort from low to high 
            ix_sort = np.argsort(cost_sum)
            
            ### Remove the highest cost 
            ix_remove = ix_sort[-NptsDrop:]
            
            ### Update indices to remove cost
            indices = np.delete(indices, ix_remove)
            
            if plot:
                f, ax = plt.subplots()
                ax.hist(push_command_mov, alpha=.3)
                ax.vlines(np.mean(push_command_mov), 0, 50, 'b')
                ax.hist(push_command[indices], alpha=.3)
                ax.vlines(np.mean(push_command[indices]), 0, 50, 'g')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 10:22:36.019358. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# ###### Test the subsampling #######
# push_command_mov = np.random.randn(100, 2)
# push_command = np.random.randn(1000, 2) + 1
# push_command[:, 1] += -1
# push_command[:, 1] *= 2
# f, ax = plt.subplots(ncols = 2)
# for i in range(2):
#     ax[i].hist(push_command_mov[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov[:, i]), 0, 50, 'b')
#     ax[i].hist(push_command[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command[:, i]), 0, 200, 'g')
#     ax[i].set_title('B %d, G %d' %(len(push_command_mov), len(push_command)))

# ix, niter = distribution_match_global_mov(push_command_mov, push_command,
#                                   plot=False)
# print('# iteration %d' %(niter))
# f, ax = plt.subplots(ncols = 2)
# for i in range(2):
#     ax[i].hist(push_command_mov[:, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command_mov[:, i]), 0, 50, 'b')
#     ax[i].hist(push_command[ix, i], alpha=0.3)
#     ax[i].vlines(np.mean(push_command[ix, i]), 0, 50, 'g')
#     ax[i].set_title('B %d, G %d' %(len(push_command_mov), len(push_command[ix, i])))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 10:22:37.213626. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def plot_example_neuron_comm(neuron_ix = 36, mag = 0, ang = 7, animal='grom', day_ix = 0, nshuffs = 1000,
                            min_bin_indices = 0, save=False):
    
    pref_colors = analysis_config.pref_colors
    
    ###### Extract data #######
    spks, push, tsk, trg, bin_num, rev_bin_num, move, dat = get_data(animal, day_ix)
    spks = spks*10
    nneur = spks.shape[1]
    mag_boundaries = pickle.load(open(analysis_config.data_params['mag_bound_file']))
    command_bins = util_fcns.commands2bins([push], mag_boundaries, animal, day_ix, 
                                       vel_ix=[3, 5])[0]

    f, ax = plt.subplots(figsize=(4,4))
    fvect, axvect = plt.subplots(figsize=(4,4))

    ### Return indices for the command ### 
    ix_com = return_indices(bin_num, rev_bin_num, push, mag_boundaries, animal=animal, 
                            day_ix=day_ix, mag=mag, ang=ang, min_bin_num=min_bin_indices,
                            min_rev_bin_num=min_bin_indices)

    cnt = 0
    mFR = {}; 
    mFR_vect = {};
    mov_number = []; 
    mFR_shuffle = {}
    mFR_shuffle_vect = {}

    for mov in np.unique(move[ix_com]):

        ### Movement specific command indices 
        ix_mc = np.nonzero(move[ix_com] == mov)[0]
        
        ### Which global indices used for command/movement 
        ix_mc_all = ix_com[ix_mc] 

        ### If enought of these then proceed; 
        if len(ix_mc) >= 15:    
            
            print('Starting move %.1f' %(mov))
            
            ### FR for neuron ### 
            FR = spks[ix_mc_all, neuron_ix]
            FR_vect = spks[ix_mc_all, :]

            ### Figure out which of the "ix_com" indices can be used for shuffling for this movement 
            ix_ok, niter = distribution_match_global_mov(push[np.ix_(ix_mc_all, [3, 5])], 
                                                         push[np.ix_(ix_com, [3, 5])])
            print('# Iters %d'%(niter))
            
            ### which indices we can use in global distribution for this shuffle ----> #### 
            global_ix_com_ok_for_shuffle_for_this_mov = ix_com[ix_ok] 
            global_mean_vect = np.mean(spks[global_ix_com_ok_for_shuffle_for_this_mov, :], axis=0)
            
            assert(np.all(command_bins[global_ix_com_ok_for_shuffle_for_this_mov, 0] == mag))
            assert(np.all(command_bins[global_ix_com_ok_for_shuffle_for_this_mov, 1] == ang))
            assert(len(np.unique(move[global_ix_com_ok_for_shuffle_for_this_mov])) > 1)
            
            Nglobal = len(global_ix_com_ok_for_shuffle_for_this_mov)
            Ncommand_mov = len(ix_mc_all)
            
            ### Get matching global distribution 
            mFR_shuffle[mov] = []
            mFR_shuffle_vect[mov] = []
            
            for i_shuff in range(nshuffs):
                ix_sub = np.random.permutation(Nglobal)[:Ncommand_mov]
                mFR_shuffle[mov].append(np.mean(spks[global_ix_com_ok_for_shuffle_for_this_mov[ix_sub], neuron_ix]))
                
                mshuff_vect = np.mean(spks[global_ix_com_ok_for_shuffle_for_this_mov[ix_sub], :], axis=0)
                mFR_shuffle_vect[mov].append(np.linalg.norm(mshuff_vect - global_mean_vect)/nneur)
            
            mFR[mov] = np.mean(FR)
            mFR_vect[mov] = np.linalg.norm(np.mean(FR_vect, axis=0) - global_mean_vect)/nneur
            mov_number.append(mov)
           
            print('mov %.1f, N = %d, mFR = %.2f'% (mov, len(ix_mc), np.mean(FR)))
        else:
            print('skipping %.1f, N = %d' %(mov, len(ix_mc)))

    keys = np.argsort(np.hstack((mFR.keys())) % 10)
        
    for x, mov in enumerate(np.hstack((mFR.keys()))[keys]):

        ### Draw shuffle ###
        colnm = pref_colors[int(mov)%10]
        colrgba = np.array(mpl_colors.to_rgba(colnm))
        if mov >= 10:
            colrgba[-1] = 0.5
        else:
            colrgba[-1] = 1.0
        
        ### Single neuron 
        util_fcns.draw_plot(x, mFR_shuffle[mov], colrgba, np.array([0., 0., 0., 0.]), ax)
        ax.plot(x, mFR[mov], 'k.')
        
        ### Population 
        mn_shuf = np.mean(mFR_shuffle_vect[mov])
        util_fcns.draw_plot(x, mFR_shuffle_vect[mov] - mn_shuf, colrgba, np.array([0., 0., 0., 0.]), axvect)
        axvect.plot(x, mFR_vect[mov] - mn_shuf, 'k.')
    
    for axi in [ax, axvect]:
        axi.set_xlim([-1, 9])        
        axi.set_xlabel('Movement')
        
    ax.hlines(np.mean(spks[ix_com, neuron_ix]), -1, 8, 'gray', linestyle='dashed')
    ax.set_ylabel('Activity (Hz)')   
    ax.set_title('Neuron %d' %(neuron_ix))
    ax.set_ylim([5, 35])
    f.tight_layout()
    if save:
        util_fcns.savefig(f, 'n%d_mag%d_ang%d_%s_d%d_min_bin%d'%(neuron_ix, mag, ang, animal, day_ix, min_bin_indices))
    
    axvect.set_ylabel('Pop. Activity Dist. \n centered by shuffle mn (Hz) ')    
    fvect.tight_layout()
    if save:
        util_fcns.savefig(fvect, 'POP_mag%d_ang%d_%s_d%d_min_bin%d'%(mag, ang, animal, day_ix, min_bin_indices))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 12:43:58.761231. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_example_neuron_comm(min_bin_indices=0)
# Out:
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="288">
# skipping 0.0, N = 6
# Starting move 1.0
# # Iters 0
# mov 1.0, N = 26, mFR = 14.62
# Starting move 2.0
# # Iters 0
# mov 2.0, N = 27, mFR = 21.11
# Starting move 3.0
# # Iters 0
# mov 3.0, N = 15, mFR = 30.00
# skipping 4.0, N = 6
# skipping 5.0, N = 3
# skipping 7.0, N = 1
# Starting move 10.1
# # Iters 0
# mov 10.1, N = 40, mFR = 12.25
# Starting move 11.1
# # Iters 0
# mov 11.1, N = 62, mFR = 16.61
# Starting move 12.1
# # Iters 0
# mov 12.1, N = 61, mFR = 20.82
# Starting move 13.1
# # Iters 0
# mov 13.1, N = 92, mFR = 23.04
# skipping 14.0, N = 12
# Starting move 14.1
# # Iters 0
# mov 14.1, N = 60, mFR = 29.50
# Starting move 15.0
# # Iters 0
# mov 15.0, N = 24, mFR = 26.67
# skipping 16.1, N = 2
# skipping 17.1, N = 8
# ...

# %%
###### TO DO REMOVE low FR neurons #########
##### TO DO only analyze behaviors with sig. effects from Fig. 2 ########


def perc_neuron_command_move_sig(nshuffs = 1000, min_bin_indices = 5):
    
    mag_boundaries = pickle.load(open(analysis_config.data_params['mag_bound_file']))
    perc_sig = {}; 
    perc_sig_vect = {}; 
    niter2match = {}
    
    for ia, animal in enumerate(['grom', 'jeev']):
        
        for day_ix in range(analysis_config.data_params['%s_ndays'%animal]):
            
            perc_sig[animal, day_ix] = {}
            perc_sig_vect[animal, day_ix] = {}
            niter2match[animal, day_ix] = {}
                        
            ### Pull data ### 
            spks, push, tsk, trg, bin_num, rev_bin_num, move, dat = get_data(animal, day_ix)
            spks = spks * 10
            nneur = spks.shape[1]
            command_bins = util_fcns.commands2bins([push], mag_boundaries, animal, day_ix, 
                                       vel_ix=[3, 5])[0]
            
            for mag in range(4):
                
                for ang in range(8): 
            
                    #### Get the indices for command ####
                    ix_com = return_indices(bin_num, rev_bin_num, push, mag_boundaries, mag=mag, ang=ang,
                                           animal=animal, day_ix=day_ix, min_bin_num=min_bin_indices,
                            min_rev_bin_num=min_bin_indices)
                    
                    #### Go through the movements ####
                    for mov in np.unique(move[ix_com]):
                        
                        ### Movement specific command indices 
                        ix_mc = np.nonzero(move[ix_com] == mov)[0]
                        ix_mc_all = ix_com[ix_mc]
                        Ncommand_mov = len(ix_mc_all)
                        
                        ### If enough of these then proceed; 
                        if len(ix_mc) > 15:    
                            perc_sig[animal, day_ix][mag, ang, mov] = []
                            
                            ### FR for neuron ### 
                            mean_FR = np.mean(spks[ix_com[ix_mc], :], axis=0)
                            
                            ### Figure out which of the "ix_com" indices can be used for shuffling for this movement 
                            ix_ok, niter = distribution_match_global_mov(push[np.ix_(ix_mc_all, [3, 5])], 
                                                         push[np.ix_(ix_com, [3, 5])])
                            niter2match[animal, day_ix][mag, ang, mov] = niter 
                            
                            ### which indices we can use in global distribution for this shuffle ----> #### 
                            global_ix_com_ok_for_shuffle_for_this_mov = ix_com[ix_ok] 
                            global_mean = np.mean(spks[global_ix_com_ok_for_shuffle_for_this_mov, :], axis=0)
                            dmean_FR = np.abs(mean_FR - global_mean)
                            
                            Nglobal = len(global_ix_com_ok_for_shuffle_for_this_mov)
                            
                            assert(np.all(command_bins[global_ix_com_ok_for_shuffle_for_this_mov, 0] == mag))
                            assert(np.all(command_bins[global_ix_com_ok_for_shuffle_for_this_mov, 1] == ang))
                            assert(len(np.unique(move[global_ix_com_ok_for_shuffle_for_this_mov])) > 1)

                            ### Get matching global distribution 
                            dmFR_shuffle = []; mFR_shuffle = []
                            for i_shuff in range(nshuffs):
                                ix_sub = np.random.permutation(Nglobal)[:Ncommand_mov]
                                mn_tmp = np.mean(spks[global_ix_com_ok_for_shuffle_for_this_mov[ix_sub], :], axis=0)
                                dmFR_shuffle.append(np.abs(mn_tmp - global_mean))
                                mFR_shuffle.append(mn_tmp)
                                
                            dmFR_shuffle = np.vstack((dmFR_shuffle))
                            mFR_shuffle = np.vstack((mFR_shuffle))
                            
                            for i_neur in range(nneur):
                                ### For each neuron go through and test ;
                                n_lte = len(np.nonzero(dmFR_shuffle[:, i_neur] >= dmean_FR[i_neur])[0])
                                pv = float(n_lte) / float(nshuffs)
                                dFR = np.abs(mean_FR[i_neur] - np.mean(mFR_shuffle[:, i_neur]))
                                perc_sig[animal, day_ix][mag, ang, mov].append([pv, dFR, dFR/np.mean(mFR_shuffle[:, i_neur])]) 
                                
                            #### Vector #####
                            n_lte = len(np.nonzero(np.linalg.norm(dmFR_shuffle, axis=1) >= np.linalg.norm(dmean_FR))[0])
                            pv = float(n_lte) / float(nshuffs)
                            dist = np.linalg.norm(mean_FR - np.mean(mFR_shuffle,axis=0))
                            perc_sig_vect[animal, day_ix][mag, ang, mov] = [pv, dist/nneur]
                            
    return perc_sig, perc_sig_vect, niter2match
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 12:44:16.596815. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### 
ps, psv, niter = perc_neuron_command_move_sig(nshuffs = 1000, min_bin_indices=0)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: invalid value encountered in double_scalars
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:83: RuntimeWarning: divide by zero encountered in double_scalars
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-10-16 12:44:20.175534. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Plot this; 
#### Single neuron plots ######
f, ax = plt.subplots(figsize=(4, 4))
f2, ax2 = plt.subplots(figsize=(4, 4))
feff, axeff = plt.subplots(figsize=(6, 4))
feff2, axeff2 = plt.subplots(figsize=(6, 4))

#### Vector plots ######
fv, axv = plt.subplots(figsize=(4, 4))
fv2, axv2 = plt.subplots(figsize=(4, 4))

# Just show abstract vector norm diff ? 
fveff, axveff = plt.subplots(figsize=(6, 4)) 

for ia, animal in enumerate(['grom', 'jeev']):
    an_bar = []; an_bar2 = []; 
    an_vect_bar = []; an_vect_bar2 = []; 
    
    for day_ix in range(analysis_config.data_params['%s_ndays'%animal]):
        
        cnt_sig = 0
        cnt_tot = 0 
        num_sig = None
        
        sig_hz_diff = []
        sig_frac_diff = []
        
        ###### Single neuron ########
        for i, (k, varr) in enumerate(ps[animal, day_ix].items()):
            
            ### Pvalues ####
            v = np.vstack((varr))[:, 0]
            varr = np.vstack((varr))
            
            if num_sig is None:
                num_sig = np.zeros((len(v)))
                
            for j, vi in enumerate(v): 
                if vi < 0.05:
                    cnt_sig += 1
                    num_sig[j] += 1
                    
                    sig_hz_diff.append(varr[j, 1])
                    sig_frac_diff.append(varr[j, 2])
                    assert(vi == varr[j, 0])
                    
                cnt_tot += 1
        
        ####### Single Neuorns ######
        ax.plot(ia, float(cnt_sig)/float(cnt_tot), 'k.')
        an_bar.append(float(cnt_sig)/float(cnt_tot))
        
        sig_n = len(np.nonzero(num_sig > 0)[0])
        an_bar2.append(float(sig_n) / float(len(num_sig)))
        ax2.plot(ia, float(sig_n) / float(len(num_sig)), 'k.')
        
        ##### Vector ########
        vect_sig = 0 
        vect_tot = 0 
        
        fsig, axsig = plt.subplots(ncols = 4, figsize = (12, 4))
        axsig[0].set_title('%s Day %d '%(animal, day_ix))
        for ai, axi in enumerate(axsig): 
            axi.set_xlabel('Movement\n Mag %d'%(ai))
            axi.set_ylabel('Ang')
        
        ##### Effect size #######
        util_fcns.draw_plot(day_ix + 10*ia, sig_hz_diff, 'k', 'w', axeff)
        util_fcns.draw_plot(day_ix + 10*ia, sig_frac_diff, 'k', 'w', axeff2)
        
        ####################
        commands_w_sig = np.zeros((4, 8)) ### How many are sig? 
        command_cnt = np.zeros((4, 8)) ### How many movements count? 
        sig_hz_diff_vect = []
        
        for i, (k, varr) in enumerate(psv[animal, day_ix].items()):
            v = varr[0]
            
            if v < 0.05:
                vect_sig += 1
                commands_w_sig[k[0], k[1]] += 1
                axsig[k[0]].plot(k[2], k[1], '.', color='orangered')
                
                ### For commands / moves that are different what is the np.linalg.norm? 
                sig_hz_diff_vect.append(varr[1])
            
            else:
                axsig[k[0]].plot(k[2], k[1], '.', color='k')
            
            command_cnt[k[0], k[1]] += 1
            vect_tot += 1
        
        fsig.tight_layout()
        
        ####### Need at least 2 movemetns #####
        ix_consider = np.nonzero(command_cnt.reshape(-1) >= 2)[0]
        vect_tot = np.sum(command_cnt.reshape(-1)[ix_consider])
        vect_sig = np.sum(commands_w_sig.reshape(-1)[ix_consider])
        axv.plot(ia, float(vect_sig)/float(vect_tot), 'k.')
        
        an_vect_bar.append(float(vect_sig)/float(vect_tot))
        
        
        ### Need at least 1 sig 
        ix1 = np.nonzero(commands_w_sig.reshape(-1)[ix_consider] >= 1)[0]
        axv2.plot(ia, float(len(ix1))/float(len(ix_consider)), 'k.')
        an_vect_bar2.append(float(len(ix1))/float(len(ix_consider)))
        
        ### Distribution of population ###
        util_fcns.draw_plot(ia*10 + day_ix, sig_hz_diff_vect, 'k', 'w', axveff)
        
    ####### Single neuron summary for the day #####
    ax.bar(ia, np.mean(an_bar), width=.8,alpha=0.2, color='k')
    ax2.bar(ia, np.mean(an_bar2), width=.8, alpha=0.2, color='k')
    
    ####### Vector  neuron summary for the day #####
    axv.bar(ia, np.mean(an_vect_bar), width=.8,alpha=0.2, color='k')
    axv2.bar(ia, np.mean(an_vect_bar2), width=.8, alpha=0.2, color='k')
    
    
    
for axi in [ax, ax2, axv, axv2]:
    axi.set_xticks([0, 1])
    axi.set_xticklabels(['G', 'J'])
    axi.set_xlim([-1, 2])

ax.set_ylabel('Frac of neurons/command/mov sig. diff \nfrom global (nshuff=1000)')
ax2.set_ylabel('Frac of neurons with > 0 sig. diff \nfrom global (nshuff=1000)')

axv.set_ylabel('Frac of command/mov sig. diff \nfrom global (nshuff=1000)')
axv2.set_ylabel('Frac of commands with > 0 sig. diff mov\nfrom global (nshuff=1000)')

f.tight_layout()
f2.tight_layout()
fv.tight_layout()
fv2.tight_layout()

util_fcns.savefig(f, 'frac_neur_comm_mov_sig_diff_from_global')
util_fcns.savefig(f2, 'frac_with_gte_0_sig_diff_from_global')
util_fcns.savefig(fv, 'frac_comm_mov_sig_diff_from_global')
util_fcns.savefig(fv2, 'frac_comm_with_gte_0_sig_diff_mov_from_global')

###### Effect size plots #######
for ax_ in [axeff, axeff2, axveff]:
    ax_.set_xlim([-1, 14])
axeff.set_ylim([0, 9.])
axeff2.set_ylim([0, 3.0])

axeff.set_ylabel('Activity Diff from Shuffle Mean (Hz)')
axeff.set_title('Sig. Diff Neurons/Command/Move')

axeff2.set_ylabel('Frac. Diff Activity from Shuffle Mean')
axeff2.set_title('Sig. Diff Neurons/Command/Move')

axveff.set_ylabel('Pop. Activity Diff from Shuffle Mean')
axveff.set_title('Sig. Diff. Command/Moves')
######  #######
# Out:
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="288">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# <img src="data:image/png;base64,..." width="864">
# ...

# %%
plot_fr_diffs.neuraldiff_vs_behdiff_corr_pw_by_command(min_move_per_command=6)
# Out:
# <div id='0ee65297-7c20-4757-a5e7-99e94e2f163d'></div>
# <div id='30cb8bc3-bac1-4701-92b3-6d4036ce957c'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-550611bf366e> in <module>()
# ----> 1 plot_fr_diffs.neuraldiff_vs_behdiff_corr_pw_by_command(min_move_per_command=6)
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_fr_diffs.py in neuraldiff_vs_behdiff_corr_pw_by_command(min_bin_indices, min_move_per_command, min_commands, ncommands_psth)
#    1858             nneur = spks.shape[1]
#    1859             command_bins = util_fcns.commands2bins([push], mag_boundaries, animal, day_ix,
# -> 1860                                        vel_ix=[3, 5])[0]
#    1861
#    1862             ncomm_tot = 0;
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/util_fcns.pyc in commands2bins(commands, mag_boundaries, animal, day_ix, vel_ix, ndiv)
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import plot_fr_diffs
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
plot_fr_diffs.eg_command_PSTH()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-05 22:37:50.867670. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.eg_command_PSTH_pred(arrow_scale = .007, width=.01)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 12:27:37.202420. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 10:49:20.047480. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
