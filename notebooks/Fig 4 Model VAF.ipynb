# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-22 16:14:33.634045. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# #### Looks like we want model #1 #####
# generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 2)
# generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='grom')
# generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='jeev')
generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal='grom', 
                                                    fit_task_spec_and_general=True)
generate_models.model_individual_cell_tuning_curves(model_set_number=2, animal='jeev', 
                                                    fit_task_spec_and_general=True)
# Out:
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# online_analysis/generate_models_utils.py:914: DeprecationWarning: createTable() is pending deprecation, use create_table() instead. You may use the pt2to3 tool to update your source code.
#   tab = h5file.createTable("/", model_nm+'_fold_'+str(int(fold)), Model_Table)
#
# ...

# %%
### Now want to plot stuff ####
#plot_generated_models.plot_r2_bar_model_1(perc_increase = False)
plot_generated_models.plot_r2_bar_model_1(perc_increase = True, task_spec_ix = 2)
# Out:
# Option 2
# <img src="data:image/png;base64,..." width="745.5555753060335">
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.3113
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.3721
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1030
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1031
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.0732
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1166
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.1486
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.0887
# General task spec baseline, model: prespos_0psh_1spksm_0_spksp_0, 2
# R2 baseline; 0.0855
# ...

# %%
#### Examples of plots for different models ####
plot_generated_models.mean_diffs_plot(animal='grom',next_pt_pred=False, plot_pred_vals = False, 
                                      ndays=3, model_set_number = 1)

# %%
for mfr_opt in ['ultra_pooled']:#'pooled', 'command_spec', 'command_axis_spec']:
    plot_generated_models.plot_real_vs_pred(model_set_number = 2, 
                                        min_obs = 15, cov = False,
                                           use_mFR_option = mfr_opt)
# Out:
# <img src="data:image/png;base64,..." width="647.777794938029">
# <img src="data:image/png;base64,..." width="647.777794938029">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom, Mods [0 1], pv: 0.000, slp: 0.029, N: 18
# Animal grom, Mods [1 2], pv: 0.000, slp: 0.028, N: 18
# <img src="data:image/png;base64,..." width="647.777794938029">
# <img src="data:image/png;base64,..." width="647.777794938029">
# ...
