# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
from online_analysis import co_obs_tuning_curves_fig3
from online_analysis import co_obs_tuning_matrices
from online_analysis import plot_generated_models
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# ...

# %%
###################################################
############## ORIGINAL PLOTS #####################
###################################################
### Get the radial edges: 
co_obs_tuning_matrices.extract_radial_bin_edges_grom_jeev()
# Out:
# online_analysis/co_obs_tuning_matrices.py:1086: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   dec = co_obs_dict[te, 'dec']
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# ...

# %%
###################################################
############## ORIGINAL PLOTS #####################
###################################################
### Get the tuning matrices: 
### This calls co_obs_tuning_matrices.get_all_tuning

### Update -- this is now doing tuning matrices by task 
### and target, not just by task; 

for animal in ['jeev','grom']:
    co_obs_tuning_curves_fig3.generate_hist_tuning(animal)

### saves to the file: 
## hist_tuning_w_fit_mag_boundaries_grom_16_trials_dist_

# %%
### Get the distribution of commands 
for animal in ['jeev']:#, 'grom']:
    co_obs_tuning_curves_fig3.distrib_of_neural_pushs_by_day(animal=animal, vmax=.1)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/lib/type_check.py:546: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   'a.item() instead', DeprecationWarning, stacklevel=1)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-04 14:57:05.386483. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### So now this doesnt work....becasue tuning plot comparisons all rely on non-target splits; 
#### Plot all the comparison plots 
co_obs_tuning_curves_fig3.plot_all()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 08:45:08.958448. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 08:50:32.866309. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
###################################################
############## NEW PLOTS #####################
###################################################

### Mean diffs ###
plot_generated_models.plot_real_mean_diffplot_r2_bar_tg_spec_7_gens(plot_disc=True, cov=False, 
                                                                    plot_ex=True, percent_change = True)
#### TODO -- add controls for changes over time ####
# Out:
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="575.5555708025713">
# Day 0, Grom, Target 4 CO / Target 5 OBS / neuron 38
# <img src="data:image/png;base64,..." width="431.1111225316557">
# online_analysis/plot_generated_models.py:788: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   angles1 = angles1[:-1]
#
# online_analysis/plot_generated_models.py:789: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   angles2 = angles2[:-1]
# Animal grom, Day 0, Tg CO 4, Tg OB 5, ang 1, mag 2, mFR Co = 73.75, mFR OB = 70.80
# Animal grom, Day 0, Tg CO 4, Tg OB 5, ang 2, mag 2, mFR Co = 71.30, mFR OB = 69.06
# Animal grom, Day 0, Tg CO 4, Tg OB 5, ang 1, mag 3, mFR Co = 104.23, mFR OB = 84.69
# Animal grom, Day 0, Tg CO 4, Tg OB 5, ang 2, mag 3, mFR Co = 98.57, mFR OB = 111.02
# ...

# %%
#plot_generated_models.tiny_wedge_plot(3, 2)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-06 08:51:42.299237. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
ang 1, mag 3, mFR Co = 104.23, mFR OB = 84.69
ang 2, mag 3, mFR Co = 98.57, mFR OB = 111.02

# %%
104.23- 84.69
# Out:
# 19.540000000000006
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-06 08:57:06.196312. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
111.02 - 98.57
# Out:
# 12.450000000000003
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-06 08:57:03.236200. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#plot_generated_models.plot_real_mean_diffs_wi_vs_x()
plot_generated_models.plot_real_mean_diffs_wi_vs_x(cov=False, percent_change = False, 
                                                   skip_within = True)

##### TODO -- make the null / potent plots with top 2D null
# Out:
# <img src="data:image/png;base64,..." width="287.77778540128566">
# <img src="data:image/png;base64,..." width="323.33334189874176">
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 408700, ndays = 9, pv = 0.0000, slp = -0.3669
# LME model, fixed effect is day, rand effect is X vs. SHUFF., N = 408700, ndays = 9, pv = 0.0000, slp = -0.1233
# <img src="data:image/png;base64,..." width="143.33333713037007">
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 61368, ndays = 4, pv = 0.0000, slp = -0.8383
# LME model, fixed effect is day, rand effect is X vs. SHUFF., N = 61368, ndays = 4, pv = 0.0000, slp = -0.3661
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-30 11:55:54.011217. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-17 16:23:19.956517. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
tips = seaborn.load_dataset("tips")
f, ax = plt.subplots()
ax.violinplot([np.random.randn(300), np.random.randn(300)], positions = [3, 4])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# {u'bodies': [<matplotlib.collections.PolyCollection at 0x11f662450>,
# ...
#  u'cbars': <matplotlib.collections.LineCollection at 0x11fdcc050>,
#  u'cmaxes': <matplotlib.collections.LineCollection at 0x11f453490>,
#  u'cmins': <matplotlib.collections.LineCollection at 0x11f662cd0>}
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-17 16:56:46.665917. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-17 16:56:22.309364. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
