# %%
from brokenaxes import brokenaxes

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(5, 2))

bax = brokenaxes(ylims=((-1, .7), (.79, 1)), hspace=.5)

x = np.linspace(0, 1, 100)
bax.plot(x, np.sin(10 * x), label='sin')
bax.plot(x, np.cos(10 * x), label='cos')
bax.legend(loc=3)
bax.set_xlabel('time')
bax.set_ylabel('value')
# Out:
# <img src="data:image/png;base64,..." width="499.4444576752042">
# Text(0,0.5,'value')

# %%
# %matplotlib notebook

# %%
brokenaxes?

# %%
x = np.array([0, 1, 2])
f, ax = plt.subplots()
ax.plot(x, x, 'r.-')
# Out:
# <img src="data:image/png;base64,..." width="317.2222306257415">
