# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from resim_ppf import ppf_pa

# %%
ppf_pa.plot_jeev_trials(targ_only = None)
# Out:
# Xlims: -0.08, 0.16
# Ylims: 0.02, 0.26
# Bin Curson kin Size 20
# (171, (46, 7))
