# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
from online_analysis import plot_generated_models, generate_models
import analysis_config
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
for animal in ['grom']:#, 'jeev']:
    generate_models.model_individual_cell_tuning_curves(model_set_number = 6, animal=animal, 
                                                    fit_task_spec_and_general=True, match_task_spec_n = True,
                                                    add_model_to_datafile = False)
# Out:
# online_analysis/generate_models.py:334: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
#
# online_analysis/generate_models_utils.py:87: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(pref+hdf[hdfix:])
# ##############################
# ########## DAY 0 ##########
# ##############################
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ...

# %%
##### Differences b/w within vs. across condition in action at the next timestep ######
plot_generated_models.plot_real_mean_diffs_behavior_next()
# Out:
# <img src="data:image/png;base64,..." width="381.111121207108">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 13376, ndays = 9, pv = 0.0000, slp = 0.1860
# <img src="data:image/png;base64,..." width="143.33333713037007">
# min bin: 1
# min bin: 1
# min bin: 1
# min bin: 1
# LME model, fixed effect is day, rand effect is X vs. Wi., N = 4288, ndays = 4, pv = 0.0000, slp = 0.4705
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 11:31:34.244673. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_generated_models.plot_r2_bar_model_dynamics_only(min_obs = 15, 
    r2_pop = True, perc_increase = False, model_dicts = None, 
                                cond_on_act = False)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 14:22:06.911199. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
model_set_number = 6
model_dicts = {}
for animal in ['grom', 'jeev']:
    model_dict = pickle.load(open(analysis_config.config[animal+'_pref']+'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen_match_tsk_N.pkl'%model_set_number, 'rb'))
    model_dicts[animal] = model_dict
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 15:17:40.136551. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for plot_act in [True, False]:
    plot_generated_models.plot_r2_bar_model_dynamics_only(min_obs = 15, 
        r2_pop = True, perc_increase = False, model_dicts = model_dicts, 
        cond_on_act = False, plot_act = plot_act, skip_task_spec = True)
# Out:
# <img src="data:image/png;base64,..." width="359.4444539664707">
# <img src="data:image/png;base64,..." width="359.4444539664707">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 16:09:21.615868. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Want to plot condition-specific next action scatter ####
plot_generated_models.fig_5_cond_spec_next_action_scatter_bars(model_dicts=model_dicts)
# Out:
# <img src="data:image/png;base64,..." width="358.88889839619793">
# online_analysis/plot_generated_models.py:3025: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   x_pred = np.vstack((pred_z_vel[model, i_d, i_ds][i][ns, :] for i in range(NT)))
#
# online_analysis/plot_generated_models.py:3041: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   x_pred = np.vstack((pred_z_vel[model, i_d, i_ds][i][0, :] for i in range(NT)))
# <img src="data:image/png;base64,..." width="287.77778540128566">
# <img src="data:image/png;base64,..." width="287.77778540128566">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-02 17:09:49.915454. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
