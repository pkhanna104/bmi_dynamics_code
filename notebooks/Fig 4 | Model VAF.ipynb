# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 19:41:33.571986. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# #### Looks like we want model #1 #####
generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 1)
generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='grom')
generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='jeev')
# Out:
# online_analysis/generate_models.py:89: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# Only using 4 days
# 199 (15, 7)
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# <div id='83f2ae91-b787-4884-8b9d-ecf512fbf58d'></div>
# <div id='553b7e76-8efe-4a81-8290-9f258d021bf1'></div>
# online_analysis/generate_models_utils.py:596: DeprecationWarning: createTable() is pending deprecation, use create_table() instead. You may use the pt2to3 tool to update your source code.
#   col = h5file.createGroup(h5file.root, model_nm+'_fold_'+str(int(fold))+'_nms')
#
# online_analysis/generate_models_utils.py:597: DeprecationWarning: createGroup() is pending deprecation, use create_group() instead. You may use the pt2to3 tool to update your source code.
#
#
# online_analysis/generate_models_utils.py:601: DeprecationWarning: createArray() is pending deprecation, use create_array() instead. You may use the pt2to3 tool to update your source code.
#   except:
# 16 (38, 7)
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# <div id='902b828b-330e-4cc5-96e1-73fec909e94f'></div>
# <div id='d535f3dc-f5d6-4c39-9cf5-7d28ded984da'></div>
# 90 (16, 7)
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# <div id='0db895b4-29be-445f-9a6c-f290187a6ddb'></div>
# <div id='ad5053ff-ea95-4ab3-b9a4-9be514e0cb3f'></div>
# 80 (17, 7)
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# <div id='6ff09ef4-c783-4287-a1e5-ac8a5d7cd41c'></div>
# <div id='4c7c5c98-d4d9-4865-8a73-296a7b274fd9'></div>
# online_analysis/generate_models.py:664: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   ndays = 4;
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_sweep_alpha_days_models_set1.h5
# online_analysis/generate_models_utils.py:83: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile(pref+hdf[hdfix:])
# Only using 9 days
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='f6f3ef95-8e4d-471c-ad29-c2369cae1c8d'></div>
# <div id='add7b6f0-7825-447a-b185-3eb944f094c7'></div>
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='9f9ed2fa-fc24-4cd5-80dc-4bab1dde129d'></div>
# <div id='aa4e87dd-2af9-4a9f-8285-df1708f265b8'></div>
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='8ec96b2d-b6dc-4313-a8c6-50b22271e2e8'></div>
# <div id='5a376b75-e08f-4561-9b82-5a2cbaf5437c'></div>
# online_analysis/generate_models_utils.py:725: RuntimeWarning: invalid value encountered in divide
#   model.pvalues = 2 * (1 - scipy.stats.t.cdf(np.abs(model.t_), Y.shape[0] - X.shape[1]))
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1738: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= self.b) & cond0
#
# online_analysis/generate_models_utils.py:729: RuntimeWarning: invalid value encountered in divide
#   model.rsquared_pop = 1 - (SSR_pop/SST_pop)
#
# online_analysis/generate_models_utils.py:733: RuntimeWarning: divide by zero encountered in log
#   llf -= (1+np.log(np.pi/nobs2))*nobs2
#
# online_analysis/generate_models_utils.py:724: RuntimeWarning: invalid value encountered in sqrt
#   model.t_ = np.mat(model.coef_) / se
#
# online_analysis/generate_models_utils.py:725: RuntimeWarning: divide by zero encountered in divide
#   model.pvalues = 2 * (1 - scipy.stats.t.cdf(np.abs(model.t_), Y.shape[0] - X.shape[1]))
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='172246f2-4382-4e13-88da-a6903e0e4022'></div>
# <div id='d218eba3-1d9c-4beb-a048-51121c1f2617'></div>
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='86b87fb9-2237-414d-bb6b-190a7ee1c644'></div>
# <div id='f9e64d95-51bf-4681-a81e-63740ddceea6'></div>
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <div id='5a10fb24-49a4-42e5-85a5-304953b4ba53'></div>
# <div id='c3fbad35-db53-46e7-861c-db58bc8f1d6b'></div>
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='8f21fd55-3b47-4975-ab7f-77ec170e7fe7'></div>
# <div id='68440d83-9060-4023-bcbf-afe5e964aeab'></div>
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='9791cdf2-0f13-4a9f-ad35-88d5dbf8f005'></div>
# <div id='6fe65e69-98ad-4f80-9921-aad3aadd2f1d'></div>
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='10e58fdd-8a65-48c6-9de7-68477c17d984'></div>
# <div id='987ee197-2b34-411b-bdef-7df055b0857f'></div>
# online_analysis/generate_models.py:659: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   ndays = 9;
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/grom_sweep_alpha_days_models_set1.h5
# Done with max_alphas_ridge
# online_analysis/generate_models.py:255: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='e422a8f2-a066-433d-8593-88f3390fbd9a'></div>
# <div id='01003f4a-6bff-4fe4-8867-7ceb497bf208'></div>
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_0'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_0_nms'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_1_nms'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_2_nms'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_3'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_3_nms'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_4'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'hist_1pos_-1psh_1spksm_0_spksp_0_fold_4_nms'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (129,) (129,) (21, 35) 6 (21,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='ec464b88-1044-4d8b-8f90-a027761aa027'></div>
# <div id='d05e0244-e998-431f-8f40-a9a49a85036a'></div>
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (24, 148) 6 (24,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (255,) (255,) (20, 148) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (208,) (208,) (23, 148) 6 (23,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='685eaecf-009a-44ee-8866-d7a4c39c2fd6'></div>
# <div id='e2bf60be-4ad5-44e6-a218-b13fbff3ac52'></div>
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (29, 53) 6 (29,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (73,) (73,) (30, 53) 6 (30,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (237,) (237,) (26, 53) 6 (26,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (32, 53) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='c060fa2e-3deb-4b6b-bca2-e81922634288'></div>
# <div id='49a4a1fb-bae3-44b1-8496-a6205f074a29'></div>
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='694ab930-3562-4a59-ac7c-5adfe7ea7887'></div>
# <div id='ad24f6fc-89ee-4540-856e-a15926d30d82'></div>
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (20, 42) 6 (20,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (12, 42) 6 (12,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (97,) (97,) (32, 42) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (174,) (174,) (38, 42) 6 (38,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='da22832f-8d81-45ae-b43f-9c6fd4c7b4e7'></div>
# <div id='222cd8c7-71a2-4756-9ba9-2695459bb2e8'></div>
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (63,) (63,) (18, 50) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (29,) (29,) (31, 50) 6 (31,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (47, 50) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='243a57dd-7ef2-410b-888d-4815e05506e4'></div>
# <div id='5ef205ee-4594-4dd4-a6f2-531de5743303'></div>
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (35, 48) 6 (35,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (100,) (100,) (48, 48) 6 (48,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='7f219fd5-497e-4245-af35-60cd78a8b0ea'></div>
# <div id='79eb2be0-0a1c-4437-9299-b0e41ab4d7a4'></div>
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (36, 48) 6 (36,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (75,) (75,) (32, 48) 6 (32,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# <div id='e200d443-4a37-48f6-9ccd-3a235b8a9966'></div>
# <div id='eb664d0f-6971-4510-9d6a-737a67037917'></div>
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/grom_models_to_pred_mn_diffs_model_set1.h5
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-2f86d959ced7> in <module>()
#       2 generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 1)
#       3 generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='grom')
# ----> 4 generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='jeev')
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generate_models.py in model_individual_cell_tuning_curves(hdf_filename, animal, n_folds, norm_neur, return_models, model_set_number, ndays, include_null_pot, only_potent_predictor, fit_task_specific_model_test_task_spec)
#     229
#     230     ### Get the ridge dict:
# --> 231     ridge_dict = pickle.load(open(analysis_config.config[animal+'_pref'] + 'max_alphas_ridge_model_set%d.pkl' %model_set_number, 'rb'));
#     232
#     233     for obj in gc.get_objects():   # Browse through ALL objects
#
# IOError: [Errno 2] No such file or directory: '/Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/max_alphas_ridge_model_set1.pkl'
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 20:01:01.051805. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Now want to plot stuff ####
plot_generated_models.plot_r2_bar_model_1(pt_2 = False)
# Out:
# <img src="data:image/png;base64,..." width="287.4999957159162">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal grom, Model 1: 0, Model 2: 4, Pv: 0.0000, Slp: 0.0389
# ---------------------------
# ---------------------------
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal grom, Model 1: 4, Model 2: 5, Pv: 0.0000, Slp: 0.1749
# ---------------------------
# ---------------------------
# <img src="data:image/png;base64,..." width="287.4999957159162">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal jeev, Model 1: 0, Model 2: 4, Pv: 0.0000, Slp: 0.0388
# ---------------------------
# ---------------------------
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal jeev, Model 1: 4, Model 2: 5, Pv: 0.0000, Slp: 0.1357
# ---------------------------
# ---------------------------
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 19:48:42.199753. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Examples of plots for different models ####
plot_generated_models.mean_diffs_plot(animal='grom',next_pt_pred=False, plot_pred_vals = False, 
                                      ndays=3, model_set_number = 1)
# Out:
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# Important neruons 0
# Done with day -- -1 --
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# Done with day -- 0 --
# Done with day -- 1 --
# Done with day -- 2 --
# Done with day -- 3 --
# Done with day -- 4 --
# Done with day -- 5 --
# Done with day -- end --
# Important neruons 0
# Done with day -- -1 --
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# Done with day -- 0 --
# Done with day -- 1 --
# Done with day -- 2 --
# Done with day -- 3 --
# Done with day -- 4 --
# Done with day -- 5 --
# Done with day -- end --
# Important neruons 0
# Done with day -- -1 --
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# <img src="data:image/png;base64,..." width="1799.9999731779103">
# Done with day -- 0 --
# Done with day -- 1 --
# Done with day -- 2 --
# Done with day -- 3 --
# Done with day -- 4 --
# Done with day -- 5 --
# Done with day -- end --
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 14:53:40.480689. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### BAR PLOT -- mean and COV ---- plot_real_vs_pred
plot_generated_models.plot_real_vs_pred(cov = False)
plot_generated_models.plot_real_vs_pred(cov = True)
# Out:
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="999.999985098839">
# Animal grom, Mods [0 1], pv: 0.000, slp: 0.115, N: 18
# Animal grom, Mods [1 2], pv: 0.000, slp: 0.106, N: 18
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="999.999985098839">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal jeev, Mods [0 1], pv: 0.000, slp: 0.178, N: 8
# Animal jeev, Mods [1 2], pv: 0.004, slp: 0.189, N: 8
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="999.999985098839">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom, Mods [0 1], pv: 0.225, slp: 0.006, N: 18
# Animal grom, Mods [1 2], pv: 0.048, slp: 0.024, N: 18
# <img src="data:image/png;base64,..." width="299.9999955296517">
# <img src="data:image/png;base64,..." width="999.999985098839">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2001: ConvergenceWarning: Gradient optimization failed.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal jeev, Mods [0 1], pv: 0.981, slp: -0.000, N: 8
# Animal jeev, Mods [1 2], pv: 0.002, slp: 0.068, N: 8
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 15:08:54.857089. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
