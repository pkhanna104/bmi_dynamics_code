# %%
import os
os.chdir(os.environ['BMI_DYN'])
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 11:45:01.481535. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 09:53:43.433873. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#### Looks like we want model #1 #####
# generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 1)
# generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='grom')
# generate_models.model_individual_cell_tuning_curves(model_set_number=1, animal='jeev')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 11:01:38.862267. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Now want to plot stuff ####
plot_generated_models.plot_r2_bar_model_1(pt_2 = True)
# Out:
# <img src="data:image/png;base64,..." width="892.4999867007139">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal grom, Model 1: 0, Model 2: 4, Pv: 0.0000, Slp: 0.0389
# ---------------------------
# ---------------------------
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal grom, Model 1: 4, Model 2: 5, Pv: 0.0000, Slp: 0.1749
# ---------------------------
# ---------------------------
# <img src="data:image/png;base64,..." width="918.7499863095584">
# <img src="data:image/png;base64,..." width="1494.9999777227642">
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="399.99999403953564">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2019: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal jeev, Model 1: 0, Model 2: 4, Pv: 0.0000, Slp: 0.0388
# ---------------------------
# ---------------------------
# ---------------------------
# ---------------------------
# Pop R2 True, Percent Increase True
# LME: Animal jeev, Model 1: 4, Model 2: 5, Pv: 0.0000, Slp: 0.1357
# ---------------------------
# ---------------------------
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="1249.9999813735487">
# <img src="data:image/png;base64,..." width="639.999990463257">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 11:45:05.406832. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
