# %%
import os
os.chdir(os.environ['BMI_DYN'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-afa563242002> in <module>()
#       1 import os
# ----> 2 os.chdir(os.environ['BMI_DYN'])
#
# /anaconda2/lib/python2.7/UserDict.pyc in __getitem__(self, key)
#      38         if hasattr(self.__class__, "__missing__"):
#      39             return self.__class__.__missing__(self, key)
# ---> 40         raise KeyError(key)
#      41     def __setitem__(self, key, item): self.data[key] = item
#      42     def __delitem__(self, key): del self.data[key]
#
# KeyError: 'BMI_DYN'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 19:55:41.865320. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Generate the alphas / models ###
generate_models.sweep_alpha_all(run_alphas=True, model_set_number = 3)
# Out:
# online_analysis/generate_models.py:89: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# Only using 4 days
# 199 (15, 7)
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# 16 (38, 7)
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# 90 (16, 7)
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# 80 (17, 7)
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# online_analysis/generate_models.py:662: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   hdf = tables.openFile('/Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_sweep_alpha_days_models_set%d.h5' %model_set_number)
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_sweep_alpha_days_models_set3.h5
# Done with max_alphas_ridge
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 20:21:20.286190. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Models ### 
#generate_models.model_individual_cell_tuning_curves(model_set_number=3, animal='grom')
generate_models.model_individual_cell_tuning_curves(model_set_number=3, animal='jeev')
# Out:
# online_analysis/generate_models.py:254: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# 199 (15, 7)
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# 16 (38, 7)
# 152 (39, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# 90 (16, 7)
# 133 (35, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# 80 (17, 7)
# 101 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# No push
# H5 File Done:  /Users/preeyakhanna/Dropbox/TimeMachineBackups/jeev2013/jeev_models_to_pred_mn_diffs_model_set3.h5
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-13 20:24:23.782999. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
### Now plot this potent vs. null difference --> Fig  ### ?
plot_generated_models.plot_real_mean_diffs_x_null_vs_potent(model_set_number = 3, cov=False)
plot_generated_models.plot_real_mean_diffs_x_null_vs_potent(model_set_number = 3, cov=True)
# Out:
# LME model, fixed effect is day, rand effect is nul vs. pot., N = 408700, ndays = 9, pv = 0.0000, slp = -2.1315
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2001: ConvergenceWarning: Gradient optimization failed.
#   warnings.warn(msg, ConvergenceWarning)
# LME model, fixed effect is day, rand effect is nul vs. pot., N = 43240, ndays = 4, pv = 0.0000, slp = -1.9333
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2001: ConvergenceWarning: Gradient optimization failed.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2039: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:1029: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# LME model, fixed effect is day, rand effect is nul vs. pot., N = 17730564, ndays = 9, pv = 0.0000, slp = -11.8248
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2039: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# LME model, fixed effect is day, rand effect is nul vs. pot., N = 457800, ndays = 4, pv = 0.0000, slp = -11.0934
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2001: ConvergenceWarning: Gradient optimization failed.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-08 14:03:53.763377. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### PLot avg trajectories by conditon; 
from online_analysis import plot_avg_traj_cond_for_all_vels
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 09:59:19.566202. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_avg_traj_cond_for_all_vels.make_plots()
plot_avg_traj_cond_for_all_vels.make_plots(animal='jeev')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-12 10:03:48.010448. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
