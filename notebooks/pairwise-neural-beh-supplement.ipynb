# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import plot_pred_fr_diffs, pred_fwd

# %%
plot_pred_fr_diffs.pw_comparison()
# Out:
# Shuffle 0, 0.94601
# Done with big fcn, 1.13158
# Skipping Movement PW 1.0, 2.0, Niter = 2
# Skipping Movement PW 1.0, 15.0, Niter = 2
# Skipping Movement PW 1.0, 14.1, Niter = 12
# Skipping Movement PW 1.0, 17.1, Niter = 2
# Skipping Movement PW 11.1, 15.0, Niter = 4
# Skipping Movement PW 12.1, 15.0, Niter = 3
# Skipping Movement PW 12.1, 7.0, Niter = 3
# Skipping Movement PW 15.0, 7.0, Niter = 2
# Skipping Movement PW 4.0, 14.0, Niter = 5
# Skipping Movement PW 13.1, 16.1, Niter = 22
# Skipping Movement PW 4.0, 16.1, Niter = 6
# Skipping Movement PW 14.0, 16.1, Niter = 22
# Skipping Movement PW 5.0, 16.1, Niter = 2
# Skipping Movement PW 10.1, 14.1, Niter = 3
# Skipping Movement PW 10.1, 3.0, Niter = 10
# Skipping Movement PW 1.0, 3.0, Niter = 2
# Skipping Movement PW 1.0, 14.1, Niter = 5
# Skipping Movement PW 13.1, 17.1, Niter = 21
# Skipping Movement PW 4.0, 17.1, Niter = 7
# Skipping Movement PW 14.0, 17.1, Niter = 20
# Skipping Movement PW 14.1, 17.1, Niter = 38
# Skipping Movement PW 0.0, 14.1, Niter = 12
# Skipping Movement PW 14.1, 6.0, Niter = 6
# Skipping Movement PW 1.0, 12.1, Niter = 3
# Skipping Movement PW 12.1, 16.1, Niter = 10
# Skipping Movement PW 12.1, 7.0, Niter = 3
# Day 0, Animal grom, len(data) true, su = 700
# Day 0, Animal grom, len(data) true, pop = 700
# Animal grom, Day 0, true:su, slp=0.308, intc=-0.032, rv=0.626, pv=0.00000
# Animal grom, Day 0, true:pop, slp=0.415, intc=-0.080, rv=0.646, pv=0.00000
# Shuffle 0, 0.63703
# Done with big fcn, 0.73307
# Animal grom, Day 1, true:su, slp=0.339, intc=-0.034, rv=0.675, pv=0.00000
# Animal grom, Day 1, true:pop, slp=0.353, intc=0.146, rv=0.646, pv=0.00000
# Shuffle 0, 2.07213
# Done with big fcn, 2.63951
# Animal grom, Day 2, true:su, slp=0.231, intc=0.006, rv=0.620, pv=0.00000
# Animal grom, Day 2, true:pop, slp=0.306, intc=0.032, rv=0.708, pv=0.00000
# Shuffle 0, 1.24245
# Done with big fcn, 1.53761
# Animal grom, Day 3, true:su, slp=0.135, intc=0.154, rv=0.466, pv=0.00000
# Animal grom, Day 3, true:pop, slp=0.216, intc=0.085, rv=0.592, pv=0.00000
# Shuffle 0, 1.10409
# Done with big fcn, 1.55123
# Animal grom, Day 4, true:su, slp=0.267, intc=-0.012, rv=0.669, pv=0.00000
# Animal grom, Day 4, true:pop, slp=0.442, intc=-0.256, rv=0.761, pv=0.00000
# Shuffle 0, 0.92840
# Done with big fcn, 1.10098
# Animal grom, Day 5, true:su, slp=0.076, intc=0.180, rv=0.336, pv=0.00000
# Animal grom, Day 5, true:pop, slp=0.185, intc=-0.027, rv=0.550, pv=0.00000
# Shuffle 0, 0.41474
# Done with big fcn, 0.47407
# Animal grom, Day 6, true:su, slp=0.152, intc=0.108, rv=0.505, pv=0.00000
# Animal grom, Day 6, true:pop, slp=0.217, intc=0.084, rv=0.615, pv=0.00000
# Shuffle 0, 0.49409
# Done with big fcn, 0.56999
# Animal grom, Day 7, true:su, slp=0.101, intc=0.110, rv=0.396, pv=0.00000
# Animal grom, Day 7, true:pop, slp=0.205, intc=-0.050, rv=0.516, pv=0.00000
# Shuffle 0, 0.47926
# Done with big fcn, 0.55284
# Animal grom, Day 8, true:su, slp=0.099, intc=0.174, rv=0.372, pv=0.00000
# Animal grom, Day 8, true:pop, slp=0.201, intc=0.041, rv=0.545, pv=0.00000
# Animal POOLED grom, su, slp=0.221, intc=0.022, rv=0.584, pv=0.00000, N = 377489
# Animal POOLED grom, pop, slp=0.350, intc=-0.168, rv=0.638, pv=0.00000, N = 5112
# Shuffle 0, 0.70811
# Done with big fcn, 0.80686
# Animal jeev, Day 0, true:su, slp=0.345, intc=0.085, rv=0.705, pv=0.00000
# Animal jeev, Day 0, true:pop, slp=0.451, intc=-0.088, rv=0.774, pv=0.00000
# Shuffle 0, 0.42050
# Done with big fcn, 0.47608
# Animal jeev, Day 1, true:su, slp=0.323, intc=0.149, rv=0.715, pv=0.00000
# Animal jeev, Day 1, true:pop, slp=0.383, intc=0.093, rv=0.769, pv=0.00000
# Shuffle 0, 0.45264
# Done with big fcn, 0.50990
# Animal jeev, Day 2, true:su, slp=0.303, intc=0.135, rv=0.686, pv=0.00000
# Animal jeev, Day 2, true:pop, slp=0.387, intc=-0.001, rv=0.750, pv=0.00000
# Shuffle 0, 0.48348
# Done with big fcn, 0.63300
# Animal jeev, Day 3, true:su, slp=0.146, intc=0.110, rv=0.517, pv=0.00000
# Animal jeev, Day 3, true:pop, slp=0.214, intc=0.039, rv=0.603, pv=0.00000
# Animal POOLED jeev, su, slp=0.317, intc=0.081, rv=0.693, pv=0.00000, N = 34643
# Animal POOLED jeev, pop, slp=0.449, intc=-0.184, rv=0.800, pv=0.00000, N = 1714

# %%
plot_pred_fr_diffs.neuraldiff_vs_behaviordiff_corr_pairwise_predictions()
# Out:
# Shuffle 0, 1.04017
# Done with big fcn, 1.22551
# Grom day 0, mag = 0, ang = 7
# True slp 0.675, intc 1.847, rv 0.729, N = 36
# Pred slp 0.214, intc 0.651, rv 0.503, N = 36
# Animal grom, Day 0 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 656     Method:             REML
# No. Groups:       26      Scale:              0.8646
# Min. group size:  15      Likelihood:         -895.8312
# Max. group size:  36      Converged:          Yes
# Mean group size:  25.2
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     2.449    0.093 26.356 0.000  2.267  2.631
# dbeh          0.362    0.024 15.257 0.000  0.316  0.409
# Group Var     0.034    0.022
# =======================================================
#
#
# Animal grom, Day 0 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 656     Method:             REML
# No. Groups:       26      Scale:              0.3527
# Min. group size:  15      Likelihood:         -610.4352
# Max. group size:  36      Converged:          Yes
# Mean group size:  25.2
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.764     0.069  11.137  0.000   0.630   0.899
# dbeh       0.209     0.016  13.226  0.000   0.178   0.240
# Group Var  0.039     0.025
# ========================================================
#
# Shuffle 0, 0.68037
# Done with big fcn, 0.76944
# Animal grom, Day 1 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 313     Method:             REML
# No. Groups:       12      Scale:              0.3386
# Min. group size:  15      Likelihood:         -294.0907
# Max. group size:  52      Converged:          Yes
# Mean group size:  26.1
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.412    0.161  8.747 0.000  1.096  1.728
# dbeh          0.261    0.025 10.652 0.000  0.213  0.309
# Group Var     0.212    0.174
# =======================================================
#
#
# Animal grom, Day 1 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 313     Method:             REML
# No. Groups:       12      Scale:              0.0795
# Min. group size:  15      Likelihood:         -64.9800
# Max. group size:  52      Converged:          Yes
# Mean group size:  26.1
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.235     0.062   3.805  0.000   0.114   0.357
# dbeh       0.204     0.012  17.344  0.000   0.181   0.227
# Group Var  0.023     0.041
# ========================================================
#
# Shuffle 0, 2.07639
# Done with big fcn, 2.65458
# Animal grom, Day 2 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 622     Method:             REML
# No. Groups:       22      Scale:              0.1822
# Min. group size:  15      Likelihood:         -378.0058
# Max. group size:  49      Converged:          Yes
# Mean group size:  28.3
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.012    0.065 15.474 0.000  0.883  1.140
# dbeh          0.140    0.007 19.395 0.000  0.126  0.154
# Group Var     0.034    0.031
# =======================================================
#
#
# Animal grom, Day 2 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 622     Method:             REML
# No. Groups:       22      Scale:              0.0265
# Min. group size:  15      Likelihood:         212.3742
# Max. group size:  49      Converged:          Yes
# Mean group size:  28.3
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.121     0.031   3.944  0.000   0.061   0.180
# dbeh       0.076     0.003  26.907  0.000   0.070   0.081
# Group Var  0.011     0.025
# ========================================================
#
# Shuffle 0, 1.25920
# Done with big fcn, 1.61407
# Animal grom, Day 3 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 1080    Method:             REML
# No. Groups:       31      Scale:              0.3032
# Min. group size:  15      Likelihood:         -921.2605
# Max. group size:  102     Converged:          Yes
# Mean group size:  34.8
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.661    0.070 23.685 0.000  1.524  1.799
# dbeh          0.458    0.027 16.741 0.000  0.404  0.512
# Group Var     0.055    0.031
# =======================================================
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# Animal grom, Day 3 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 1080    Method:             REML
# No. Groups:       31      Scale:              0.0404
# Min. group size:  15      Likelihood:         169.6580
# Max. group size:  102     Converged:          Yes
# Mean group size:  34.8
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.233     0.024   9.686  0.000   0.186   0.280
# dbeh       0.207     0.010  20.828  0.000   0.188   0.227
# Group Var  0.005     0.009
# ========================================================
#
# Shuffle 0, 1.16283
# Done with big fcn, 1.62977
# Animal grom, Day 4 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 634     Method:             REML
# No. Groups:       18      Scale:              0.3850
# Min. group size:  14      Likelihood:         -614.0045
# Max. group size:  78      Converged:          Yes
# Mean group size:  35.2
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.331    0.093 14.241 0.000  1.148  1.515
# dbeh          0.563    0.039 14.544 0.000  0.487  0.639
# Group Var     0.044    0.033
# =======================================================
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# Animal grom, Day 4 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 634     Method:             REML
# No. Groups:       18      Scale:              0.1237
# Min. group size:  14      Likelihood:         -249.7027
# Max. group size:  78      Converged:          Yes
# Mean group size:  35.2
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.073     0.047   1.548  0.122  -0.019   0.166
# dbeh       0.384     0.022  17.684  0.000   0.341   0.426
# Group Var  0.005     0.008
# ========================================================
#
# Shuffle 0, 1.04173
# Done with big fcn, 1.22530
# Animal grom, Day 5 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 922     Method:             REML
# No. Groups:       29      Scale:              0.2497
# Min. group size:  14      Likelihood:         -700.2873
# Max. group size:  55      Converged:          Yes
# Mean group size:  31.8
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     2.017    0.063 32.175 0.000  1.894  2.140
# dbeh          0.213    0.014 14.751 0.000  0.185  0.241
# Group Var     0.045    0.029
# =======================================================
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#
# Animal grom, Day 5 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 922     Method:             REML
# No. Groups:       29      Scale:              0.0254
# Min. group size:  14      Likelihood:         347.0941
# Max. group size:  55      Converged:          Yes
# Mean group size:  31.8
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.263     0.022  12.021  0.000   0.220   0.305
# dbeh       0.067     0.005  14.416  0.000   0.058   0.076
# Group Var  0.007     0.013
# ========================================================
#
# Shuffle 0, 0.40833
# Done with big fcn, 0.46598
# Animal grom, Day 6 TRUE population
#          Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 98      Method:             REML
# No. Groups:       5       Scale:              0.2826
# Min. group size:  14      Likelihood:         -84.6735
# Max. group size:  33      Converged:          Yes
# Mean group size:  19.6
# ------------------------------------------------------
#               Coef. Std.Err.   z   P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept     1.769    0.246 7.178 0.000  1.286  2.252
# dbeh          0.236    0.063 3.754 0.000  0.113  0.359
# Group Var     0.145    0.220
# ======================================================
#
#
# Animal grom, Day 6 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 98      Method:             REML
# No. Groups:       5       Scale:              0.0459
# Min. group size:  14      Likelihood:         5.0891
# Max. group size:  33      Converged:          Yes
# Mean group size:  19.6
# ---------------------------------------------------------
#             Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept   0.390     0.079  4.925  0.000   0.235   0.546
# dbeh        0.084     0.026  3.273  0.001   0.034   0.134
# Group Var   0.005     0.026
# ========================================================
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Shuffle 0, 0.48898
# Done with big fcn, 0.56486
# Animal grom, Day 7 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 188     Method:             REML
# No. Groups:       9       Scale:              0.2928
# Min. group size:  14      Likelihood:         -165.1628
# Max. group size:  32      Converged:          Yes
# Mean group size:  20.9
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     2.315    0.198 11.710 0.000  1.927  2.702
# dbeh          0.458    0.085  5.368 0.000  0.291  0.626
# Group Var     0.216    0.216
# =======================================================
#
#
# Animal grom, Day 7 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 188     Method:             REML
# No. Groups:       9       Scale:              0.0509
# Min. group size:  14      Likelihood:         -0.8693
# Max. group size:  32      Converged:          Yes
# Mean group size:  20.9
# ---------------------------------------------------------
#             Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept   0.153     0.073  2.107  0.035   0.011   0.295
# dbeh        0.301     0.035  8.517  0.000   0.232   0.370
# Group Var   0.024     0.061
# ========================================================
#
# Shuffle 0, 0.45684
# Done with big fcn, 0.52549
# Animal grom, Day 8 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 161     Method:             REML
# No. Groups:       7       Scale:              0.2270
# Min. group size:  14      Likelihood:         -115.6166
# Max. group size:  36      Converged:          Yes
# Mean group size:  23.0
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.735    0.108 16.084 0.000  1.523  1.946
# dbeh          0.264    0.031  8.593 0.000  0.204  0.324
# Group Var     0.014    0.029
# =======================================================
#
#
# Animal grom, Day 8 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 161     Method:             REML
# No. Groups:       7       Scale:              0.0238
# Min. group size:  14      Likelihood:         59.8728
# Max. group size:  36      Converged:          Yes
# Mean group size:  23.0
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.249     0.047   5.321  0.000   0.157   0.341
# dbeh       0.103     0.010  10.382  0.000   0.084   0.123
# Group Var  0.008     0.036
# ========================================================
#
#
#
#
# Pooled TRUE grom
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal grom POOLED
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 4674    Method:             REML
# No. Groups:       159     Scale:              0.3851
# Min. group size:  14      Likelihood:         -4703.7665
# Max. group size:  102     Converged:          Yes
# Mean group size:  29.4
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  1.936     0.066  29.475  0.000   1.808   2.065
# dbeh       0.224     0.007  31.044  0.000   0.210   0.238
# Group Var  0.586     0.113
# ========================================================
#
# Pv = %.5f
# Intercept    5.966478e-191
# dbeh         1.364355e-211
# Group Var     6.386148e-17
# dtype: float64
# Pooled PREDICTIONS grom
# Animal grom POOLED
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 4674    Method:             REML
# No. Groups:       159     Scale:              0.1027
# Min. group size:  14      Likelihood:         -1618.1921
# Max. group size:  102     Converged:          Yes
# Mean group size:  29.4
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.381     0.034  11.115  0.000   0.314   0.448
# dbeh       0.122     0.004  33.092  0.000   0.115   0.130
# Group Var  0.160     0.059
# ========================================================
#
# Pv = %.5f
# Intercept     1.056790e-28
# dbeh         3.919600e-240
# Group Var     3.188612e-17
# dtype: float64
# Shuffle 0, 0.72983
# Done with big fcn, 0.84793
# Animal jeev, Day 0 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 729     Method:             REML
# No. Groups:       12      Scale:              0.6350
# Min. group size:  14      Likelihood:         -891.4255
# Max. group size:  105     Converged:          Yes
# Mean group size:  60.8
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     2.031    0.182 11.162 0.000  1.675  2.388
# dbeh          0.124    0.013  9.409 0.000  0.098  0.150
# Group Var     0.307    0.172
# =======================================================
#
#
# Animal jeev, Day 0 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 729     Method:             REML
# No. Groups:       12      Scale:              0.2238
# Min. group size:  14      Likelihood:         -509.1164
# Max. group size:  105     Converged:          Yes
# Mean group size:  60.8
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.452     0.087   5.204  0.000   0.282   0.622
# dbeh       0.110     0.008  14.004  0.000   0.094   0.125
# Group Var  0.059     0.058
# ========================================================
#
# Shuffle 0, 0.41739
# Done with big fcn, 0.47087
# Animal jeev, Day 1 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 149     Method:             REML
# No. Groups:       8       Scale:              0.9209
# Min. group size:  14      Likelihood:         -215.0819
# Max. group size:  28      Converged:          Yes
# Mean group size:  18.6
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     2.882    0.278 10.362 0.000  2.337  3.427
# dbeh          0.064    0.030  2.131 0.033  0.005  0.124
# Group Var     0.284    0.190
# =======================================================
#
#
# Animal jeev, Day 1 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 149     Method:             REML
# No. Groups:       8       Scale:              0.2285
# Min. group size:  14      Likelihood:         -110.5246
# Max. group size:  28      Converged:          Yes
# Mean group size:  18.6
# ---------------------------------------------------------
#             Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept   0.924     0.120  7.690  0.000   0.688   1.159
# dbeh        0.070     0.015  4.655  0.000   0.040   0.099
# Group Var   0.033     0.051
# ========================================================
#
# Shuffle 0, 0.44116
# Done with big fcn, 0.49694
# Skipping jeev, 2, command 3 0 mov 7 mov2 15.1 -- psth fail :(
# Animal jeev, Day 2 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 413     Method:             REML
# No. Groups:       10      Scale:              0.7524
# Min. group size:  15      Likelihood:         -547.5484
# Max. group size:  85      Converged:          Yes
# Mean group size:  41.3
# --------------------------------------------------------
#            Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# --------------------------------------------------------
# Intercept  2.196     0.291  7.544  0.000   1.625   2.766
# dbeh       0.133     0.018  7.453  0.000   0.098   0.168
# Group Var  0.712     0.407
# =======================================================
#
#
# Animal jeev, Day 2 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 413     Method:             REML
# No. Groups:       10      Scale:              0.1778
# Min. group size:  15      Likelihood:         -248.1323
# Max. group size:  85      Converged:          Yes
# Mean group size:  41.3
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.389     0.107   3.622  0.000   0.179   0.600
# dbeh       0.120     0.009  13.873  0.000   0.103   0.137
# Group Var  0.084     0.101
# ========================================================
#
# Shuffle 0, 0.48224
# Done with big fcn, 0.55801
# Animal jeev, Day 3 TRUE population
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 338     Method:             REML
# No. Groups:       12      Scale:              0.2361
# Min. group size:  15      Likelihood:         -252.4286
# Max. group size:  51      Converged:          Yes
# Mean group size:  28.2
# -------------------------------------------------------
#               Coef. Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.103    0.107 10.326 0.000  0.894  1.312
# dbeh          0.190    0.019  9.871 0.000  0.152  0.228
# Group Var     0.071    0.072
# =======================================================
#
#
# Animal jeev, Day 3 PREDICTED w DYNAMICS
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 338     Method:             REML
# No. Groups:       12      Scale:              0.0237
# Min. group size:  15      Likelihood:         133.0221
# Max. group size:  51      Converged:          Yes
# Mean group size:  28.2
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.110     0.035   3.140  0.002   0.041   0.179
# dbeh       0.082     0.006  13.487  0.000   0.071   0.094
# Group Var  0.008     0.025
# ========================================================
#
#
#
#
# Pooled TRUE jeev
# /Users/preeyakhanna/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/mixed_linear_model.py:2094: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Animal jeev POOLED
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur
# No. Observations: 1629    Method:             REML
# No. Groups:       42      Scale:              0.6114
# Min. group size:  14      Likelihood:         -1983.5591
# Max. group size:  105     Converged:          Yes
# Mean group size:  38.8
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  1.959     0.120  16.268  0.000   1.723   2.195
# dbeh       0.127     0.009  14.180  0.000   0.109   0.145
# Group Var  0.491     0.148
# ========================================================
#
# Pv = %.5f
# Intercept    1.670102e-59
# dbeh         1.221963e-45
# Group Var    2.179406e-05
# dtype: float64
# Pooled PREDICTIONS jeev
# Animal jeev POOLED
#           Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: dneur_pred
# No. Observations: 1629    Method:             REML
# No. Groups:       42      Scale:              0.1726
# Min. group size:  14      Likelihood:         -948.3089
# Max. group size:  105     Converged:          Yes
# Mean group size:  38.8
# ---------------------------------------------------------
#            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept  0.380     0.056   6.746  0.000   0.269   0.490
# dbeh       0.107     0.005  22.484  0.000   0.098   0.117
# Group Var  0.100     0.058
# ========================================================
#
# Pv = %.5f
# Intercept     1.524729e-11
# dbeh         5.931796e-112
# Group Var     3.057192e-05
# dtype: float64

# %%
###### predict next command:
pred_fwd.pred_vs_true_next_command()
# Out:
# grom, 0, pv = 0.00000
# grom, 1, pv = 0.00000
# grom, 2, pv = 0.00000
# grom, 3, pv = 0.00000
# grom, 4, pv = 0.00000
# grom, 5, pv = 0.00000
# grom, 6, pv = 0.00028
# grom, 7, pv = 0.11750
# grom, 8, pv = 0.00000
# POOLED STATS grom, pv = 0.00000, rv = 0.76, slp=0.263
# jeev, 0, pv = 0.00000
# jeev, 1, pv = 0.00000
# jeev, 2, pv = 0.00000
# jeev, 3, pv = 0.00000
# POOLED STATS jeev, pv = 0.00000, rv = 0.63, slp=0.178
