# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-12 21:59:45.813130. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import analysis_config
from online_analysis import generalization_plots
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
#generalization_plots.plot_loo_n36_eg_lo_command()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 10:21:50.814946. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for cat in ['mov']:
    print('########################################')
    print('########################################')
    print('########################################')
    print('')
    print('Starting %s'%cat)
    generalization_plots.plot_loo_r2_overall(cat=cat, yval='r2', nshuffs=1000, plot_eig=False)
# Out:
# ########################################
# ########################################
# ########################################
#
# Starting mov
# Shuffle 0, 0.03062
# Shuffle 100, 0.02976
# Shuffle 200, 0.02985
# Shuffle 300, 0.03019
# Shuffle 400, 0.03192
# Shuffle 500, 0.03005
# Shuffle 600, 0.02986
# Shuffle 700, 0.03030
# Shuffle 800, 0.02963
# Shuffle 900, 0.03011
# Animal jeev, Day ix 0, pv = 0.00000, r2_ = 0.322, shuff = [0.267, 0.267]
# Shuffle 0, 0.01761
# Shuffle 100, 0.01768
# Shuffle 200, 0.01687
# Shuffle 300, 0.01758
# Shuffle 400, 0.01724
# Shuffle 500, 0.01717
# Shuffle 600, 0.01690
# Shuffle 700, 0.01831
# Shuffle 800, 0.01670
# Shuffle 900, 0.01701
# Animal jeev, Day ix 1, pv = 0.00000, r2_ = 0.293, shuff = [0.240, 0.240]
# Shuffle 0, 0.01958
# Shuffle 100, 0.01972
# Shuffle 200, 0.01948
# Shuffle 300, 0.02232
# Shuffle 400, 0.01941
# Shuffle 500, 0.01914
# Shuffle 600, 0.01952
# Shuffle 700, 0.01974
# Shuffle 800, 0.01991
# Shuffle 900, 0.01920
# ...

# %%
import time
time.sleep(60*180)
for cat in ['com', 'com_ang', 'com_mag', 'mov']:
    print('########################################')
    print('########################################')
    print('########################################')
    print('')
    print('Starting %s'%cat)
    generalization_plots.plot_loo_r2_overall(cat=cat, model_nm='hist_1pos_0psh_2spksm_1_spksp_0', nshuffs=5)
    #generalization_plots.plot_loo_r2_overall(cat=cat, yval='r2', nshuffs=1000, plot_eig=False)
# Out:
# ########################################
# ########################################
# ########################################
#
# Starting com
# Shuff 0, tm = 0.000
# Animal grom, Day ix 0, pv = 0.00000, r2_ = 0.307, shuff = [0.260, 0.261]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 1, pv = 0.00000, r2_ = 0.368, shuff = [0.316, 0.317]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 2, pv = 0.00000, r2_ = 0.126, shuff = [0.089, 0.089]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 3, pv = 0.00000, r2_ = 0.124, shuff = [0.093, 0.093]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 4, pv = 0.00000, r2_ = 0.107, shuff = [0.068, 0.068]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 5, pv = 0.00000, r2_ = 0.115, shuff = [0.098, 0.098]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 6, pv = 0.00000, r2_ = 0.164, shuff = [0.129, 0.129]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 7, pv = 0.00000, r2_ = 0.103, shuff = [0.078, 0.079]
# Shuff 0, tm = 0.000
# ...

# %%
x=10
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-12 21:03:37.026312. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_r2_overall(cat='com', nshuffs = 2,
    model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0')
# Out:
# <img src="data:image/png;base64,..." width="298.88889680674066">
# Shuff 0, tm = 0.000
# Animal grom, Day ix 0, pv = 1.00000, r2_ = 0.359, shuff = [0.368, 0.369]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 1, pv = 1.00000, r2_ = 0.313, shuff = [0.357, 0.358]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 2, pv = 1.00000, r2_ = 0.240, shuff = [0.248, 0.249]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 3, pv = 1.00000, r2_ = 0.277, shuff = [0.283, 0.284]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 4, pv = 0.00000, r2_ = 0.231, shuff = [0.210, 0.211]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 5, pv = 1.00000, r2_ = 0.257, shuff = [0.294, 0.294]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 6, pv = 1.00000, r2_ = 0.253, shuff = [0.257, 0.257]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 7, pv = 1.00000, r2_ = 0.253, shuff = [0.267, 0.269]
# Shuff 0, tm = 0.000
# Animal grom, Day ix 8, pv = 1.00000, r2_ = 0.224, shuff = [0.245, 0.247]
# ...

# %%
generalization_plots.plot_loo_r2_overall(cat='com', nshuffs = 2,
    model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0')

# %%
import time
time.sleep(180*60)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 01:15:54.434106. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_r2_overall(cat='com', nshuffs = 1000,
    model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', return_trans_from_lo = True)
# Out:
# <img src="data:image/png;base64,..." width="298.88889680674066">
# Shuff 0, tm = 0.000
# Shuff 100, tm = 7.167
# Shuff 200, tm = 13.295
# Shuff 300, tm = 19.472
# Shuff 400, tm = 25.887
# Shuff 500, tm = 31.743
# Shuff 600, tm = 37.575
# Shuff 700, tm = 44.325
# Shuff 800, tm = 50.440
# Shuff 900, tm = 56.601
# Animal grom, Day ix 0, pv = 0.00000, r2_ = 0.395, shuff = [0.357, 0.361]
# Shuff 0, tm = 0.000
# Shuff 100, tm = 4.401
# Shuff 200, tm = 8.731
# Shuff 300, tm = 13.113
# Shuff 400, tm = 17.511
# Shuff 500, tm = 21.938
# Shuff 600, tm = 26.415
# Shuff 700, tm = 31.050
# Shuff 800, tm = 35.246
# Shuff 900, tm = 38.180
# Animal grom, Day ix 1, pv = 0.00000, r2_ = 0.367, shuff = [0.340, 0.344]
# Shuff 0, tm = 0.000
# Shuff 100, tm = 20.089
# Shuff 200, tm = 40.497
# Shuff 300, tm = 60.441
# Shuff 400, tm = 80.689
# Shuff 500, tm = 100.703
# Shuff 600, tm = 120.940
# Shuff 700, tm = 141.248
# Shuff 800, tm = 161.574
# Shuff 900, tm = 182.144
# ...

# %%
generalization_plots.plot_loo_r2_overall(cat='mov', nshuffs = 1000,
    model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', return_trans_from_lo = False)
# Out:
# <img src="data:image/png;base64,..." width="298.88889680674066">
# Shuff 0, tm = 0.000
# Shuff 100, tm = 6.159
# Shuff 200, tm = 12.298
# Shuff 300, tm = 18.274
# Shuff 400, tm = 24.367
# Shuff 500, tm = 30.112
# Shuff 600, tm = 35.888
# Shuff 700, tm = 42.660
# Shuff 800, tm = 48.754
# Shuff 900, tm = 54.826
# Animal grom, Day ix 0, pv = 0.00000, r2_ = 0.387, shuff = [0.357, 0.361]
# Shuff 0, tm = 0.000
# Shuff 100, tm = 4.300
# Shuff 200, tm = 8.586
# Shuff 300, tm = 12.990
# Shuff 400, tm = 17.354
# Shuff 500, tm = 21.759
# Shuff 600, tm = 26.236
# Shuff 700, tm = 30.798
# Shuff 800, tm = 34.144
# Shuff 900, tm = 36.089
# Animal grom, Day ix 1, pv = 0.00000, r2_ = 0.363, shuff = [0.340, 0.344]
# Shuff 0, tm = 0.000
# Shuff 100, tm = 19.507
# Shuff 200, tm = 39.514
# Shuff 300, tm = 59.147
# Shuff 400, tm = 79.316
# Shuff 500, tm = 99.019
# Shuff 600, tm = 118.846
# Shuff 700, tm = 138.650
# Shuff 800, tm = 158.435
# Shuff 900, tm = 178.527
# ...

# %%
generalization_plots.plot_loo_r2_overall(cat='com', nshuffs = 2,
    model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', plot_r2_by_lo_cat = True, yval='err')
# Out:
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# Shuff 0, tm = 0.000
# Animal grom, Day ix 0, pv = 0.00000, r2_ = 0.548, shuff = [0.547, 0.547]
# Animal POOLED grom, pv = 0.00000, r2_ = 0.548, shuff = [0.547, 0.547]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 11:25:38.722116. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_r2_overall(cat='com', nshuffs = 2,
    model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', plot_r2_by_lo_cat = True, 
                                         return_trans_from_lo = True,
                                        yval='err')
# Out:
# <img src="data:image/png;base64,..." width="298.88889680674066">
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="1025.5555827235005">
# Shuff 0, tm = 0.000
# Animal grom, Day ix 0, pv = 1.00000, r2_ = 0.530, shuff = [0.547, 0.547]
# Animal POOLED grom, pv = 1.00000, r2_ = 0.530, shuff = [0.547, 0.547]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 11:50:42.466466. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
