# %%
#### plot example of how behavior is different than average in the -5:5 bin trajectory;

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import util_fcns, plot_fr_diffs
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-29 18:24:23.678745. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.plot_example_beh_comm(save=True, center_by_global = True)
# Out:
# Mov 14.1, # Iters 0 to match global
# Mov 1.0, # Iters 0 to match global
# Mov 2.0, # Iters 0 to match global
# Mov 3.0, # Iters 0 to match global
# Mov 12.1, # Iters 0 to match global
# Mov 10.1, # Iters 0 to match global
# Mov 11.1, # Iters 0 to match global
# Mov 15.0, # Iters 0 to match global
# Mov 13.1, # Iters 0 to match global
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-22 17:07:39.089071. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# use_saved_move_command_sig --> uses simulations that were run for 1000 times to say if significant or not
# saves ones that are sig. 
plot_fr_diffs.plot_perc_command_beh_sig_diff_than_global(nshuffs=100,
                                                        use_saved_move_command_sig = False)
# Out:
# Starting animal grom, Day 0
# Pv = 0.00000, dpsth = 2.111, mnshuff = 0.845
# Pv osa = 0.00000, dpsth = 0.444, mnshuff = 0.190
# Starting animal grom, Day 1
# Pv = 0.00000, dpsth = 2.141, mnshuff = 1.014
# Pv osa = 0.00000, dpsth = 0.454, mnshuff = 0.229
# Starting animal grom, Day 2
# Pv = 0.00000, dpsth = 4.311, mnshuff = 1.597
# Pv osa = 0.00000, dpsth = 0.947, mnshuff = 0.354
# Starting animal grom, Day 3
# Pv = 0.00000, dpsth = 1.306, mnshuff = 0.616
# Pv osa = 0.00000, dpsth = 0.276, mnshuff = 0.137
# Starting animal grom, Day 4
# Pv = 0.00000, dpsth = 1.190, mnshuff = 0.598
# Pv osa = 0.00000, dpsth = 0.261, mnshuff = 0.138
# Starting animal grom, Day 5
# Pv = 0.00000, dpsth = 2.160, mnshuff = 1.162
# Pv osa = 0.00000, dpsth = 0.412, mnshuff = 0.247
# Starting animal grom, Day 6
# Pv = 0.00000, dpsth = 1.510, mnshuff = 1.067
# Pv osa = 0.00000, dpsth = 0.282, mnshuff = 0.232
# Starting animal grom, Day 7
# Pv = 0.00000, dpsth = 0.797, mnshuff = 0.503
# Pv osa = 0.00000, dpsth = 0.168, mnshuff = 0.114
# Starting animal grom, Day 8
# Pv = 0.00000, dpsth = 2.033, mnshuff = 1.211
# Pv osa = 0.00000, dpsth = 0.480, mnshuff = 0.288
# POOLED:
# PV grom: 0.00000, dpsth = 1.951, mnshuff = 0.957 (0.967)
# PV OSA grom: 0.00000, dpsth = 0.414, mnshuff = 0.214 (0.220)
# Starting animal jeev, Day 0
# Pv = 0.00000, dpsth = 4.280, mnshuff = 1.624
# Pv osa = 0.00000, dpsth = 0.827, mnshuff = 0.352
# Starting animal jeev, Day 1
# Pv = 0.00000, dpsth = 3.965, mnshuff = 1.411
# Pv osa = 0.00000, dpsth = 0.814, mnshuff = 0.320
# Starting animal jeev, Day 2
# Pv = 0.00000, dpsth = 3.899, mnshuff = 1.585
# Pv osa = 0.00000, dpsth = 0.802, mnshuff = 0.348
# Starting animal jeev, Day 3
# Pv = 0.00000, dpsth = 2.394, mnshuff = 1.273
# Pv osa = 0.00000, dpsth = 0.546, mnshuff = 0.300
# POOLED:
# PV jeev: 0.00000, dpsth = 3.635, mnshuff = 1.473 (1.502)
# PV OSA jeev: 0.00000, dpsth = 0.747, mnshuff = 0.330 (0.346)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-01-13 22:57:36.838438. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.plot_distribution_of_nmov_per_command(min_obs=15)
# Out:
# Animal grom, Day 0, MAG 0: 2843
# Animal grom, Day 0, MAG 1: 2843
# Animal grom, Day 0, MAG 2: 2843
# Animal grom, Day 0, MAG 3: 2843
# Animal grom, Day 1, MAG 0: 1723
# Animal grom, Day 1, MAG 1: 1722
# Animal grom, Day 1, MAG 2: 1722
# Animal grom, Day 1, MAG 3: 1722
# Animal grom, Day 2, MAG 0: 3920
# Animal grom, Day 2, MAG 1: 3920
# Animal grom, Day 2, MAG 2: 3920
# Animal grom, Day 2, MAG 3: 3919
# Animal grom, Day 3, MAG 0: 3769
# Animal grom, Day 3, MAG 1: 3769
# Animal grom, Day 3, MAG 2: 3769
# Animal grom, Day 3, MAG 3: 3769
# Animal grom, Day 4, MAG 0: 2941
# Animal grom, Day 4, MAG 1: 2941
# Animal grom, Day 4, MAG 2: 2941
# Animal grom, Day 4, MAG 3: 2940
# Animal grom, Day 5, MAG 0: 2778
# Animal grom, Day 5, MAG 1: 2778
# Animal grom, Day 5, MAG 2: 2777
# Animal grom, Day 5, MAG 3: 2778
# Animal grom, Day 6, MAG 0: 1078
# Animal grom, Day 6, MAG 1: 1077
# Animal grom, Day 6, MAG 2: 1077
# Animal grom, Day 6, MAG 3: 1077
# Animal grom, Day 7, MAG 0: 1352
# Animal grom, Day 7, MAG 1: 1352
# Animal grom, Day 7, MAG 2: 1351
# Animal grom, Day 7, MAG 3: 1352
# Animal grom, Day 8, MAG 0: 1286
# Animal grom, Day 8, MAG 1: 1285
# Animal grom, Day 8, MAG 2: 1285
# Animal grom, Day 8, MAG 3: 1285
# Animal jeev, Day 0, MAG 0: 2088
# Animal jeev, Day 0, MAG 1: 2066
# Animal jeev, Day 0, MAG 2: 2068
# Animal jeev, Day 0, MAG 3: 2089
# Animal jeev, Day 1, MAG 0: 1226
# Animal jeev, Day 1, MAG 1: 1222
# Animal jeev, Day 1, MAG 2: 1206
# Animal jeev, Day 1, MAG 3: 1206
# Animal jeev, Day 2, MAG 0: 1295
# Animal jeev, Day 2, MAG 1: 1312
# Animal jeev, Day 2, MAG 2: 1308
# Animal jeev, Day 2, MAG 3: 1329
# Animal jeev, Day 3, MAG 0: 1434
# Animal jeev, Day 3, MAG 1: 1433
# Animal jeev, Day 3, MAG 2: 1429
# Animal jeev, Day 3, MAG 3: 1425
# Animal home, Day 0, MAG 0: 3195
# Animal home, Day 0, MAG 1: 3368
# Animal home, Day 0, MAG 2: 3289
# Animal home, Day 0, MAG 3: 3283
# Animal home, Day 1, MAG 0: 4038
# Animal home, Day 1, MAG 1: 4042
# Animal home, Day 1, MAG 2: 4040
# Animal home, Day 1, MAG 3: 4040
# Animal home, Day 2, MAG 0: 3801
# Animal home, Day 2, MAG 1: 3801
# Animal home, Day 2, MAG 2: 3801
# Animal home, Day 2, MAG 3: 3801
# Animal home, Day 3, MAG 0: 2479
# Animal home, Day 3, MAG 1: 2479
# Animal home, Day 3, MAG 2: 2479
# Animal home, Day 3, MAG 3: 2479
# Animal home, Day 4, MAG 0: 3889
# Animal home, Day 4, MAG 1: 3890
# Animal home, Day 4, MAG 2: 3890
# Animal home, Day 4, MAG 3: 3890
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-29 22:09:12.914353. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.plot_distribution_of_nmov_per_command(min_obs=0)
# Out:
# Animal grom, Day 0, MAG 0: 2843
# Animal grom, Day 0, MAG 1: 2843
# Animal grom, Day 0, MAG 2: 2843
# Animal grom, Day 0, MAG 3: 2843
# Animal grom, Day 1, MAG 0: 1723
# Animal grom, Day 1, MAG 1: 1722
# Animal grom, Day 1, MAG 2: 1722
# Animal grom, Day 1, MAG 3: 1722
# Animal grom, Day 2, MAG 0: 3920
# Animal grom, Day 2, MAG 1: 3920
# Animal grom, Day 2, MAG 2: 3920
# Animal grom, Day 2, MAG 3: 3919
# Animal grom, Day 3, MAG 0: 3769
# Animal grom, Day 3, MAG 1: 3769
# Animal grom, Day 3, MAG 2: 3769
# Animal grom, Day 3, MAG 3: 3769
# Animal grom, Day 4, MAG 0: 2941
# Animal grom, Day 4, MAG 1: 2941
# Animal grom, Day 4, MAG 2: 2941
# Animal grom, Day 4, MAG 3: 2940
# Animal grom, Day 5, MAG 0: 2778
# Animal grom, Day 5, MAG 1: 2778
# Animal grom, Day 5, MAG 2: 2777
# Animal grom, Day 5, MAG 3: 2778
# Animal grom, Day 6, MAG 0: 1078
# Animal grom, Day 6, MAG 1: 1077
# Animal grom, Day 6, MAG 2: 1077
# Animal grom, Day 6, MAG 3: 1077
# Animal grom, Day 7, MAG 0: 1352
# Animal grom, Day 7, MAG 1: 1352
# Animal grom, Day 7, MAG 2: 1351
# Animal grom, Day 7, MAG 3: 1352
# Animal grom, Day 8, MAG 0: 1286
# Animal grom, Day 8, MAG 1: 1285
# Animal grom, Day 8, MAG 2: 1285
# Animal grom, Day 8, MAG 3: 1285
# Animal jeev, Day 0, MAG 0: 2088
# Animal jeev, Day 0, MAG 1: 2066
# Animal jeev, Day 0, MAG 2: 2068
# Animal jeev, Day 0, MAG 3: 2089
# Animal jeev, Day 1, MAG 0: 1226
# Animal jeev, Day 1, MAG 1: 1222
# Animal jeev, Day 1, MAG 2: 1206
# Animal jeev, Day 1, MAG 3: 1206
# Animal jeev, Day 2, MAG 0: 1295
# Animal jeev, Day 2, MAG 1: 1312
# Animal jeev, Day 2, MAG 2: 1308
# Animal jeev, Day 2, MAG 3: 1329
# Animal jeev, Day 3, MAG 0: 1434
# Animal jeev, Day 3, MAG 1: 1433
# Animal jeev, Day 3, MAG 2: 1429
# Animal jeev, Day 3, MAG 3: 1425
# Animal home, Day 0, MAG 0: 3195
# Animal home, Day 0, MAG 1: 3368
# Animal home, Day 0, MAG 2: 3289
# Animal home, Day 0, MAG 3: 3283
# Animal home, Day 1, MAG 0: 4038
# Animal home, Day 1, MAG 1: 4042
# Animal home, Day 1, MAG 2: 4040
# Animal home, Day 1, MAG 3: 4040
# Animal home, Day 2, MAG 0: 3801
# Animal home, Day 2, MAG 1: 3801
# Animal home, Day 2, MAG 2: 3801
# Animal home, Day 2, MAG 3: 3801
# Animal home, Day 3, MAG 0: 2479
# Animal home, Day 3, MAG 1: 2479
# Animal home, Day 3, MAG 2: 2479
# Animal home, Day 3, MAG 3: 2479
# Animal home, Day 4, MAG 0: 3889
# Animal home, Day 4, MAG 1: 3890
# Animal home, Day 4, MAG 2: 3890
# Animal home, Day 4, MAG 3: 3890
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-29 22:10:46.771023. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#dat = pickle.load(open('/Users/preeyakhanna/Dropbox/TimeMachineBackups/grom2016/radial_boundaries_fit_based_on_perc_oct_2020_95th_max.pkl', 'rb'))
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-03-28 22:20:48.163967. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
