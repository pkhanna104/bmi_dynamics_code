# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from online_analysis import pred_fwd

# %%
.16/np.pi*180
# Out:
# 9.167324722093172

# %%
import seaborn

# %%
seaborn.set(font='Arial',context='talk',font_scale=.6, style='white')

# %%
pred_fwd.frac_next_com_mov_sig(nshuffs=100)
# Out:
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="200">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="200">
# PC stats Animal grom, Day 0, pv = 0.01000, r2 true 0.757, mn shuff 0.640, 95th shuff 0.664
# AE stats Animal grom, Day 0, pv = 0.00000, AE true 22.126, mn shuff 26.888, 95th shuff 27.261
# ERR: Animal grom, Day 0, pv = 0.00000, mn_err = 3.817, mn_shuf = [4.790, 4.741]
# PC stats Animal grom, Day 1, pv = 0.01000, r2 true 0.657, mn shuff 0.424, 95th shuff 0.436
# AE stats Animal grom, Day 1, pv = 0.00000, AE true 20.005, mn shuff 28.829, 95th shuff 29.354
# ERR: Animal grom, Day 1, pv = 0.00000, mn_err = 4.310, mn_shuf = [5.708, 5.646]
# PC stats Animal grom, Day 2, pv = 0.01000, r2 true 0.710, mn shuff 0.503, 95th shuff 0.512
# AE stats Animal grom, Day 2, pv = 0.00000, AE true 22.070, mn shuff 32.297, 95th shuff 32.583
# ERR: Animal grom, Day 2, pv = 0.00000, mn_err = 7.481, mn_shuf = [10.573, 10.481]
# PC stats Animal grom, Day 3, pv = 0.01000, r2 true 0.791, mn shuff 0.599, 95th shuff 0.619
# AE stats Animal grom, Day 3, pv = 0.00000, AE true 21.875, mn shuff 28.266, 95th shuff 28.642
# ERR: Animal grom, Day 3, pv = 0.00000, mn_err = 2.301, mn_shuf = [3.015, 2.990]
# PC stats Animal grom, Day 4, pv = 0.01000, r2 true 0.749, mn shuff 0.512, 95th shuff 0.517
# AE stats Animal grom, Day 4, pv = 0.00000, AE true 21.402, mn shuff 38.456, 95th shuff 38.928
# ERR: Animal grom, Day 4, pv = 0.00000, mn_err = 2.095, mn_shuf = [3.410, 3.374]
# PC stats Animal grom, Day 5, pv = 0.01000, r2 true 0.598, mn shuff 0.544, 95th shuff 0.563
# AE stats Animal grom, Day 5, pv = 0.00000, AE true 24.111, mn shuff 25.831, 95th shuff 26.103
# ERR: Animal grom, Day 5, pv = 0.00000, mn_err = 4.175, mn_shuf = [4.892, 4.858]
# PC stats Animal grom, Day 6, pv = 0.01000, r2 true 0.732, mn shuff 0.552, 95th shuff 0.592
# AE stats Animal grom, Day 6, pv = 0.00000, AE true 13.585, mn shuff 18.265, 95th shuff 18.753
# ERR: Animal grom, Day 6, pv = 0.00000, mn_err = 3.558, mn_shuf = [5.365, 5.303]
# PC stats Animal grom, Day 7, pv = 0.01000, r2 true 0.734, mn shuff 0.596, 95th shuff 0.629
# AE stats Animal grom, Day 7, pv = 0.00000, AE true 13.982, mn shuff 16.024, 95th shuff 16.454
# ERR: Animal grom, Day 7, pv = 0.00000, mn_err = 2.035, mn_shuf = [2.830, 2.790]
# PC stats Animal grom, Day 8, pv = 0.01000, r2 true 0.645, mn shuff 0.443, 95th shuff 0.467
# AE stats Animal grom, Day 8, pv = 0.00000, AE true 16.372, mn shuff 24.218, 95th shuff 24.681
# ERR: Animal grom, Day 8, pv = 0.00000, mn_err = 5.829, mn_shuf = [8.010, 7.926]
#
#
# POOLED Met err, Animal grom, Pooled: pv = 0.000, mn_val = 3.956, [5th perc, mn, 95th perc] = [5.379, 5.399, 5.418]
# POOLED Met ae, Animal grom, Pooled: pv = 0.000, mn_val = 19.503, [5th perc, mn, 95th perc] = [26.415, 26.564, 26.686]
# POOLED Met pc, Animal grom, Pooled: pv = 0.000, mn_val = 0.708, [5th perc, mn, 95th perc] = [0.528, 0.535, 0.541]
#
#
# PC stats Animal jeev, Day 0, pv = 0.01000, r2 true 0.619, mn shuff 0.489, 95th shuff 0.489
# AE stats Animal jeev, Day 0, pv = 0.00000, AE true 9.292, mn shuff 12.221, 95th shuff 12.423
# ERR: Animal jeev, Day 0, pv = 0.00000, mn_err = 8.316, mn_shuf = [10.269, 10.170]
# PC stats Animal jeev, Day 1, pv = 0.01000, r2 true 0.653, mn shuff 0.507, 95th shuff 0.507
# AE stats Animal jeev, Day 1, pv = 0.00000, AE true 8.827, mn shuff 12.129, 95th shuff 12.385
# ERR: Animal jeev, Day 1, pv = 0.00000, mn_err = 7.336, mn_shuf = [9.553, 9.421]
# PC stats Animal jeev, Day 2, pv = 0.01000, r2 true 0.698, mn shuff 0.500, 95th shuff 0.519
# AE stats Animal jeev, Day 2, pv = 0.00000, AE true 8.559, mn shuff 12.405, 95th shuff 12.748
# ERR: Animal jeev, Day 2, pv = 0.00000, mn_err = 7.648, mn_shuf = [10.284, 10.110]
# PC stats Animal jeev, Day 3, pv = 0.01000, r2 true 0.496, mn shuff 0.395, 95th shuff 0.413
# AE stats Animal jeev, Day 3, pv = 0.00000, AE true 11.755, mn shuff 14.359, 95th shuff 14.629
# ERR: Animal jeev, Day 3, pv = 0.00000, mn_err = 5.997, mn_shuf = [7.110, 7.027]
#
#
# POOLED Met err, Animal jeev, Pooled: pv = 0.000, mn_val = 7.324, [5th perc, mn, 95th perc] = [9.227, 9.304, 9.366]
# POOLED Met ae, Animal jeev, Pooled: pv = 0.000, mn_val = 9.608, [5th perc, mn, 95th perc] = [12.636, 12.779, 12.908]
# POOLED Met pc, Animal jeev, Pooled: pv = 0.000, mn_val = 0.617, [5th perc, mn, 95th perc] = [0.466, 0.473, 0.480]
# {'fracCC': [0.8407079646017699,
#   0.8571428571428571,
#   0.8647342995169082,
#   0.7985347985347986,
#   0.8985507246376812,
#   0.6692913385826772,
#   0.8873239436619719,
#   0.9032258064516129,
#   0.9439252336448598,
#   0.697841726618705,
#   0.7066666666666667,
#   0.7830188679245284,
#   0.7024793388429752],
#  'fracCom': [0.9375,
#   1.0,
#   1.0,
#   1.0,
#   1.0,
#   0.84375,
#   0.95,
#   1.0,
#   1.0,
#   1.0,
#   0.9333333333333333,
#   1.0,
#   0.9047619047619048],
#  'nCC': [226, 140, 207, 273, 207, 254, 71, 124, 107, 139, 75, 106, 121]}

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %matplotlib notebook

# %%
### test out 
theta_d = [0]#np.linspace(-np.pi, np.pi, 20)
theta_o = np.linspace(-np.pi, np.pi, 20)
f, ax = plt.subplots()

for t0 in theta_d: 
    v0 = np.array([np.cos(t0), np.sin(t0)])
    for t1 in theta_o: 
        v1 = np.array([np.cos(t0+t1), np.sin(t0+t1)])
        
        dang = pred_fwd.compute_angle_diff(v0, v1)
        ax.plot(t1, dang, 'k.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import math

# %%
f, ax = plt.subplots()
theta = np.linspace(-np.pi, np.pi, 100)
t=0.
v0 = np.array([np.cos(t), np.sin(t)])
for t in theta:
    v1 = np.array([np.cos(t), np.sin(t)])
    dv = np.dot(v1, v0)
    dang = np.arccos(dv)
    
    if np.sign(np.cross(v0, v1)) < 0: 
        dang *= -1
    
    ax.plot(t, dang, 'k.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
v1
# Out:
# array([-1.0000000e+00,  1.2246468e-16])
