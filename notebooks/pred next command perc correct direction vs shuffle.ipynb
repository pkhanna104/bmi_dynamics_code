# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
from online_analysis import pred_fwd

# %%
.16/np.pi*180
# Out:
# 9.167324722093172

# %%
import seaborn

# %%
seaborn.set(font='Arial',context='talk',font_scale=.6, style='white')

# %%
pred_fwd.frac_next_com_mov_sig(nshuffs=100)
# Out:
# <div id='9884499e-08d7-4db1-9f25-7beb8dd127b1'></div>
# <div id='55ba3cab-2862-4a0f-b179-0d8ca62fc5d1'></div>
# <div id='0cb0b056-c313-4435-af9e-385024efd23e'></div>
# <div id='76e3bc8c-1c59-4d03-9d7e-51074d5b85b3'></div>
# <div id='358b4170-ad2b-4810-af59-291464408c7e'></div>
# <div id='07668d40-96a6-41b9-9a6f-6a445ca0ac0f'></div>
# <div id='82920e3d-2597-4414-891e-19de6e863990'></div>
# <div id='cf780844-7eaf-48fa-8991-f0f0c9aeac21'></div>

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# %matplotlib notebook

# %%
### test out 
theta_d = [0]#np.linspace(-np.pi, np.pi, 20)
theta_o = np.linspace(-np.pi, np.pi, 20)
f, ax = plt.subplots()

for t0 in theta_d: 
    v0 = np.array([np.cos(t0), np.sin(t0)])
    for t1 in theta_o: 
        v1 = np.array([np.cos(t0+t1), np.sin(t0+t1)])
        
        dang = pred_fwd.compute_angle_diff(v0, v1)
        ax.plot(t1, dang, 'k.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import math

# %%
f, ax = plt.subplots()
theta = np.linspace(-np.pi, np.pi, 100)
t=0.
v0 = np.array([np.cos(t), np.sin(t)])
for t in theta:
    v1 = np.array([np.cos(t), np.sin(t)])
    dv = np.dot(v1, v0)
    dang = np.arccos(dv)
    
    if np.sign(np.cross(v0, v1)) < 0: 
        dang *= -1
    
    ax.plot(t, dang, 'k.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
v1
# Out:
# array([-1.0000000e+00,  1.2246468e-16])
