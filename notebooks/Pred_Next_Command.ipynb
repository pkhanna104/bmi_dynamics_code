# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_fr_diffs, pred_fwd
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
plot_fr_diffs.eg_command_PSTH_pred(arrow_scale = .007, width=.01)
# Out:
# <img src="data:image/png;base64,..." width="360">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 12:29:57.475314. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.plot_R2_model(nshuffs=100)
#pred_fwd.plot_R2_model(plot_action=False)
# Out:
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.05081
# Shuffle 10, 1.61964
# Shuffle 20, 3.00749
# Shuffle 30, 4.55023
# Shuffle 40, 5.80381
# Shuffle 50, 6.92493
# Shuffle 60, 8.05975
# Shuffle 70, 9.17420
# Shuffle 80, 10.28192
# Shuffle 90, 11.40505
# Conditioning on push
# No push
# Shuffle 0, 0.03753
# Shuffle 10, 2.38738
# Shuffle 20, 4.20245
# Shuffle 30, 6.74112
# Shuffle 40, 8.64108
# Shuffle 50, 10.37995
# Shuffle 60, 12.07851
# Shuffle 70, 13.79716
# Shuffle 80, 15.47481
# Shuffle 90, 17.17765
# Conditioning on push
# No push
# Shuffle 0, 0.02562
# Shuffle 10, 0.41127
# Shuffle 20, 0.71977
# Shuffle 30, 1.02657
# Shuffle 40, 1.31217
# Shuffle 50, 1.62821
# Shuffle 60, 1.88635
# Shuffle 70, 2.13787
# Shuffle 80, 2.37658
# Shuffle 90, 2.66758
# Conditioning on push
# No push
# Shuffle 0, 0.02198
# Shuffle 10, 0.83326
# Shuffle 20, 1.52325
# Shuffle 30, 2.26635
# Shuffle 40, 2.94070
# Shuffle 50, 3.70546
# ...

# %%
pred_fwd.plot_R2_model(nshuffs=5,plot_action=True)
# Out:
# <img src="data:image/png;base64,..." width="618.8889052838459">
# Conditioning on push
# No push
# Shuffle 0, 0.04395
# Conditioning on push
# No push
# Shuffle 0, 0.03845
# Conditioning on push
# No push
# Shuffle 0, 0.02923
# Conditioning on push
# No push
# Shuffle 0, 0.02627
# Conditioning on push
# No push
# Shuffle 0, 0.04869
# Conditioning on push
# No push
# Shuffle 0, 0.05087
# Conditioning on push
# No push
# Shuffle 0, 0.06512
# Conditioning on push
# No push
# Shuffle 0, 0.05581
# Conditioning on push
# No push
# Shuffle 0, 0.03455
# Conditioning on push
# No push
# Shuffle 0, 0.03971
# Conditioning on push
# No push
# Shuffle 0, 0.03986
# Conditioning on push
# No push
# Shuffle 0, 0.03830
# Conditioning on push
# No push
# Shuffle 0, 0.01412
# Conditioning on push
# No push
# Shuffle 0, 0.02058
# Conditioning on push
# No push
# Shuffle 0, 0.01619
# Conditioning on push
# No push
# Shuffle 0, 0.01727
# Conditioning on push
# No push
# Shuffle 0, 0.01670
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-11 22:45:55.159079. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.pred_vs_true_next_command()
# Out:
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# Conditioning on push
# No push
# Shuffle 0, 0.04830
# Conditioning on push
# No push
# Shuffle 0, 0.03682
# Conditioning on push
# No push
# Shuffle 0, 0.02618
# Conditioning on push
# No push
# Shuffle 0, 0.02901
# Conditioning on push
# No push
# Shuffle 0, 0.04969
# Conditioning on push
# No push
# Shuffle 0, 0.04803
# Conditioning on push
# No push
# Shuffle 0, 0.05230
# Conditioning on push
# No push
# Shuffle 0, 0.04755
# Conditioning on push
# No push
# Shuffle 0, 0.04110
# Conditioning on push
# No push
# Shuffle 0, 0.03570
# Conditioning on push
# No push
# Shuffle 0, 0.03605
# Conditioning on push
# No push
# Shuffle 0, 0.04263
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 17:22:13.830376. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import analysis_config
from online_analysis import generalization_plots, generate_models, util_fcns
from online_analysis.generalization_plots import DataExtract
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-11 17:31:25.146809. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
f, ax = plt.subplots()
f1, ax1 = plt.subplots()

for i_a, animal in enumerate(['jeev']):#, 'jeev']):
    for day_ix in range(4):#analysis_config.data_params['%s_ndays'%animal]):
        
        #### Get true data ####
        dataObj = DataExtract(animal, day_ix, model_nm = 'hist_1pos_0psh_2spksm_1_spksp_0', 
                model_set_number = 6, nshuffs=0)
        dataObj.load()

        if animal == 'grom':
            KG, KG_null_proj, KG_potent_orth = generate_models.get_KG_decoder_grom(day_ix)
        elif animal == 'jeev':
            KG, KG_null_proj, KG_potent_orth = generate_models.get_KG_decoder_jeev(day_ix)
            
        null, pot = generate_models.decompose_null_pot(0.1*dataObj.spks, dataObj.push, KG, KG_null_proj, KG_potent_orth)
        null_tm1, pot_tm1 = generate_models.decompose_null_pot(0.1*dataObj.spks_tm1, dataObj.push_tm1, KG, 
                                                               KG_null_proj, KG_potent_orth)

        ## Dynamics R2 of null / pot / combined ####
        T = dataObj.spks.shape[0]
        spks_pred, _, _ = generalization_plots.train_and_pred(0.1*dataObj.spks_tm1, 0.1*dataObj.spks, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), 0, KG, add_mean = None, 
                                                              skip_cond = True)
        spks_r2 = util_fcns.get_R2(0.1*dataObj.spks, spks_pred)
        KG = np.array(KG)
        act_r2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred.T).T)
        ax1.plot(day_ix + 10*i_a, act_r2, 'k*')
        
        #### NULL ####
        null_pred, _, _ = generalization_plots.train_and_pred(null_tm1, null, dataObj.push[:, [3, 5]], 
                                                        np.arange(T), np.arange(T), 0, KG, add_mean = None, 
                                                        skip_cond = True)
        null_r2 = util_fcns.get_R2(null, null_pred)

        #### POT ####

        pot_pred, _, _ = generalization_plots.train_and_pred(pot_tm1, pot, dataObj.push[:, [3, 5]], 
                                                        np.arange(T), np.arange(T), 0, KG, add_mean = None, 
                                                        skip_cond = True)
        pot_r2 = util_fcns.get_R2(pot, pot_pred)

        ax.plot(day_ix + 10*i_a, spks_r2, 'k*')
        ax.plot(day_ix + 10*i_a, null_r2, 'g*')
        ax.plot(day_ix + 10*i_a, pot_r2, 'r*')
        print('day %d: spks r2 %.3f, null r2 %.3f, pot r2 %.3f' %(day_ix, spks_r2, null_r2, pot_r2))
        
        shuff = []; shuff_act = []; 
        #### Now do some rolling; 
        for i in range(10): 
            
            #### Roll this guy ; 
            ix = np.arange(T)
            roll_ix = np.roll(ix, np.random.randint(0, T))
            
            spks_0 = null[roll_ix] + pot; 
            spks_1 = null_tm1[roll_ix] + pot_tm1; 
            
            spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_0, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), 0, KG, add_mean = None, 
                                                              skip_cond = True)
            r2i = util_fcns.get_R2(spks_0, spks_pred_i)
            shuff.append(r2i)
            KG = np.array(KG)
            r2i2 = util_fcns.get_R2(np.dot(KG, spks_0.T).T, np.dot(KG, spks_pred_i.T).T)
            shuff_act.append(r2i2)
        
        util_fcns.draw_plot(10*i_a + day_ix, shuff, 'k', np.array([1.,1.,1.,0.]), ax)
        util_fcns.draw_plot(10*i_a + day_ix, shuff_act, 'k', np.array([1.,1.,1.,0.]), ax1)
        
ax.set_xlim([-1, 5])
ax1.set_xlim([-1, 5])
# Out:
# <img src="data:image/png;base64,..." width="431.6666781019284">
# <img src="data:image/png;base64,..." width="431.6666781019284">
# day 0: spks r2 0.174, null r2 0.144, pot r2 0.302
# day 1: spks r2 0.174, null r2 0.146, pot r2 0.283
# day 2: spks r2 0.179, null r2 0.143, pot r2 0.255
# day 3: spks r2 0.076, null r2 0.057, pot r2 0.163
# (-1, 5)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-12 00:36:02.380453. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
