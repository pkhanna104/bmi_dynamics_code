# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_fr_diffs, pred_fwd
# Out:
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 11:04:47.063462. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.eg_command_PSTH_pred(arrow_scale = .007, width=.01)
# Out:
# <img src="data:image/png;base64,..." width="360">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 12:29:57.475314. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.plot_R2_model(nshuffs=2)
#pred_fwd.plot_R2_model(plot_action=False)
# Out:
# <div id='d346f7a9-5ff9-4e72-a8ad-34b1a505dba3'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.03772
# Conditioning on push
# No push
# Shuffle 0, 0.04860
# --Return--
# > /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generalization_plots.py(99)load_pot_only_shuff()->None
# -> import pdb; pdb.set_trace()
# (Pdb) self.KG = util_fcns.get_decoder(self.animal, self.day_ix)
# (Pdb) self.KG
# array([[ 0.03104744,  0.05586906, -0.33756993, -0.23316671, -0.08718834,
#          0.00520423, -0.03883397,  0.06091106, -0.09777431,  0.15066971,
#         -0.30129908,  0.00408885, -0.00216486, -0.05032097, -0.00482018,
#         -0.03787217,  0.14564867,  0.03938232,  0.12298475, -0.05490133,
#          0.02610104, -0.07462489,  0.04968146, -0.02257142, -0.20976066,
#          0.05759919, -0.03220544, -0.11483305,  0.01661764,  0.03587499,
#         -0.01355046,  0.0627183 , -0.11891051, -0.10783948, -0.25645551,
#         -0.14100748, -0.13166426, -0.0320499 ,  0.14353924, -0.28371742,
#          0.37843005, -0.0894859 ,  0.08491187,  0.06226606],
#        [-0.0623252 , -0.02020976, -0.39146454, -0.03239881,  0.03679993,
#         -0.08150742, -0.00955679,  0.08747434,  0.81397671, -0.51086898,
#          0.08444218, -0.01588763,  0.01989112,  0.13135303, -0.0577254 ,
#         -0.0487205 , -0.02861329, -0.07766848, -0.04671264, -0.04456854,
#         -0.17905692, -0.05357899,  0.00781751, -0.01020823,  0.27828474,
#          0.04018416, -0.03523367, -0.0094236 ,  0.00563291, -0.08160686,
#         -0.0720351 , -0.01264521,  0.01294437, -0.01695013,  0.15951242,
#         -0.11384194, -0.01003153, -0.02705882,  0.43057351,  0.01675617,
#         -0.27031223, -0.01659321, -0.04523338, -0.08467846]])
# (Pdb) self.KG.shape
# (2, 44)
# (Pdb) self.pred_spks_shuffle.shape
# (11397, 44, 2)
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-38-751a6f95809b> in <module>()
# ----> 1 pred_fwd.plot_R2_model(nshuffs=2)
#       2 #pred_fwd.plot_R2_model(plot_action=False)
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/pred_fwd.py in plot_R2_model(model_nm, model_set_number, nshuffs, plot_action)
#      26             dataObj.load()
#      27             dataObj.load_null_roll()
# ---> 28
#      29             if plot_action:
#      30                 KG = util_fcns.get_decoder(animal, day_ix)
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generalization_plots.py in load_pot_only_shuff(self)
#      97 ######### UTILS ##########
#      98 def stack_dict(d):
# ---> 99     for k in d.keys():
#     100         d[k] = np.hstack((d[k]))
#     101     return d
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      51             return self.dispatch_call(frame, arg)
#      52         if event == 'return':
# ---> 53             return self.dispatch_return(frame, arg)
#      54         if event == 'exception':
#      55             return self.dispatch_exception(frame, arg)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.pyc in dispatch_return(self, frame, arg)
#      89             finally:
#      90                 self.frame_returning = None
# ---> 91             if self.quitting: raise BdbQuit
#      92         return self.trace_dispatch
#      93
#
# BdbQuit:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 16:10:39.945634. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.plot_R2_model(nshuffs=100,plot_action=False)
# Out:
# <div id='b26dcb98-5316-41f9-8940-7226f44a29f5'></div>
# Conditioning on push
# No push
# Shuffle 0, 0.05641
# Shuffle 10, 1.59896
# Shuffle 20, 2.78078
# Shuffle 30, 3.95794
# Shuffle 40, 5.07777
# Shuffle 50, 6.23221
# Shuffle 60, 7.36856
# Shuffle 70, 8.68541
# Shuffle 80, 9.98899
# Shuffle 90, 11.28914
# Conditioning on push
# No push
# Shuffle 0, 0.06494
# Shuffle 10, 3.10088
# Shuffle 20, 4.97668
# Shuffle 30, 6.80199
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-795473e0831e> in <module>()
# ----> 1 pred_fwd.plot_R2_model(nshuffs=100,plot_action=False)
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/pred_fwd.py in plot_R2_model(model_nm, model_set_number, nshuffs, plot_action)
#      25                 model_set_number = model_set_number, nshuffs=nshuffs)
#      26             dataObj.load()
# ---> 27             dataObj.load_null_roll()
#      28
#      29             if plot_action:
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generalization_plots.pyc in load_null_roll(self)
#      91     def load_null_roll(self):
#      92         pred, true = plot_generated_models.get_shuffled_data_pred_null_roll(self.animal, self.day_ix, self.model_nm, nshuffs = self.nshuffs,
# ---> 93             testing_mode = False)
#      94         self.null_roll_pred = 10*pred;
#      95         self.null_roll_true = 10*true
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/plot_generated_models.py in get_shuffled_data_pred_null_roll(animal, day, model_name, nshuffs, testing_mode)
#    2249
#    2250         #### get the spikes and previous spikes with roll applied ###
# -> 2251         sub_spikes, sub_spikes_tm1, sub_push, tm0, tm1 = generate_models.get_temp_spks_null_pot_roll(data_file['Data'], shuff_ix)
#    2252
#    2253         ### Makes ure sub_push matches:
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generate_models.py in get_temp_spks_null_pot_roll(Data2, shuff_ix)
#    1265     nN = spks_null_tm0.shape[1]
#    1266
# -> 1267     spks_null_tm1 = np.vstack(( np.zeros((1, nN)) + np.nan, Data2['spks_null'][:-1, :] ))[spks_keep, :]
#    1268     assert(spks_null_tm0.shape == spks_null_tm1.shape)
#    1269     assert(np.sum(np.isnan(spks_null_tm1)) == 0)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/core/shape_base.pyc in vstack(tup)
#     281     """
#     282     _warn_for_nonsequence(tup)
# --> 283     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     284
#     285
#
# KeyboardInterrupt:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 15:37:54.498730. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-11 22:45:55.159079. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.pred_vs_true_next_command()
# Out:
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="358.88889839619793">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.03654
# Conditioning on push
# No push
# Shuffle 0, 0.03482
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.02381
# Conditioning on push
# No push
# Shuffle 0, 0.02034
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.05828
# Conditioning on push
# No push
# Shuffle 0, 0.06016
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.05382
# Conditioning on push
# No push
# Shuffle 0, 0.04844
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.03499
# Conditioning on push
# No push
# Shuffle 0, 0.03732
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.03705
# Conditioning on push
# No push
# Shuffle 0, 0.03593
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.01350
# Conditioning on push
# No push
# Shuffle 0, 0.01323
# <img src="data:image/png;base64,..." width="422.22223340729164">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.01671
# Conditioning on push
# No push
# Shuffle 0, 0.01596
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.01604
# Conditioning on push
# No push
# Shuffle 0, 0.01738
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.03795
# Conditioning on push
# No push
# Shuffle 0, 0.02629
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.01664
# Conditioning on push
# No push
# Shuffle 0, 0.01480
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.02068
# Conditioning on push
# No push
# Shuffle 0, 0.02234
# <img src="data:image/png;base64,..." width="215.55556126582786">
# <img src="data:image/png;base64,..." width="215.55556126582786">
# Conditioning on push
# No push
# Shuffle 0, 0.02208
# Conditioning on push
# No push
# Shuffle 0, 0.02155
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 14:51:37.655387. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 17:22:13.830376. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
import analysis_config
from online_analysis import generalization_plots, generate_models, util_fcns, generate_models_utils
from online_analysis.generalization_plots import DataExtract
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 11:39:50.354643. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
f, ax = plt.subplots()
f1, ax1 = plt.subplots()

alpha_dict = pickle.load(open(analysis_config.config['grom_pref'] + 'max_alphas_ridge_model_set6.pkl', 'rb'))
mag_boundaries = pickle.load(open(analysis_config.data_params['mag_bound_file']))

for i_a, animal in enumerate(['grom']):#, 'jeev']):
    for day_ix in [2, 4]:#range(analysis_config.data_params['%s_ndays'%animal]):
        
        #### Alpha ####
        alpha = alpha_dict[animal][0][day_ix, 'hist_1pos_0psh_0spksm_1_spksp_0']
        
        #### Get true data ####
        dataObj = DataExtract(animal, day_ix, model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0', 
                model_set_number = 6, nshuffs=0)
        dataObj.load()
        
        if animal == 'grom':
            KG, KG_null_proj, KG_potent_orth = generate_models.get_KG_decoder_grom(day_ix)
        elif animal == 'jeev':
            KG, KG_null_proj, KG_potent_orth = generate_models.get_KG_decoder_jeev(day_ix)
            
        #### Decompose activity (tm0 and tm1) into null / potent 
        #### maek sure spks and push are aligned? 
        if animal == 'grom':
            assert(np.allclose(np.dot(KG, 0.1*dataObj.spks.T).T, dataObj.push[:, [3, 5]]))
        
        elif animal == 'jeev': 
            assert(generate_models_utils.quick_reg(np.array(np.dot(KG, 0.1*dataObj.spks.T).T), 
                            dataObj.push[:, [3, 5]]) > .98)
            
            #### Make sure null proj is zero ###
            assert(np.allclose(np.dot(KG, np.dot(KG_null_proj, 0.1*dataObj.spks.T)).T, 
                               0.))
            
            ### Make sure pot proj works: 
            assert(np.allclose(np.array(np.dot(KG, 0.1*dataObj.spks.T).T), 
                            np.dot(KG, np.dot(KG_potent_orth, 0.1*dataObj.spks.T)).T))
        
        ##### Get the null / potent activity ###
        null, pot = generate_models.decompose_null_pot(0.1*dataObj.spks, dataObj.push, KG, KG_null_proj, KG_potent_orth)
        null_tm1, pot_tm1 = generate_models.decompose_null_pot(0.1*dataObj.spks_tm1, dataObj.push_tm1, KG, 
                                                               KG_null_proj, KG_potent_orth)
        
        ### Push at time - 1; 
        command_bins_tm1 = util_fcns.commands2bins([dataObj.push_tm1], mag_boundaries, animal, day_ix, vel_ix = [3, 5])[0]
        
        #### get command bins disk ####
        assert(np.allclose(np.dot(KG, null.T).T, 0.))
        assert(np.allclose(np.dot(KG, null_tm1.T).T, 0.))
        
        ## Dynamics R2 of null / pot / combined ####
        T = dataObj.spks.shape[0]
        spks_pred, _, _ = generalization_plots.train_and_pred(0.1*dataObj.spks_tm1, 0.1*dataObj.spks, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                              skip_cond = True)
        spks_r2 = util_fcns.get_R2(0.1*dataObj.spks, spks_pred)
        print('day %d: spks r2 %.3f' %(day_ix, spks_r2))
        KG = np.array(KG)
        act_r2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred.T).T)
        ax1.plot(day_ix + 10*i_a, act_r2, 'k*')
        print('day %d: act r2 %.3f' %(day_ix, act_r2))
        ax.plot(day_ix + 10*i_a, spks_r2, 'k*')
 
        shuff = dict(); 
        shuff_act = dict();
        for i in range(5):
            shuff[i] = []
            shuff_act[i] = []
            
        #### Now do some rolling; 
        for i in range(10): 
            
            #### Roll this guy ; 
            ix = np.arange(T)
            roll_ix = np.roll(ix, np.random.randint(100, T))
            
            ### Next time step ###
            spks_0 = null[roll_ix] + pot; 
            
            ### Shuffle #### 
            spks_11 = pot_tm1
            spks_2 = null_tm1[roll_ix]
            spks_3 = null_tm1[roll_ix] + pot_tm1; 
            
            for i_s, spks_1 in enumerate([spks_11, spks_2, spks_3]):
                ### Get the 
                spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_0, 
                                                                  dataObj.push[:, [3, 5]], 
                                                                  np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                                  skip_cond = True)
                r2i = util_fcns.get_R2(spks_0, spks_pred_i)
                shuff[i_s].append(r2i)
                KG = np.array(KG)
                #assert(np.allclose(np.dot(KG, spks_0.T).T, dataObj.push[:, [3, 5]]))
                r2i2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred_i.T).T)
                shuff_act[i_s].append(r2i2)
        
        
            #### Another shuffle type
            spks_10 = 0.1*dataObj.spks
            shuff_ix, _ = generate_models_utils.within_bin_shuffling(pot_tm1, dataObj.push_tm1[:, [3, 5]], 
                                                                       animal, day_ix)
            pot_tm1_shuff = pot_tm1[shuff_ix, :]
            
            #### Make srue the same command bins 
            command_bins_tm1_shuff = util_fcns.commands2bins([dataObj.push_tm1[np.ix_(shuff_ix, [3, 5])]], 
                                                             mag_boundaries, animal, day_ix, 
                                                             vel_ix = [0, 1])[0]
            assert(np.allclose(command_bins_tm1_shuff, command_bins_tm1))

            ##### If acceptable, make the tm1 shuff ###
            spks_tm1_shuff1 = null_tm1 + pot_tm1_shuff; 
            spks_tm1_shuff2 = null_tm1[roll_ix] + pot_tm1_shuff; 
            
            for i_s, spks_1 in enumerate([spks_tm1_shuff1, spks_tm1_shuff2]):
                if i_s == 0:
                    spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_10, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                              skip_cond = True)
                    r2i = util_fcns.get_R2(spks_10, spks_pred_i)
                
                elif i_s == 1:
                    spks_pred_i, _, _ = generalization_plots.train_and_pred(spks_1, spks_0, 
                                                              dataObj.push[:, [3, 5]], 
                                                              np.arange(T), np.arange(T), alpha, KG, add_mean = None, 
                                                              skip_cond = True)
                    r2i = util_fcns.get_R2(spks_0, spks_pred_i)
                
                shuff[3+i_s].append(r2i)
                KG = np.array(KG)
                #assert(np.allclose(np.dot(KG, spks_0.T).T, dataObj.push[:, [3, 5]]))
                r2i2 = util_fcns.get_R2(dataObj.push[:, [3, 5]], np.dot(KG, spks_pred_i.T).T)
                shuff_act[3+i_s].append(r2i2)

            
            
        cols = ['r', 'g', 'k', 'deeppink', 'b']
        for i_s in range(5):
            util_fcns.draw_plot(10*i_a + day_ix, shuff[i_s], cols[i_s], np.array([1.,1.,1.,0.]), ax)
            util_fcns.draw_plot(10*i_a + day_ix, shuff_act[i_s], cols[i_s], np.array([1.,1.,1.,0.]), ax1)
            #print('pink shuffle spks mean %s %d = %.4f' %(animal, day_ix, np.mean(shuff)))
            #print('pink shuffle act mean %s %d = %.4f' %(animal, day_ix, np.mean(shuff_act)))
        
ax.set_xlim([-1, 14])
ax.set_ylabel('R2 of next activity')
f.tight_layout()

ax1.set_xlim([-1, 14])
ax1.set_ylabel('R2 of next command')
f1.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="757.7777978520339">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# day 2: spks r2 0.101
# day 2: act r2 0.331
# day 4: spks r2 0.099
# day 4: act r2 0.322
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 18:02:18.845169. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.test_shuffles()
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-16 18:52:23.571354. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
