# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import plot_fr_diffs, pred_fwd
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 12:37:37.123752. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plot_fr_diffs.eg_command_PSTH_pred(arrow_scale = .007, width=.01)
# Out:
# <img src="data:image/png;base64,..." width="360">
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 12:29:57.475314. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.plot_R2_model()
#pred_fwd.plot_R2_model(plot_action=False)
# Out:
# <img src="data:image/png;base64,..." width="216">
# Conditioning on push
# No push
# Shuffle 0, 0.04661
# Shuffle 10, 1.41477
# Conditioning on push
# No push
# Shuffle 0, 0.02934
# Shuffle 10, 0.42186
# Conditioning on push
# No push
# Shuffle 0, 0.05905
# Shuffle 10, 17.36520
# Conditioning on push
# No push
# Shuffle 0, 0.05533
# Shuffle 10, 2.55992
# Conditioning on push
# No push
# Shuffle 0, 0.03907
# Shuffle 10, 14.75881
# Conditioning on push
# No push
# Shuffle 0, 0.04796
# Shuffle 10, 1.42485
# Conditioning on push
# No push
# Shuffle 0, 0.01713
# Shuffle 10, 0.77176
# Conditioning on push
# No push
# Shuffle 0, 0.02055
# Shuffle 10, 0.94234
# Conditioning on push
# No push
# Shuffle 0, 0.02375
# Shuffle 10, 0.89577
# Conditioning on push
# No push
# Shuffle 0, 0.03879
# Shuffle 10, 0.27169
# Conditioning on push
# No push
# Shuffle 0, 0.02587
# Shuffle 10, 0.18433
# Conditioning on push
# No push
# Shuffle 0, 0.02115
# Shuffle 10, 0.15418
# Conditioning on push
# No push
# Shuffle 0, 0.02569
# Shuffle 10, 0.16896
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 13:10:17.059433. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.plot_R2_model(plot_action=True)
# Out:
# <img src="data:image/png;base64,..." width="216">
# Conditioning on push
# No push
# Shuffle 0, 0.04820
# Shuffle 10, 2.34983
# Conditioning on push
# No push
# Shuffle 0, 0.03192
# Shuffle 10, 0.44478
# Conditioning on push
# No push
# Shuffle 0, 0.06900
# Shuffle 10, 19.42357
# Conditioning on push
# No push
# Shuffle 0, 0.06919
# Shuffle 10, 2.88122
# Conditioning on push
# No push
# Shuffle 0, 0.04352
# Shuffle 10, 14.74694
# Conditioning on push
# No push
# Shuffle 0, 0.05084
# Shuffle 10, 1.47956
# Conditioning on push
# No push
# Shuffle 0, 0.01650
# Shuffle 10, 0.79690
# Conditioning on push
# No push
# Shuffle 0, 0.02153
# Shuffle 10, 0.88676
# Conditioning on push
# No push
# Shuffle 0, 0.02449
# Shuffle 10, 0.88358
# Conditioning on push
# No push
# Shuffle 0, 0.03898
# Shuffle 10, 0.25736
# Conditioning on push
# No push
# Shuffle 0, 0.02436
# Shuffle 10, 0.16985
# Conditioning on push
# No push
# Shuffle 0, 0.02581
# Shuffle 10, 0.22150
# Conditioning on push
# No push
# Shuffle 0, 0.02768
# Shuffle 10, 0.25186
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 13:19:50.621849. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pred_fwd.pred_vs_true_next_command()
# Out:
# <img src="data:image/png;base64,..." width="144">
# <img src="data:image/png;base64,..." width="144">
# <img src="data:image/png;base64,..." width="216">
# <img src="data:image/png;base64,..." width="216">
# <img src="data:image/png;base64,..." width="360">
# Conditioning on push
# No push
# Shuffle 0, 0.04753
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 17:30:14.067700. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-11-06 17:22:13.830376. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
