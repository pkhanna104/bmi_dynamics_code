# %%
cd ~/bmi_dynamics_code/
# Out:
# /Users/preeyakhanna/bmi_dynamics_code

# %%
import resim
# Out:
# /Users/preeyakhanna/bmi3d/riglib/experiment/experiment.py:24: UserWarning: experiment.py: Cannot import 'pygame'
#   warnings.warn("experiment.py: Cannot import 'pygame'")
# /Users/preeyakhanna/bmi3d/riglib/experiment/__init__.py:67: UserWarning: riglib/experiment/__init__.py: could not import Pygame (note capital P)
#   warnings.warn('riglib/experiment/__init__.py: could not import Pygame (note capital P)')
# No handlers could be found for logger "OpenGL.GLUT.fonts"
# /Users/preeyakhanna/bmi3d/riglib/stereo_opengl/primitives.py:11: UserWarning: riglib/stereo_opengl_primitives.py: not importing name pygame
#   warnings.warn('riglib/stereo_opengl_primitives.py: not importing name pygame')
# /Users/preeyakhanna/bmi3d/riglib/stereo_opengl/window.py:31: UserWarning: riglib/stereo_opengl/window.py: not importing name pygame
#   warnings.warn('riglib/stereo_opengl/window.py: not importing name pygame')

# %%
resim.test()
# Out:
# iter 1, error 11.14
# premove in loop 5
# iter 2, error 0.55
# iter 3, error 0.25
# iter 4, error 0.04
# iter 5, error 0.02
# iter 6, error 0.01
# iter 7, error 0.01
# iter 8, error 0.00
# iter 9, error 0.00
# iter 10, error 0.00
# iter 11, error 0.00
# iter 12, error 0.00
# iter 13, error 0.00
# premove in loop 155
# premove in loop 365
# premove in loop 515
# premove in loop 785
# premove in loop 977
# premove in loop 1163
# premove in loop 1289
# premove in loop 1391
# premove in loop 1547
# premove in loop 1715
# premove in loop 1847
# premove in loop 1919
# premove in loop 2087
# premove in loop 2237
# premove in loop 2411
# premove in loop 2567
# premove in loop 2753
# premove in loop 2987
# premove in loop 3155
# premove in loop 3305
# premove in loop 3515
# premove in loop 3719
# premove in loop 3899
# premove in loop 4019
# premove in loop 4181
# premove in loop 4295
# premove in loop 4427
# premove in loop 4733
# premove in loop 4889
# premove in loop 5015
# ...

# %%
# %matplotlib notebook
