# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from online_analysis import generate_models, plot_generated_models
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# ...

# %%
#generate_models.sweep_alpha_all(model_set_number=10)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-03 09:48:04.430599. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
##### Run the actual models #####
# for animal in ['jeev','grom']:
#     generate_models.model_individual_cell_tuning_curves(hdf_filename='_models_to_pred_mn_diffs', 
#     animal=animal, 
#     n_folds = 5, 
#     model_set_number = 10,
#     fit_task_spec_and_general = True)
# Out:
# online_analysis/generate_models.py:265: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   h5file = tables.openFile(hdf_filename, mode="w", title=animal+'_tuning')
# 199 (15, 7)
# 171 (46, 7)
# Len Obs Targs [1 2 3 4 5 6 8 9]
# <div id='54856d72-6fa4-4ce1-91fe-5aee1c6f3f79'></div>
# <div id='ef41dfd0-bb04-40bd-8a0d-d1d37a580242'></div>
# No push
# No push
# No push
# No push
# No push
# No push
# Adding model
# Adding model
# Adding model
# Adding model
# Adding model
# Adding model
# No push
# No push
# No push
# No push
# No push
# No push
# Adding model
# Adding model
# Adding model
# Adding model
# Adding model
# Adding model
# No push
# No push
# No push
# No push
# No push
# No push
# Adding model
# Adding model
# Adding model
# Adding model
# Adding model
# Adding model
# No push
# No push
# No push
# No push
# No push
# No push
# Adding model
# Adding model
# Adding model
# Adding model
# ...

# %%
###### Plot the R2 for the actual models #####
savedir = '/Users/preeyakhanna/Dropbox/Carmena_Lab/Documentation/BMI_co_obs_paper/data/r2_past_future/'
for pred in ['neural', 'action']:
    plot_generated_models.generic_r2_plotter([10], 
                                   [['hist_1pos_0psh_0spksm_1_spksp_0',
                                     'hist_1pos_0psh_0spksm_0_spksp_1',
                                     'hist_1pos_0psh_0spksm_2_spksp_0',
                                     'hist_1pos_0psh_0spksm_0_spksp_2',
                                     'hist_1pos_0psh_0spksm_1_spksp_1',
                                     'hist_1pos_0psh_0spksm_2_spksp_2']],
                                   '_task_spec_pls_gen', plot_ix = 2, 
                                         neural_or_action = pred,
                                            savedir = savedir)
# Out:
# Bars 6, Width = 0.12
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# Bars 6, Width = 0.12
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# Bars 6, Width = 0.12
# <img src="data:image/png;base64,..." width="1198.8889206485992">
# ...
