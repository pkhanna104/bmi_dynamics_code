# %%
# %load_ext autoreload
# %autoreload 2

# %%
from online_analysis import generalization_plots
# Out:
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pybasicbayes-0.2.4-py2.7-macosx-10.9-x86_64.egg/pybasicbayes/util/stats.py:11: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#
# ...

# %%
for null_opt in ['nulldyn']:# ['null2null', 'full2null', 'nulldyn']:
    for potent_addon in [True]:
        generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=2, model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0',
                                        return_trans_from_lo = True, plot_action=False,
                                                null_opt=null_opt, potent_addon=potent_addon,
                                                 nulldyn_opt='alpha_opt')
            
#         generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=2, model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0',
#                                         return_trans_from_lo = True, plot_action=False,
#                                                 null_opt=null_opt, potent_addon=potent_addon,
#                                                 nulldyn_opt='alpha_adj')
# Out:
# ##################
# Starting Animal grom Day 2
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.0806
# online_analysis/generalization_plots.py:2348: RuntimeWarning: divide by zero encountered in double_scalars
#   ######## Plot whether the move-speicfic command activity has the right structure #####
#
# online_analysis/generalization_plots.py:2348: RuntimeWarning: invalid value encountered in double_scalars
#   ######## Plot whether the move-speicfic command activity has the right structure #####
#
# online_analysis/generalization_plots.py:2351: RuntimeWarning: divide by zero encountered in double_scalars
#   cat = 'com'
#
# online_analysis/generalization_plots.py:2351: RuntimeWarning: invalid value encountered in double_scalars
#   cat = 'com'
# Shuff 0, tm = 0.000
# Animal grom, Day ix 2, pv = 0.00000, r2_ = 0.07986, shuff = [0.032, 0.032], null_r2 0.08057
# ##################
# Starting Animal grom Day 4
# ...

# %%
for null_opt in ['nulldyn']:# ['null2null', 'full2null', 'nulldyn']:
    for potent_addon in [True]:
        generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=2, model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0',
                                        return_trans_from_lo = True, plot_action=False,
                                                null_opt=null_opt, potent_addon=potent_addon,
                                                 nulldyn_opt='alpha_opt', include_command_corr=False)
# Out:
# <img src="data:image/png;base64,..." width="486">
# ##################
# Starting Animal grom Day 0
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.1779
# Shuff 0, tm = 0.000
# Animal grom, Day ix 0, pv = 0.00000, purple r2_ = 0.19167, cyan r2_0.19371, shuff = [0.132, 0.133], null_r2 0.17794
# ##################
# Starting Animal grom Day 1
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.1667
# Shuff 0, tm = 0.000
# Animal grom, Day ix 1, pv = 0.00000, purple r2_ = 0.22773, cyan r2_0.23100, shuff = [0.159, 0.162], null_r2 0.16671
# ##################
# Starting Animal grom Day 2
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.0806
# Shuff 0, tm = 0.000
# Animal grom, Day ix 2, pv = 0.00000, purple r2_ = 0.07986, cyan r2_0.08088, shuff = [0.032, 0.032], null_r2 0.08057
# ##################
# ...

# %%
for null_opt in ['null2null']:# ['null2null', 'full2null', 'nulldyn']:
    for potent_addon in [True]:
        generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=3, 
                                                 model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0',
                                                return_trans_from_lo=True, plot_action=True,
                                                null_opt=null_opt, potent_addon=potent_addon,
                                                 include_command_corr=True, redoshuffs = True)
# Out:
# <img src="data:image/png;base64,..." width="570">
# ##################
# Starting Animal grom Day 0
# ##################
# done with iter 0
# done with iter 1
# done with iter 2
# done with iter 3
# done with iter 4
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.0000
# command r2 = 0.34422
# getting shuff quick
# getting shuff quick
# getting shuff quick
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-05 22:59:47.287904. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
for null_opt in ['null2null']:# ['null2null', 'full2null', 'nulldyn']:
    for potent_addon in [True]:
        generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=3, 
                                                 model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0',
                                                return_trans_from_lo=True, plot_action=False,
                                                null_opt=null_opt, potent_addon=potent_addon,
                                                 include_command_corr=False, redoshuffs = True)
# Out:
# <img src="data:image/png;base64,..." width="509">
# ##################
# Starting Animal grom Day 0
# ##################
# done with iter 0
# done with iter 1
# done with iter 2
# done with iter 3
# done with iter 4
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.1739
# getting shuff quick
# getting shuff quick
# getting shuff quick
# ##################
# Starting Animal grom Day 1
# ##################
# done with iter 0
# done with iter 1
# done with iter 2
# done with iter 3
# done with iter 4
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.1514
# getting shuff quick
# getting shuff quick
# getting shuff quick
# ##################
# Starting Animal grom Day 2
# ##################
# done with iter 0
# done with iter 1
# done with iter 2
# done with iter 3
# done with iter 4
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.0805
# getting shuff quick
# getting shuff quick
# ...

# %%
for null_opt in ['nulldyn']:# ['null2null', 'full2null', 'nulldyn']:
    for potent_addon in [True]:
        generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=3, 
                                                 model_nm = 'hist_1pos_0psh_0spksm_1_spksp_0',
                                                return_trans_from_lo=True, plot_action=False,
                                                null_opt=null_opt, nulldyn_opt='alpha_opt',
                                                 potent_addon=potent_addon,
                                                 include_command_corr=False, redoshuffs = True)
# Out:
# <img src="data:image/png;base64,..." width="702">
# ##################
# Starting Animal grom Day 0
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.1779
# getting shuff quick
# getting shuff quick
# getting shuff quick
# ##################
# Starting Animal grom Day 1
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.1667
# getting shuff quick
# getting shuff quick
# getting shuff quick
# ##################
# Starting Animal grom Day 2
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.0806
# getting shuff quick
# getting shuff quick
# getting shuff quick
# ##################
# Starting Animal grom Day 3
# ##################
# done with estimating null spks
# done with left out
# r2 of null predicting full: 0.0628
# getting shuff quick
# getting shuff quick
# getting shuff quick
# ##################
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-05 17:37:36.787214. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
generalization_plots.plot_loo_r2_overall(cat='com', nshuffs=3, 
                                                 model_nm = 'hist_1pos_0psh_2spksm_1_spksp_0',
                                                return_trans_from_lo=True, plot_action=False,
                                                null_opt=null_opt, nulldyn_opt='alpha_opt',
                                                 potent_addon=potent_addon,
                                                 include_command_corr=False, redoshuffs = True)
# Out:
# <div id='70c02d42-0dbb-4f5b-8dd5-b471d4b33dc4'></div>
# ##################
# Starting Animal grom Day 0
# ##################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-999ba2e17116> in <module>()
#       4                                                 null_opt=null_opt, nulldyn_opt='alpha_opt',
#       5                                                  potent_addon=potent_addon,
# ----> 6                                                  include_command_corr=False, redoshuffs = True)
#
# /Users/preeyakhanna/bmi_dynamics_code/online_analysis/generalization_plots.py in plot_loo_r2_overall(cat, yval, nshuffs, model_nm, return_trans_from_lo, plot_r2_by_lo_cat, plot_action, null_opt, potent_addon, nulldyn_opt, include_command_corr, redoshuffs)
#    1908                 ext3 = '_nocond'
#    1909
# ...

# %%
# for plot_act in [True, False]:
#     generalization_plots.test_quick_shuffle(nshuffs=5, plot_action=plot_act)
generalization_plots.test_quick_shuffle(nshuffs=5, plot_action=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# keep 0.9484 percent
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (14, 151) 6 (14,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (159,) (159,) (34, 151) 6 (34,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 223, total trls in this blk 159
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (121,) (121,) (47, 151) 6 (47,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 344, total trls in this blk 121
# verified shuffling
#  perc 0.2499
#  perc 0.2500
#  perc 0.2500
#  perc 0.2500
#  perc 0.2501
# how many same points ? 5
# verified shuffling
#  perc 0.2499
#  perc 0.2500
#  perc 0.2500
#  perc 0.2500
#  perc 0.2501
# ...

# %%
generalization_plots.test_quick_regressions_to_exclude_A_b()
# Out:
# <img src="data:image/png;base64,..." width="352">
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-06 09:45:15.079818. Please add timezone info to timestamps.
# ...

# %%
### No ridge, (alpha = 0), no action, yes xval
generalization_plots.test_quick_regressions_to_exclude_A_b()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ...

# %%
### No ridge, (alpha = 0), no action, yes xval
generalization_plots.test_quick_regressions_to_exclude_A_b(use_ridge=True)
# Out:
# <img src="data:image/png;base64,..." width="839">
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ...

# %%
generalization_plots.test_quick_regressions_to_exclude_A_b(use_ridge=True, plot_action = True)
# Out:
# <img src="data:image/png;base64,..." width="777">
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# ...

# %%
generalization_plots.test_quick_regressions_to_exclude_A_b(use_ridge=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2021-04-06 11:46:58.700421. Please add timezone info to timestamps.
# ...
