# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#plot_n_b_psth.ipynb
#plot neural and behavior psth

import scipy.io as sio
import scipy.stats as sio_stat
import scipy.interpolate
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt 

import os
import pickle
import sys
import copy

import time
import pylab as pl
from IPython import display

from bmi_dynamics_code import behavior_co_obs as bmi_b
from bmi_dynamics_code import data_for_v as preeyacode
from bmi_dynamics_code import util as bmi_util

import timeit
from sklearn import decomposition as skl_decomp

# %matplotlib notebook

# %%
# %matplotlib notebook

# %%
save_dir = r'D:\Dropbox\BMI_co_obs_paper\data\vivek\cartoon'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
# data_dir = '/Users/vivekathalye/Dropbox/Code/preeya_co_obstacle'
save_dir = r'D:\Dropbox\BMI_co_obs_paper\data\vivek\cartoon'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

home_dir = r'D:\Dropbox\Code\preeya_co_obstacle'
data_dir = r'D:\Dropbox\Data\preeya_co_obstacle'
data_path = os.path.join(data_dir, 'for_v_df.pkl')
print(os.path.exists(data_path))
d = pickle.load(open(data_path))

#UNPACK: 
decoder = d['decoder']
pre = d['pre']
num_targets = d['num_targets']
sample_period = d['sample_period']
target_hold_time = d['target_hold_time']
num_neurons = d['num_neurons']
target_color = d['target_color']
obs_big = d['obs_big']
obs_small = d['obs_small']
target_r_task = d['target_r_task']
cursor_r = d['cursor_r']
target_r_eff = d['target_r_eff']
target_pos = d['target_pos']
target_angle = np.arctan2(target_pos[:,1], target_pos[:,0])
target_dist = np.linalg.norm(target_pos, axis=1)
obs_pos = d['obs_pos']

tc_meta = d['tc_meta']
task_list = d['task_list']
num_tasks = len(task_list)
task2idx = d['task2idx']
idx2task = bmi_util.invert_dic(task2idx)
task2tc = d['task2tc']
tc_list = d['tc_list']
df = d['df']
df_label = d['df_label']

task_color = ['k', 'r']
# Out:
# True

# %%
#Plot the targets and obstacles: 
plot_task = True

plot_target = True
plot_obs_big = True
plot_obs_small = False

save_bool = False
plt_ext = ['.eps']

if plot_task:
    plot = {}
    plot['size'] = (10,10)
    plot['xlim'] = (-12.5,12.5)
    plot['ylim'] = (-12.5,12.5)

    plt.figure(figsize=plot['size'])

    if plot_obs_small:
        bmi_util.plot_obstacles(obs_pos, target_color, obs_small*np.ones(num_targets))
    if plot_obs_big:
        bmi_util.plot_obstacles(obs_pos, target_color, obs_big*np.ones(num_targets))
    if plot_target: 
        for task in range(num_tasks):
            bmi_util.plot_targets(target_pos, target_color, target_r_task[task]*np.ones(num_targets))                
    plt.axis('square')
    plt.xlim(plot['xlim'])
    plt.ylim(plot['ylim'])
    plt.show()
    
    if save_bool: 
        plt_name = 'target_obstacle'
        for ext in plt_ext:
            plt.savefig(os.path.join(save_dir, plt_name+ext))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
target_pos
# Out:
# array([[-7.07106781e+00, -7.07106781e+00],
#        [-1.83697020e-15, -1.00000000e+01],
#        [ 7.07106781e+00, -7.07106781e+00],
#        [ 1.00000000e+01,  0.00000000e+00],
#        [ 7.07106781e+00,  7.07106781e+00],
#        [ 6.12323400e-16,  1.00000000e+01],
#        [-7.07106781e+00,  7.07106781e+00],
#        [-1.00000000e+01,  1.22464680e-15]])

# %%
np.linalg.norm(target_pos,axis=1)
# Out:
# array([10., 10., 10., 10., 10., 10., 10., 10.])

# %%
save_bool = True
plt.figure()
for target in range(num_targets):
    x = np.array([0, target_pos[target, 0]])
    y = np.array([0, target_pos[target, 1]])
    plt.plot(x, y, color=target_color[target])
    plt.axis('square')
    
    if save_bool: 
        plt_name = 'target_dir'
        for ext in plt_ext:
            plt.savefig(os.path.join(save_dir, plt_name+ext))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Make 4 sample straight movements to the targets: 
num_pts=4
move_dic = {}
for target in range(num_targets):
    move_dic[(target,'x')] = np.linspace(0,target_pos[target,0],num_pts)
    move_dic[(target,'y')] = np.linspace(0,target_pos[target,1],num_pts)
    move_dic[(target,'c')] = target_color[target]

# %%
plt_target = [3,4,5]
plt.figure()
for target in plt_target: 
    plt.plot(move_dic[target,'x'], move_dic[target,'y'], '.-', color=move_dic[target,'c'])
plt.axis('square')

if save_bool: 
    plt_name = 'ex_straight_move'
    for ext in plt_ext:
        plt.savefig(os.path.join(save_dir, plt_name+ext))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Construct curved movement: 
delta = {}
for target in range(num_targets):
    delta[target, 'x'] = move_dic[target, 'x'][1]
    delta[target, 'y'] = move_dic[target, 'y'][1]

x = np.zeros(4)    
y = np.zeros(4)
for i,target in enumerate([5,4,3]):
    x[i+1] = x[i] + delta[target,'x']
    y[i+1] = y[i] + delta[target,'y']
    
plt.figure()
for i,target in enumerate([5,4,3]):
    x_plt = x[i:i+2]
    y_plt = y[i:i+2]
    
    plt.plot(x_plt, y_plt, '.-', color=target_color[target])
    plt.axis('square')

    if save_bool: 
        plt_name = 'ex_curve_up_right'
        for ext in plt_ext:
            plt.savefig(os.path.join(save_dir, plt_name+ext))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Construct curved movement: 
target_order = [3,4,5]
delta = {}
for target in range(num_targets):
    delta[target, 'x'] = move_dic[target, 'x'][1]
    delta[target, 'y'] = move_dic[target, 'y'][1]

x = np.zeros(4)    
y = np.zeros(4)
for i,target in enumerate(target_order):
    x[i+1] = x[i] + delta[target,'x']
    y[i+1] = y[i] + delta[target,'y']
    
plt.figure()
for i,target in enumerate(target_order):
    x_plt = x[i:i+2]
    y_plt = y[i:i+2]
    
    plt.plot(x_plt, y_plt, '.-', color=target_color[target])
    plt.axis('square')

    if save_bool: 
        plt_name = 'ex_curve_right_up'
        for ext in plt_ext:
            plt.savefig(os.path.join(save_dir, plt_name+ext))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Plot decaying dynamics

# %%
#Plt exp decay
rot_mat = bmi_b.rot2D_mat(45*np.pi/180)

n = np.arange(0,40)

alpha_y = 0.9
alpha_x = 0.5
y0=(1-0.25*0)
x0=(1+0.25*0)
y = y0*alpha_y**(n)
x = x0*alpha_x**(n)
yn = -y
xn = -x

proj = np.dot(rot_mat, np.array([y,x]))


plt.figure()
r = plt.plot(x,y, '.-')
r = plt.plot(xn,yn, '.-')
plt.plot(np.linspace(-0.5,0.5,2), np.linspace(0.5,-0.5,2))
plt.plot(np.linspace(-0.5,0.5,2), np.linspace(-0.5,0.5,2))


# r = plt.axis('square')
# r = plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')
plt.title('y vs x')
r = plt.axis('equal')
# plt.xlim((-1.1,1.1))
# plt.ylim((-1.1,1.1))

plt.xlabel('time')
plt.legend()
plt.title('time vs x, x')

plt.figure()
plt.plot(n, x, label='x')
plt.plot(n, y, label='y')
plt.plot(n, proj[0,:], label='proj on y+x=0')
# plt.plot(n, proj[1,:], label='proj on y-x=0')

plt.xlabel('time')
plt.legend()
plt.title('time vs x, x')
# plt.axis('square')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'time vs x, x')

# %%
#Loop 
#dynamics: 
A = np.array([[0.9, 0], [0, 0.5]])

#initial conditions: 
# init = np.array([[1,1], [-1,1], [1,-1], [-1,-1]])
starter = np.array([[-1,1], [1,-1]])

init = starter*0.5
init = np.vstack((init, 1*starter))
# init = np.vstack((init, 0.5*init))

traj_dic = {}
N = 40
for i, x0 in enumerate(init): 
    traj_dic[i,'x0'] = x0
    traj_dic[i] = np.zeros((2,N))
    traj_dic[i][:,0] = x0.T
    for n in np.arange(1,N): 
        traj_dic[i][:,n] = np.dot(np.linalg.matrix_power(A,n), x0.T)

# %%
dyn_dic = {}
dyn_dic['decay'] = traj_dic

# %%
plt.figure()
plt.plot(np.linspace(-1.0,1.0,2), np.linspace(1.0,-1.0,2), '--', color='k')
plt.plot(np.linspace(-1.0,1.0,2), np.linspace(-1.0,1.0,2), color='k')

for i in np.arange(0, init.shape[0]):
    plt.plot(traj_dic[i][0,:], traj_dic[i][1,:], '-')


plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-1.1, 1.1, -1.1, 1.1)

# %%
readout = bmi_b.rot2D_mat(45*np.pi/180)
traj_dic = dyn_dic['decay']
plt.figure()
for i in np.arange(0, init.shape[0]):
    proj = np.dot(readout, traj_dic[i])
    
    print(i, np.abs(proj[1,:]).max())
    plt.plot(proj[1,:], '-', linewidth=3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 0.21354624791833735)
# (1, 0.21354624791833735)
# (2, 0.4270924958366747)
# (3, 0.4270924958366747)

# %%
# plt.figure()
# plt.plot(traj_dic[0][0,:], label='x')
# plt.plot(traj_dic[0][1,:], label='y')

# plt.plot(traj_dic[4][0,:], label='x')
# plt.plot(traj_dic[4][1,:], label='y')
# plt.legend()
# Out:
# <div id='5085782a-b12b-4e1b-aa0d-9e2e17a4dba3'></div>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-211-0102a3180dc4> in <module>()
#       3 plt.plot(traj_dic[0][1,:], label='y')
#       4
# ----> 5 plt.plot(traj_dic[4][0,:], label='x')
#       6 plt.plot(traj_dic[4][1,:], label='y')
#       7 plt.legend()
#
# KeyError: 4

# %% [markdown]
# ### Plot flow field

# %%
#Plot dynamics flow field
#Inefficient strategy:
#At each grid point, evaluate the delta.  Quiver it.  

#Dynamics: 
save_bool = True

A = np.array([[0.9, 0], [0, 0.5]])
I = np.eye(2)

num_div = 6
grid_lim = 1
x_grid = np.hstack((np.linspace(-grid_lim,0,num_div), np.linspace(0,grid_lim,num_div)[1:]))
y_grid = x_grid

gain = 1
width = 0.002
plt.figure()
for x in x_grid:
    for y in y_grid:
        d = np.dot((A-I), np.array([x,y]).T)
        plt.quiver(x, y, d[0], d[1], angles='xy', scale=1/gain, scale_units='xy', width=width, color='k') #, zorder=10
plt.axis('square')

plt.plot(np.linspace(-grid_lim,grid_lim,2), np.linspace(grid_lim,-grid_lim,2), '--', color='k')
plt.plot(np.linspace(-grid_lim,grid_lim,2), np.linspace(-grid_lim,grid_lim,2), color='k')

for i in np.arange(0, init.shape[0]):
    plt.plot(traj_dic[i][0,:], traj_dic[i][1,:], '-', linewidth=3)
    
print(A)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[0.9 0. ]
#  [0.  0.5]]

# %%
readout = bmi_b.rot2D_mat(45*np.pi/180)
plt.figure()
for i in np.arange(0, init.shape[0]):
    proj = np.dot(readout, traj_dic[i])
    
    print(i, np.abs(proj[1,:]).max())
    plt.plot(proj[1,:], '-', linewidth=3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 0.21354624791833735)
# (1, 0.21354624791833735)
# (2, 0.4270924958366747)
# (3, 0.4270924958366747)

# %%
#Circular dynamics

# %%
A = bmi_b.rot2D_mat(45*np.pi/180)
np.dot(A, np.dot(A, np.array([1,0])))
# Out:
# array([1.79380389e-16, 1.00000000e+00])

# %%
np.dot(bmi_b.rot2D_mat(-90*np.pi/180), np.array([0.4270924958366747/2, 0.4270924958366747/2]))
# Out:
# array([ 0.21354625, -0.21354625])

# %%
np.dot(bmi_b.rot2D_mat(-90*np.pi/180), np.array([0.21354624791833735/2, 0.21354624791833735/2]))
# Out:
# array([ 0.10677312, -0.10677312])

# %%
#Loop 
#dynamics: 
A = bmi_b.rot2D_mat(10*np.pi/180)

#initial conditions: 
# init = np.array([[1, -1]])
starter = np.array([[-1,1], [1,-1]])
# init1 = starter*0.10677312
# init2 = starter*0.21354625

init1 = starter*0.14
init2 = starter*0.28
init = np.vstack((init1, init2))
# init = np.vstack((init, 0.5*init))

traj_dic = {}
N = 18
for i, x0 in enumerate(init): 
    traj_dic[i,'x0'] = x0
    traj_dic[i] = np.zeros((2,N))
    traj_dic[i][:,0] = x0.T
    for n in np.arange(1,N): 
        traj_dic[i][:,n] = np.dot(np.linalg.matrix_power(A,n), x0.T)
dyn_dic['rot'] = traj_dic

# %%
# plt.figure()
# plt.plot(traj_dic[0][0,:])
# plt.plot(traj_dic[0][1,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plt.figure()
# plt.plot(np.sum(dyn_dic['rot'][0], axis=0))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Circlular dynamics: 
A = bmi_b.rot2D_mat(10*np.pi/180)
I = np.eye(2)

num_div = 6
grid_lim = 1.0
x_grid = np.hstack((np.linspace(-grid_lim,0,num_div), np.linspace(0,grid_lim,num_div)[1:]))
y_grid = x_grid

gain = 1
width = 0.002
plt.figure()
for x in x_grid:
    for y in y_grid:
        d = np.dot((A-I), np.array([x,y]).T)
        plt.quiver(x, y, d[0], d[1], angles='xy', scale=1/gain, scale_units='xy', width=width, color='k') #, zorder=10
plt.axis('square')

plt.plot(np.linspace(-grid_lim,grid_lim,2), np.linspace(grid_lim,-grid_lim,2), '--', color='k')
plt.plot(np.linspace(-grid_lim,grid_lim,2), np.linspace(-grid_lim,grid_lim,2), color='k')

for i in np.arange(0, init.shape[0]):
    plt.plot(dyn_dic['decay'][i][0,:], dyn_dic['decay'][i][1,:], '-', linewidth=3)

for i in np.arange(0, init.shape[0]):
    plt.plot(dyn_dic['rot'][i][0,:], dyn_dic['rot'][i][1,:], '-', linewidth=3)    
    
print(A)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[ 0.98480775 -0.17364818]
#  [ 0.17364818  0.98480775]]
