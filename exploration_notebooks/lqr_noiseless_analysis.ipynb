# %%
# %load_ext autoreload
# %autoreload 2

# %%
#Adapted from: 
# lqr_neural_error_dynamics.ipynb

import scipy.io as sio
import scipy.stats as sio_stat
import scipy.interpolate
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt 

import os
import pickle
import sys
import copy

import time
import pylab as pl
from IPython import display

from bmi_dynamics_code import behavior_co_obs as bmi_b
from bmi_dynamics_code import data_for_v as preeyacode
from bmi_dynamics_code import util as bmi_util

import timeit
from sklearn import decomposition as skl_decomp

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# %matplotlib notebook

# %%
# %matplotlib notebook

# %%
# data_dir = '/Users/vivekathalye/Dropbox/Code/preeya_co_obstacle'
save_dir = r'D:\Dropbox\BMI_co_obs_paper\data\vivek\lqr'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
ext_list =['.png', '.eps']

home_dir = r'D:\Dropbox\Code\preeya_co_obstacle'
data_dir = r'D:\Dropbox\Data\preeya_co_obstacle'
data_path = os.path.join(data_dir, 'for_v_df.pkl')
print(os.path.exists(data_path))
d = pickle.load(open(data_path))

#UNPACK: 
decoder = d['decoder']
pre = d['pre']
num_targets = d['num_targets']
sample_period = d['sample_period']
target_hold_time = d['target_hold_time']
num_neurons = d['num_neurons']
target_color = d['target_color']
obs_big = d['obs_big']
obs_small = d['obs_small']
target_r_task = d['target_r_task'] #target_r_task = {0:1.7, 1:2.0}
cursor_r = d['cursor_r']
target_r_eff = d['target_r_eff']
target_pos = d['target_pos']
target_angle = np.arctan2(target_pos[:,1], target_pos[:,0])
target_dist = np.linalg.norm(target_pos, axis=1)
obs_pos = d['obs_pos']

tc_meta = d['tc_meta']
task_list = d['task_list']
num_tasks = len(task_list)
task2idx = d['task2idx']
idx2task = bmi_util.invert_dic(task2idx)
task2tc = d['task2tc']
tc_list = d['tc_list']
df = d['df']
df_label = d['df_label']

task_color = ['k', 'r']

#Pre-processing: 

bmi_b.preprocess_bmi_df(df, target_pos, pre, num_tasks, num_targets)
num_cw = 2
cw_label = ['cw', 'ccw']
task_rot_list = [0,1.1,1.2]

#Binning: 
#MAGNITUDE:
num_mag_bins = 5
num_mag_bins_analyze = 4
# mag_bin_perc = np.array([0,25,50,75,100])
mag_bin_perc = np.concatenate([np.linspace(0,95,5),np.array([100])])
#ANGLE:
num_angle_bins = 8
T0_angle = -3*(2*np.pi)/8
mag_bin, mag_bin_edges, mag_bin_c, angle_bin_c, angle_bin, angle_bin_edges =\
bmi_b.def_command_bin(df, mag_bin_perc, num_angle_bins, T0_angle)
#CENTER ANGLE DATA FOR BINNING (based on bin boundaries): 
angle_center_for_binning = bmi_b.df_center_angle_for_binning(df, angle_bin)
#BIN: 
bmi_b.df_bin_command(df, mag_bin_edges,angle_bin_edges)

#Pre-processing continued:

#Center angles to command bin, target: 
bmi_b.center_df_angle(df, angle_bin_c, target_angle)
# Out:
# True
# ('angle_center:', 22.5)
# ('min centered angle:', -157.47162455426732)
# ('max centered angle:', 202.46708261619673)

# %%
#Plot cw vs ccw trials, to confirm: 
plot = {}
plot['size'] = (10,10)
plot['xlim'] = (-12.5,12.5)
plot['ylim'] = (-12.5,12.5)
task_rot_list = [0,1.1,1.2]
task_rot_label = ['co','obs_ccw', 'obs_cw']

for i,task in enumerate(task_rot_list):
    plt.figure(figsize=plot['size'])
    plt.title(task_rot_label[i])
    for target in range(num_targets):    
            sel = (df['task_rot']==task) & (df['bin']>=0) & (df['target']==target)
            df_sel = df[sel]
            #------------------------------------------------------------------------------------
            #TRIALS: 
            trial_start = np.where(df_sel['bin']==0)[0]
            trial_stop = np.where(df_sel['bin_end']==0)[0]
            trial_bound = np.vstack((trial_start,trial_stop)).T
            #------------------------------------------------------------------------------------
            for bnd in trial_bound[:,:]: #trial_bound[0:1,:]:
    #             if (task_str == 'co') or (task_str == 'obs') and (df_sel['obs_size'][bnd[0]:bnd[0]+1] == obs_big).bool(): 
                x = df_sel['kin_px'][bnd[0]:bnd[1]+1]
                y = df_sel['kin_py'][bnd[0]:bnd[1]+1]
                color = target_color[target]
                plt.plot(x,y,'-',color=color)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
# <img src="data:image/png;base64,..." width="999.9999783255842">
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
target = 4
sel_target = (df['target']==target)
sel_start = (df['bin']==0)
sel_task = (df['task_rot']==1.2) #1.2 is clockwise, 1.1 is counterclockwise
sel = sel_target&sel_start&sel_task
trials = df.loc[sel,'trial_global']
print(trials)

trial = int(trials.iloc[0])
sel_trial = (df['trial_global']==trial)
sel_bin = (df['bin']>=0)
sel = sel_trial&sel_bin

x = df.loc[sel, 'kin_px']
y = df.loc[sel, 'kin_py']

plt.figure(figsize=(5,5))
plt.plot(x,y, '.-')
c = target_color[target]
bmi_util.plot_obstacles(obs_pos[target,:].reshape((1,-1)), [c], obs_big*np.ones(1))
bmi_util.plot_targets(target_pos[target,:].reshape((1,-1)), [c], target_r_task[1]*np.ones(1))
plt.axis('square')
# Out:
# 4704     115.0
# 4755     116.0
# 4796     117.0
# 4842     118.0
# 4890     119.0
# 4941     120.0
# 4988     121.0
# 5046     122.0
# 5122     123.0
# 5392     127.0
# 10206    238.0
# Name: trial_global, dtype: float64
# <img src="data:image/png;base64,..." width="499.9999891627921">
# (-1.3012247717787875,
#  9.564986506324725,
#  -0.5427594616898825,
#  10.32345181641363)

# %% [markdown]
# ### Load noiseless lqr

# %%
save_path = os.path.join(save_dir, 'lqr_noiseless.pkl')
with open(save_path, 'rb') as f: 
    r = pickle.load(f)
#Note the simulations were run with neural activity initialized to 0    
for (k,v) in r.items():
    exec(k+'=v')
    
n_list = ['n_'+ str(i) for i in np.arange(num_neurons)]

# %%
r.keys()
# Out:
# ['Qv_s',
#  'num_targets',
#  'num_mag_bins_analyze',
#  'A_dic',
#  'angle_bin_edges',
#  'input_label',
#  'obs_margin',
#  'Qfp_s',
#  'Q_f',
#  'mag_bin',
#  'angle_bin',
#  'state_label',
#  'df_mean',
#  'mag_bin_c',
#  'kin_var',
#  'df_diff',
#  'Qfv_s',
#  'model_list',
#  'n_init',
#  'df_lqr',
#  'B',
#  'task_rot_list',
#  'F',
#  'bn',
#  'R_s',
#  'Kn',
#  'Q',
#  'R',
#  'mag_bin_edges',
#  'df_norm_lqr',
#  'offset_var',
#  'angle_bin_c',
#  'waypoint_speed',
#  'A_list',
#  'angle_center_for_binning',
#  'center',
#  'move_lqr',
#  'An',
#  'Qp_s',
#  'move_horizon']

# %% [markdown]
# ### Fit regression to different models

# %% [markdown]
# ### Dynamics model, use A

# %%
m = 'n_do'

sel_m = (df_lqr['model']==m)

sel_t_bin = (df_lqr['bin'] >= 0)
sel_t_bin_end = (df_lqr['bin_end'] >= 1)
sel_t = (sel_t_bin)&(sel_t_bin_end)&sel_m
n_t = np.array(df_lqr.loc[sel_t,n_list]).T

sel_tp1_bin = (df_lqr['bin'] >= 1)
sel_tp1_bin_end = (df_lqr['bin_end'] >= 0)
sel_tp1 = (sel_tp1_bin)&(sel_tp1_bin_end)&sel_m
n_tp1 = np.array(df_lqr.loc[sel_tp1,n_list]).T

nhat_tp1 = np.dot(An, n_t)+ bn.reshape((-1,1))


#sanity check we can use the dynamics parameters:
total_cov = np.cov(n_tp1)
total_var = np.trace(total_cov)

res_hat = nhat_tp1-n_tp1 #44 x num_obs
res_cov = np.cov(res_hat) #44 x 44
res_var = np.trace(res_cov)

pred_cov = np.cov(nhat_tp1)
pred_var = np.trace(pred_cov)

print('sanity check on neural dynamics fit:')
print('model A R2: ', 1-res_var/total_var)
# print('true R2: ', clf.score(n_t, n_tp1))
# Out:
# sanity check on neural dynamics fit:
# ('model A R2: ', 0.8836633403341088)

# %%
plt.figure()
plt.imshow(An)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Dynamics model, fit new A, b

# %%
m = 'n_do'

sel_m = (df_lqr['model']==m)

sel_t_bin = (df_lqr['bin'] >= 0)
sel_t_bin_end = (df_lqr['bin_end'] >= 1)
sel_t = (sel_t_bin)&(sel_t_bin_end)&sel_m
n_t = np.array(df_lqr.loc[sel_t,n_list]).T

sel_tp1_bin = (df_lqr['bin'] >= 1)
sel_tp1_bin_end = (df_lqr['bin_end'] >= 0)
sel_tp1 = (sel_tp1_bin)&(sel_tp1_bin_end)&sel_m
n_tp1 = np.array(df_lqr.loc[sel_tp1,n_list]).T


# regression: 
#ridge parameter from Preeya: 2500
clf = Ridge(alpha=1)
clf.fit(n_t.T, n_tp1.T)

An_fit = clf.coef_
bn_fit = clf.intercept_

print('fit A R2: ', clf.score(n_t.T, n_tp1.T))
# Out:
# ('fit A R2: ', 0.986268332601159)

# %%
plt.figure()
plt.imshow(An_fit)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### No dynamics model, fit new A, b

# %%
m = 'n_null'

sel_m = (df_lqr['model']==m)

sel_t_bin = (df_lqr['bin'] >= 0)
sel_t_bin_end = (df_lqr['bin_end'] >= 1)
sel_t = (sel_t_bin)&(sel_t_bin_end)&sel_m
n_t = np.array(df_lqr.loc[sel_t,n_list]).T

sel_tp1_bin = (df_lqr['bin'] >= 1)
sel_tp1_bin_end = (df_lqr['bin_end'] >= 0)
sel_tp1 = (sel_tp1_bin)&(sel_tp1_bin_end)&sel_m
n_tp1 = np.array(df_lqr.loc[sel_tp1,n_list]).T

clf = Ridge(alpha=1)
clf.fit(np.array(n_t).T, np.array(n_tp1).T)

An_fit_null = clf.coef_
bn_fit_null = clf.intercept_

print('fit A R2: ', clf.score(n_t.T, n_tp1.T))
# Out:
# ('fit A R2: ', 0.65499554368196)

# %%
plt.figure()
plt.imshow(An_fit_null)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Load  lqr sim data

# %%
save_path = os.path.join(save_dir, 'lqr_noiseless.pkl')
with open(save_path, 'rb') as f: 
    r = pickle.load(f)
#Note the simulations were run with neural activity initialized to 0    
for (k,v) in r.items():
    exec(k+'=v')

# %%
num_mag_bins_analyze=4
def plot_command_bin(): 
    bmi_b.plot_polar_bins(angle_bin_edges, mag_bin_edges[:,:(num_mag_bins_analyze)], target_color)
    
plt.figure(figsize=(5,5))
plot_command_bin()
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
#Plot cw vs ccw trials, to confirm: 
m = 'n_do'
plot = {}
plot['size'] = (10,3)
plot['xlim'] = (-12.5,12.5)
plot['ylim'] = (-12.5,12.5)
task_rot_list = [0,1.1,1.2]
task_rot_label = ['co','obs_ccw', 'obs_cw']


num_trials_plot = 10
plt.figure(figsize=plot['size'])
for i,task in enumerate(task_rot_list): 
    plt.subplot(1,3,i+1)
    plt.title(task_rot_label[i])    
    for target in range(num_targets):    
        sel = (df_lqr['task_rot']==task) & (df_lqr['bin']>=0) & (df_lqr['target']==target) & (df_lqr['model'] == m)
        df_sel = df_lqr[sel]
        #------------------------------------------------------------------------------------
        #TRIALS: 
        trial_start = np.where(df_sel['bin']==0)[0]
        trial_stop = np.where(df_sel['bin_end']==0)[0]
        trial_bound = np.vstack((trial_start,trial_stop)).T
        #------------------------------------------------------------------------------------
        for bnd in trial_bound[:num_trials_plot,:]: #trial_bound[0:1,:]:
#             if (task_str == 'co') or (task_str == 'obs') and (df_sel['obs_size'][bnd[0]:bnd[0]+1] == obs_big).bool(): 
            x = df_sel['kin_px'][bnd[0]:bnd[1]+1]
            y = df_sel['kin_py'][bnd[0]:bnd[1]+1]
            color = target_color[target]
            plt.plot(x,y,'-',color=color)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# ### Analyze diff command-movement vs command

# %%
#mean diff: 
df_diff_col = n_list + ['diff', 'diff_null', 'diff_potent', 'ba', 'bm', 'model', 'target', 'task_rot', 'num']
nan_df = pd.DataFrame()
df_diff = []
for ba in range(num_angle_bins):
    sel_ba = (df_lqr['u_v_angle_bin']==ba)
    sel_d_ba = (df_mean['ba'] == ba)    
    for bm in range(num_mag_bins_analyze):
        sel_bm = (df_lqr['u_v_mag_bin']==bm)
        sel_d_bm = (df_mean['bm'] == bm)
        for m in model_list:
            sel_m = (df_lqr['model'] == m)
            sel_d_m = (df_mean['model'] == m)
            sel_d = sel_d_ba&sel_d_bm&sel_d_m
            mean_i = df_mean.loc[sel_d, n_list]
            
            
            for task in task_rot_list:
                sel_task = (df_lqr['task_rot']==task)
                for target in range(num_targets):
                    sel_target = (df_lqr['target']==target)
                    
                    sel = sel_ba&sel_bm&sel_m&sel_task&sel_target
                    num = len(np.where(sel)[0])
                    if num > 0:
                        n_i = df_lqr.loc[sel,n_list].mean()
                        diff_i = n_i-mean_i
                        diff_potent_i, diff_null_i, _ = bmi_util.proj_null_potent(Kn[2:4,:].T, np.array(diff_i).reshape((-1,1)))
                        
                        df_i = pd.DataFrame(pd.DataFrame(np.ones((1,len(df_diff_col)))*np.nan, columns=df_diff_col))
                        df_i.loc[0,n_list]=n_i
                        df_i['diff']=np.linalg.norm(diff_i)
                        df_i['diff_null']=np.linalg.norm(diff_null_i)
                        df_i['diff_potent']=np.linalg.norm(diff_potent_i)
                        df_i['ba'] = ba
                        df_i['bm'] = bm
                        df_i['model'] = m
                        df_i['task_rot'] = task
                        df_i['target'] = target
                        df_i['num'] = num

                        df_diff.append(df_i)
df_diff = pd.concat(df_diff, ignore_index=True)

# %%
plt.figure(figsize=(5,5))

model_list = ['n_do', 'n_null']
model_color = {'n_do':'g', 'n_o':'r', 'n_null':'k'}
d_cm_diff = []


min_obs = 1
for i,m in enumerate(model_list):
    print(m)
    sel_m = df_diff['model']==m
    sel_obs = df_diff['num']>=min_obs
    
    sel = sel_m&sel_obs
#     sel = sel_m&sel_obs
    diff_i = df_diff.loc[sel, 'diff']
    d_cm_diff.append(diff_i)
    diff_mean_i = df_diff.loc[sel, 'diff'].mean()
#     num = df_diff.loc[sel, 'num'].mean()
#     print(m, test, num)
    plt.scatter(i*np.ones(len(diff_i)), diff_i, alpha=0.3,color=model_color[m])
    plt.hlines(diff_mean_i, i-0.25,i+0.25)
    
_=plt.xticks([0,1], model_list)
plt.title('noiseless lqr: cm-c activity')
plt.ylabel('norm difference of activity')
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">
# n_do
# n_null
# Text(0,0.5,'norm difference of activity')

# %%
#Histogram the diffs and plot overlapping distributions:
vmin = 0
vmax = 7
num_bins = (vmax-vmin)*5+1
cm_diff_bins_c = np.linspace(0,7,num_bins)
bin_w = cm_diff_bins_c[1]-cm_diff_bins_c[0]
cm_diff_bins_e = np.vstack((cm_diff_bins_c-bin_w/2, cm_diff_bins_c+bin_w/2))
bin_dic = {0:cm_diff_bins_e}

cm_diff_binned = []
for i,d in enumerate(d_cm_diff):
    d = np.array(d).reshape((-1,1))
    bin_result, hist_result = bmi_b.bin_vec_data(d,bin_dic)
    cm_diff_binned.append(hist_result)


model_color = {'n_do':'g', 'n_o':'r', 'n_null':'k'}    
cm_diff_bins_e_flat = np.hstack((cm_diff_bins_e[0,:], cm_diff_bins_e[1,-1]))

plt.figure(figsize=(6,6))
for i,d in enumerate(cm_diff_binned):
    m = model_list[i]
    d_plot = d/np.sum(d)
#     d_plot = np.cumsum(d_plot)
    bmi_util.hist_step_plot(cm_diff_bins_e_flat, d_plot,color=model_color[m],label=m)
    
    d_mean = np.mean(d_cm_diff[i])
    plt.vlines(d_mean, 0, 0.6, color=model_color[m],alpha=0.2)
plt.xlim((-0.5,6))    
plt.legend()    
plt.xlabel('distance bw cm and c activity')
plt.ylabel('frac commands')
plt.title('Dist bw command-movement and command activity')
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# 36
# (74L,)
# 36
# (74L,)
# Text(0.5,1,'Dist bw command-movement and command activity')

# %% [markdown]
# ### Posthoc noise:
# add null space noise and then subselect the pool samples to match within command distribution
# get a sense of how many noisy samples you need
#
# Starting Questions:
#
# 1) How many trials do I have now?  1 per movement.  (see trial column in df_lqr)

# %% [markdown]
# approach:
# if we only add null-space noise, the commands won't get matched... but we should still reproduce the noiseless effect by averaging.
#
# so let's start here.
#
# THEN, we simulate with null noise and replicate.
#
# THEN, we proceed to noise (not just null space noise)
#
# --
#
# we keep dictionary of arrays:
# (to execute more quickly than df)
# command-movement
# command - all qualified movements are equally represented.
#
# loop model
#     loop command
#         loop movement
#             take the observations, add some amount of noise to each of them.
#             collect N of them into the general pool.
#             calculate the movement mean
#         calculate the command mean

# %%
#Noise to add:

# %%
cdata = {}


for ba in range(num_angle_bins):
    sel_ba = (df_lqr['u_v_angle_bin']==ba) 
   
    for bm in range(num_mag_bins_analyze):
        sel_bm = (df_lqr['u_v_mag_bin']==bm)
        
        for m in model_list:
            sel_m = (df_lqr['model'] == m)
            cdata[m,ba,bm] = []
            
            for task_rot in task_rot_list:
                sel_task = (df_lqr['task_rot'] == task_rot)
                
                for target in range(num_targets):
                    sel_target = (df_lqr['target'] == target)

                    sel = sel_ba\
                    &sel_bm\
                    &sel_m\
                    &sel_task\
                    &sel_target
                    if sum(sel) > 0: 
                        n_i = np.array(df_lqr.loc[sel,n_list]).T
                        #Add noise: 
                        
                        #For each n_i, add 100 noise samples... 
                        
#                         cdata[m,ba,bm,target,task_rot] = n_i
#                         cdata[m,ba,bm].append(n_i)       
#             cdata[m,ba,bm] = np.concatenate(cdata[m,ba,bm],axis=1)

# %%
cdata[m,ba,bm].shape
# Out:
# (44L, 68L)

# %%
list(df_lqr.columns)
# Out:
# ['n_0',
#  'n_1',
#  'n_2',
#  'n_3',
#  'n_4',
#  'n_5',
#  'n_6',
#  'n_7',
#  'n_8',
#  'n_9',
#  'n_10',
#  'n_11',
#  'n_12',
#  'n_13',
#  'n_14',
#  'n_15',
#  'n_16',
#  'n_17',
#  'n_18',
#  'n_19',
#  'n_20',
#  'n_21',
#  'n_22',
#  'n_23',
#  'n_24',
#  'n_25',
#  'n_26',
#  'n_27',
#  'n_28',
#  'n_29',
#  'n_30',
#  'n_31',
#  'n_32',
#  'n_33',
#  'n_34',
#  'n_35',
#  'n_36',
#  'n_37',
#  'n_38',
#  'n_39',
#  'n_40',
#  'n_41',
#  'n_42',
#  'n_43',
#  'kin_px',
#  'kin_py',
#  'kin_vx',
#  'kin_vy',
#  'u_px',
#  'u_py',
#  'u_vx',
#  'u_vy',
#  'u_offset',
#  'u_0',
#  'u_1',
#  'u_2',
#  'u_3',
#  'u_4',
#  'u_5',
#  'u_6',
#  'u_7',
#  'u_8',
#  'u_9',
#  'u_10',
#  'u_11',
#  'u_12',
#  'u_13',
#  'u_14',
#  'u_15',
#  'u_16',
#  'u_17',
#  'u_18',
#  'u_19',
#  'u_20',
#  'u_21',
#  'u_22',
#  'u_23',
#  'u_24',
#  'u_25',
#  'u_26',
#  'u_27',
#  'u_28',
#  'u_29',
#  'u_30',
#  'u_31',
#  'u_32',
#  'u_33',
#  'u_34',
#  'u_35',
#  'u_36',
#  'u_37',
#  'u_38',
#  'u_39',
#  'u_40',
#  'u_41',
#  'u_42',
#  'u_43',
#  'task_rot',
#  'target',
#  'bin',
#  'bin_end',
#  'trial',
#  'model',
#  'p_mag',
#  'p_angle',
#  'v_mag',
#  'v_angle',
#  'u_p_mag',
#  'u_p_angle',
#  'u_v_mag',
#  'u_v_angle',
#  'u_v_mag_bin',
#  'u_v_angle_bin',
#  'p_angle_ctr_t',
#  'v_angle_ctr_t',
#  'u_p_angle_ctr_t',
#  'u_v_angle_ctr_t',
#  'u_v_angle_ctr_bin']

# %%
#Let's loop and confirm there's no within bin difference: 
#loop each command (get command distribution)
#loop each movement (get cm distribution)
#use t-test to compare x and y distribution

model_list = ['n_do', 'n_null']
df_t_col = ['diff_x', 'diff_y', 'xstat', 'xp', 'ystat', 'yp', 'ba', 'bm', 'model', 'task_rot', 'target', 'num_cm', 'num_c']
df_t = []
for ba in range(num_angle_bins):
    sel_ba = (df_lqr['u_v_angle_bin']==ba)
    for bm in range(num_mag_bins_analyze):
        sel_bm = (df_lqr['u_v_mag_bin']==bm)
        for m in model_list:
            sel_m = (df_lqr['model'] == m)
            sel_c = sel_ba&sel_bm&sel_m
            cx = df_lqr.loc[sel_c, 'u_vx'] 
            cy = df_lqr.loc[sel_c, 'u_vy'] 
            num_c = len(np.where(sel_c)[0])
            
            for task in task_rot_list:
                sel_task = (df_lqr['task_rot']==task)
                for target in range(num_targets):
                    sel_target = (df_lqr['target']==target)
                    sel_cm = sel_ba&sel_bm&sel_m&sel_task&sel_target
                    cmx = df_lqr.loc[sel_cm, 'u_vx'] 
                    cmy = df_lqr.loc[sel_cm, 'u_vy']                     
                    
                    num_cm = len(np.where(sel_cm)[0])
                    if num_cm > 0:
                        print(ba, bm, m, task, target)
                        xstat, xp = sio_stat.ttest_ind(cx, cmx)
                        ystat, yp = sio_stat.ttest_ind(cy, cmy)
                        
                        df_i = pd.DataFrame(pd.DataFrame(np.ones((1,len(df_t_col)))*np.nan, columns=df_t_col))
                        df_i['diff_x']=cx.mean()-cmx.mean()
                        df_i['diff_y']=cy.mean()-cmy.mean()
                        df_i['xstat'] = xstat
                        df_i['xp'] = xp
                        df_i['ystat'] = ystat
                        df_i['yp'] = yp
                        
                        df_i['ba'] = ba
                        df_i['bm'] = bm
                        df_i['model'] = m
                        df_i['task_rot'] = task
                        df_i['target'] = target
                        df_i['num_cm'] = num_cm
                        df_i['num_c'] = num_c

                        df_t.append(df_i)
df_t = pd.concat(df_t, ignore_index=True)
# Out:
# (0, 0, 'n_do', 0, 0)
# (0, 0, 'n_do', 0, 1)
# (0, 0, 'n_do', 0, 2)
# (0, 0, 'n_do', 0, 3)
# (0, 0, 'n_do', 0, 4)
# (0, 0, 'n_do', 0, 5)
# (0, 0, 'n_do', 0, 6)
# (0, 0, 'n_do', 0, 7)
# (0, 0, 'n_do', 1.1, 0)
# (0, 0, 'n_do', 1.1, 1)
# (0, 0, 'n_do', 1.1, 2)
# (0, 0, 'n_do', 1.1, 3)
# (0, 0, 'n_do', 1.1, 4)
# (0, 0, 'n_do', 1.1, 5)
# (0, 0, 'n_do', 1.1, 6)
# (0, 0, 'n_do', 1.1, 7)
# (0, 0, 'n_do', 1.2, 0)
# (0, 0, 'n_do', 1.2, 1)
# (0, 0, 'n_do', 1.2, 2)
# (0, 0, 'n_do', 1.2, 3)
# (0, 0, 'n_do', 1.2, 4)
# (0, 0, 'n_do', 1.2, 5)
# (0, 0, 'n_do', 1.2, 6)
# (0, 0, 'n_do', 1.2, 7)
# (0, 0, 'n_null', 0, 0)
# (0, 0, 'n_null', 0, 1)
# (0, 0, 'n_null', 0, 2)
# (0, 0, 'n_null', 0, 3)
# (0, 0, 'n_null', 0, 4)
# (0, 0, 'n_null', 0, 5)
# (0, 0, 'n_null', 0, 6)
# (0, 0, 'n_null', 0, 7)
# (0, 0, 'n_null', 1.1, 0)
# (0, 0, 'n_null', 1.1, 1)
# (0, 0, 'n_null', 1.1, 2)
# (0, 0, 'n_null', 1.1, 3)
# (0, 0, 'n_null', 1.1, 4)
# (0, 0, 'n_null', 1.1, 5)
# (0, 0, 'n_null', 1.1, 6)
# (0, 0, 'n_null', 1.1, 7)
# (0, 0, 'n_null', 1.2, 0)
# (0, 0, 'n_null', 1.2, 1)
# (0, 0, 'n_null', 1.2, 2)
# (0, 0, 'n_null', 1.2, 3)
# (0, 0, 'n_null', 1.2, 4)
# (0, 0, 'n_null', 1.2, 5)
# (0, 0, 'n_null', 1.2, 6)
# (0, 0, 'n_null', 1.2, 7)
# (0, 1, 'n_do', 0, 0)
# (0, 1, 'n_do', 0, 1)
# (0, 1, 'n_do', 0, 2)
# (0, 1, 'n_do', 0, 3)
# (0, 1, 'n_do', 0, 4)
# (0, 1, 'n_do', 0, 5)
# (0, 1, 'n_do', 0, 6)
# (0, 1, 'n_do', 0, 7)
# (0, 1, 'n_do', 1.1, 0)
# (0, 1, 'n_do', 1.1, 1)
# (0, 1, 'n_do', 1.1, 2)
# (0, 1, 'n_do', 1.1, 3)
# (0, 1, 'n_do', 1.1, 4)
# (0, 1, 'n_do', 1.1, 5)
# (0, 1, 'n_do', 1.1, 6)
# (0, 1, 'n_do', 1.1, 7)
# (0, 1, 'n_do', 1.2, 0)
# (0, 1, 'n_do', 1.2, 1)
# (0, 1, 'n_do', 1.2, 2)
# (0, 1, 'n_do', 1.2, 3)
# (0, 1, 'n_do', 1.2, 4)
# (0, 1, 'n_do', 1.2, 5)
# (0, 1, 'n_do', 1.2, 6)
# (0, 1, 'n_do', 1.2, 7)
# (0, 1, 'n_null', 0, 0)
# (0, 1, 'n_null', 0, 1)
# (0, 1, 'n_null', 0, 2)
# (0, 1, 'n_null', 0, 3)
# (0, 1, 'n_null', 0, 4)
# (0, 1, 'n_null', 0, 5)
# (0, 1, 'n_null', 0, 6)
# (0, 1, 'n_null', 0, 7)
# (0, 1, 'n_null', 1.1, 0)
# (0, 1, 'n_null', 1.1, 1)
# (0, 1, 'n_null', 1.1, 2)
# (0, 1, 'n_null', 1.1, 3)
# (0, 1, 'n_null', 1.1, 4)
# (0, 1, 'n_null', 1.1, 5)
# (0, 1, 'n_null', 1.1, 6)
# (0, 1, 'n_null', 1.1, 7)
# (0, 1, 'n_null', 1.2, 0)
# (0, 1, 'n_null', 1.2, 1)
# (0, 1, 'n_null', 1.2, 2)
# (0, 1, 'n_null', 1.2, 3)
# (0, 1, 'n_null', 1.2, 4)
# (0, 1, 'n_null', 1.2, 5)
# (0, 1, 'n_null', 1.2, 6)
# (0, 1, 'n_null', 1.2, 7)
# (0, 2, 'n_do', 0, 0)
# (0, 2, 'n_do', 0, 1)
# (0, 2, 'n_do', 0, 2)
# (0, 2, 'n_do', 0, 3)
# (0, 2, 'n_do', 0, 4)
# (0, 2, 'n_do', 0, 5)
# (0, 2, 'n_do', 0, 6)
# (0, 2, 'n_do', 0, 7)
# (0, 2, 'n_do', 1.1, 0)
# (0, 2, 'n_do', 1.1, 1)
# (0, 2, 'n_do', 1.1, 2)
# (0, 2, 'n_do', 1.1, 3)
# (0, 2, 'n_do', 1.1, 4)
# (0, 2, 'n_do', 1.1, 5)
# (0, 2, 'n_do', 1.1, 6)
# (0, 2, 'n_do', 1.1, 7)
# (0, 2, 'n_do', 1.2, 0)
# (0, 2, 'n_do', 1.2, 1)
# (0, 2, 'n_do', 1.2, 2)
# (0, 2, 'n_do', 1.2, 3)
# (0, 2, 'n_do', 1.2, 4)
# (0, 2, 'n_do', 1.2, 5)
# (0, 2, 'n_do', 1.2, 6)
# (0, 2, 'n_do', 1.2, 7)
# (0, 2, 'n_null', 0, 0)
# (0, 2, 'n_null', 0, 1)
# (0, 2, 'n_null', 0, 2)
# (0, 2, 'n_null', 0, 3)
# (0, 2, 'n_null', 0, 4)
# (0, 2, 'n_null', 0, 5)
# (0, 2, 'n_null', 0, 6)
# (0, 2, 'n_null', 0, 7)
# (0, 2, 'n_null', 1.1, 0)
# (0, 2, 'n_null', 1.1, 1)
# (0, 2, 'n_null', 1.1, 2)
# (0, 2, 'n_null', 1.1, 3)
# (0, 2, 'n_null', 1.1, 4)
# (0, 2, 'n_null', 1.1, 5)
# (0, 2, 'n_null', 1.1, 6)
# (0, 2, 'n_null', 1.1, 7)
# (0, 2, 'n_null', 1.2, 0)
# (0, 2, 'n_null', 1.2, 1)
# (0, 2, 'n_null', 1.2, 2)
# (0, 2, 'n_null', 1.2, 3)
# (0, 2, 'n_null', 1.2, 4)
# (0, 2, 'n_null', 1.2, 5)
# (0, 2, 'n_null', 1.2, 6)
# (0, 2, 'n_null', 1.2, 7)
# (0, 3, 'n_do', 0, 0)
# (0, 3, 'n_do', 0, 1)
# (0, 3, 'n_do', 0, 2)
# (0, 3, 'n_do', 0, 3)
# (0, 3, 'n_do', 0, 4)
# (0, 3, 'n_do', 0, 5)
# (0, 3, 'n_do', 0, 6)
# (0, 3, 'n_do', 0, 7)
# (0, 3, 'n_do', 1.1, 0)
# (0, 3, 'n_do', 1.1, 1)
# (0, 3, 'n_do', 1.1, 2)
# (0, 3, 'n_do', 1.1, 3)
# (0, 3, 'n_do', 1.1, 4)
# (0, 3, 'n_do', 1.1, 5)
# (0, 3, 'n_do', 1.1, 6)
# (0, 3, 'n_do', 1.1, 7)
# (0, 3, 'n_do', 1.2, 0)
# (0, 3, 'n_do', 1.2, 1)
# (0, 3, 'n_do', 1.2, 2)
# (0, 3, 'n_do', 1.2, 3)
# (0, 3, 'n_do', 1.2, 4)
# (0, 3, 'n_do', 1.2, 5)
# (0, 3, 'n_do', 1.2, 6)
# (0, 3, 'n_do', 1.2, 7)
# (0, 3, 'n_null', 0, 0)
# (0, 3, 'n_null', 0, 1)
# (0, 3, 'n_null', 0, 2)
# (0, 3, 'n_null', 0, 3)
# (0, 3, 'n_null', 0, 4)
# (0, 3, 'n_null', 0, 5)
# (0, 3, 'n_null', 0, 6)
# (0, 3, 'n_null', 0, 7)
# (0, 3, 'n_null', 1.1, 0)
# (0, 3, 'n_null', 1.1, 1)
# (0, 3, 'n_null', 1.1, 2)
# (0, 3, 'n_null', 1.1, 3)
# (0, 3, 'n_null', 1.1, 4)
# (0, 3, 'n_null', 1.1, 5)
# (0, 3, 'n_null', 1.1, 6)
# (0, 3, 'n_null', 1.1, 7)
# (0, 3, 'n_null', 1.2, 0)
# (0, 3, 'n_null', 1.2, 1)
# (0, 3, 'n_null', 1.2, 2)
# (0, 3, 'n_null', 1.2, 3)
# (0, 3, 'n_null', 1.2, 4)
# (0, 3, 'n_null', 1.2, 5)
# (0, 3, 'n_null', 1.2, 6)
# (0, 3, 'n_null', 1.2, 7)
# (1, 0, 'n_do', 0, 0)
# (1, 0, 'n_do', 0, 1)
# (1, 0, 'n_do', 0, 2)
# (1, 0, 'n_do', 0, 3)
# (1, 0, 'n_do', 0, 4)
# (1, 0, 'n_do', 0, 5)
# (1, 0, 'n_do', 0, 6)
# (1, 0, 'n_do', 0, 7)
# (1, 0, 'n_do', 1.1, 0)
# (1, 0, 'n_do', 1.1, 1)
# (1, 0, 'n_do', 1.1, 2)
# (1, 0, 'n_do', 1.1, 3)
# (1, 0, 'n_do', 1.1, 4)
# (1, 0, 'n_do', 1.1, 5)
# (1, 0, 'n_do', 1.1, 6)
# (1, 0, 'n_do', 1.1, 7)
# (1, 0, 'n_do', 1.2, 0)
# (1, 0, 'n_do', 1.2, 1)
# (1, 0, 'n_do', 1.2, 2)
# (1, 0, 'n_do', 1.2, 3)
# (1, 0, 'n_do', 1.2, 4)
# (1, 0, 'n_do', 1.2, 5)
# (1, 0, 'n_do', 1.2, 6)
# (1, 0, 'n_do', 1.2, 7)
# (1, 0, 'n_null', 0, 0)
# (1, 0, 'n_null', 0, 1)
# (1, 0, 'n_null', 0, 2)
# (1, 0, 'n_null', 0, 3)
# (1, 0, 'n_null', 0, 4)
# (1, 0, 'n_null', 0, 5)
# (1, 0, 'n_null', 0, 6)
# (1, 0, 'n_null', 0, 7)
# (1, 0, 'n_null', 1.1, 0)
# (1, 0, 'n_null', 1.1, 1)
# (1, 0, 'n_null', 1.1, 2)
# (1, 0, 'n_null', 1.1, 3)
# (1, 0, 'n_null', 1.1, 4)
# (1, 0, 'n_null', 1.1, 5)
# (1, 0, 'n_null', 1.1, 6)
# (1, 0, 'n_null', 1.1, 7)
# (1, 0, 'n_null', 1.2, 0)
# (1, 0, 'n_null', 1.2, 1)
# (1, 0, 'n_null', 1.2, 2)
# (1, 0, 'n_null', 1.2, 3)
# (1, 0, 'n_null', 1.2, 4)
# (1, 0, 'n_null', 1.2, 5)
# (1, 0, 'n_null', 1.2, 6)
# (1, 0, 'n_null', 1.2, 7)
# (1, 1, 'n_do', 0, 0)
# (1, 1, 'n_do', 0, 1)
# (1, 1, 'n_do', 0, 2)
# (1, 1, 'n_do', 0, 3)
# (1, 1, 'n_do', 0, 4)
# (1, 1, 'n_do', 0, 5)
# (1, 1, 'n_do', 0, 6)
# (1, 1, 'n_do', 0, 7)
# (1, 1, 'n_do', 1.1, 0)
# (1, 1, 'n_do', 1.1, 1)
# (1, 1, 'n_do', 1.1, 2)
# (1, 1, 'n_do', 1.1, 3)
# (1, 1, 'n_do', 1.1, 4)
# (1, 1, 'n_do', 1.1, 5)
# (1, 1, 'n_do', 1.1, 6)
# (1, 1, 'n_do', 1.1, 7)
# (1, 1, 'n_do', 1.2, 0)
# (1, 1, 'n_do', 1.2, 1)
# (1, 1, 'n_do', 1.2, 2)
# (1, 1, 'n_do', 1.2, 3)
# (1, 1, 'n_do', 1.2, 4)
# (1, 1, 'n_do', 1.2, 5)
# (1, 1, 'n_do', 1.2, 6)
# (1, 1, 'n_do', 1.2, 7)
# (1, 1, 'n_null', 0, 0)
# (1, 1, 'n_null', 0, 1)
# (1, 1, 'n_null', 0, 2)
# (1, 1, 'n_null', 0, 3)
# (1, 1, 'n_null', 0, 4)
# (1, 1, 'n_null', 0, 5)
# (1, 1, 'n_null', 0, 6)
# (1, 1, 'n_null', 0, 7)
# (1, 1, 'n_null', 1.1, 0)
# (1, 1, 'n_null', 1.1, 1)
# (1, 1, 'n_null', 1.1, 2)
# (1, 1, 'n_null', 1.1, 3)
# (1, 1, 'n_null', 1.1, 4)
# (1, 1, 'n_null', 1.1, 5)
# (1, 1, 'n_null', 1.1, 6)
# (1, 1, 'n_null', 1.1, 7)
# (1, 1, 'n_null', 1.2, 0)
# (1, 1, 'n_null', 1.2, 1)
# (1, 1, 'n_null', 1.2, 2)
# (1, 1, 'n_null', 1.2, 3)
# (1, 1, 'n_null', 1.2, 4)
# (1, 1, 'n_null', 1.2, 5)
# (1, 1, 'n_null', 1.2, 6)
# (1, 1, 'n_null', 1.2, 7)
# (1, 2, 'n_do', 0, 0)
# (1, 2, 'n_do', 0, 1)
# (1, 2, 'n_do', 0, 2)
# (1, 2, 'n_do', 0, 3)
# (1, 2, 'n_do', 0, 4)
# (1, 2, 'n_do', 0, 5)
# (1, 2, 'n_do', 0, 6)
# (1, 2, 'n_do', 0, 7)
# (1, 2, 'n_do', 1.1, 0)
# (1, 2, 'n_do', 1.1, 1)
# (1, 2, 'n_do', 1.1, 2)
# (1, 2, 'n_do', 1.1, 3)
# (1, 2, 'n_do', 1.1, 4)
# (1, 2, 'n_do', 1.1, 5)
# (1, 2, 'n_do', 1.1, 6)
# (1, 2, 'n_do', 1.1, 7)
# (1, 2, 'n_do', 1.2, 0)
# (1, 2, 'n_do', 1.2, 1)
# (1, 2, 'n_do', 1.2, 2)
# (1, 2, 'n_do', 1.2, 3)
# (1, 2, 'n_do', 1.2, 4)
# (1, 2, 'n_do', 1.2, 5)
# (1, 2, 'n_do', 1.2, 6)
# (1, 2, 'n_do', 1.2, 7)
# (1, 2, 'n_null', 0, 0)
# (1, 2, 'n_null', 0, 1)
# (1, 2, 'n_null', 0, 2)
# (1, 2, 'n_null', 0, 3)
# (1, 2, 'n_null', 0, 4)
# (1, 2, 'n_null', 0, 5)
# (1, 2, 'n_null', 0, 6)
# (1, 2, 'n_null', 0, 7)
# (1, 2, 'n_null', 1.1, 0)
# (1, 2, 'n_null', 1.1, 1)
# (1, 2, 'n_null', 1.1, 2)
# (1, 2, 'n_null', 1.1, 3)
# (1, 2, 'n_null', 1.1, 4)
# (1, 2, 'n_null', 1.1, 5)
# (1, 2, 'n_null', 1.1, 6)
# (1, 2, 'n_null', 1.1, 7)
# (1, 2, 'n_null', 1.2, 0)
# (1, 2, 'n_null', 1.2, 1)
# (1, 2, 'n_null', 1.2, 2)
# (1, 2, 'n_null', 1.2, 3)
# (1, 2, 'n_null', 1.2, 4)
# (1, 2, 'n_null', 1.2, 5)
# (1, 2, 'n_null', 1.2, 6)
# (1, 2, 'n_null', 1.2, 7)
# (1, 3, 'n_do', 0, 0)
# (1, 3, 'n_do', 0, 1)
# (1, 3, 'n_do', 0, 2)
# (1, 3, 'n_do', 0, 3)
# (1, 3, 'n_do', 0, 4)
# (1, 3, 'n_do', 0, 5)
# (1, 3, 'n_do', 0, 6)
# (1, 3, 'n_do', 0, 7)
# (1, 3, 'n_do', 1.1, 0)
# (1, 3, 'n_do', 1.1, 1)
# (1, 3, 'n_do', 1.1, 2)
# (1, 3, 'n_do', 1.1, 3)
# (1, 3, 'n_do', 1.1, 4)
# (1, 3, 'n_do', 1.1, 5)
# (1, 3, 'n_do', 1.1, 6)
# (1, 3, 'n_do', 1.1, 7)
# (1, 3, 'n_do', 1.2, 0)
# (1, 3, 'n_do', 1.2, 1)
# (1, 3, 'n_do', 1.2, 2)
# (1, 3, 'n_do', 1.2, 3)
# (1, 3, 'n_do', 1.2, 4)
# (1, 3, 'n_do', 1.2, 5)
# (1, 3, 'n_do', 1.2, 6)
# (1, 3, 'n_do', 1.2, 7)
# (1, 3, 'n_null', 0, 0)
# (1, 3, 'n_null', 0, 1)
# (1, 3, 'n_null', 0, 2)
# (1, 3, 'n_null', 0, 3)
# (1, 3, 'n_null', 0, 4)
# (1, 3, 'n_null', 0, 5)
# (1, 3, 'n_null', 0, 6)
# (1, 3, 'n_null', 0, 7)
# (1, 3, 'n_null', 1.1, 0)
# (1, 3, 'n_null', 1.1, 1)
# (1, 3, 'n_null', 1.1, 2)
# (1, 3, 'n_null', 1.1, 3)
# (1, 3, 'n_null', 1.1, 4)
# (1, 3, 'n_null', 1.1, 5)
# (1, 3, 'n_null', 1.1, 6)
# (1, 3, 'n_null', 1.1, 7)
# (1, 3, 'n_null', 1.2, 0)
# (1, 3, 'n_null', 1.2, 1)
# (1, 3, 'n_null', 1.2, 2)
# (1, 3, 'n_null', 1.2, 3)
# (1, 3, 'n_null', 1.2, 4)
# (1, 3, 'n_null', 1.2, 5)
# (1, 3, 'n_null', 1.2, 6)
# (1, 3, 'n_null', 1.2, 7)
# (2, 0, 'n_do', 0, 0)
# (2, 0, 'n_do', 0, 1)
# (2, 0, 'n_do', 0, 2)
# (2, 0, 'n_do', 0, 3)
# (2, 0, 'n_do', 0, 4)
# (2, 0, 'n_do', 0, 5)
# (2, 0, 'n_do', 0, 6)
# (2, 0, 'n_do', 0, 7)
# (2, 0, 'n_do', 1.1, 0)
# (2, 0, 'n_do', 1.1, 1)
# (2, 0, 'n_do', 1.1, 2)
# (2, 0, 'n_do', 1.1, 3)
# (2, 0, 'n_do', 1.1, 4)
# (2, 0, 'n_do', 1.1, 5)
# (2, 0, 'n_do', 1.1, 6)
# (2, 0, 'n_do', 1.1, 7)
# (2, 0, 'n_do', 1.2, 0)
# (2, 0, 'n_do', 1.2, 1)
# (2, 0, 'n_do', 1.2, 2)
# (2, 0, 'n_do', 1.2, 3)
# (2, 0, 'n_do', 1.2, 4)
# (2, 0, 'n_do', 1.2, 5)
# (2, 0, 'n_do', 1.2, 6)
# (2, 0, 'n_do', 1.2, 7)
# (2, 0, 'n_null', 0, 0)
# (2, 0, 'n_null', 0, 1)
# (2, 0, 'n_null', 0, 2)
# (2, 0, 'n_null', 0, 3)
# (2, 0, 'n_null', 0, 4)
# (2, 0, 'n_null', 0, 5)
# (2, 0, 'n_null', 0, 6)
# (2, 0, 'n_null', 0, 7)
# (2, 0, 'n_null', 1.1, 0)
# (2, 0, 'n_null', 1.1, 1)
# (2, 0, 'n_null', 1.1, 2)
# (2, 0, 'n_null', 1.1, 3)
# (2, 0, 'n_null', 1.1, 4)
# (2, 0, 'n_null', 1.1, 5)
# (2, 0, 'n_null', 1.1, 6)
# (2, 0, 'n_null', 1.1, 7)
# (2, 0, 'n_null', 1.2, 0)
# (2, 0, 'n_null', 1.2, 1)
# (2, 0, 'n_null', 1.2, 2)
# (2, 0, 'n_null', 1.2, 3)
# (2, 0, 'n_null', 1.2, 4)
# (2, 0, 'n_null', 1.2, 5)
# (2, 0, 'n_null', 1.2, 6)
# (2, 0, 'n_null', 1.2, 7)
# (2, 1, 'n_do', 0, 0)
# (2, 1, 'n_do', 0, 1)
# (2, 1, 'n_do', 0, 2)
# (2, 1, 'n_do', 0, 3)
# (2, 1, 'n_do', 0, 4)
# (2, 1, 'n_do', 0, 5)
# (2, 1, 'n_do', 0, 6)
# (2, 1, 'n_do', 0, 7)
# (2, 1, 'n_do', 1.1, 0)
# (2, 1, 'n_do', 1.1, 1)
# (2, 1, 'n_do', 1.1, 2)
# (2, 1, 'n_do', 1.1, 3)
# (2, 1, 'n_do', 1.1, 4)
# (2, 1, 'n_do', 1.1, 5)
# (2, 1, 'n_do', 1.1, 6)
# (2, 1, 'n_do', 1.1, 7)
# (2, 1, 'n_do', 1.2, 0)
# (2, 1, 'n_do', 1.2, 1)
# (2, 1, 'n_do', 1.2, 2)
# (2, 1, 'n_do', 1.2, 3)
# (2, 1, 'n_do', 1.2, 4)
# (2, 1, 'n_do', 1.2, 5)
# (2, 1, 'n_do', 1.2, 6)
# (2, 1, 'n_do', 1.2, 7)
# (2, 1, 'n_null', 0, 0)
# (2, 1, 'n_null', 0, 1)
# (2, 1, 'n_null', 0, 2)
# (2, 1, 'n_null', 0, 3)
# (2, 1, 'n_null', 0, 4)
# (2, 1, 'n_null', 0, 5)
# (2, 1, 'n_null', 0, 6)
# (2, 1, 'n_null', 0, 7)
# (2, 1, 'n_null', 1.1, 0)
# (2, 1, 'n_null', 1.1, 1)
# (2, 1, 'n_null', 1.1, 2)
# (2, 1, 'n_null', 1.1, 3)
# (2, 1, 'n_null', 1.1, 4)
# (2, 1, 'n_null', 1.1, 5)
# (2, 1, 'n_null', 1.1, 6)
# (2, 1, 'n_null', 1.1, 7)
# (2, 1, 'n_null', 1.2, 0)
# (2, 1, 'n_null', 1.2, 1)
# (2, 1, 'n_null', 1.2, 2)
# (2, 1, 'n_null', 1.2, 3)
# (2, 1, 'n_null', 1.2, 4)
# (2, 1, 'n_null', 1.2, 5)
# (2, 1, 'n_null', 1.2, 6)
# (2, 1, 'n_null', 1.2, 7)
# (2, 2, 'n_do', 0, 0)
# (2, 2, 'n_do', 0, 1)
# (2, 2, 'n_do', 0, 2)
# (2, 2, 'n_do', 0, 3)
# (2, 2, 'n_do', 0, 4)
# (2, 2, 'n_do', 0, 5)
# (2, 2, 'n_do', 0, 6)
# (2, 2, 'n_do', 0, 7)
# (2, 2, 'n_do', 1.1, 0)
# (2, 2, 'n_do', 1.1, 1)
# (2, 2, 'n_do', 1.1, 2)
# (2, 2, 'n_do', 1.1, 3)
# (2, 2, 'n_do', 1.1, 4)
# (2, 2, 'n_do', 1.1, 5)
# (2, 2, 'n_do', 1.1, 6)
# (2, 2, 'n_do', 1.1, 7)
# (2, 2, 'n_do', 1.2, 0)
# (2, 2, 'n_do', 1.2, 1)
# (2, 2, 'n_do', 1.2, 2)
# (2, 2, 'n_do', 1.2, 3)
# (2, 2, 'n_do', 1.2, 4)
# (2, 2, 'n_do', 1.2, 5)
# (2, 2, 'n_do', 1.2, 6)
# (2, 2, 'n_do', 1.2, 7)
# (2, 2, 'n_null', 0, 0)
# (2, 2, 'n_null', 0, 1)
# (2, 2, 'n_null', 0, 2)
# (2, 2, 'n_null', 0, 3)
# (2, 2, 'n_null', 0, 4)
# (2, 2, 'n_null', 0, 5)
# (2, 2, 'n_null', 0, 6)
# (2, 2, 'n_null', 0, 7)
# (2, 2, 'n_null', 1.1, 0)
# (2, 2, 'n_null', 1.1, 1)
# (2, 2, 'n_null', 1.1, 2)
# (2, 2, 'n_null', 1.1, 3)
# (2, 2, 'n_null', 1.1, 4)
# (2, 2, 'n_null', 1.1, 5)
# (2, 2, 'n_null', 1.1, 6)
# (2, 2, 'n_null', 1.1, 7)
# (2, 2, 'n_null', 1.2, 0)
# (2, 2, 'n_null', 1.2, 1)
# (2, 2, 'n_null', 1.2, 2)
# (2, 2, 'n_null', 1.2, 3)
# (2, 2, 'n_null', 1.2, 4)
# (2, 2, 'n_null', 1.2, 5)
# (2, 2, 'n_null', 1.2, 6)
# (2, 2, 'n_null', 1.2, 7)
# (2, 3, 'n_do', 0, 0)
# (2, 3, 'n_do', 0, 1)
# (2, 3, 'n_do', 0, 2)
# (2, 3, 'n_do', 0, 3)
# (2, 3, 'n_do', 0, 4)
# (2, 3, 'n_do', 0, 5)
# (2, 3, 'n_do', 0, 6)
# (2, 3, 'n_do', 0, 7)
# (2, 3, 'n_do', 1.1, 0)
# (2, 3, 'n_do', 1.1, 1)
# (2, 3, 'n_do', 1.1, 2)
# (2, 3, 'n_do', 1.1, 3)
# (2, 3, 'n_do', 1.1, 4)
# (2, 3, 'n_do', 1.1, 5)
# (2, 3, 'n_do', 1.1, 6)
# (2, 3, 'n_do', 1.1, 7)
# (2, 3, 'n_do', 1.2, 0)
# (2, 3, 'n_do', 1.2, 1)
# (2, 3, 'n_do', 1.2, 2)
# (2, 3, 'n_do', 1.2, 3)
# (2, 3, 'n_do', 1.2, 4)
# (2, 3, 'n_do', 1.2, 5)
# (2, 3, 'n_do', 1.2, 6)
# (2, 3, 'n_do', 1.2, 7)
# (2, 3, 'n_null', 0, 0)
# (2, 3, 'n_null', 0, 1)
# (2, 3, 'n_null', 0, 2)
# (2, 3, 'n_null', 0, 3)
# (2, 3, 'n_null', 0, 4)
# (2, 3, 'n_null', 0, 5)
# (2, 3, 'n_null', 0, 6)
# (2, 3, 'n_null', 0, 7)
# (2, 3, 'n_null', 1.1, 0)
# (2, 3, 'n_null', 1.1, 1)
# (2, 3, 'n_null', 1.1, 2)
# (2, 3, 'n_null', 1.1, 3)
# (2, 3, 'n_null', 1.1, 4)
# (2, 3, 'n_null', 1.1, 5)
# (2, 3, 'n_null', 1.1, 6)
# (2, 3, 'n_null', 1.1, 7)
# (2, 3, 'n_null', 1.2, 0)
# (2, 3, 'n_null', 1.2, 1)
# (2, 3, 'n_null', 1.2, 2)
# (2, 3, 'n_null', 1.2, 3)
# (2, 3, 'n_null', 1.2, 4)
# (2, 3, 'n_null', 1.2, 5)
# (2, 3, 'n_null', 1.2, 6)
# (2, 3, 'n_null', 1.2, 7)
# (3, 0, 'n_do', 0, 0)
# (3, 0, 'n_do', 0, 1)
# (3, 0, 'n_do', 0, 2)
# (3, 0, 'n_do', 0, 3)
# (3, 0, 'n_do', 0, 4)
# (3, 0, 'n_do', 0, 5)
# (3, 0, 'n_do', 0, 6)
# (3, 0, 'n_do', 0, 7)
# (3, 0, 'n_do', 1.1, 0)
# (3, 0, 'n_do', 1.1, 1)
# (3, 0, 'n_do', 1.1, 2)
# (3, 0, 'n_do', 1.1, 3)
# (3, 0, 'n_do', 1.1, 4)
# (3, 0, 'n_do', 1.1, 5)
# (3, 0, 'n_do', 1.1, 6)
# (3, 0, 'n_do', 1.1, 7)
# (3, 0, 'n_do', 1.2, 0)
# (3, 0, 'n_do', 1.2, 1)
# (3, 0, 'n_do', 1.2, 2)
# (3, 0, 'n_do', 1.2, 3)
# (3, 0, 'n_do', 1.2, 4)
# (3, 0, 'n_do', 1.2, 5)
# (3, 0, 'n_do', 1.2, 6)
# (3, 0, 'n_do', 1.2, 7)
# (3, 0, 'n_null', 0, 0)
# (3, 0, 'n_null', 0, 1)
# (3, 0, 'n_null', 0, 2)
# (3, 0, 'n_null', 0, 3)
# (3, 0, 'n_null', 0, 4)
# (3, 0, 'n_null', 0, 5)
# (3, 0, 'n_null', 0, 6)
# (3, 0, 'n_null', 0, 7)
# (3, 0, 'n_null', 1.1, 0)
# (3, 0, 'n_null', 1.1, 1)
# (3, 0, 'n_null', 1.1, 2)
# (3, 0, 'n_null', 1.1, 3)
# (3, 0, 'n_null', 1.1, 4)
# (3, 0, 'n_null', 1.1, 5)
# (3, 0, 'n_null', 1.1, 6)
# (3, 0, 'n_null', 1.1, 7)
# (3, 0, 'n_null', 1.2, 0)
# (3, 0, 'n_null', 1.2, 1)
# (3, 0, 'n_null', 1.2, 2)
# (3, 0, 'n_null', 1.2, 3)
# (3, 0, 'n_null', 1.2, 4)
# (3, 0, 'n_null', 1.2, 5)
# (3, 0, 'n_null', 1.2, 6)
# (3, 0, 'n_null', 1.2, 7)
# (3, 1, 'n_do', 0, 0)
# (3, 1, 'n_do', 0, 1)
# (3, 1, 'n_do', 0, 2)
# (3, 1, 'n_do', 0, 3)
# (3, 1, 'n_do', 0, 4)
# (3, 1, 'n_do', 0, 5)
# (3, 1, 'n_do', 0, 6)
# (3, 1, 'n_do', 0, 7)
# (3, 1, 'n_do', 1.1, 0)
# (3, 1, 'n_do', 1.1, 1)
# (3, 1, 'n_do', 1.1, 2)
# (3, 1, 'n_do', 1.1, 3)
# (3, 1, 'n_do', 1.1, 4)
# (3, 1, 'n_do', 1.1, 5)
# (3, 1, 'n_do', 1.1, 6)
# (3, 1, 'n_do', 1.1, 7)
# (3, 1, 'n_do', 1.2, 0)
# (3, 1, 'n_do', 1.2, 1)
# (3, 1, 'n_do', 1.2, 2)
# (3, 1, 'n_do', 1.2, 3)
# (3, 1, 'n_do', 1.2, 4)
# (3, 1, 'n_do', 1.2, 5)
# (3, 1, 'n_do', 1.2, 6)
# (3, 1, 'n_do', 1.2, 7)
# (3, 1, 'n_null', 0, 0)
# (3, 1, 'n_null', 0, 1)
# (3, 1, 'n_null', 0, 2)
# (3, 1, 'n_null', 0, 3)
# (3, 1, 'n_null', 0, 4)
# (3, 1, 'n_null', 0, 5)
# (3, 1, 'n_null', 0, 6)
# (3, 1, 'n_null', 0, 7)
# (3, 1, 'n_null', 1.1, 0)
# (3, 1, 'n_null', 1.1, 1)
# (3, 1, 'n_null', 1.1, 2)
# (3, 1, 'n_null', 1.1, 3)
# (3, 1, 'n_null', 1.1, 4)
# (3, 1, 'n_null', 1.1, 5)
# (3, 1, 'n_null', 1.1, 6)
# (3, 1, 'n_null', 1.1, 7)
# (3, 1, 'n_null', 1.2, 0)
# (3, 1, 'n_null', 1.2, 1)
# (3, 1, 'n_null', 1.2, 2)
# (3, 1, 'n_null', 1.2, 3)
# (3, 1, 'n_null', 1.2, 4)
# (3, 1, 'n_null', 1.2, 5)
# (3, 1, 'n_null', 1.2, 6)
# (3, 1, 'n_null', 1.2, 7)
# (3, 2, 'n_do', 0, 0)
# (3, 2, 'n_do', 0, 1)
# (3, 2, 'n_do', 0, 2)
# (3, 2, 'n_do', 0, 3)
# (3, 2, 'n_do', 0, 4)
# (3, 2, 'n_do', 0, 5)
# (3, 2, 'n_do', 0, 6)
# (3, 2, 'n_do', 0, 7)
# (3, 2, 'n_do', 1.1, 0)
# (3, 2, 'n_do', 1.1, 1)
# (3, 2, 'n_do', 1.1, 2)
# (3, 2, 'n_do', 1.1, 3)
# (3, 2, 'n_do', 1.1, 4)
# (3, 2, 'n_do', 1.1, 5)
# (3, 2, 'n_do', 1.1, 6)
# (3, 2, 'n_do', 1.1, 7)
# (3, 2, 'n_do', 1.2, 0)
# (3, 2, 'n_do', 1.2, 1)
# (3, 2, 'n_do', 1.2, 2)
# (3, 2, 'n_do', 1.2, 3)
# (3, 2, 'n_do', 1.2, 4)
# (3, 2, 'n_do', 1.2, 5)
# (3, 2, 'n_do', 1.2, 6)
# (3, 2, 'n_do', 1.2, 7)
# (3, 2, 'n_null', 0, 0)
# (3, 2, 'n_null', 0, 1)
# (3, 2, 'n_null', 0, 2)
# (3, 2, 'n_null', 0, 3)
# (3, 2, 'n_null', 0, 4)
# (3, 2, 'n_null', 0, 5)
# (3, 2, 'n_null', 0, 6)
# (3, 2, 'n_null', 0, 7)
# (3, 2, 'n_null', 1.1, 0)
# (3, 2, 'n_null', 1.1, 1)
# (3, 2, 'n_null', 1.1, 2)
# (3, 2, 'n_null', 1.1, 3)
# (3, 2, 'n_null', 1.1, 4)
# (3, 2, 'n_null', 1.1, 5)
# (3, 2, 'n_null', 1.1, 6)
# (3, 2, 'n_null', 1.1, 7)
# (3, 2, 'n_null', 1.2, 0)
# (3, 2, 'n_null', 1.2, 1)
# (3, 2, 'n_null', 1.2, 2)
# (3, 2, 'n_null', 1.2, 3)
# (3, 2, 'n_null', 1.2, 4)
# (3, 2, 'n_null', 1.2, 5)
# (3, 2, 'n_null', 1.2, 6)
# (3, 2, 'n_null', 1.2, 7)
# (3, 3, 'n_do', 0, 0)
# (3, 3, 'n_do', 0, 1)
# (3, 3, 'n_do', 0, 2)
# (3, 3, 'n_do', 0, 3)
# (3, 3, 'n_do', 0, 4)
# (3, 3, 'n_do', 0, 5)
# (3, 3, 'n_do', 0, 6)
# (3, 3, 'n_do', 0, 7)
# (3, 3, 'n_do', 1.1, 0)
# (3, 3, 'n_do', 1.1, 1)
# (3, 3, 'n_do', 1.1, 2)
# (3, 3, 'n_do', 1.1, 3)
# (3, 3, 'n_do', 1.1, 4)
# (3, 3, 'n_do', 1.1, 5)
# (3, 3, 'n_do', 1.1, 6)
# (3, 3, 'n_do', 1.1, 7)
# (3, 3, 'n_do', 1.2, 0)
# (3, 3, 'n_do', 1.2, 1)
# (3, 3, 'n_do', 1.2, 2)
# (3, 3, 'n_do', 1.2, 3)
# (3, 3, 'n_do', 1.2, 4)
# (3, 3, 'n_do', 1.2, 5)
# (3, 3, 'n_do', 1.2, 6)
# (3, 3, 'n_do', 1.2, 7)
# (3, 3, 'n_null', 0, 0)
# (3, 3, 'n_null', 0, 1)
# (3, 3, 'n_null', 0, 2)
# (3, 3, 'n_null', 0, 3)
# (3, 3, 'n_null', 0, 4)
# (3, 3, 'n_null', 0, 5)
# (3, 3, 'n_null', 0, 6)
# (3, 3, 'n_null', 0, 7)
# (3, 3, 'n_null', 1.1, 0)
# (3, 3, 'n_null', 1.1, 1)
# (3, 3, 'n_null', 1.1, 2)
# (3, 3, 'n_null', 1.1, 3)
# (3, 3, 'n_null', 1.1, 4)
# (3, 3, 'n_null', 1.1, 5)
# (3, 3, 'n_null', 1.1, 6)
# (3, 3, 'n_null', 1.1, 7)
# (3, 3, 'n_null', 1.2, 0)
# (3, 3, 'n_null', 1.2, 1)
# (3, 3, 'n_null', 1.2, 2)
# (3, 3, 'n_null', 1.2, 3)
# (3, 3, 'n_null', 1.2, 4)
# (3, 3, 'n_null', 1.2, 5)
# (3, 3, 'n_null', 1.2, 6)
# (3, 3, 'n_null', 1.2, 7)
# (4, 0, 'n_do', 0, 0)
# (4, 0, 'n_do', 0, 1)
# (4, 0, 'n_do', 0, 2)
# (4, 0, 'n_do', 0, 3)
# (4, 0, 'n_do', 0, 4)
# (4, 0, 'n_do', 0, 5)
# (4, 0, 'n_do', 0, 6)
# (4, 0, 'n_do', 0, 7)
# (4, 0, 'n_do', 1.1, 0)
# (4, 0, 'n_do', 1.1, 1)
# (4, 0, 'n_do', 1.1, 2)
# (4, 0, 'n_do', 1.1, 3)
# (4, 0, 'n_do', 1.1, 4)
# (4, 0, 'n_do', 1.1, 5)
# (4, 0, 'n_do', 1.1, 6)
# (4, 0, 'n_do', 1.1, 7)
# (4, 0, 'n_do', 1.2, 0)
# (4, 0, 'n_do', 1.2, 1)
# (4, 0, 'n_do', 1.2, 2)
# (4, 0, 'n_do', 1.2, 3)
# (4, 0, 'n_do', 1.2, 4)
# (4, 0, 'n_do', 1.2, 5)
# (4, 0, 'n_do', 1.2, 6)
# (4, 0, 'n_do', 1.2, 7)
# (4, 0, 'n_null', 0, 0)
# (4, 0, 'n_null', 0, 1)
# (4, 0, 'n_null', 0, 2)
# (4, 0, 'n_null', 0, 3)
# (4, 0, 'n_null', 0, 4)
# (4, 0, 'n_null', 0, 5)
# (4, 0, 'n_null', 0, 6)
# (4, 0, 'n_null', 0, 7)
# (4, 0, 'n_null', 1.1, 0)
# (4, 0, 'n_null', 1.1, 1)
# (4, 0, 'n_null', 1.1, 2)
# (4, 0, 'n_null', 1.1, 3)
# (4, 0, 'n_null', 1.1, 4)
# (4, 0, 'n_null', 1.1, 5)
# (4, 0, 'n_null', 1.1, 6)
# (4, 0, 'n_null', 1.1, 7)
# (4, 0, 'n_null', 1.2, 0)
# (4, 0, 'n_null', 1.2, 1)
# (4, 0, 'n_null', 1.2, 2)
# (4, 0, 'n_null', 1.2, 3)
# (4, 0, 'n_null', 1.2, 4)
# (4, 0, 'n_null', 1.2, 5)
# (4, 0, 'n_null', 1.2, 6)
# (4, 0, 'n_null', 1.2, 7)
# (4, 1, 'n_do', 0, 0)
# (4, 1, 'n_do', 0, 1)
# (4, 1, 'n_do', 0, 2)
# (4, 1, 'n_do', 0, 3)
# (4, 1, 'n_do', 0, 4)
# (4, 1, 'n_do', 0, 5)
# (4, 1, 'n_do', 0, 6)
# (4, 1, 'n_do', 0, 7)
# (4, 1, 'n_do', 1.1, 0)
# (4, 1, 'n_do', 1.1, 1)
# (4, 1, 'n_do', 1.1, 2)
# (4, 1, 'n_do', 1.1, 3)
# (4, 1, 'n_do', 1.1, 4)
# (4, 1, 'n_do', 1.1, 5)
# (4, 1, 'n_do', 1.1, 6)
# (4, 1, 'n_do', 1.1, 7)
# (4, 1, 'n_do', 1.2, 0)
# (4, 1, 'n_do', 1.2, 1)
# (4, 1, 'n_do', 1.2, 2)
# (4, 1, 'n_do', 1.2, 3)
# (4, 1, 'n_do', 1.2, 4)
# (4, 1, 'n_do', 1.2, 5)
# (4, 1, 'n_do', 1.2, 6)
# (4, 1, 'n_do', 1.2, 7)
# (4, 1, 'n_null', 0, 0)
# (4, 1, 'n_null', 0, 1)
# (4, 1, 'n_null', 0, 2)
# (4, 1, 'n_null', 0, 3)
# (4, 1, 'n_null', 0, 4)
# (4, 1, 'n_null', 0, 5)
# (4, 1, 'n_null', 0, 6)
# (4, 1, 'n_null', 0, 7)
# (4, 1, 'n_null', 1.1, 0)
# (4, 1, 'n_null', 1.1, 1)
# (4, 1, 'n_null', 1.1, 2)
# (4, 1, 'n_null', 1.1, 3)
# (4, 1, 'n_null', 1.1, 4)
# (4, 1, 'n_null', 1.1, 5)
# (4, 1, 'n_null', 1.1, 6)
# (4, 1, 'n_null', 1.1, 7)
# (4, 1, 'n_null', 1.2, 0)
# (4, 1, 'n_null', 1.2, 1)
# (4, 1, 'n_null', 1.2, 2)
# (4, 1, 'n_null', 1.2, 3)
# (4, 1, 'n_null', 1.2, 4)
# (4, 1, 'n_null', 1.2, 5)
# (4, 1, 'n_null', 1.2, 6)
# (4, 1, 'n_null', 1.2, 7)
# (4, 2, 'n_do', 0, 0)
# (4, 2, 'n_do', 0, 1)
# (4, 2, 'n_do', 0, 2)
# (4, 2, 'n_do', 0, 3)
# (4, 2, 'n_do', 0, 4)
# (4, 2, 'n_do', 0, 5)
# (4, 2, 'n_do', 0, 6)
# (4, 2, 'n_do', 0, 7)
# (4, 2, 'n_do', 1.1, 0)
# (4, 2, 'n_do', 1.1, 1)
# (4, 2, 'n_do', 1.1, 2)
# (4, 2, 'n_do', 1.1, 3)
# (4, 2, 'n_do', 1.1, 4)
# (4, 2, 'n_do', 1.1, 5)
# (4, 2, 'n_do', 1.1, 6)
# (4, 2, 'n_do', 1.1, 7)
# (4, 2, 'n_do', 1.2, 0)
# (4, 2, 'n_do', 1.2, 1)
# (4, 2, 'n_do', 1.2, 2)
# (4, 2, 'n_do', 1.2, 3)
# (4, 2, 'n_do', 1.2, 4)
# (4, 2, 'n_do', 1.2, 5)
# (4, 2, 'n_do', 1.2, 6)
# (4, 2, 'n_do', 1.2, 7)
# (4, 2, 'n_null', 0, 0)
# (4, 2, 'n_null', 0, 1)
# (4, 2, 'n_null', 0, 2)
# (4, 2, 'n_null', 0, 3)
# (4, 2, 'n_null', 0, 4)
# (4, 2, 'n_null', 0, 5)
# (4, 2, 'n_null', 0, 6)
# (4, 2, 'n_null', 0, 7)
# (4, 2, 'n_null', 1.1, 0)
# (4, 2, 'n_null', 1.1, 1)
# (4, 2, 'n_null', 1.1, 2)
# (4, 2, 'n_null', 1.1, 3)
# (4, 2, 'n_null', 1.1, 4)
# (4, 2, 'n_null', 1.1, 5)
# (4, 2, 'n_null', 1.1, 6)
# (4, 2, 'n_null', 1.1, 7)
# (4, 2, 'n_null', 1.2, 0)
# (4, 2, 'n_null', 1.2, 1)
# (4, 2, 'n_null', 1.2, 2)
# (4, 2, 'n_null', 1.2, 3)
# (4, 2, 'n_null', 1.2, 4)
# (4, 2, 'n_null', 1.2, 5)
# (4, 2, 'n_null', 1.2, 6)
# (4, 2, 'n_null', 1.2, 7)
# (4, 3, 'n_do', 0, 0)
# (4, 3, 'n_do', 0, 1)
# (4, 3, 'n_do', 0, 2)
# (4, 3, 'n_do', 0, 3)
# (4, 3, 'n_do', 0, 4)
# (4, 3, 'n_do', 0, 5)
# (4, 3, 'n_do', 0, 6)
# (4, 3, 'n_do', 0, 7)
# (4, 3, 'n_do', 1.1, 0)
# (4, 3, 'n_do', 1.1, 1)
# (4, 3, 'n_do', 1.1, 2)
# (4, 3, 'n_do', 1.1, 3)
# (4, 3, 'n_do', 1.1, 4)
# (4, 3, 'n_do', 1.1, 5)
# (4, 3, 'n_do', 1.1, 6)
# (4, 3, 'n_do', 1.1, 7)
# (4, 3, 'n_do', 1.2, 0)
# (4, 3, 'n_do', 1.2, 1)
# (4, 3, 'n_do', 1.2, 2)
# (4, 3, 'n_do', 1.2, 3)
# (4, 3, 'n_do', 1.2, 4)
# (4, 3, 'n_do', 1.2, 5)
# (4, 3, 'n_do', 1.2, 6)
# (4, 3, 'n_do', 1.2, 7)
# (4, 3, 'n_null', 0, 0)
# (4, 3, 'n_null', 0, 1)
# (4, 3, 'n_null', 0, 2)
# (4, 3, 'n_null', 0, 3)
# (4, 3, 'n_null', 0, 4)
# (4, 3, 'n_null', 0, 5)
# (4, 3, 'n_null', 0, 6)
# (4, 3, 'n_null', 0, 7)
# (4, 3, 'n_null', 1.1, 0)
# (4, 3, 'n_null', 1.1, 1)
# (4, 3, 'n_null', 1.1, 2)
# (4, 3, 'n_null', 1.1, 3)
# (4, 3, 'n_null', 1.1, 4)
# (4, 3, 'n_null', 1.1, 5)
# (4, 3, 'n_null', 1.1, 6)
# (4, 3, 'n_null', 1.1, 7)
# (4, 3, 'n_null', 1.2, 0)
# (4, 3, 'n_null', 1.2, 1)
# (4, 3, 'n_null', 1.2, 2)
# (4, 3, 'n_null', 1.2, 3)
# (4, 3, 'n_null', 1.2, 4)
# (4, 3, 'n_null', 1.2, 5)
# (4, 3, 'n_null', 1.2, 6)
# (4, 3, 'n_null', 1.2, 7)
# (5, 0, 'n_do', 0, 0)
# (5, 0, 'n_do', 0, 1)
# (5, 0, 'n_do', 0, 2)
# (5, 0, 'n_do', 0, 3)
# (5, 0, 'n_do', 0, 4)
# (5, 0, 'n_do', 0, 5)
# (5, 0, 'n_do', 0, 6)
# (5, 0, 'n_do', 0, 7)
# (5, 0, 'n_do', 1.1, 0)
# (5, 0, 'n_do', 1.1, 1)
# (5, 0, 'n_do', 1.1, 2)
# (5, 0, 'n_do', 1.1, 3)
# (5, 0, 'n_do', 1.1, 4)
# (5, 0, 'n_do', 1.1, 5)
# (5, 0, 'n_do', 1.1, 6)
# (5, 0, 'n_do', 1.1, 7)
# (5, 0, 'n_do', 1.2, 0)
# (5, 0, 'n_do', 1.2, 1)
# (5, 0, 'n_do', 1.2, 2)
# (5, 0, 'n_do', 1.2, 3)
# (5, 0, 'n_do', 1.2, 4)
# (5, 0, 'n_do', 1.2, 5)
# (5, 0, 'n_do', 1.2, 6)
# (5, 0, 'n_do', 1.2, 7)
# (5, 0, 'n_null', 0, 0)
# (5, 0, 'n_null', 0, 1)
# (5, 0, 'n_null', 0, 2)
# (5, 0, 'n_null', 0, 3)
# (5, 0, 'n_null', 0, 4)
# (5, 0, 'n_null', 0, 5)
# (5, 0, 'n_null', 0, 6)
# (5, 0, 'n_null', 0, 7)
# (5, 0, 'n_null', 1.1, 0)
# (5, 0, 'n_null', 1.1, 1)
# (5, 0, 'n_null', 1.1, 2)
# (5, 0, 'n_null', 1.1, 3)
# (5, 0, 'n_null', 1.1, 4)
# (5, 0, 'n_null', 1.1, 5)
# (5, 0, 'n_null', 1.1, 6)
# (5, 0, 'n_null', 1.1, 7)
# (5, 0, 'n_null', 1.2, 0)
# (5, 0, 'n_null', 1.2, 1)
# (5, 0, 'n_null', 1.2, 2)
# (5, 0, 'n_null', 1.2, 3)
# (5, 0, 'n_null', 1.2, 4)
# (5, 0, 'n_null', 1.2, 5)
# (5, 0, 'n_null', 1.2, 6)
# (5, 0, 'n_null', 1.2, 7)
# (5, 1, 'n_do', 0, 0)
# (5, 1, 'n_do', 0, 1)
# (5, 1, 'n_do', 0, 2)
# (5, 1, 'n_do', 0, 3)
# (5, 1, 'n_do', 0, 4)
# (5, 1, 'n_do', 0, 5)
# (5, 1, 'n_do', 0, 6)
# (5, 1, 'n_do', 0, 7)
# (5, 1, 'n_do', 1.1, 0)
# (5, 1, 'n_do', 1.1, 1)
# (5, 1, 'n_do', 1.1, 2)
# (5, 1, 'n_do', 1.1, 3)
# (5, 1, 'n_do', 1.1, 4)
# (5, 1, 'n_do', 1.1, 5)
# (5, 1, 'n_do', 1.1, 6)
# (5, 1, 'n_do', 1.1, 7)
# (5, 1, 'n_do', 1.2, 0)
# (5, 1, 'n_do', 1.2, 1)
# (5, 1, 'n_do', 1.2, 2)
# (5, 1, 'n_do', 1.2, 3)
# (5, 1, 'n_do', 1.2, 4)
# (5, 1, 'n_do', 1.2, 5)
# (5, 1, 'n_do', 1.2, 6)
# (5, 1, 'n_do', 1.2, 7)
# (5, 1, 'n_null', 0, 0)
# (5, 1, 'n_null', 0, 1)
# (5, 1, 'n_null', 0, 2)
# (5, 1, 'n_null', 0, 3)
# (5, 1, 'n_null', 0, 4)
# (5, 1, 'n_null', 0, 5)
# (5, 1, 'n_null', 0, 6)
# (5, 1, 'n_null', 0, 7)
# (5, 1, 'n_null', 1.1, 0)
# (5, 1, 'n_null', 1.1, 1)
# (5, 1, 'n_null', 1.1, 2)
# (5, 1, 'n_null', 1.1, 3)
# (5, 1, 'n_null', 1.1, 4)
# (5, 1, 'n_null', 1.1, 5)
# (5, 1, 'n_null', 1.1, 6)
# (5, 1, 'n_null', 1.1, 7)
# (5, 1, 'n_null', 1.2, 0)
# (5, 1, 'n_null', 1.2, 1)
# (5, 1, 'n_null', 1.2, 2)
# (5, 1, 'n_null', 1.2, 3)
# (5, 1, 'n_null', 1.2, 4)
# (5, 1, 'n_null', 1.2, 5)
# (5, 1, 'n_null', 1.2, 6)
# (5, 1, 'n_null', 1.2, 7)
# (5, 2, 'n_do', 0, 0)
# (5, 2, 'n_do', 0, 1)
# (5, 2, 'n_do', 0, 2)
# (5, 2, 'n_do', 0, 3)
# (5, 2, 'n_do', 0, 4)
# (5, 2, 'n_do', 0, 5)
# (5, 2, 'n_do', 0, 6)
# (5, 2, 'n_do', 0, 7)
# (5, 2, 'n_do', 1.1, 0)
# (5, 2, 'n_do', 1.1, 1)
# (5, 2, 'n_do', 1.1, 2)
# (5, 2, 'n_do', 1.1, 3)
# (5, 2, 'n_do', 1.1, 4)
# (5, 2, 'n_do', 1.1, 5)
# (5, 2, 'n_do', 1.1, 6)
# (5, 2, 'n_do', 1.1, 7)
# (5, 2, 'n_do', 1.2, 0)
# (5, 2, 'n_do', 1.2, 1)
# (5, 2, 'n_do', 1.2, 2)
# (5, 2, 'n_do', 1.2, 3)
# (5, 2, 'n_do', 1.2, 4)
# (5, 2, 'n_do', 1.2, 5)
# (5, 2, 'n_do', 1.2, 6)
# (5, 2, 'n_do', 1.2, 7)
# (5, 2, 'n_null', 0, 0)
# (5, 2, 'n_null', 0, 1)
# (5, 2, 'n_null', 0, 2)
# (5, 2, 'n_null', 0, 3)
# (5, 2, 'n_null', 0, 4)
# (5, 2, 'n_null', 0, 5)
# (5, 2, 'n_null', 0, 6)
# (5, 2, 'n_null', 0, 7)
# (5, 2, 'n_null', 1.1, 0)
# (5, 2, 'n_null', 1.1, 1)
# (5, 2, 'n_null', 1.1, 2)
# (5, 2, 'n_null', 1.1, 3)
# (5, 2, 'n_null', 1.1, 4)
# (5, 2, 'n_null', 1.1, 5)
# (5, 2, 'n_null', 1.1, 6)
# (5, 2, 'n_null', 1.1, 7)
# (5, 2, 'n_null', 1.2, 0)
# (5, 2, 'n_null', 1.2, 1)
# (5, 2, 'n_null', 1.2, 2)
# (5, 2, 'n_null', 1.2, 3)
# (5, 2, 'n_null', 1.2, 4)
# (5, 2, 'n_null', 1.2, 5)
# (5, 2, 'n_null', 1.2, 6)
# (5, 2, 'n_null', 1.2, 7)
# (5, 3, 'n_do', 0, 0)
# (5, 3, 'n_do', 0, 1)
# (5, 3, 'n_do', 0, 2)
# (5, 3, 'n_do', 0, 3)
# (5, 3, 'n_do', 0, 4)
# (5, 3, 'n_do', 0, 5)
# (5, 3, 'n_do', 0, 6)
# (5, 3, 'n_do', 0, 7)
# (5, 3, 'n_do', 1.1, 0)
# (5, 3, 'n_do', 1.1, 1)
# (5, 3, 'n_do', 1.1, 2)
# (5, 3, 'n_do', 1.1, 3)
# (5, 3, 'n_do', 1.1, 4)
# (5, 3, 'n_do', 1.1, 5)
# (5, 3, 'n_do', 1.1, 6)
# (5, 3, 'n_do', 1.1, 7)
# (5, 3, 'n_do', 1.2, 0)
# (5, 3, 'n_do', 1.2, 1)
# (5, 3, 'n_do', 1.2, 2)
# (5, 3, 'n_do', 1.2, 3)
# (5, 3, 'n_do', 1.2, 4)
# (5, 3, 'n_do', 1.2, 5)
# (5, 3, 'n_do', 1.2, 6)
# (5, 3, 'n_do', 1.2, 7)
# (5, 3, 'n_null', 0, 0)
# (5, 3, 'n_null', 0, 1)
# (5, 3, 'n_null', 0, 2)
# (5, 3, 'n_null', 0, 3)
# (5, 3, 'n_null', 0, 4)
# (5, 3, 'n_null', 0, 5)
# (5, 3, 'n_null', 0, 6)
# (5, 3, 'n_null', 0, 7)
# (5, 3, 'n_null', 1.1, 0)
# (5, 3, 'n_null', 1.1, 1)
# (5, 3, 'n_null', 1.1, 2)
# (5, 3, 'n_null', 1.1, 3)
# (5, 3, 'n_null', 1.1, 4)
# (5, 3, 'n_null', 1.1, 5)
# (5, 3, 'n_null', 1.1, 6)
# (5, 3, 'n_null', 1.1, 7)
# (5, 3, 'n_null', 1.2, 0)
# (5, 3, 'n_null', 1.2, 1)
# (5, 3, 'n_null', 1.2, 2)
# (5, 3, 'n_null', 1.2, 3)
# (5, 3, 'n_null', 1.2, 4)
# (5, 3, 'n_null', 1.2, 5)
# (5, 3, 'n_null', 1.2, 6)
# (5, 3, 'n_null', 1.2, 7)
# (6, 0, 'n_do', 0, 0)
# (6, 0, 'n_do', 0, 1)
# (6, 0, 'n_do', 0, 2)
# (6, 0, 'n_do', 0, 3)
# (6, 0, 'n_do', 0, 4)
# (6, 0, 'n_do', 0, 5)
# (6, 0, 'n_do', 0, 6)
# (6, 0, 'n_do', 0, 7)
# (6, 0, 'n_do', 1.1, 0)
# (6, 0, 'n_do', 1.1, 1)
# (6, 0, 'n_do', 1.1, 2)
# (6, 0, 'n_do', 1.1, 3)
# (6, 0, 'n_do', 1.1, 4)
# (6, 0, 'n_do', 1.1, 5)
# (6, 0, 'n_do', 1.1, 6)
# (6, 0, 'n_do', 1.1, 7)
# (6, 0, 'n_do', 1.2, 0)
# (6, 0, 'n_do', 1.2, 1)
# (6, 0, 'n_do', 1.2, 2)
# (6, 0, 'n_do', 1.2, 3)
# (6, 0, 'n_do', 1.2, 4)
# (6, 0, 'n_do', 1.2, 5)
# (6, 0, 'n_do', 1.2, 6)
# (6, 0, 'n_do', 1.2, 7)
# (6, 0, 'n_null', 0, 0)
# (6, 0, 'n_null', 0, 1)
# (6, 0, 'n_null', 0, 2)
# (6, 0, 'n_null', 0, 3)
# (6, 0, 'n_null', 0, 4)
# (6, 0, 'n_null', 0, 5)
# (6, 0, 'n_null', 0, 6)
# (6, 0, 'n_null', 0, 7)
# (6, 0, 'n_null', 1.1, 0)
# (6, 0, 'n_null', 1.1, 1)
# (6, 0, 'n_null', 1.1, 2)
# (6, 0, 'n_null', 1.1, 3)
# (6, 0, 'n_null', 1.1, 4)
# (6, 0, 'n_null', 1.1, 5)
# (6, 0, 'n_null', 1.1, 6)
# (6, 0, 'n_null', 1.1, 7)
# (6, 0, 'n_null', 1.2, 0)
# (6, 0, 'n_null', 1.2, 1)
# (6, 0, 'n_null', 1.2, 2)
# (6, 0, 'n_null', 1.2, 3)
# (6, 0, 'n_null', 1.2, 4)
# (6, 0, 'n_null', 1.2, 5)
# (6, 0, 'n_null', 1.2, 6)
# (6, 0, 'n_null', 1.2, 7)
# (6, 1, 'n_do', 0, 0)
# (6, 1, 'n_do', 0, 1)
# (6, 1, 'n_do', 0, 2)
# (6, 1, 'n_do', 0, 3)
# (6, 1, 'n_do', 0, 4)
# (6, 1, 'n_do', 0, 5)
# (6, 1, 'n_do', 0, 6)
# (6, 1, 'n_do', 0, 7)
# (6, 1, 'n_do', 1.1, 0)
# (6, 1, 'n_do', 1.1, 1)
# (6, 1, 'n_do', 1.1, 2)
# (6, 1, 'n_do', 1.1, 3)
# (6, 1, 'n_do', 1.1, 4)
# (6, 1, 'n_do', 1.1, 5)
# (6, 1, 'n_do', 1.1, 6)
# (6, 1, 'n_do', 1.1, 7)
# (6, 1, 'n_do', 1.2, 0)
# (6, 1, 'n_do', 1.2, 1)
# (6, 1, 'n_do', 1.2, 2)
# (6, 1, 'n_do', 1.2, 3)
# (6, 1, 'n_do', 1.2, 4)
# (6, 1, 'n_do', 1.2, 5)
# (6, 1, 'n_do', 1.2, 6)
# (6, 1, 'n_do', 1.2, 7)
# (6, 1, 'n_null', 0, 0)
# (6, 1, 'n_null', 0, 1)
# (6, 1, 'n_null', 0, 2)
# (6, 1, 'n_null', 0, 3)
# (6, 1, 'n_null', 0, 4)
# (6, 1, 'n_null', 0, 5)
# (6, 1, 'n_null', 0, 6)
# (6, 1, 'n_null', 0, 7)
# (6, 1, 'n_null', 1.1, 0)
# (6, 1, 'n_null', 1.1, 1)
# (6, 1, 'n_null', 1.1, 2)
# (6, 1, 'n_null', 1.1, 3)
# (6, 1, 'n_null', 1.1, 4)
# (6, 1, 'n_null', 1.1, 5)
# (6, 1, 'n_null', 1.1, 6)
# (6, 1, 'n_null', 1.1, 7)
# (6, 1, 'n_null', 1.2, 0)
# (6, 1, 'n_null', 1.2, 1)
# (6, 1, 'n_null', 1.2, 2)
# (6, 1, 'n_null', 1.2, 3)
# (6, 1, 'n_null', 1.2, 4)
# (6, 1, 'n_null', 1.2, 5)
# (6, 1, 'n_null', 1.2, 6)
# (6, 1, 'n_null', 1.2, 7)
# (6, 2, 'n_do', 0, 0)
# (6, 2, 'n_do', 0, 1)
# (6, 2, 'n_do', 0, 2)
# (6, 2, 'n_do', 0, 3)
# (6, 2, 'n_do', 0, 4)
# (6, 2, 'n_do', 0, 5)
# (6, 2, 'n_do', 0, 6)
# (6, 2, 'n_do', 0, 7)
# (6, 2, 'n_do', 1.1, 0)
# (6, 2, 'n_do', 1.1, 1)
# (6, 2, 'n_do', 1.1, 2)
# (6, 2, 'n_do', 1.1, 3)
# (6, 2, 'n_do', 1.1, 4)
# (6, 2, 'n_do', 1.1, 5)
# (6, 2, 'n_do', 1.1, 6)
# (6, 2, 'n_do', 1.1, 7)
# (6, 2, 'n_do', 1.2, 0)
# (6, 2, 'n_do', 1.2, 1)
# (6, 2, 'n_do', 1.2, 2)
# (6, 2, 'n_do', 1.2, 3)
# (6, 2, 'n_do', 1.2, 4)
# (6, 2, 'n_do', 1.2, 5)
# (6, 2, 'n_do', 1.2, 6)
# (6, 2, 'n_do', 1.2, 7)
# (6, 2, 'n_null', 0, 0)
# (6, 2, 'n_null', 0, 1)
# (6, 2, 'n_null', 0, 2)
# (6, 2, 'n_null', 0, 3)
# (6, 2, 'n_null', 0, 4)
# (6, 2, 'n_null', 0, 5)
# (6, 2, 'n_null', 0, 6)
# (6, 2, 'n_null', 0, 7)
# (6, 2, 'n_null', 1.1, 0)
# (6, 2, 'n_null', 1.1, 1)
# (6, 2, 'n_null', 1.1, 2)
# (6, 2, 'n_null', 1.1, 3)
# (6, 2, 'n_null', 1.1, 4)
# (6, 2, 'n_null', 1.1, 5)
# (6, 2, 'n_null', 1.1, 6)
# (6, 2, 'n_null', 1.1, 7)
# (6, 2, 'n_null', 1.2, 0)
# (6, 2, 'n_null', 1.2, 1)
# (6, 2, 'n_null', 1.2, 2)
# (6, 2, 'n_null', 1.2, 3)
# (6, 2, 'n_null', 1.2, 4)
# (6, 2, 'n_null', 1.2, 5)
# (6, 2, 'n_null', 1.2, 6)
# (6, 2, 'n_null', 1.2, 7)
# (6, 3, 'n_do', 0, 0)
# (6, 3, 'n_do', 0, 1)
# (6, 3, 'n_do', 0, 2)
# (6, 3, 'n_do', 0, 3)
# (6, 3, 'n_do', 0, 4)
# (6, 3, 'n_do', 0, 5)
# (6, 3, 'n_do', 0, 6)
# (6, 3, 'n_do', 0, 7)
# (6, 3, 'n_do', 1.1, 0)
# (6, 3, 'n_do', 1.1, 1)
# (6, 3, 'n_do', 1.1, 2)
# (6, 3, 'n_do', 1.1, 3)
# (6, 3, 'n_do', 1.1, 4)
# (6, 3, 'n_do', 1.1, 5)
# (6, 3, 'n_do', 1.1, 6)
# (6, 3, 'n_do', 1.1, 7)
# (6, 3, 'n_do', 1.2, 0)
# (6, 3, 'n_do', 1.2, 1)
# (6, 3, 'n_do', 1.2, 2)
# (6, 3, 'n_do', 1.2, 3)
# (6, 3, 'n_do', 1.2, 4)
# (6, 3, 'n_do', 1.2, 5)
# (6, 3, 'n_do', 1.2, 6)
# (6, 3, 'n_do', 1.2, 7)
# (6, 3, 'n_null', 0, 0)
# (6, 3, 'n_null', 0, 1)
# (6, 3, 'n_null', 0, 2)
# (6, 3, 'n_null', 0, 3)
# (6, 3, 'n_null', 0, 4)
# (6, 3, 'n_null', 0, 5)
# (6, 3, 'n_null', 0, 6)
# (6, 3, 'n_null', 0, 7)
# (6, 3, 'n_null', 1.1, 0)
# (6, 3, 'n_null', 1.1, 1)
# (6, 3, 'n_null', 1.1, 2)
# (6, 3, 'n_null', 1.1, 3)
# (6, 3, 'n_null', 1.1, 4)
# (6, 3, 'n_null', 1.1, 5)
# (6, 3, 'n_null', 1.1, 6)
# (6, 3, 'n_null', 1.1, 7)
# (6, 3, 'n_null', 1.2, 0)
# (6, 3, 'n_null', 1.2, 1)
# (6, 3, 'n_null', 1.2, 2)
# (6, 3, 'n_null', 1.2, 3)
# (6, 3, 'n_null', 1.2, 4)
# (6, 3, 'n_null', 1.2, 5)
# (6, 3, 'n_null', 1.2, 6)
# (6, 3, 'n_null', 1.2, 7)
# (7, 0, 'n_do', 0, 0)
# (7, 0, 'n_do', 0, 1)
# (7, 0, 'n_do', 0, 2)
# (7, 0, 'n_do', 0, 3)
# (7, 0, 'n_do', 0, 4)
# (7, 0, 'n_do', 0, 5)
# (7, 0, 'n_do', 0, 6)
# (7, 0, 'n_do', 0, 7)
# (7, 0, 'n_do', 1.1, 0)
# (7, 0, 'n_do', 1.1, 1)
# (7, 0, 'n_do', 1.1, 2)
# (7, 0, 'n_do', 1.1, 3)
# (7, 0, 'n_do', 1.1, 4)
# (7, 0, 'n_do', 1.1, 5)
# (7, 0, 'n_do', 1.1, 6)
# (7, 0, 'n_do', 1.1, 7)
# (7, 0, 'n_do', 1.2, 0)
# (7, 0, 'n_do', 1.2, 1)
# (7, 0, 'n_do', 1.2, 2)
# (7, 0, 'n_do', 1.2, 3)
# (7, 0, 'n_do', 1.2, 4)
# (7, 0, 'n_do', 1.2, 5)
# (7, 0, 'n_do', 1.2, 6)
# (7, 0, 'n_do', 1.2, 7)
# (7, 0, 'n_null', 0, 0)
# (7, 0, 'n_null', 0, 1)
# (7, 0, 'n_null', 0, 2)
# (7, 0, 'n_null', 0, 3)
# (7, 0, 'n_null', 0, 4)
# (7, 0, 'n_null', 0, 5)
# (7, 0, 'n_null', 0, 6)
# (7, 0, 'n_null', 0, 7)
# (7, 0, 'n_null', 1.1, 0)
# (7, 0, 'n_null', 1.1, 1)
# (7, 0, 'n_null', 1.1, 2)
# (7, 0, 'n_null', 1.1, 3)
# (7, 0, 'n_null', 1.1, 4)
# (7, 0, 'n_null', 1.1, 5)
# (7, 0, 'n_null', 1.1, 6)
# (7, 0, 'n_null', 1.1, 7)
# (7, 0, 'n_null', 1.2, 0)
# (7, 0, 'n_null', 1.2, 1)
# (7, 0, 'n_null', 1.2, 2)
# (7, 0, 'n_null', 1.2, 3)
# (7, 0, 'n_null', 1.2, 4)
# (7, 0, 'n_null', 1.2, 5)
# (7, 0, 'n_null', 1.2, 6)
# (7, 0, 'n_null', 1.2, 7)
# (7, 1, 'n_do', 0, 0)
# (7, 1, 'n_do', 0, 1)
# (7, 1, 'n_do', 0, 2)
# (7, 1, 'n_do', 0, 3)
# (7, 1, 'n_do', 0, 4)
# (7, 1, 'n_do', 0, 5)
# (7, 1, 'n_do', 0, 6)
# (7, 1, 'n_do', 0, 7)
# (7, 1, 'n_do', 1.1, 0)
# (7, 1, 'n_do', 1.1, 1)
# (7, 1, 'n_do', 1.1, 2)
# (7, 1, 'n_do', 1.1, 3)
# (7, 1, 'n_do', 1.1, 4)
# (7, 1, 'n_do', 1.1, 5)
# (7, 1, 'n_do', 1.1, 6)
# (7, 1, 'n_do', 1.1, 7)
# (7, 1, 'n_do', 1.2, 0)
# (7, 1, 'n_do', 1.2, 1)
# (7, 1, 'n_do', 1.2, 2)
# (7, 1, 'n_do', 1.2, 3)
# (7, 1, 'n_do', 1.2, 4)
# (7, 1, 'n_do', 1.2, 5)
# (7, 1, 'n_do', 1.2, 6)
# (7, 1, 'n_do', 1.2, 7)
# (7, 1, 'n_null', 0, 0)
# (7, 1, 'n_null', 0, 1)
# (7, 1, 'n_null', 0, 2)
# (7, 1, 'n_null', 0, 3)
# (7, 1, 'n_null', 0, 4)
# (7, 1, 'n_null', 0, 5)
# (7, 1, 'n_null', 0, 6)
# (7, 1, 'n_null', 0, 7)
# (7, 1, 'n_null', 1.1, 0)
# (7, 1, 'n_null', 1.1, 1)
# (7, 1, 'n_null', 1.1, 2)
# (7, 1, 'n_null', 1.1, 3)
# (7, 1, 'n_null', 1.1, 4)
# (7, 1, 'n_null', 1.1, 5)
# (7, 1, 'n_null', 1.1, 6)
# (7, 1, 'n_null', 1.1, 7)
# (7, 1, 'n_null', 1.2, 0)
# (7, 1, 'n_null', 1.2, 1)
# (7, 1, 'n_null', 1.2, 2)
# (7, 1, 'n_null', 1.2, 3)
# (7, 1, 'n_null', 1.2, 4)
# (7, 1, 'n_null', 1.2, 5)
# (7, 1, 'n_null', 1.2, 6)
# (7, 1, 'n_null', 1.2, 7)
# (7, 2, 'n_do', 0, 0)
# (7, 2, 'n_do', 0, 1)
# (7, 2, 'n_do', 0, 2)
# (7, 2, 'n_do', 0, 3)
# (7, 2, 'n_do', 0, 4)
# (7, 2, 'n_do', 0, 5)
# (7, 2, 'n_do', 0, 6)
# (7, 2, 'n_do', 0, 7)
# (7, 2, 'n_do', 1.1, 0)
# (7, 2, 'n_do', 1.1, 1)
# (7, 2, 'n_do', 1.1, 2)
# (7, 2, 'n_do', 1.1, 3)
# (7, 2, 'n_do', 1.1, 4)
# (7, 2, 'n_do', 1.1, 5)
# (7, 2, 'n_do', 1.1, 6)
# (7, 2, 'n_do', 1.1, 7)
# (7, 2, 'n_do', 1.2, 0)
# (7, 2, 'n_do', 1.2, 1)
# (7, 2, 'n_do', 1.2, 2)
# (7, 2, 'n_do', 1.2, 3)
# (7, 2, 'n_do', 1.2, 4)
# (7, 2, 'n_do', 1.2, 5)
# (7, 2, 'n_do', 1.2, 6)
# (7, 2, 'n_do', 1.2, 7)
# (7, 2, 'n_null', 0, 0)
# (7, 2, 'n_null', 0, 1)
# (7, 2, 'n_null', 0, 2)
# (7, 2, 'n_null', 0, 3)
# (7, 2, 'n_null', 0, 4)
# (7, 2, 'n_null', 0, 5)
# (7, 2, 'n_null', 0, 6)
# (7, 2, 'n_null', 0, 7)
# (7, 2, 'n_null', 1.1, 0)
# (7, 2, 'n_null', 1.1, 1)
# (7, 2, 'n_null', 1.1, 2)
# (7, 2, 'n_null', 1.1, 3)
# (7, 2, 'n_null', 1.1, 4)
# (7, 2, 'n_null', 1.1, 5)
# (7, 2, 'n_null', 1.1, 6)
# (7, 2, 'n_null', 1.1, 7)
# (7, 2, 'n_null', 1.2, 0)
# (7, 2, 'n_null', 1.2, 1)
# (7, 2, 'n_null', 1.2, 2)
# (7, 2, 'n_null', 1.2, 3)
# (7, 2, 'n_null', 1.2, 4)
# (7, 2, 'n_null', 1.2, 5)
# (7, 2, 'n_null', 1.2, 6)
# (7, 2, 'n_null', 1.2, 7)
# (7, 3, 'n_do', 0, 0)
# (7, 3, 'n_do', 0, 1)
# (7, 3, 'n_do', 0, 2)
# (7, 3, 'n_do', 0, 3)
# (7, 3, 'n_do', 0, 4)
# (7, 3, 'n_do', 0, 5)
# (7, 3, 'n_do', 0, 6)
# (7, 3, 'n_do', 0, 7)
# (7, 3, 'n_do', 1.1, 0)
# (7, 3, 'n_do', 1.1, 1)
# (7, 3, 'n_do', 1.1, 2)
# (7, 3, 'n_do', 1.1, 3)
# (7, 3, 'n_do', 1.1, 4)
# (7, 3, 'n_do', 1.1, 5)
# (7, 3, 'n_do', 1.1, 6)
# (7, 3, 'n_do', 1.1, 7)
# (7, 3, 'n_do', 1.2, 0)
# (7, 3, 'n_do', 1.2, 1)
# (7, 3, 'n_do', 1.2, 2)
# (7, 3, 'n_do', 1.2, 3)
# (7, 3, 'n_do', 1.2, 4)
# (7, 3, 'n_do', 1.2, 5)
# (7, 3, 'n_do', 1.2, 6)
# (7, 3, 'n_do', 1.2, 7)
# (7, 3, 'n_null', 0, 0)
# (7, 3, 'n_null', 0, 1)
# (7, 3, 'n_null', 0, 2)
# (7, 3, 'n_null', 0, 3)
# (7, 3, 'n_null', 0, 4)
# (7, 3, 'n_null', 0, 5)
# (7, 3, 'n_null', 0, 6)
# (7, 3, 'n_null', 0, 7)
# (7, 3, 'n_null', 1.1, 0)
# (7, 3, 'n_null', 1.1, 1)
# (7, 3, 'n_null', 1.1, 2)
# (7, 3, 'n_null', 1.1, 3)
# (7, 3, 'n_null', 1.1, 4)
# (7, 3, 'n_null', 1.1, 5)
# (7, 3, 'n_null', 1.1, 6)
# (7, 3, 'n_null', 1.1, 7)
# (7, 3, 'n_null', 1.2, 0)
# (7, 3, 'n_null', 1.2, 1)
# (7, 3, 'n_null', 1.2, 2)
# (7, 3, 'n_null', 1.2, 3)
# (7, 3, 'n_null', 1.2, 4)
# (7, 3, 'n_null', 1.2, 5)
# (7, 3, 'n_null', 1.2, 6)
# (7, 3, 'n_null', 1.2, 7)

# %%
df_t
# Out:
#         diff_x    diff_y      xstat            xp      ystat             yp  \
# 0     0.054174  0.030060  12.513861  7.821203e-36   6.901342   5.261130e-12
# 1    -0.015053  0.022107  -3.541329  3.987607e-04   5.108250   3.272800e-07
# 2    -0.085401 -0.032850 -13.510724  1.861746e-41  -5.119367   3.087307e-07
# 3    -0.108708 -0.069845 -11.062460  2.215774e-28  -7.034886   2.044889e-12
# 4    -0.123412 -0.095584 -12.152157  6.943963e-34  -9.324888   1.198964e-20
# 5    -0.090471 -0.108404 -10.456118  1.547086e-25 -12.429733   2.281764e-35
# 6    -0.024004 -0.060763  -3.686675  2.276629e-04  -9.284090   1.753730e-20
# 7     0.064774  0.004882  12.206805  3.522603e-34   0.919786   3.576927e-01
# 8    -0.006691 -0.004240  -0.859071  3.903091e-01  -0.540034   5.891786e-01
# 9     0.031887  0.014011   3.915457  9.046680e-05   1.707828   8.768031e-02
# 10    0.039407  0.064785   5.147581  2.658070e-07   8.383661   5.389682e-17
# 11   -0.035821  0.020882  -4.398438  1.094720e-05   2.533842   1.128787e-02
# 12   -0.061743 -0.054481  -5.235525  1.658362e-07  -4.579392   4.685613e-06
# 13   -0.015091 -0.032864  -1.358360  1.743618e-01  -2.936727   3.319959e-03
# 14    0.044407  0.000618   4.691069  2.731949e-06   0.064975   9.481940e-01
# 15    0.000532  0.012664   0.071829  9.427383e-01   1.694697   9.014497e-02
# 16    0.001816 -0.009252   0.223025  8.235181e-01  -1.128022   2.593210e-01
# 17    0.022161  0.015567   2.729647  6.344537e-03   1.902041   5.717701e-02
# 18    0.025287  0.047505   3.188581  1.431445e-03   5.942394   2.845111e-09
# 19   -0.056351 -0.011923  -6.210518  5.362684e-10  -1.300002   1.936120e-01
# 20   -0.029413 -0.065590  -2.448503  1.435190e-02  -5.418275   6.072857e-08
# 21    0.015909 -0.026318   1.496252  1.346004e-01  -2.460362   1.388635e-02
# 22    0.052049  0.017971   5.707009  1.162557e-08   1.957828   5.026114e-02
# 23    0.028172  0.041148   3.737676  1.861305e-04   5.398126   6.793522e-08
# 24    0.067175  0.034064  15.982991  2.982024e-57   8.250880   1.639516e-16
# 25   -0.023449  0.022781  -5.739798  9.574520e-09   5.577291   2.464951e-08
# 26   -0.109679 -0.041072 -15.694224  2.964133e-55  -5.906370   3.540555e-09
# 27   -0.128298 -0.105335 -11.509059  1.414391e-30  -9.560264   1.277269e-21
# 28   -0.109221 -0.100174  -9.493045  2.434618e-21  -8.817480   1.244235e-18
# 29   -0.101541 -0.115691 -11.347111  9.027132e-30 -13.114713   3.625753e-39
# ...        ...       ...        ...           ...        ...            ...
# 1506 -0.131772  0.484017  -5.553644  2.819066e-08  11.361967   7.340217e-30
# 1507 -0.110910  0.133257  -1.807503  7.069299e-02   1.209709   2.263994e-01
# 1508 -0.189366 -0.451876  -5.055536  4.314633e-07  -6.720118   1.845101e-11
# 1509 -0.037724 -0.344546  -4.579770  4.670826e-06 -23.421440  2.168526e-120
# 1510  0.045566  0.071313   7.202166  6.039862e-13   6.317764   2.684066e-10
# 1511  0.157823  0.123101  18.775220  2.916670e-78   8.202328   2.437237e-16
# 1512 -0.138628  0.244194 -10.516733  8.085179e-26   9.642893   5.700902e-22
# 1513 -0.057165  0.117295  -1.077412  2.813058e-01   1.153865   2.485654e-01
# 1514  0.010975  0.064373   0.156909  8.753173e-01   0.480320   6.310036e-01
# 1515 -0.021275 -0.214361  -0.317157  7.511268e-01  -1.667135   9.549903e-02
# 1516 -0.083125 -0.112999  -1.135503  2.561747e-01  -0.805569   4.204986e-01
# 1517 -0.079910 -0.006842  -1.237866  2.157765e-01  -0.055295   9.559040e-01
# 1518 -0.172930 -0.390106 -10.008851  1.528487e-23 -11.783421   5.668943e-32
# 1519 -0.116869 -0.085525 -15.470754  8.921999e-54  -5.861664   4.631532e-09
# 1520  0.045803 -0.160613   7.134466  9.934241e-13 -13.165387   1.781944e-39
# 1521 -0.019574  0.283106  -2.740834  6.132018e-03  20.708576   1.358066e-94
# 1522 -0.146967  0.252789  -4.990142  6.070456e-07   4.476478   7.619038e-06
# 1523 -0.121527  0.161287  -1.882733  5.974726e-02   1.303573   1.923901e-01
# 1524 -0.016512 -0.185606  -0.318791  7.498872e-01  -1.870683   6.139970e-02
# 1525 -0.026959 -0.397641  -3.061147  2.206941e-03 -23.732702  2.543211e-123
# 1526  0.028556  0.135467   5.005474  5.602760e-07  12.454926   1.597243e-35
# 1527  0.075532  0.031137   6.583966  4.661195e-11   1.422150   1.549938e-01
# 1528  0.019689 -0.223430   3.207253  1.341471e-03 -19.122473   4.882664e-81
# 1529 -0.015166  0.320213  -2.118879  3.410898e-02  23.438097  2.183828e-120
# 1530 -0.067534  0.278991  -1.918183  5.509822e-02   4.134529   3.567438e-05
# 1531 -0.134905  0.111190  -2.127908  3.335366e-02   0.915177   3.601068e-01
# 1532 -0.076607 -0.295466  -1.949949  5.119242e-02  -3.925172   8.688006e-05
# 1533 -0.039536 -0.361516  -4.683716  2.830000e-06 -22.476248  6.333903e-111
# 1534  0.040896  0.104003   6.838348  8.160446e-12   9.126072   7.523225e-20
# 1535  0.115138  0.238819   9.873347  5.920104e-23  10.765728   5.640071e-27
#
#       ba  bm   model  task_rot  target  num_cm  num_c
# 0      0   0    n_do       0.0       0    3192  24793
# 1      0   0    n_do       0.0       1    3303  24793
# 2      0   0    n_do       0.0       2    1401  24793
# 3      0   0    n_do       0.0       3     565  24793
# 4      0   0    n_do       0.0       4     528  24793
# 5      0   0    n_do       0.0       5     734  24793
# 6      0   0    n_do       0.0       6    1331  24793
# 7      0   0    n_do       0.0       7    2058  24793
# 8      0   0    n_do       1.1       0     912  24793
# 9      0   0    n_do       1.1       1     833  24793
# 10     0   0    n_do       1.1       2     943  24793
# 11     0   0    n_do       1.1       3     830  24793
# 12     0   0    n_do       1.1       4     390  24793
# 13     0   0    n_do       1.1       5     441  24793
# 14     0   0    n_do       1.1       6     613  24793
# 15     0   0    n_do       1.1       7    1015  24793
# 16     0   0    n_do       1.2       0     833  24793
# 17     0   0    n_do       1.2       1     837  24793
# 18     0   0    n_do       1.2       2     879  24793
# 19     0   0    n_do       1.2       3     665  24793
# 20     0   0    n_do       1.2       4     376  24793
# 21     0   0    n_do       1.2       5     482  24793
# 22     0   0    n_do       1.2       6     660  24793
# 23     0   0    n_do       1.2       7     972  24793
# 24     0   0  n_null       0.0       0    3505  24949
# 25     0   0  n_null       0.0       1    3708  24949
# 26     0   0  n_null       0.0       2    1168  24949
# 27     0   0  n_null       0.0       3     450  24949
# 28     0   0  n_null       0.0       4     422  24949
# 29     0   0  n_null       0.0       5     706  24949
# ...   ..  ..     ...       ...     ...     ...    ...
# 1506   7   3    n_do       1.2       2     235  33091
# 1507   7   3    n_do       1.2       3      35  33091
# 1508   7   3    n_do       1.2       4      94  33091
# 1509   7   3    n_do       1.2       5    2044  33091
# 1510   7   3    n_do       1.2       6    3688  33091
# 1511   7   3    n_do       1.2       7    2002  33091
# 1512   7   3  n_null       0.0       0     657  27253
# 1513   7   3  n_null       0.0       1      40  27253
# 1514   7   3  n_null       0.0       2      23  27253
# 1515   7   3  n_null       0.0       3      25  27253
# 1516   7   3  n_null       0.0       4      21  27253
# 1517   7   3  n_null       0.0       5      27  27253
# 1518   7   3  n_null       0.0       6     380  27253
# 1519   7   3  n_null       0.0       7    2066  27253
# 1520   7   3  n_null       1.1       0    3063  27253
# 1521   7   3  n_null       1.1       1    2375  27253
# 1522   7   3  n_null       1.1       2     130  27253
# 1523   7   3  n_null       1.1       3      27  27253
# 1524   7   3  n_null       1.1       4      42  27253
# 1525   7   3  n_null       1.1       5    1524  27253
# 1526   7   3  n_null       1.1       6    3951  27253
# 1527   7   3  n_null       1.1       7     894  27253
# 1528   7   3  n_null       1.2       0    3337  27253
# 1529   7   3  n_null       1.2       1    2371  27253
# 1530   7   3  n_null       1.2       2      91  27253
# 1531   7   3  n_null       1.2       3      28  27253
# 1532   7   3  n_null       1.2       4      73  27253
# 1533   7   3  n_null       1.2       5    1661  27253
# 1534   7   3  n_null       1.2       6    3581  27253
# 1535   7   3  n_null       1.2       7     866  27253
#
# [1536 rows x 13 columns]

# %%
#Visualize some command distributions:

# %%
#mean diff: 
df_diff_col = n_list + ['diff', 'ba', 'bm', 'model', 'target', 'task_rot', 'num']
nan_df = pd.DataFrame()
df_diff = []
for ba in range(num_angle_bins):
    sel_ba = (df_lqr['u_v_angle_bin']==ba)
    sel_d_ba = (df_mean['ba'] == ba)    
    for bm in range(num_mag_bins_analyze):
        sel_bm = (df_lqr['u_v_mag_bin']==bm)
        sel_d_bm = (df_mean['bm'] == bm)
        for m in model_list:
            sel_m = (df_lqr['model'] == m)
            sel_d_m = (df_mean['model'] == m)
            sel_d = sel_d_ba&sel_d_bm&sel_d_m
            mean_i = df_mean.loc[sel_d, n_list]
            
            
            for task in task_rot_list:
                sel_task = (df_lqr['task_rot']==task)
                for target in range(num_targets):
                    sel_target = (df_lqr['target']==target)
                    
                    sel = sel_ba&sel_bm&sel_m&sel_task&sel_target
                    num = len(np.where(sel)[0])
                    if num > 0:
                        n_i = df_lqr.loc[sel,n_list].mean()
                        diff_i = n_i-mean_i
                        
                        df_i = pd.DataFrame(pd.DataFrame(np.ones((1,len(df_diff_col)))*np.nan, columns=df_diff_col))
                        df_i.loc[0,n_list]=n_i
                        df_i['diff']=np.linalg.norm(diff_i)
                        df_i['ba'] = ba
                        df_i['bm'] = bm
                        df_i['model'] = m
                        df_i['task_rot'] = task
                        df_i['target'] = target
                        df_i['num'] = num

                        df_diff.append(df_i)
df_diff = pd.concat(df_diff, ignore_index=True)
