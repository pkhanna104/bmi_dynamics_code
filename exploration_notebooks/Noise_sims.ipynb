# %%
# %load_ext autoreload
# %autoreload 2

# %%
import null_vs_potent_noise

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
null_vs_potent_noise.run_all()

# %%
null_vs_potent_noise.run_all(nT=10000,nneurons=100)
