# %%
from dynamics_sims import test_offset
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
test_offset.simulate_dyn()
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">
# no zero dim: 2
# no zero dim: 2
# no zero dim: 2
# no zero dim: 2
# no zero dim: 2
# no zero dim: 2
# no zero dim: 2
# no zero dim: 2
