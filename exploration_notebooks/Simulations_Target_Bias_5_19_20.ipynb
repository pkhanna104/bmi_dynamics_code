# %%
from dynamics_sims import lqr_simulation
# %matplotlib notebook
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-05-19 16:56:37.093961. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
day = 0; 
task = 'co'; 
zeroA = True; 
for reps in range(3):
    ctl = lqr_simulation.Combined_Curs_Brain_LQR_Simulation_Data_Driven(day, task = task, zeroA = zeroA, 
                R = 10000, keep_offset = False, state_noise = .0005)
    f, ax = plt.subplots(ncols = 2)
    _, _, _, _, _ = ctl.run_all_targets(nreps=2, rad=8, plot_traj = True,
        ax = ax[0], ax2 = ax[1], max_trial_time = 2000)
# Out:
# Testing, fix this later
# > /Users/preeyakhanna/bmi_dynamics_code/dynamics_sims/lqr_simulation.py(297)__init__()
# -> if zeroA:
# (Pdb) c
# <img src="data:image/png;base64,..." width="929.9999861419203">
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Testing, fix this later
# > /Users/preeyakhanna/bmi_dynamics_code/dynamics_sims/lqr_simulation.py(297)__init__()
# -> if zeroA:
# (Pdb) c
# <img src="data:image/png;base64,..." width="949.9999858438971">
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# Starting rep: 0
# Starting rep: 1
# ...
