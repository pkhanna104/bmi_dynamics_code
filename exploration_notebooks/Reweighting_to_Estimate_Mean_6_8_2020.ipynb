# %%
### For a given day and command, generate estimates of all plausible transitions that can occur
### Have the option of excluding 2 conditions

### Then "reconstruct" the null component of the mean command given each condition; 
### Do PCA on the mean null activity to get a 2D space to plot; 

### How much variance does this PC account for?

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import analysis_config
from online_analysis import generate_models, util_fcns, reweighting_analysis
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-09 10:50:58.050761. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
day = 0
animal = 'grom'
#dat = pickle.load(open(analysis_config.config[animal+'_pref'] + 'tuning_models_'+animal+'_model_set%d_task_spec_pls_gen.pkl' %(7), 'rb'))
reweighting_analysis.PC_proj_plot(animal, day, dat=dat)
# Out:
# <img src="data:image/png;base64,..." width="755.555575570943">
# <img src="data:image/png;base64,..." width="735.5555750411239">
# online_analysis/reweighting_analysis.py:67: ComplexWarning: Casting complex values to real discards the imaginary part
#   ax.set_title('Mag %d, Ang %d, VAF %.2f' %(m, a, vaf))
#
# online_analysis/reweighting_analysis.py:68: ComplexWarning: Casting complex values to real discards the imaginary part
#   ax.set_xlabel('PC 1 VAF %.2f' %(ev[0]/np.sum(ev)))
#
# online_analysis/reweighting_analysis.py:69: ComplexWarning: Casting complex values to real discards the imaginary part
#   ax.set_ylabel('PC 2 VAF %.2f' %(ev[1]/np.sum(ev)))
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="431.1111225316557">
# <img src="data:image/png;base64,..." width="888.8889124364035">
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-06-08 23:22:21.554315. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
