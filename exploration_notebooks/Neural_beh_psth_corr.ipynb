# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from online_analysis import beh_psth_vs_mn_neur_diffs
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# in task
# in task
# in task
# Import Error in db.namelist: from tasklist import tasks -- likely error in a single task preventing import
# error importing BMI configuration variables
# Traceback (most recent call last):
#   File "/Users/preeyakhanna/bmi3d/db/namelist.py", line 92, in <module>
#     from bmilist import *
#   File "/Users/preeyakhanna/bmi3d/config_files/bmilist.py", line 25, in <module>
#     from ismore.ismore_bmi_lib import StateSpaceArmAssist, StateSpaceReHand, StateSpaceIsMore
# ImportError: No module named ismore.ismore_bmi_lib
# ...

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2020-07-06 11:37:47.520884. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#beh_psth_vs_mn_neur_diffs.plot_mean_diffs_all(zscore=True, plot_beh_mn_diffs = True)
beh_psth_vs_mn_neur_diffs.plot_mean_diffs_all(zscore=False, plot_beh_mn_diffs = False, plot_beh_vs_neur=True)
# Out:
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Staring shuff 0
# online_analysis/beh_psth_vs_mn_neur_diffs.py:492: RuntimeWarning: invalid value encountered in greater
#   if np.all(np.diff(snip_bins) > 0):
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ...

# %%
beh_psth_vs_mn_neur_diffs.plot_mean_diffs_all(zscore=True, plot_beh_mn_diffs = False)
# Out:
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (18, 44) 6 (18,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 64, total trls in this blk 64
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (101,) (101,) (40, 44) 6 (40,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 165, total trls in this blk 101
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (122,) (122,) (97, 44) 6 (97,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# new trial offset 287, total trls in this blk 122
# Staring shuff 0
# online_analysis/beh_psth_vs_mn_neur_diffs.py:402: RuntimeWarning: invalid value encountered in greater
#   spks_shuff = spks_shuff['spks_shuff']
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# (64,) (64,) (51, 35) 6 (51,)
# [0. 1. 2. 3. 4. 5. 6. 7.]
# ...
